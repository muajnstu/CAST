# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/CAST/blob/main/Revised_implementation_of_Perception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import io
import math
import csv
import pandas as pd
import numpy as np
import warnings
from google.colab import files
warnings.filterwarnings('ignore')

# Core ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.metrics import (
    accuracy_score, classification_report,
    matthews_corrcoef, roc_auc_score
)
from imblearn.metrics import geometric_mean_score
from sklearn.model_selection import StratifiedKFold

# Classifiers
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier,
    GradientBoostingClassifier, VotingClassifier, StackingClassifier
)
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron,
    SGDClassifier, PassiveAggressiveClassifier
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Balancing
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.combine import SMOTETomek


# optimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv('https://raw.githubusercontent.com/muajnstu/CAST/refs/heads/main/Quality_Gap(P-E)/Gap_Catagorized.csv')
print(f"Raw dataset shape : {df.shape}")
print(f"Target distribution:\n{df['CAST'].value_counts()}\n")

X_raw = df.drop(columns=['CAST'])
y_raw = df['CAST']
# Out:
# Raw dataset shape : (400, 47)
# Target distribution:
# CAST
# 1    185
# 0    182
# 2     33
# Name: count, dtype: int64

# %%
BALANCERS = {
    "B1_RandomOverSampling":  RandomOverSampler(random_state=42),
    "B2_RandomUnderSampling": RandomUnderSampler(random_state=42),
    "B3_ADASYN":              ADASYN(random_state=42),
    "B4_SMOTE":               SMOTE(random_state=42),
    "B5_BorderlineSMOTE":     BorderlineSMOTE(random_state=42),
    "B6_TomekLinks":          TomekLinks(),
    "B7_SMOTETomek":          SMOTETomek(random_state=42),
}


def apply_balancer(name, sampler, X, y):
    try:
        X_b, y_b = sampler.fit_resample(X, y)
        df_b = pd.DataFrame(X_b, columns=X.columns)
        df_b['CAST'] = y_b
        print(f"  {name:30s} -> shape {df_b.shape}  "
              f"dist: {dict(pd.Series(y_b).value_counts())}")
        return df_b
    except Exception as e:
        print(f"  {name:30s} -> FAILED: {e}")
        return None

# %%
CV      = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
CV_EST  = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
N_TOTAL = X_raw.shape[1]

def _cv_score(X_sel, y):
    """Mean 5-fold CV accuracy for a given feature subset."""
    return cross_val_score(CV_EST, X_sel, y, cv=CV,
                           scoring='accuracy', n_jobs=-1).mean()

def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# Tune FS1
print("\n" + "="*70)
print("  TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)")
print("="*70)

print("\n[FS1] Sweeping correlation threshold...")
thresholds   = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
fs1_results  = {}
for thr in thresholds:
    corr  = X_raw.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= thr)]
    X_sel = X_raw.drop(columns=drop)
    score = _cv_score(X_sel, y_raw)
    fs1_results[thr] = (score, X_sel.shape[1])
    print(f"  threshold={thr:.2f}  features={X_sel.shape[1]:3d}  CV_acc={score:.4f}")

best_fs1_thr   = max(fs1_results, key=lambda t: fs1_results[t][0])
best_fs1_score = fs1_results[best_fs1_thr][0]
best_fs1_feats = fs1_results[best_fs1_thr][1]
print(f"  >> BEST threshold={best_fs1_thr}  features={best_fs1_feats}  CV_acc={best_fs1_score:.4f}")

# Tune FS2: KBest (f_classif)
print("\n[FS2] Sweeping k for SelectKBest (f_classif)...")
k_range     = list(range(1, N_TOTAL + 1))
fs2_results = {}
for k in k_range:
    sel   = SelectKBest(f_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs2_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs2_k     = max(fs2_results, key=fs2_results.get)
best_fs2_score = fs2_results[best_fs2_k]
print(f"  >> BEST k={best_fs2_k}  CV_acc={best_fs2_score:.4f}")

# Tune FS3: RFE
print("\n[FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...")
rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1),
    step=1, cv=CV, scoring='accuracy', n_jobs=-1, min_features_to_select=1
)
rfecv.fit(X_raw, y_raw)
best_fs3_n     = rfecv.n_features_
best_fs3_score = rfecv.cv_results_['mean_test_score'][best_fs3_n - 1]
_rfecv_support = rfecv.support_
print(f"  >> BEST n_features={best_fs3_n}  CV_acc={best_fs3_score:.4f}")

# Tune FS4: Mutual Information
print("\n[FS4] Sweeping k for SelectKBest (mutual_info_classif)...")
fs4_results = {}
for k in k_range:
    sel   = SelectKBest(mutual_info_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs4_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs4_k     = max(fs4_results, key=fs4_results.get)
best_fs4_score = fs4_results[best_fs4_k]
print(f"  >> BEST k={best_fs4_k}  CV_acc={best_fs4_score:.4f}")

# Tune FS5: RF Importance cumulative threshold
print("\n[FS5] Sweeping cumulative importance threshold for RF feature importance...")
_rf_imp  = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
_rf_imp.fit(X_raw, y_raw)
imp_series = pd.Series(_rf_imp.feature_importances_, index=X_raw.columns)\
               .sort_values(ascending=False)
cum_imp = imp_series.cumsum()

cum_thresholds = [0.80, 0.85, 0.90, 0.95, 0.99]
fs5_results    = {}
for ct in cum_thresholds:
    top_feats = cum_imp[cum_imp <= ct].index.tolist()
    if len(top_feats) == 0:
        top_feats = [imp_series.index[0]]
    X_sel = X_raw[top_feats]
    score = _cv_score(X_sel, y_raw)
    fs5_results[ct] = (score, len(top_feats))
    print(f"  cum_threshold={ct:.2f}  features={len(top_feats):3d}  CV_acc={score:.4f}")

best_fs5_ct    = max(fs5_results, key=lambda t: fs5_results[t][0])
best_fs5_score = fs5_results[best_fs5_ct][0]
best_fs5_feats = fs5_results[best_fs5_ct][1]
print(f"  >> BEST cum_threshold={best_fs5_ct}  features={best_fs5_feats}  CV_acc={best_fs5_score:.4f}")

# Summary of tuned parameters
print("\n" + "="*70)
print("  TUNING SUMMARY")
print("="*70)
tuning_summary = pd.DataFrame([
    {"FS": "FS1_Correlation",  "Parameter": "threshold",        "Best_Value": best_fs1_thr,  "n_features": best_fs1_feats, "CV_Accuracy": round(best_fs1_score, 4)},
    {"FS": "FS2_KBest",        "Parameter": "k",                "Best_Value": best_fs2_k,    "n_features": best_fs2_k,     "CV_Accuracy": round(best_fs2_score, 4)},
    {"FS": "FS3_RFE",          "Parameter": "n_features (RFECV)","Best_Value": best_fs3_n,   "n_features": best_fs3_n,     "CV_Accuracy": round(best_fs3_score, 4)},
    {"FS": "FS4_MutualInfo",   "Parameter": "k",                "Best_Value": best_fs4_k,    "n_features": best_fs4_k,     "CV_Accuracy": round(best_fs4_score, 4)},
    {"FS": "FS5_RFImportance", "Parameter": "cum_threshold",    "Best_Value": best_fs5_ct,   "n_features": best_fs5_feats, "CV_Accuracy": round(best_fs5_score, 4)},
])
print(tuning_summary.to_string(index=False))
# Out:
# ======================================================================
#   TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)
# ======================================================================
#
# [FS1] Sweeping correlation threshold...
#   threshold=0.70  features= 44  CV_acc=0.5650
#   threshold=0.75  features= 46  CV_acc=0.5675
#   threshold=0.80  features= 46  CV_acc=0.5675
#   threshold=0.85  features= 46  CV_acc=0.5675
#   threshold=0.90  features= 46  CV_acc=0.5675
#   threshold=0.95  features= 46  CV_acc=0.5675
#   >> BEST threshold=0.75  features=46  CV_acc=0.5675
#
# [FS2] Sweeping k for SelectKBest (f_classif)...
#   k=  1  CV_acc=0.5525
#   k=  2  CV_acc=0.5475
#   k=  3  CV_acc=0.5625
#   k=  4  CV_acc=0.5575
#   k=  5  CV_acc=0.5450
#   k=  6  CV_acc=0.5700
#   k=  7  CV_acc=0.6000
#   k=  8  CV_acc=0.5800
#   k=  9  CV_acc=0.5750
#   k= 10  CV_acc=0.5575
#   k= 11  CV_acc=0.6150
#   k= 12  CV_acc=0.5875
#   k= 13  CV_acc=0.5825
#   k= 14  CV_acc=0.5950
#   k= 15  CV_acc=0.5825
#   k= 16  CV_acc=0.5775
#   k= 17  CV_acc=0.5600
#   k= 18  CV_acc=0.5750
#   k= 19  CV_acc=0.5650
#   k= 20  CV_acc=0.5750
#   k= 21  CV_acc=0.5875
#   k= 22  CV_acc=0.5875
#   k= 23  CV_acc=0.5625
#   k= 24  CV_acc=0.5825
#   k= 25  CV_acc=0.5800
#   k= 26  CV_acc=0.5575
#   k= 27  CV_acc=0.5750
#   k= 28  CV_acc=0.5650
#   k= 29  CV_acc=0.5900
#   k= 30  CV_acc=0.5800
#   k= 31  CV_acc=0.5700
#   k= 32  CV_acc=0.5625
#   k= 33  CV_acc=0.5700
#   k= 34  CV_acc=0.5625
#   k= 35  CV_acc=0.5750
#   k= 36  CV_acc=0.5550
#   k= 37  CV_acc=0.5600
#   k= 38  CV_acc=0.5375
#   k= 39  CV_acc=0.5475
#   k= 40  CV_acc=0.5425
#   k= 41  CV_acc=0.5925
#   k= 42  CV_acc=0.5800
#   k= 43  CV_acc=0.5600
#   k= 44  CV_acc=0.5650
#   k= 45  CV_acc=0.5700
#   k= 46  CV_acc=0.5675
#   >> BEST k=11  CV_acc=0.6150
#
# [FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...
#   >> BEST n_features=31  CV_acc=0.6025
#
# [FS4] Sweeping k for SelectKBest (mutual_info_classif)...
#   k=  1  CV_acc=0.5650
#   k=  2  CV_acc=0.5375
#   k=  3  CV_acc=0.6100
#   k=  4  CV_acc=0.5600
#   k=  5  CV_acc=0.5525
#   k=  6  CV_acc=0.5250
#   k=  7  CV_acc=0.5225
#   k=  8  CV_acc=0.5350
#   k=  9  CV_acc=0.5450
#   k= 10  CV_acc=0.5325
#   k= 11  CV_acc=0.5375
#   k= 12  CV_acc=0.5500
#   k= 13  CV_acc=0.5150
#   k= 14  CV_acc=0.5325
#   k= 15  CV_acc=0.5750
#   k= 16  CV_acc=0.5725
#   k= 17  CV_acc=0.5850
#   k= 18  CV_acc=0.5975
#   k= 19  CV_acc=0.5975
#   k= 20  CV_acc=0.5825
#   k= 21  CV_acc=0.5475
#   k= 22  CV_acc=0.5450
#   k= 23  CV_acc=0.5475
#   k= 24  CV_acc=0.5500
#   k= 25  CV_acc=0.5625
#   k= 26  CV_acc=0.5625
#   k= 27  CV_acc=0.5875
#   k= 28  CV_acc=0.5575
#   k= 29  CV_acc=0.5850
#   k= 30  CV_acc=0.5750
#   k= 31  CV_acc=0.5750
#   k= 32  CV_acc=0.5875
#   k= 33  CV_acc=0.5975
#   k= 34  CV_acc=0.5625
#   k= 35  CV_acc=0.5675
#   k= 36  CV_acc=0.5850
#   k= 37  CV_acc=0.5450
#   k= 38  CV_acc=0.5600
#   k= 39  CV_acc=0.5850
#   k= 40  CV_acc=0.5750
#   k= 41  CV_acc=0.5775
#   k= 42  CV_acc=0.5825
#   k= 43  CV_acc=0.5500
#   k= 44  CV_acc=0.5650
#   k= 45  CV_acc=0.5675
#   k= 46  CV_acc=0.5675
#   >> BEST k=3  CV_acc=0.6100
#
# [FS5] Sweeping cumulative importance threshold for RF feature importance...
#   cum_threshold=0.80  features= 34  CV_acc=0.5925
#   cum_threshold=0.85  features= 36  CV_acc=0.5850
#   cum_threshold=0.90  features= 39  CV_acc=0.6050
#   cum_threshold=0.95  features= 42  CV_acc=0.5750
#   cum_threshold=0.99  features= 45  CV_acc=0.5800
#   >> BEST cum_threshold=0.9  features=39  CV_acc=0.6050
#
# ======================================================================
#   TUNING SUMMARY
# ======================================================================
#               FS          Parameter  Best_Value  n_features  CV_Accuracy
#  FS1_Correlation          threshold        0.75          46       0.5675
#        FS2_KBest                  k       11.00          11       0.6150
#          FS3_RFE n_features (RFECV)       31.00          31       0.6025
#   FS4_MutualInfo                  k        3.00           3       0.6100
# FS5_RFImportance      cum_threshold        0.90          39       0.6050

# %%
def fs_correlation(data, target_col='CAST', threshold=best_fs1_thr):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    corr  = X_.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= threshold)]
    out   = X_.drop(columns=drop).copy(); out[target_col] = y_.values
    return out

def fs_kbest(data, target_col='CAST', k=best_fs2_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(f_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rfe(data, target_col='CAST', support=_rfecv_support):

    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    cols = X_.columns[support] if len(support) == X_.shape[1] else X_.columns
    out  = X_[cols].copy(); out[target_col] = y_.values
    return out

def fs_mi(data, target_col='CAST', k=best_fs4_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(mutual_info_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rf_importance(data, target_col='CAST', cum_threshold=best_fs5_ct):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    rf  = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_, y_)
    imp = pd.Series(rf.feature_importances_, index=X_.columns).sort_values(ascending=False)
    top = imp.cumsum()[imp.cumsum() <= cum_threshold].index.tolist()
    if len(top) == 0:
        top = [imp.index[0]]
    out = X_[top].copy(); out[target_col] = y_.values
    return out

FEATURE_SELECTORS = {
    "FS1_Correlation":  lambda d: fs_correlation(d),
    "FS2_KBest":        lambda d: fs_kbest(d),
    "FS3_RFE":          lambda d: fs_rfe(d),
    "FS4_MutualInfo":   lambda d: fs_mi(d),
    "FS5_RFImportance": lambda d: fs_rf_importance(d),
}

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True, n_splits=10):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    rows = []
    for clf_name, model in build_models().items():
        fold_metrics = {
            'Accuracy': [], 'Macro_F1': [], 'Macro_Precision': [],
            'Macro_Recall': [], 'MCC': [], 'G_Mean': [], 'AUC': []
        }

        for train_idx, test_idx in skf.split(X_, y_):
            X_tr, X_te = X_.iloc[train_idx], X_.iloc[test_idx]
            y_tr, y_te = y_.iloc[train_idx], y_.iloc[test_idx]

            try:
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_te)

                acc   = accuracy_score(y_te, y_pred)
                rep   = classification_report(y_te, y_pred, zero_division=0, output_dict=True)
                mcc   = matthews_corrcoef(y_te, y_pred)
                gmean = geometric_mean_score(y_te, y_pred, average='macro')

                n_classes = len(np.unique(y_te))
                auc = None
                try:
                    if hasattr(model, 'predict_proba'):
                        y_score = model.predict_proba(X_te)
                    else:
                        y_score = model.decision_function(X_te)
                        if n_classes <= 2:
                            y_score = y_score.reshape(-1, 1)

                    if n_classes == 2:
                        prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                        auc = roc_auc_score(y_te, prob)
                    else:
                        auc = roc_auc_score(
                            y_te, y_score,
                            multi_class='ovr', average='macro',
                            labels=np.unique(y_te)
                        )
                except Exception:
                    pass

                fold_metrics['Accuracy'].append(acc)
                fold_metrics['Macro_F1'].append(rep['macro avg']['f1-score'])
                fold_metrics['Macro_Precision'].append(rep['macro avg']['precision'])
                fold_metrics['Macro_Recall'].append(rep['macro avg']['recall'])
                fold_metrics['MCC'].append(mcc)
                fold_metrics['G_Mean'].append(gmean)
                if auc is not None:
                    fold_metrics['AUC'].append(auc)

            except Exception as e:
                if verbose:
                    print(f"    {clf_name:25s}  Fold ERROR: {e}")

        # Aggregate: mean ± std across folds
        def fmt(vals):
            if not vals:
                return None, None
            return round(np.mean(vals), 3), round(np.std(vals), 3)

        acc_m,   acc_s   = fmt(fold_metrics['Accuracy'])
        f1_m,    f1_s    = fmt(fold_metrics['Macro_F1'])
        prec_m,  prec_s  = fmt(fold_metrics['Macro_Precision'])
        rec_m,   rec_s   = fmt(fold_metrics['Macro_Recall'])
        mcc_m,   mcc_s   = fmt(fold_metrics['MCC'])
        gm_m,    gm_s    = fmt(fold_metrics['G_Mean'])
        auc_m,   auc_s   = fmt(fold_metrics['AUC'])

        rows.append({
            'Label':                label,
            'Classifier':           clf_name,
            'Accuracy':             acc_m,  'Accuracy_SD':   acc_s,
            'Macro_F1':             f1_m,   'Macro_F1_SD':   f1_s,
            'Macro_Precision':      prec_m, 'Macro_Prec_SD': prec_s,
            'Macro_Recall':         rec_m,  'Macro_Rec_SD':  rec_s,
            'MCC':                  mcc_m,  'MCC_SD':        mcc_s,
            'G_Mean':               gm_m,   'G_Mean_SD':     gm_s,
            'AUC':                  auc_m,  'AUC_SD':        auc_s,
        })

        if verbose:
            auc_str = f"{auc_m:.3f}±{auc_s:.3f}" if auc_m is not None else "N/A"
            print(f"    {clf_name:25s}  "
                  f"Acc={acc_m:.3f}±{acc_s:.3f}  "
                  f"F1={f1_m:.3f}±{f1_s:.3f}  "
                  f"MCC={mcc_m:.3f}±{mcc_s:.3f}  "
                  f"G-Mean={gm_m:.3f}±{gm_s:.3f}  "
                  f"AUC={auc_str}")

    return rows

# %%
def build_models():
    return {
        "RandomForest":       RandomForestClassifier(random_state=42),
        "ExtraTrees":         ExtraTreesClassifier(random_state=42),
        "Bagging":            BaggingClassifier(random_state=42),
        "GradientBoosting":   GradientBoostingClassifier(random_state=42),
        "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
        "RidgeClassifier":    RidgeClassifier(),
        "DecisionTree":       DecisionTreeClassifier(random_state=42),
        "NaiveBayes":         GaussianNB(),
        "Perceptron":         Perceptron(random_state=42),
        "SGDClassifier":      SGDClassifier(random_state=42),
        "PassiveAggressive":  PassiveAggressiveClassifier(random_state=42),
        "LDA":                LinearDiscriminantAnalysis(),
        "QDA":                QuadraticDiscriminantAnalysis(),
        "LightGBM":           LGBMClassifier(verbosity=-1, random_state=42),
        "XGBoost":            XGBClassifier(n_estimators=100, random_state=42,
                                            eval_metric='mlogloss',
                                            use_label_encoder=False, verbosity=0),
        "VotingSoft": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='soft', n_jobs=-1),
        "VotingHard": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='hard', n_jobs=-1),
        "Stacking": StackingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], final_estimator=LogisticRegression(max_iter=1000, random_state=42),
           cv=5, stack_method='predict_proba', n_jobs=-1),
    }

# %% [markdown]
# experiment 1

# %%
section_header("PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)")

print("\nApplying balancers to raw data...")
balanced_datasets = {}
for bal_name, sampler in BALANCERS.items():
    df_b = apply_balancer(bal_name, sampler, X_raw, y_raw)
    if df_b is not None:
        balanced_datasets[bal_name] = df_b

phase1_rows = []
for bal_name, bal_df in balanced_datasets.items():
    sub_header(f"Balancer: {bal_name}  |  shape={bal_df.shape}")
    rows = evaluate_dataset(bal_df, label=bal_name, verbose=True)
    phase1_rows.extend(rows)

phase1_df = pd.DataFrame(phase1_rows).dropna(subset=['Accuracy'])
phase1_df['Phase'] = 'Phase1_BalancingOnly'
phase1_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 1 Summary (top 20 by Accuracy) --")
p1_show = phase1_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer'})
METRICS = ['Accuracy','Macro_F1','MCC','G_Mean','AUC']
print(p1_show[['Balancer','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 1: Best Classifier per Balancer --")
best_p1 = (p1_show.groupby('Balancer', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer','Classifier'] + METRICS])
print(best_p1.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)
# ################################################################################
#
# Applying balancers to raw data...
#   B1_RandomOverSampling          -> shape (555, 47)  dist: {0: np.int64(185), 2: np.int64(185), 1: np.int64(185)}
#   B2_RandomUnderSampling         -> shape (99, 47)  dist: {0: np.int64(33), 1: np.int64(33), 2: np.int64(33)}
#   B3_ADASYN                      -> FAILED: No samples will be generated with the provided ratio settings.
#   B4_SMOTE                       -> shape (555, 47)  dist: {0: np.int64(185), 2: np.int64(185), 1: np.int64(185)}
#   B5_BorderlineSMOTE             -> shape (555, 47)  dist: {0: np.int64(185), 2: np.int64(185), 1: np.int64(185)}
#   B6_TomekLinks                  -> shape (366, 47)  dist: {1: np.int64(168), 0: np.int64(165), 2: np.int64(33)}
#   B7_SMOTETomek                  -> shape (531, 47)  dist: {2: np.int64(185), 0: np.int64(173), 1: np.int64(173)}
#
# ======================================================================
#   Balancer: B1_RandomOverSampling  |  shape=(555, 47)
# ======================================================================
#     RandomForest               Acc=0.740±0.050  F1=0.734±0.053  MCC=0.613±0.075  G-Mean=0.802±0.040  AUC=0.887±0.027
#     ExtraTrees                 Acc=0.744±0.046  F1=0.740±0.051  MCC=0.617±0.068  G-Mean=0.805±0.037  AUC=0.888±0.023
#     Bagging                    Acc=0.708±0.060  F1=0.695±0.064  MCC=0.570±0.089  G-Mean=0.778±0.046  AUC=0.866±0.035
#     GradientBoosting           Acc=0.715±0.051  F1=0.708±0.052  MCC=0.575±0.077  G-Mean=0.783±0.040  AUC=0.876±0.033
#     LogisticRegression         Acc=0.631±0.052  F1=0.621±0.055  MCC=0.451±0.078  G-Mean=0.717±0.041  AUC=0.785±0.045
#     RidgeClassifier            Acc=0.600±0.054  F1=0.584±0.059  MCC=0.408±0.082  G-Mean=0.693±0.042  AUC=N/A
#     DecisionTree               Acc=0.692±0.042  F1=0.680±0.042  MCC=0.543±0.064  G-Mean=0.765±0.031  AUC=0.769±0.030
#     NaiveBayes                 Acc=0.571±0.084  F1=0.566±0.087  MCC=0.359±0.127  G-Mean=0.669±0.068  AUC=0.756±0.064
#     Perceptron                 Acc=0.523±0.067  F1=0.485±0.065  MCC=0.305±0.111  G-Mean=0.629±0.055  AUC=N/A
#     SGDClassifier              Acc=0.602±0.051  F1=0.567±0.065  MCC=0.428±0.076  G-Mean=0.694±0.040  AUC=N/A
#     PassiveAggressive          Acc=0.501±0.070  F1=0.461±0.070  MCC=0.284±0.122  G-Mean=0.611±0.059  AUC=N/A
#     LDA                        Acc=0.611±0.048  F1=0.601±0.048  MCC=0.420±0.073  G-Mean=0.701±0.038  AUC=0.777±0.042
#     QDA                        Acc=0.701±0.040  F1=0.700±0.041  MCC=0.553±0.060  G-Mean=0.772±0.031  AUC=0.854±0.024
#     LightGBM                   Acc=0.724±0.046  F1=0.718±0.050  MCC=0.588±0.069  G-Mean=0.790±0.037  AUC=0.881±0.027
#     XGBoost                    Acc=0.728±0.049  F1=0.719±0.052  MCC=0.595±0.074  G-Mean=0.793±0.039  AUC=0.884±0.028
#     VotingSoft                 Acc=0.728±0.047  F1=0.722±0.050  MCC=0.593±0.071  G-Mean=0.793±0.037  AUC=0.891±0.026
#     VotingHard                 Acc=0.742±0.043  F1=0.737±0.046  MCC=0.615±0.064  G-Mean=0.804±0.034  AUC=N/A
#     Stacking                   Acc=0.740±0.076  F1=0.738±0.078  MCC=0.612±0.114  G-Mean=0.802±0.060  AUC=0.883±0.040
#
# ======================================================================
#   Balancer: B2_RandomUnderSampling  |  shape=(99, 47)
# ======================================================================
#     RandomForest               Acc=0.456±0.165  F1=0.445±0.142  MCC=0.184±0.274  G-Mean=0.569±0.146  AUC=0.677±0.110
#     ExtraTrees                 Acc=0.466±0.131  F1=0.451±0.103  MCC=0.200±0.219  G-Mean=0.579±0.108  AUC=0.644±0.114
#     Bagging                    Acc=0.406±0.146  F1=0.393±0.163  MCC=0.100±0.229  G-Mean=0.530±0.124  AUC=0.623±0.111
#     GradientBoosting           Acc=0.446±0.073  F1=0.425±0.076  MCC=0.173±0.128  G-Mean=0.564±0.068  AUC=0.591±0.120
#     LogisticRegression         Acc=0.414±0.084  F1=0.389±0.089  MCC=0.114±0.133  G-Mean=0.532±0.069  AUC=0.552±0.106
#     RidgeClassifier            Acc=0.414±0.130  F1=0.389±0.121  MCC=0.123±0.198  G-Mean=0.532±0.112  AUC=N/A
#     DecisionTree               Acc=0.366±0.156  F1=0.351±0.146  MCC=0.039±0.242  G-Mean=0.486±0.134  AUC=0.518±0.115
#     NaiveBayes                 Acc=0.464±0.134  F1=0.446±0.125  MCC=0.200±0.237  G-Mean=0.581±0.126  AUC=0.704±0.083
#     Perceptron                 Acc=0.344±0.131  F1=0.294±0.143  MCC=0.020±0.225  G-Mean=0.476±0.116  AUC=N/A
#     SGDClassifier              Acc=0.363±0.127  F1=0.292±0.122  MCC=0.020±0.200  G-Mean=0.472±0.112  AUC=N/A
#     PassiveAggressive          Acc=0.344±0.115  F1=0.319±0.117  MCC=0.026±0.170  G-Mean=0.485±0.094  AUC=N/A
#     LDA                        Acc=0.413±0.156  F1=0.393±0.155  MCC=0.118±0.244  G-Mean=0.532±0.137  AUC=0.577±0.122
#     QDA                        Acc=0.354±0.084  F1=0.285±0.104  MCC=0.028±0.143  G-Mean=0.479±0.078  AUC=0.509±0.064
#     LightGBM                   Acc=0.374±0.112  F1=0.359±0.110  MCC=0.064±0.183  G-Mean=0.504±0.113  AUC=0.559±0.082
#     XGBoost                    Acc=0.404±0.079  F1=0.382±0.083  MCC=0.105±0.132  G-Mean=0.528±0.074  AUC=0.575±0.116
#     VotingSoft                 Acc=0.454±0.111  F1=0.441±0.100  MCC=0.179±0.173  G-Mean=0.569±0.095  AUC=0.636±0.106
#     VotingHard                 Acc=0.466±0.152  F1=0.448±0.137  MCC=0.199±0.253  G-Mean=0.577±0.135  AUC=N/A
#     Stacking                   Acc=0.452±0.107  F1=0.421±0.114  MCC=0.179±0.166  G-Mean=0.566±0.093  AUC=0.643±0.120
#
# ======================================================================
#   Balancer: B4_SMOTE  |  shape=(555, 47)
# ======================================================================
#     RandomForest               Acc=0.706±0.047  F1=0.697±0.049  MCC=0.564±0.070  G-Mean=0.776±0.036  AUC=0.868±0.028
#     ExtraTrees                 Acc=0.728±0.048  F1=0.723±0.051  MCC=0.594±0.071  G-Mean=0.793±0.037  AUC=0.876±0.023
#     Bagging                    Acc=0.688±0.058  F1=0.679±0.061  MCC=0.538±0.085  G-Mean=0.762±0.045  AUC=0.852±0.039
#     GradientBoosting           Acc=0.681±0.046  F1=0.673±0.049  MCC=0.524±0.069  G-Mean=0.756±0.036  AUC=0.841±0.037
#     LogisticRegression         Acc=0.611±0.062  F1=0.607±0.060  MCC=0.419±0.093  G-Mean=0.701±0.049  AUC=0.779±0.043
#     RidgeClassifier            Acc=0.598±0.054  F1=0.583±0.057  MCC=0.405±0.084  G-Mean=0.691±0.044  AUC=N/A
#     DecisionTree               Acc=0.604±0.053  F1=0.590±0.052  MCC=0.410±0.081  G-Mean=0.696±0.041  AUC=0.703±0.039
#     NaiveBayes                 Acc=0.557±0.045  F1=0.550±0.046  MCC=0.341±0.067  G-Mean=0.658±0.036  AUC=0.738±0.054
#     Perceptron                 Acc=0.490±0.060  F1=0.436±0.074  MCC=0.280±0.089  G-Mean=0.603±0.049  AUC=N/A
#     SGDClassifier              Acc=0.551±0.078  F1=0.511±0.096  MCC=0.358±0.114  G-Mean=0.654±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.562±0.040  F1=0.533±0.049  MCC=0.372±0.068  G-Mean=0.663±0.034  AUC=N/A
#     LDA                        Acc=0.587±0.063  F1=0.579±0.063  MCC=0.386±0.097  G-Mean=0.683±0.052  AUC=0.777±0.051
#     QDA                        Acc=0.640±0.060  F1=0.648±0.055  MCC=0.462±0.089  G-Mean=0.724±0.047  AUC=0.810±0.039
#     LightGBM                   Acc=0.681±0.043  F1=0.675±0.043  MCC=0.524±0.065  G-Mean=0.756±0.033  AUC=0.858±0.036
#     XGBoost                    Acc=0.692±0.040  F1=0.687±0.041  MCC=0.540±0.061  G-Mean=0.765±0.032  AUC=0.864±0.025
#     VotingSoft                 Acc=0.697±0.056  F1=0.690±0.058  MCC=0.548±0.085  G-Mean=0.769±0.044  AUC=0.872±0.028
#     VotingHard                 Acc=0.724±0.053  F1=0.718±0.055  MCC=0.590±0.079  G-Mean=0.790±0.041  AUC=N/A
#     Stacking                   Acc=0.710±0.050  F1=0.707±0.052  MCC=0.567±0.075  G-Mean=0.778±0.039  AUC=0.865±0.034
#
# ======================================================================
#   Balancer: B5_BorderlineSMOTE  |  shape=(555, 47)
# ======================================================================
#     RandomForest               Acc=0.728±0.049  F1=0.724±0.049  MCC=0.594±0.073  G-Mean=0.793±0.037  AUC=0.868±0.029
#     ExtraTrees                 Acc=0.724±0.064  F1=0.720±0.065  MCC=0.589±0.097  G-Mean=0.790±0.049  AUC=0.873±0.033
#     Bagging                    Acc=0.706±0.028  F1=0.699±0.031  MCC=0.564±0.040  G-Mean=0.776±0.022  AUC=0.851±0.029
#     GradientBoosting           Acc=0.697±0.072  F1=0.691±0.073  MCC=0.549±0.108  G-Mean=0.769±0.056  AUC=0.860±0.036
#     LogisticRegression         Acc=0.656±0.044  F1=0.646±0.043  MCC=0.488±0.068  G-Mean=0.737±0.035  AUC=0.811±0.049
#     RidgeClassifier            Acc=0.630±0.045  F1=0.611±0.050  MCC=0.455±0.070  G-Mean=0.717±0.037  AUC=N/A
#     DecisionTree               Acc=0.638±0.066  F1=0.628±0.070  MCC=0.462±0.100  G-Mean=0.723±0.052  AUC=0.729±0.049
#     NaiveBayes                 Acc=0.566±0.073  F1=0.557±0.070  MCC=0.355±0.115  G-Mean=0.665±0.059  AUC=0.760±0.065
#     Perceptron                 Acc=0.551±0.078  F1=0.525±0.087  MCC=0.348±0.114  G-Mean=0.653±0.063  AUC=N/A
#     SGDClassifier              Acc=0.618±0.075  F1=0.582±0.090  MCC=0.460±0.097  G-Mean=0.707±0.059  AUC=N/A
#     PassiveAggressive          Acc=0.588±0.045  F1=0.573±0.045  MCC=0.394±0.068  G-Mean=0.682±0.036  AUC=N/A
#     LDA                        Acc=0.641±0.045  F1=0.630±0.043  MCC=0.468±0.069  G-Mean=0.725±0.036  AUC=0.806±0.051
#     QDA                        Acc=0.647±0.047  F1=0.655±0.044  MCC=0.473±0.070  G-Mean=0.729±0.037  AUC=0.818±0.034
#     LightGBM                   Acc=0.692±0.061  F1=0.689±0.058  MCC=0.540±0.093  G-Mean=0.765±0.047  AUC=0.852±0.041
#     XGBoost                    Acc=0.679±0.053  F1=0.674±0.051  MCC=0.521±0.081  G-Mean=0.755±0.041  AUC=0.859±0.035
#     VotingSoft                 Acc=0.699±0.067  F1=0.695±0.066  MCC=0.551±0.101  G-Mean=0.770±0.053  AUC=0.871±0.036
#     VotingHard                 Acc=0.726±0.049  F1=0.723±0.049  MCC=0.590±0.072  G-Mean=0.791±0.037  AUC=N/A
#     Stacking                   Acc=0.710±0.065  F1=0.709±0.064  MCC=0.567±0.098  G-Mean=0.778±0.051  AUC=0.872±0.037
#
# ======================================================================
#   Balancer: B6_TomekLinks  |  shape=(366, 47)
# ======================================================================
#     RandomForest               Acc=0.620±0.070  F1=0.528±0.129  MCC=0.321±0.131  G-Mean=0.629±0.079  AUC=0.723±0.102
#     ExtraTrees                 Acc=0.596±0.073  F1=0.496±0.117  MCC=0.274±0.140  G-Mean=0.604±0.076  AUC=0.730±0.099
#     Bagging                    Acc=0.555±0.077  F1=0.451±0.115  MCC=0.205±0.137  G-Mean=0.569±0.075  AUC=0.696±0.082
#     GradientBoosting           Acc=0.591±0.071  F1=0.492±0.116  MCC=0.281±0.125  G-Mean=0.607±0.079  AUC=0.701±0.089
#     LogisticRegression         Acc=0.585±0.070  F1=0.498±0.082  MCC=0.270±0.119  G-Mean=0.609±0.056  AUC=0.698±0.093
#     RidgeClassifier            Acc=0.563±0.078  F1=0.404±0.057  MCC=0.212±0.141  G-Mean=0.555±0.054  AUC=N/A
#     DecisionTree               Acc=0.503±0.076  F1=0.433±0.072  MCC=0.138±0.126  G-Mean=0.552±0.060  AUC=0.571±0.054
#     NaiveBayes                 Acc=0.558±0.129  F1=0.530±0.146  MCC=0.280±0.205  G-Mean=0.655±0.120  AUC=0.720±0.103
#     Perceptron                 Acc=0.473±0.066  F1=0.342±0.089  MCC=0.106±0.119  G-Mean=0.511±0.067  AUC=N/A
#     SGDClassifier              Acc=0.528±0.067  F1=0.465±0.072  MCC=0.205±0.107  G-Mean=0.596±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.519±0.060  F1=0.370±0.081  MCC=0.176±0.141  G-Mean=0.538±0.060  AUC=N/A
#     LDA                        Acc=0.596±0.070  F1=0.524±0.088  MCC=0.287±0.130  G-Mean=0.622±0.067  AUC=0.694±0.099
#     QDA                        Acc=0.506±0.078  F1=0.352±0.057  MCC=0.098±0.156  G-Mean=0.509±0.060  AUC=0.550±0.063
#     LightGBM                   Acc=0.588±0.100  F1=0.487±0.116  MCC=0.274±0.186  G-Mean=0.607±0.098  AUC=0.722±0.103
#     XGBoost                    Acc=0.568±0.099  F1=0.471±0.133  MCC=0.235±0.182  G-Mean=0.591±0.101  AUC=0.687±0.103
#     VotingSoft                 Acc=0.591±0.102  F1=0.491±0.136  MCC=0.276±0.189  G-Mean=0.601±0.097  AUC=0.730±0.096
#     VotingHard                 Acc=0.609±0.060  F1=0.504±0.109  MCC=0.301±0.115  G-Mean=0.614±0.066  AUC=N/A
#     Stacking                   Acc=0.585±0.058  F1=0.459±0.118  MCC=0.251±0.114  G-Mean=0.586±0.072  AUC=0.701±0.089
#
# ======================================================================
#   Balancer: B7_SMOTETomek  |  shape=(531, 47)
# ======================================================================
#     RandomForest               Acc=0.742±0.069  F1=0.729±0.073  MCC=0.618±0.101  G-Mean=0.801±0.053  AUC=0.890±0.037
#     ExtraTrees                 Acc=0.740±0.065  F1=0.727±0.069  MCC=0.615±0.098  G-Mean=0.800±0.051  AUC=0.890±0.031
#     Bagging                    Acc=0.652±0.059  F1=0.633±0.065  MCC=0.482±0.088  G-Mean=0.730±0.047  AUC=0.846±0.036
#     GradientBoosting           Acc=0.687±0.047  F1=0.675±0.051  MCC=0.535±0.069  G-Mean=0.759±0.037  AUC=0.866±0.034
#     LogisticRegression         Acc=0.620±0.089  F1=0.606±0.091  MCC=0.433±0.134  G-Mean=0.706±0.070  AUC=0.789±0.051
#     RidgeClassifier            Acc=0.624±0.095  F1=0.602±0.099  MCC=0.442±0.144  G-Mean=0.707±0.075  AUC=N/A
#     DecisionTree               Acc=0.601±0.047  F1=0.583±0.046  MCC=0.408±0.071  G-Mean=0.691±0.037  AUC=0.698±0.035
#     NaiveBayes                 Acc=0.569±0.069  F1=0.563±0.066  MCC=0.360±0.105  G-Mean=0.667±0.054  AUC=0.747±0.057
#     Perceptron                 Acc=0.535±0.083  F1=0.510±0.086  MCC=0.334±0.123  G-Mean=0.640±0.066  AUC=N/A
#     SGDClassifier              Acc=0.603±0.069  F1=0.555±0.074  MCC=0.434±0.103  G-Mean=0.692±0.053  AUC=N/A
#     PassiveAggressive          Acc=0.497±0.087  F1=0.461±0.109  MCC=0.275±0.138  G-Mean=0.611±0.069  AUC=N/A
#     LDA                        Acc=0.618±0.087  F1=0.602±0.089  MCC=0.431±0.131  G-Mean=0.704±0.069  AUC=0.790±0.058
#     QDA                        Acc=0.648±0.064  F1=0.651±0.061  MCC=0.478±0.091  G-Mean=0.729±0.050  AUC=0.820±0.030
#     LightGBM                   Acc=0.703±0.068  F1=0.691±0.070  MCC=0.558±0.101  G-Mean=0.771±0.052  AUC=0.879±0.036
#     XGBoost                    Acc=0.704±0.076  F1=0.691±0.081  MCC=0.561±0.114  G-Mean=0.772±0.059  AUC=0.873±0.040
#     VotingSoft                 Acc=0.701±0.058  F1=0.688±0.060  MCC=0.555±0.086  G-Mean=0.769±0.045  AUC=0.892±0.031
#     VotingHard                 Acc=0.746±0.053  F1=0.733±0.055  MCC=0.623±0.080  G-Mean=0.804±0.041  AUC=N/A
#     Stacking                   Acc=0.731±0.046  F1=0.723±0.048  MCC=0.602±0.072  G-Mean=0.793±0.036  AUC=0.894±0.029
#
#
# -- Phase 1 Summary (top 20 by Accuracy) --
#              Balancer       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#         B7_SMOTETomek       VotingHard     0.746     0.733 0.623   0.804   NaN
# B1_RandomOverSampling       ExtraTrees     0.744     0.740 0.617   0.805 0.888
#         B7_SMOTETomek     RandomForest     0.742     0.729 0.618   0.801 0.890
# B1_RandomOverSampling       VotingHard     0.742     0.737 0.615   0.804   NaN
# B1_RandomOverSampling         Stacking     0.740     0.738 0.612   0.802 0.883
#         B7_SMOTETomek       ExtraTrees     0.740     0.727 0.615   0.800 0.890
# B1_RandomOverSampling     RandomForest     0.740     0.734 0.613   0.802 0.887
#         B7_SMOTETomek         Stacking     0.731     0.723 0.602   0.793 0.894
# B1_RandomOverSampling          XGBoost     0.728     0.719 0.595   0.793 0.884
# B1_RandomOverSampling       VotingSoft     0.728     0.722 0.593   0.793 0.891
#              B4_SMOTE       ExtraTrees     0.728     0.723 0.594   0.793 0.876
#    B5_BorderlineSMOTE     RandomForest     0.728     0.724 0.594   0.793 0.868
#    B5_BorderlineSMOTE       VotingHard     0.726     0.723 0.590   0.791   NaN
#    B5_BorderlineSMOTE       ExtraTrees     0.724     0.720 0.589   0.790 0.873
#              B4_SMOTE       VotingHard     0.724     0.718 0.590   0.790   NaN
# B1_RandomOverSampling         LightGBM     0.724     0.718 0.588   0.790 0.881
# B1_RandomOverSampling GradientBoosting     0.715     0.708 0.575   0.783 0.876
#    B5_BorderlineSMOTE         Stacking     0.710     0.709 0.567   0.778 0.872
#              B4_SMOTE         Stacking     0.710     0.707 0.567   0.778 0.865
# B1_RandomOverSampling          Bagging     0.708     0.695 0.570   0.778 0.866
#
# -- Phase 1: Best Classifier per Balancer --
#               Balancer   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling   ExtraTrees     0.744     0.740 0.617   0.805 0.888
# B2_RandomUnderSampling   VotingHard     0.466     0.448 0.199   0.577   NaN
#               B4_SMOTE   ExtraTrees     0.728     0.723 0.594   0.793 0.876
#     B5_BorderlineSMOTE RandomForest     0.728     0.724 0.594   0.793 0.868
#          B6_TomekLinks RandomForest     0.620     0.528 0.321   0.629 0.723
#          B7_SMOTETomek   VotingHard     0.746     0.733 0.623   0.804   NaN

# %%
def fmt_metric(mean_val, std_val):
    """Format mean±std, returning N/A if None or NaN."""
    try:
        if mean_val is None or std_val is None:
            return "N/A"
        if math.isnan(float(mean_val)) or math.isnan(float(std_val)):
            return "N/A"
        return f"{float(mean_val):.3f}\u00b1{float(std_val):.3f}"  # \u00b1 = ±
    except (TypeError, ValueError):
        return "N/A"

COLUMNS = ["Model",
           f"Accuracy (Mean \u00b1 SD)",
           f"MCC (Mean \u00b1 SD)",
           f"G-Mean (Mean \u00b1 SD)",
           f"F1-Score (Mean \u00b1 SD)",
           f"AUROC (Mean \u00b1 SD)"]

output = io.StringIO()
writer = csv.writer(output)

# %%
for bal_name, bal_df in balanced_datasets.items():
    shape_info = bal_df.shape
    group = phase1_df[phase1_df['Variant'] == bal_name]

    # Section heading
    writer.writerow([f"Balancer: {bal_name}  |  shape={shape_info}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

# ── KEY FIX: save with utf-8-sig (adds BOM so Excel reads ± correctly) ──
with open("Phase1_Balancers_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase1_Balancers_Results.csv")
print("Downloaded: Phase1_Balancers_Results.csv")
# Out:
# Downloaded: Phase1_Balancers_Results.csv

# %% [markdown]
# Experiment 2

# %%
section_header("PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)")

phase2_rows = []
for fs_name, fs_fn in FEATURE_SELECTORS.items():
    try:
        fs_df = fs_fn(df)
        sub_header(f"Feature Selector: {fs_name}  |  features={fs_df.shape[1]-1}")
        rows = evaluate_dataset(fs_df, label=fs_name, verbose=True)
        phase2_rows.extend(rows)
    except Exception as e:
        print(f"  {fs_name} FAILED: {e}")

phase2_df = pd.DataFrame(phase2_rows).dropna(subset=['Accuracy'])
phase2_df['Phase'] = 'Phase2_FeatureSelectionOnly'
phase2_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 2 Summary (top 20 by Accuracy) --")
p2_show = phase2_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'FeatureSelector'})
print(p2_show[['FeatureSelector','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 2: Best Classifier per Feature Selector --")
best_p2 = (p2_show.groupby('FeatureSelector', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['FeatureSelector','Classifier'] + METRICS])
print(best_p2.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)
# ################################################################################
#
# ======================================================================
#   Feature Selector: FS1_Correlation  |  features=46
# ======================================================================
#     RandomForest               Acc=0.580±0.137  F1=0.468±0.179  MCC=0.234±0.265  G-Mean=0.584±0.131  AUC=0.719±0.095
#     ExtraTrees                 Acc=0.585±0.102  F1=0.477±0.140  MCC=0.246±0.198  G-Mean=0.593±0.105  AUC=0.720±0.071
#     Bagging                    Acc=0.575±0.069  F1=0.452±0.103  MCC=0.230±0.125  G-Mean=0.577±0.068  AUC=0.664±0.086
#     GradientBoosting           Acc=0.580±0.124  F1=0.489±0.167  MCC=0.249±0.232  G-Mean=0.600±0.127  AUC=0.692±0.105
#     LogisticRegression         Acc=0.552±0.071  F1=0.480±0.130  MCC=0.205±0.144  G-Mean=0.595±0.095  AUC=0.686±0.081
#     RidgeClassifier            Acc=0.538±0.060  F1=0.374±0.045  MCC=0.150±0.118  G-Mean=0.529±0.045  AUC=N/A
#     DecisionTree               Acc=0.495±0.059  F1=0.393±0.076  MCC=0.122±0.120  G-Mean=0.533±0.067  AUC=0.556±0.059
#     NaiveBayes                 Acc=0.557±0.101  F1=0.517±0.084  MCC=0.273±0.175  G-Mean=0.657±0.081  AUC=0.716±0.076
#     Perceptron                 Acc=0.498±0.070  F1=0.389±0.099  MCC=0.158±0.126  G-Mean=0.557±0.080  AUC=N/A
#     SGDClassifier              Acc=0.510±0.055  F1=0.411±0.111  MCC=0.153±0.134  G-Mean=0.569±0.099  AUC=N/A
#     PassiveAggressive          Acc=0.537±0.069  F1=0.384±0.089  MCC=0.193±0.126  G-Mean=0.541±0.055  AUC=N/A
#     LDA                        Acc=0.555±0.075  F1=0.471±0.143  MCC=0.206±0.148  G-Mean=0.588±0.102  AUC=0.679±0.085
#     QDA                        Acc=0.475±0.072  F1=0.328±0.053  MCC=0.031±0.141  G-Mean=0.484±0.054  AUC=0.517±0.058
#     LightGBM                   Acc=0.580±0.093  F1=0.472±0.139  MCC=0.242±0.179  G-Mean=0.591±0.099  AUC=0.701±0.098
#     XGBoost                    Acc=0.575±0.093  F1=0.488±0.143  MCC=0.238±0.180  G-Mean=0.598±0.104  AUC=0.697±0.096
#     VotingSoft                 Acc=0.590±0.128  F1=0.492±0.161  MCC=0.260±0.242  G-Mean=0.601±0.122  AUC=0.725±0.083
#     VotingHard                 Acc=0.588±0.120  F1=0.482±0.159  MCC=0.253±0.233  G-Mean=0.594±0.116  AUC=N/A
#     Stacking                   Acc=0.578±0.134  F1=0.445±0.153  MCC=0.229±0.257  G-Mean=0.573±0.117  AUC=0.709±0.112
#
# ======================================================================
#   Feature Selector: FS2_KBest  |  features=11
# ======================================================================
#     RandomForest               Acc=0.585±0.098  F1=0.511±0.132  MCC=0.262±0.181  G-Mean=0.614±0.103  AUC=0.718±0.085
#     ExtraTrees                 Acc=0.568±0.090  F1=0.466±0.100  MCC=0.230±0.171  G-Mean=0.588±0.081  AUC=0.694±0.075
#     Bagging                    Acc=0.595±0.071  F1=0.539±0.072  MCC=0.287±0.127  G-Mean=0.636±0.056  AUC=0.698±0.077
#     GradientBoosting           Acc=0.608±0.119  F1=0.498±0.134  MCC=0.300±0.220  G-Mean=0.614±0.109  AUC=0.726±0.087
#     LogisticRegression         Acc=0.602±0.089  F1=0.505±0.136  MCC=0.282±0.161  G-Mean=0.611±0.090  AUC=0.720±0.090
#     RidgeClassifier            Acc=0.580±0.084  F1=0.402±0.059  MCC=0.228±0.157  G-Mean=0.558±0.060  AUC=N/A
#     DecisionTree               Acc=0.582±0.076  F1=0.527±0.098  MCC=0.266±0.139  G-Mean=0.631±0.082  AUC=0.635±0.090
#     NaiveBayes                 Acc=0.585±0.109  F1=0.536±0.109  MCC=0.300±0.192  G-Mean=0.664±0.103  AUC=0.742±0.082
#     Perceptron                 Acc=0.538±0.076  F1=0.384±0.090  MCC=0.190±0.120  G-Mean=0.551±0.049  AUC=N/A
#     SGDClassifier              Acc=0.535±0.087  F1=0.424±0.142  MCC=0.174±0.196  G-Mean=0.564±0.099  AUC=N/A
#     PassiveAggressive          Acc=0.480±0.057  F1=0.338±0.066  MCC=0.114±0.103  G-Mean=0.518±0.035  AUC=N/A
#     LDA                        Acc=0.592±0.089  F1=0.506±0.131  MCC=0.270±0.162  G-Mean=0.611±0.094  AUC=0.718±0.089
#     QDA                        Acc=0.605±0.091  F1=0.547±0.122  MCC=0.299±0.165  G-Mean=0.638±0.086  AUC=0.686±0.076
#     LightGBM                   Acc=0.618±0.111  F1=0.535±0.162  MCC=0.319±0.210  G-Mean=0.642±0.125  AUC=0.736±0.092
#     XGBoost                    Acc=0.590±0.078  F1=0.531±0.097  MCC=0.276±0.141  G-Mean=0.630±0.075  AUC=0.703±0.093
#     VotingSoft                 Acc=0.587±0.104  F1=0.518±0.125  MCC=0.269±0.197  G-Mean=0.623±0.106  AUC=0.733±0.083
#     VotingHard                 Acc=0.590±0.107  F1=0.513±0.136  MCC=0.269±0.200  G-Mean=0.617±0.107  AUC=N/A
#     Stacking                   Acc=0.602±0.092  F1=0.451±0.112  MCC=0.274±0.172  G-Mean=0.586±0.081  AUC=0.723±0.086
#
# ======================================================================
#   Feature Selector: FS3_RFE  |  features=31
# ======================================================================
#     RandomForest               Acc=0.590±0.130  F1=0.503±0.171  MCC=0.256±0.252  G-Mean=0.604±0.124  AUC=0.718±0.100
#     ExtraTrees                 Acc=0.590±0.106  F1=0.494±0.150  MCC=0.258±0.206  G-Mean=0.601±0.108  AUC=0.726±0.093
#     Bagging                    Acc=0.562±0.083  F1=0.461±0.112  MCC=0.217±0.160  G-Mean=0.582±0.083  AUC=0.672±0.108
#     GradientBoosting           Acc=0.595±0.081  F1=0.516±0.120  MCC=0.278±0.158  G-Mean=0.620±0.091  AUC=0.701±0.101
#     LogisticRegression         Acc=0.592±0.077  F1=0.508±0.116  MCC=0.279±0.141  G-Mean=0.622±0.086  AUC=0.710±0.080
#     RidgeClassifier            Acc=0.562±0.063  F1=0.389±0.045  MCC=0.198±0.116  G-Mean=0.547±0.044  AUC=N/A
#     DecisionTree               Acc=0.503±0.085  F1=0.386±0.069  MCC=0.137±0.137  G-Mean=0.531±0.065  AUC=0.555±0.058
#     NaiveBayes                 Acc=0.570±0.106  F1=0.527±0.094  MCC=0.282±0.195  G-Mean=0.658±0.097  AUC=0.730±0.079
#     Perceptron                 Acc=0.530±0.043  F1=0.399±0.087  MCC=0.184±0.098  G-Mean=0.564±0.067  AUC=N/A
#     SGDClassifier              Acc=0.540±0.082  F1=0.420±0.137  MCC=0.210±0.143  G-Mean=0.583±0.088  AUC=N/A
#     PassiveAggressive          Acc=0.500±0.082  F1=0.336±0.083  MCC=0.128±0.153  G-Mean=0.516±0.058  AUC=N/A
#     LDA                        Acc=0.575±0.069  F1=0.497±0.114  MCC=0.250±0.128  G-Mean=0.610±0.080  AUC=0.710±0.081
#     QDA                        Acc=0.495±0.076  F1=0.340±0.055  MCC=0.070±0.145  G-Mean=0.498±0.055  AUC=0.544±0.060
#     LightGBM                   Acc=0.575±0.084  F1=0.497±0.128  MCC=0.243±0.168  G-Mean=0.602±0.093  AUC=0.703±0.094
#     XGBoost                    Acc=0.570±0.112  F1=0.501±0.159  MCC=0.230±0.210  G-Mean=0.601±0.117  AUC=0.699±0.090
#     VotingSoft                 Acc=0.587±0.107  F1=0.493±0.150  MCC=0.260±0.211  G-Mean=0.604±0.111  AUC=0.723±0.092
#     VotingHard                 Acc=0.585±0.111  F1=0.498±0.159  MCC=0.250±0.219  G-Mean=0.601±0.114  AUC=N/A
#     Stacking                   Acc=0.575±0.125  F1=0.457±0.154  MCC=0.227±0.243  G-Mean=0.576±0.113  AUC=0.707±0.108
#
# ======================================================================
#   Feature Selector: FS4_MutualInfo  |  features=3
# ======================================================================
#     RandomForest               Acc=0.555±0.061  F1=0.476±0.105  MCC=0.208±0.112  G-Mean=0.584±0.068  AUC=0.651±0.080
#     ExtraTrees                 Acc=0.555±0.061  F1=0.486±0.111  MCC=0.200±0.118  G-Mean=0.582±0.071  AUC=0.651±0.080
#     Bagging                    Acc=0.555±0.058  F1=0.474±0.101  MCC=0.207±0.104  G-Mean=0.584±0.064  AUC=0.646±0.078
#     GradientBoosting           Acc=0.550±0.065  F1=0.478±0.109  MCC=0.194±0.127  G-Mean=0.579±0.073  AUC=0.661±0.071
#     LogisticRegression         Acc=0.542±0.058  F1=0.423±0.101  MCC=0.169±0.110  G-Mean=0.554±0.069  AUC=0.678±0.066
#     RidgeClassifier            Acc=0.540±0.056  F1=0.374±0.037  MCC=0.154±0.100  G-Mean=0.530±0.038  AUC=N/A
#     DecisionTree               Acc=0.552±0.065  F1=0.482±0.110  MCC=0.198±0.124  G-Mean=0.581±0.074  AUC=0.653±0.082
#     NaiveBayes                 Acc=0.552±0.056  F1=0.505±0.070  MCC=0.212±0.101  G-Mean=0.605±0.055  AUC=0.690±0.064
#     Perceptron                 Acc=0.467±0.110  F1=0.300±0.085  MCC=0.108±0.119  G-Mean=0.516±0.042  AUC=N/A
#     SGDClassifier              Acc=0.505±0.058  F1=0.318±0.076  MCC=0.117±0.110  G-Mean=0.516±0.038  AUC=N/A
#     PassiveAggressive          Acc=0.488±0.078  F1=0.327±0.150  MCC=0.111±0.160  G-Mean=0.535±0.089  AUC=N/A
#     LDA                        Acc=0.548±0.048  F1=0.477±0.073  MCC=0.189±0.091  G-Mean=0.581±0.054  AUC=0.680±0.067
#     QDA                        Acc=0.557±0.056  F1=0.471±0.099  MCC=0.204±0.107  G-Mean=0.581±0.067  AUC=0.678±0.061
#     LightGBM                   Acc=0.548±0.061  F1=0.479±0.114  MCC=0.195±0.108  G-Mean=0.584±0.076  AUC=0.662±0.072
#     XGBoost                    Acc=0.550±0.065  F1=0.471±0.102  MCC=0.197±0.125  G-Mean=0.580±0.073  AUC=0.655±0.081
#     VotingSoft                 Acc=0.550±0.065  F1=0.471±0.108  MCC=0.202±0.118  G-Mean=0.581±0.072  AUC=0.654±0.080
#     VotingHard                 Acc=0.550±0.065  F1=0.475±0.110  MCC=0.196±0.123  G-Mean=0.580±0.073  AUC=N/A
#     Stacking                   Acc=0.557±0.047  F1=0.414±0.070  MCC=0.197±0.087  G-Mean=0.555±0.043  AUC=0.677±0.063
#
# ======================================================================
#   Feature Selector: FS5_RFImportance  |  features=39
# ======================================================================
#     RandomForest               Acc=0.608±0.119  F1=0.498±0.160  MCC=0.288±0.228  G-Mean=0.608±0.115  AUC=0.720±0.087
#     ExtraTrees                 Acc=0.588±0.110  F1=0.484±0.156  MCC=0.251±0.207  G-Mean=0.595±0.111  AUC=0.714±0.091
#     Bagging                    Acc=0.577±0.077  F1=0.449±0.102  MCC=0.238±0.146  G-Mean=0.579±0.075  AUC=0.673±0.106
#     GradientBoosting           Acc=0.575±0.112  F1=0.480±0.139  MCC=0.239±0.216  G-Mean=0.596±0.111  AUC=0.701±0.103
#     LogisticRegression         Acc=0.580±0.077  F1=0.494±0.119  MCC=0.256±0.143  G-Mean=0.615±0.089  AUC=0.697±0.075
#     RidgeClassifier            Acc=0.555±0.073  F1=0.385±0.051  MCC=0.184±0.138  G-Mean=0.541±0.052  AUC=N/A
#     DecisionTree               Acc=0.490±0.066  F1=0.388±0.067  MCC=0.107±0.117  G-Mean=0.524±0.053  AUC=0.547±0.047
#     NaiveBayes                 Acc=0.563±0.108  F1=0.516±0.098  MCC=0.280±0.197  G-Mean=0.655±0.100  AUC=0.720±0.080
#     Perceptron                 Acc=0.467±0.104  F1=0.329±0.082  MCC=0.129±0.111  G-Mean=0.519±0.053  AUC=N/A
#     SGDClassifier              Acc=0.492±0.085  F1=0.432±0.110  MCC=0.150±0.143  G-Mean=0.576±0.082  AUC=N/A
#     PassiveAggressive          Acc=0.528±0.063  F1=0.357±0.073  MCC=0.158±0.128  G-Mean=0.527±0.049  AUC=N/A
#     LDA                        Acc=0.565±0.080  F1=0.492±0.129  MCC=0.228±0.149  G-Mean=0.604±0.092  AUC=0.694±0.074
#     QDA                        Acc=0.493±0.059  F1=0.338±0.043  MCC=0.064±0.115  G-Mean=0.496±0.044  AUC=0.528±0.060
#     LightGBM                   Acc=0.560±0.095  F1=0.452±0.134  MCC=0.207±0.189  G-Mean=0.577±0.104  AUC=0.705±0.082
#     XGBoost                    Acc=0.578±0.098  F1=0.478±0.139  MCC=0.242±0.185  G-Mean=0.594±0.101  AUC=0.716±0.097
#     VotingSoft                 Acc=0.592±0.121  F1=0.497±0.156  MCC=0.266±0.234  G-Mean=0.607±0.118  AUC=0.721±0.087
#     VotingHard                 Acc=0.588±0.122  F1=0.484±0.163  MCC=0.251±0.229  G-Mean=0.594±0.118  AUC=N/A
#     Stacking                   Acc=0.575±0.101  F1=0.453±0.134  MCC=0.226±0.193  G-Mean=0.576±0.095  AUC=0.721±0.089
#
#
# -- Phase 2 Summary (top 20 by Accuracy) --
#  FeatureSelector         Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#        FS2_KBest           LightGBM     0.618     0.535 0.319   0.642 0.736
#        FS2_KBest   GradientBoosting     0.608     0.498 0.300   0.614 0.726
# FS5_RFImportance       RandomForest     0.608     0.498 0.288   0.608 0.720
#        FS2_KBest                QDA     0.605     0.547 0.299   0.638 0.686
#        FS2_KBest           Stacking     0.602     0.451 0.274   0.586 0.723
#        FS2_KBest LogisticRegression     0.602     0.505 0.282   0.611 0.720
#        FS2_KBest            Bagging     0.595     0.539 0.287   0.636 0.698
#          FS3_RFE   GradientBoosting     0.595     0.516 0.278   0.620 0.701
#        FS2_KBest                LDA     0.592     0.506 0.270   0.611 0.718
# FS5_RFImportance         VotingSoft     0.592     0.497 0.266   0.607 0.721
#          FS3_RFE LogisticRegression     0.592     0.508 0.279   0.622 0.710
#  FS1_Correlation         VotingSoft     0.590     0.492 0.260   0.601 0.725
#          FS3_RFE       RandomForest     0.590     0.503 0.256   0.604 0.718
#          FS3_RFE         ExtraTrees     0.590     0.494 0.258   0.601 0.726
#        FS2_KBest            XGBoost     0.590     0.531 0.276   0.630 0.703
#        FS2_KBest         VotingHard     0.590     0.513 0.269   0.617   NaN
# FS5_RFImportance         VotingHard     0.588     0.484 0.251   0.594   NaN
# FS5_RFImportance         ExtraTrees     0.588     0.484 0.251   0.595 0.714
#  FS1_Correlation         VotingHard     0.588     0.482 0.253   0.594   NaN
#        FS2_KBest         VotingSoft     0.587     0.518 0.269   0.623 0.733
#
# -- Phase 2: Best Classifier per Feature Selector --
#  FeatureSelector       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  FS1_Correlation       VotingSoft     0.590     0.492 0.260   0.601 0.725
#        FS2_KBest         LightGBM     0.618     0.535 0.319   0.642 0.736
#          FS3_RFE GradientBoosting     0.595     0.516 0.278   0.620 0.701
#   FS4_MutualInfo         Stacking     0.557     0.414 0.197   0.555 0.677
# FS5_RFImportance     RandomForest     0.608     0.498 0.288   0.608 0.720

# %%
phase2_only = phase2_df[phase2_df['Phase'] == 'Phase2_FeatureSelectionOnly'].copy()

output = io.StringIO()
writer = csv.writer(output)

for fs_name in phase2_only['Variant'].unique():
    group = phase2_only[phase2_only['Variant'] == fs_name]

    try:
        fs_df = FEATURE_SELECTORS[fs_name](df)
        n_features = fs_df.shape[1] - 1
    except:
        n_features = "N/A"

    writer.writerow([f"Feature Selector: {fs_name}  |  features={n_features}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

with open("Phase2_FeatureSelection_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase2_FeatureSelection_Results.csv")
print(" Downloaded: Phase2_FeatureSelection_Results.csv")
# Out:
#  Downloaded: Phase2_FeatureSelection_Results.csv

# %% [markdown]
# Experiment 3

# %%
section_header("PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)")

phase3_rows = []
for bal_name, bal_df in balanced_datasets.items():
    for fs_name, fs_fn in FEATURE_SELECTORS.items():
        combo = f"{bal_name} + {fs_name}"
        try:
            fs_df = fs_fn(bal_df)
            sub_header(f"Combo: {combo}  |  shape={fs_df.shape}")
            rows = evaluate_dataset(fs_df, label=combo, verbose=True)
            phase3_rows.extend(rows)
        except Exception as e:
            print(f"  {combo} FAILED: {e}")

phase3_df = pd.DataFrame(phase3_rows).dropna(subset=['Accuracy'])
phase3_df['Phase'] = 'Phase3_Balancing+FS'
phase3_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 3 Summary (top 30 combos by Accuracy) --")
p3_show = phase3_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer+FS'})
print(p3_show[['Balancer+FS','Classifier'] + METRICS].head(30).to_string(index=False))

print("\n-- Phase 3: Best Classifier per Balancer+FS combo --")
best_p3 = (p3_show.groupby('Balancer+FS', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer+FS','Classifier'] + METRICS]
           .sort_values('Accuracy', ascending=False))
print(best_p3.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)
# ################################################################################
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS1_Correlation  |  shape=(555, 46)
# ======================================================================
#     RandomForest               Acc=0.737±0.039  F1=0.731±0.043  MCC=0.608±0.059  G-Mean=0.800±0.031  AUC=0.885±0.026
#     ExtraTrees                 Acc=0.753±0.049  F1=0.750±0.053  MCC=0.630±0.074  G-Mean=0.812±0.039  AUC=0.897±0.025
#     Bagging                    Acc=0.697±0.051  F1=0.683±0.055  MCC=0.556±0.076  G-Mean=0.769±0.039  AUC=0.865±0.029
#     GradientBoosting           Acc=0.714±0.051  F1=0.707±0.051  MCC=0.572±0.076  G-Mean=0.782±0.039  AUC=0.875±0.036
#     LogisticRegression         Acc=0.631±0.055  F1=0.621±0.058  MCC=0.450±0.081  G-Mean=0.717±0.043  AUC=0.786±0.045
#     RidgeClassifier            Acc=0.604±0.051  F1=0.589±0.055  MCC=0.413±0.079  G-Mean=0.695±0.040  AUC=N/A
#     DecisionTree               Acc=0.694±0.036  F1=0.684±0.036  MCC=0.545±0.059  G-Mean=0.766±0.028  AUC=0.770±0.027
#     NaiveBayes                 Acc=0.571±0.082  F1=0.566±0.083  MCC=0.359±0.124  G-Mean=0.669±0.066  AUC=0.755±0.067
#     Perceptron                 Acc=0.537±0.048  F1=0.502±0.062  MCC=0.332±0.072  G-Mean=0.641±0.041  AUC=N/A
#     SGDClassifier              Acc=0.544±0.030  F1=0.518±0.047  MCC=0.341±0.047  G-Mean=0.648±0.024  AUC=N/A
#     PassiveAggressive          Acc=0.481±0.056  F1=0.445±0.064  MCC=0.251±0.096  G-Mean=0.594±0.047  AUC=N/A
#     LDA                        Acc=0.609±0.052  F1=0.599±0.053  MCC=0.417±0.080  G-Mean=0.699±0.041  AUC=0.779±0.042
#     QDA                        Acc=0.692±0.035  F1=0.691±0.036  MCC=0.539±0.052  G-Mean=0.765±0.027  AUC=0.852±0.026
#     LightGBM                   Acc=0.719±0.031  F1=0.712±0.033  MCC=0.580±0.047  G-Mean=0.786±0.024  AUC=0.884±0.025
#     XGBoost                    Acc=0.715±0.044  F1=0.707±0.047  MCC=0.574±0.065  G-Mean=0.783±0.035  AUC=0.884±0.030
#     VotingSoft                 Acc=0.724±0.045  F1=0.719±0.047  MCC=0.588±0.067  G-Mean=0.790±0.035  AUC=0.893±0.023
#     VotingHard                 Acc=0.739±0.039  F1=0.734±0.043  MCC=0.609±0.060  G-Mean=0.801±0.032  AUC=N/A
#     Stacking                   Acc=0.735±0.055  F1=0.733±0.057  MCC=0.604±0.083  G-Mean=0.798±0.043  AUC=0.881±0.039
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS2_KBest  |  shape=(555, 12)
# ======================================================================
#     RandomForest               Acc=0.701±0.045  F1=0.688±0.051  MCC=0.557±0.066  G-Mean=0.772±0.035  AUC=0.863±0.033
#     ExtraTrees                 Acc=0.710±0.057  F1=0.701±0.061  MCC=0.568±0.085  G-Mean=0.779±0.045  AUC=0.852±0.041
#     Bagging                    Acc=0.699±0.056  F1=0.690±0.058  MCC=0.552±0.085  G-Mean=0.770±0.043  AUC=0.847±0.042
#     GradientBoosting           Acc=0.685±0.060  F1=0.676±0.062  MCC=0.532±0.091  G-Mean=0.759±0.047  AUC=0.837±0.046
#     LogisticRegression         Acc=0.611±0.067  F1=0.602±0.069  MCC=0.421±0.100  G-Mean=0.701±0.052  AUC=0.764±0.047
#     RidgeClassifier            Acc=0.553±0.046  F1=0.509±0.049  MCC=0.351±0.075  G-Mean=0.656±0.035  AUC=N/A
#     DecisionTree               Acc=0.678±0.052  F1=0.667±0.055  MCC=0.519±0.077  G-Mean=0.754±0.040  AUC=0.769±0.046
#     NaiveBayes                 Acc=0.596±0.058  F1=0.593±0.059  MCC=0.399±0.088  G-Mean=0.690±0.046  AUC=0.785±0.042
#     Perceptron                 Acc=0.534±0.047  F1=0.489±0.068  MCC=0.342±0.064  G-Mean=0.638±0.037  AUC=N/A
#     SGDClassifier              Acc=0.495±0.037  F1=0.419±0.040  MCC=0.290±0.071  G-Mean=0.608±0.033  AUC=N/A
#     PassiveAggressive          Acc=0.434±0.051  F1=0.366±0.077  MCC=0.180±0.069  G-Mean=0.555±0.041  AUC=N/A
#     LDA                        Acc=0.598±0.067  F1=0.589±0.070  MCC=0.403±0.100  G-Mean=0.691±0.053  AUC=0.761±0.044
#     QDA                        Acc=0.578±0.087  F1=0.567±0.090  MCC=0.372±0.134  G-Mean=0.674±0.071  AUC=0.783±0.058
#     LightGBM                   Acc=0.688±0.059  F1=0.678±0.060  MCC=0.538±0.088  G-Mean=0.762±0.046  AUC=0.853±0.042
#     XGBoost                    Acc=0.706±0.069  F1=0.696±0.074  MCC=0.564±0.103  G-Mean=0.776±0.054  AUC=0.844±0.052
#     VotingSoft                 Acc=0.703±0.057  F1=0.693±0.061  MCC=0.559±0.086  G-Mean=0.773±0.045  AUC=0.864±0.039
#     VotingHard                 Acc=0.704±0.053  F1=0.693±0.058  MCC=0.562±0.078  G-Mean=0.774±0.042  AUC=N/A
#     Stacking                   Acc=0.715±0.053  F1=0.710±0.057  MCC=0.577±0.078  G-Mean=0.783±0.042  AUC=0.867±0.033
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS3_RFE  |  shape=(555, 32)
# ======================================================================
#     RandomForest               Acc=0.755±0.059  F1=0.747±0.065  MCC=0.636±0.086  G-Mean=0.813±0.047  AUC=0.893±0.027
#     ExtraTrees                 Acc=0.751±0.052  F1=0.747±0.054  MCC=0.630±0.077  G-Mean=0.811±0.040  AUC=0.900±0.026
#     Bagging                    Acc=0.728±0.049  F1=0.720±0.051  MCC=0.598±0.076  G-Mean=0.793±0.038  AUC=0.879±0.022
#     GradientBoosting           Acc=0.715±0.060  F1=0.708±0.062  MCC=0.575±0.090  G-Mean=0.783±0.047  AUC=0.881±0.035
#     LogisticRegression         Acc=0.631±0.058  F1=0.624±0.056  MCC=0.449±0.088  G-Mean=0.717±0.045  AUC=0.787±0.045
#     RidgeClassifier            Acc=0.570±0.063  F1=0.551±0.060  MCC=0.364±0.100  G-Mean=0.668±0.050  AUC=N/A
#     DecisionTree               Acc=0.692±0.059  F1=0.678±0.063  MCC=0.544±0.090  G-Mean=0.765±0.046  AUC=0.769±0.045
#     NaiveBayes                 Acc=0.607±0.074  F1=0.601±0.080  MCC=0.414±0.111  G-Mean=0.698±0.058  AUC=0.772±0.055
#     Perceptron                 Acc=0.512±0.088  F1=0.460±0.098  MCC=0.300±0.129  G-Mean=0.621±0.070  AUC=N/A
#     SGDClassifier              Acc=0.564±0.055  F1=0.526±0.076  MCC=0.375±0.073  G-Mean=0.665±0.044  AUC=N/A
#     PassiveAggressive          Acc=0.467±0.058  F1=0.408±0.072  MCC=0.239±0.096  G-Mean=0.582±0.049  AUC=N/A
#     LDA                        Acc=0.596±0.066  F1=0.592±0.066  MCC=0.397±0.100  G-Mean=0.690±0.053  AUC=0.777±0.044
#     QDA                        Acc=0.691±0.060  F1=0.697±0.060  MCC=0.540±0.089  G-Mean=0.764±0.048  AUC=0.850±0.032
#     LightGBM                   Acc=0.739±0.037  F1=0.734±0.039  MCC=0.610±0.055  G-Mean=0.801±0.029  AUC=0.885±0.031
#     XGBoost                    Acc=0.722±0.030  F1=0.715±0.031  MCC=0.586±0.045  G-Mean=0.789±0.024  AUC=0.890±0.027
#     VotingSoft                 Acc=0.737±0.049  F1=0.731±0.052  MCC=0.608±0.072  G-Mean=0.800±0.038  AUC=0.895±0.028
#     VotingHard                 Acc=0.749±0.044  F1=0.744±0.048  MCC=0.627±0.064  G-Mean=0.809±0.034  AUC=N/A
#     Stacking                   Acc=0.767±0.055  F1=0.765±0.057  MCC=0.653±0.082  G-Mean=0.823±0.043  AUC=0.890±0.031
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS4_MutualInfo  |  shape=(555, 4)
# ======================================================================
#     RandomForest               Acc=0.598±0.058  F1=0.599±0.058  MCC=0.401±0.088  G-Mean=0.691±0.047  AUC=0.756±0.046
#     ExtraTrees                 Acc=0.602±0.066  F1=0.603±0.066  MCC=0.406±0.099  G-Mean=0.694±0.053  AUC=0.757±0.046
#     Bagging                    Acc=0.600±0.069  F1=0.601±0.069  MCC=0.404±0.103  G-Mean=0.692±0.055  AUC=0.754±0.044
#     GradientBoosting           Acc=0.602±0.065  F1=0.603±0.065  MCC=0.406±0.098  G-Mean=0.694±0.052  AUC=0.760±0.044
#     LogisticRegression         Acc=0.595±0.049  F1=0.594±0.048  MCC=0.394±0.074  G-Mean=0.688±0.039  AUC=0.745±0.042
#     RidgeClassifier            Acc=0.535±0.047  F1=0.457±0.055  MCC=0.347±0.078  G-Mean=0.641±0.037  AUC=N/A
#     DecisionTree               Acc=0.598±0.067  F1=0.599±0.067  MCC=0.401±0.101  G-Mean=0.691±0.054  AUC=0.753±0.046
#     NaiveBayes                 Acc=0.570±0.065  F1=0.565±0.065  MCC=0.358±0.099  G-Mean=0.668±0.053  AUC=0.743±0.043
#     Perceptron                 Acc=0.503±0.072  F1=0.426±0.096  MCC=0.301±0.125  G-Mean=0.613±0.062  AUC=N/A
#     SGDClassifier              Acc=0.486±0.063  F1=0.419±0.068  MCC=0.277±0.108  G-Mean=0.601±0.052  AUC=N/A
#     PassiveAggressive          Acc=0.436±0.051  F1=0.357±0.090  MCC=0.206±0.095  G-Mean=0.557±0.043  AUC=N/A
#     LDA                        Acc=0.593±0.048  F1=0.593±0.046  MCC=0.391±0.073  G-Mean=0.687±0.038  AUC=0.744±0.042
#     QDA                        Acc=0.589±0.052  F1=0.588±0.052  MCC=0.386±0.078  G-Mean=0.684±0.041  AUC=0.739±0.039
#     LightGBM                   Acc=0.597±0.064  F1=0.597±0.064  MCC=0.399±0.097  G-Mean=0.690±0.052  AUC=0.755±0.040
#     XGBoost                    Acc=0.606±0.061  F1=0.607±0.060  MCC=0.412±0.091  G-Mean=0.697±0.049  AUC=0.755±0.044
#     VotingSoft                 Acc=0.602±0.065  F1=0.603±0.065  MCC=0.406±0.098  G-Mean=0.694±0.052  AUC=0.758±0.045
#     VotingHard                 Acc=0.596±0.060  F1=0.597±0.059  MCC=0.398±0.090  G-Mean=0.690±0.048  AUC=N/A
#     Stacking                   Acc=0.597±0.064  F1=0.597±0.063  MCC=0.399±0.096  G-Mean=0.690±0.051  AUC=0.763±0.044
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS5_RFImportance  |  shape=(555, 40)
# ======================================================================
#     RandomForest               Acc=0.762±0.050  F1=0.757±0.054  MCC=0.646±0.074  G-Mean=0.819±0.039  AUC=0.893±0.022
#     ExtraTrees                 Acc=0.740±0.046  F1=0.737±0.049  MCC=0.613±0.067  G-Mean=0.802±0.036  AUC=0.894±0.023
#     Bagging                    Acc=0.708±0.068  F1=0.699±0.067  MCC=0.568±0.104  G-Mean=0.778±0.052  AUC=0.872±0.034
#     GradientBoosting           Acc=0.713±0.047  F1=0.705±0.050  MCC=0.573±0.072  G-Mean=0.781±0.038  AUC=0.881±0.036
#     LogisticRegression         Acc=0.620±0.055  F1=0.612±0.055  MCC=0.434±0.083  G-Mean=0.708±0.043  AUC=0.782±0.035
#     RidgeClassifier            Acc=0.591±0.054  F1=0.574±0.055  MCC=0.395±0.082  G-Mean=0.686±0.041  AUC=N/A
#     DecisionTree               Acc=0.717±0.053  F1=0.707±0.056  MCC=0.580±0.081  G-Mean=0.785±0.041  AUC=0.788±0.040
#     NaiveBayes                 Acc=0.584±0.076  F1=0.577±0.079  MCC=0.378±0.114  G-Mean=0.679±0.061  AUC=0.768±0.060
#     Perceptron                 Acc=0.533±0.085  F1=0.505±0.089  MCC=0.317±0.131  G-Mean=0.637±0.071  AUC=N/A
#     SGDClassifier              Acc=0.579±0.048  F1=0.545±0.045  MCC=0.389±0.079  G-Mean=0.675±0.038  AUC=N/A
#     PassiveAggressive          Acc=0.481±0.073  F1=0.435±0.101  MCC=0.248±0.120  G-Mean=0.595±0.062  AUC=N/A
#     LDA                        Acc=0.605±0.062  F1=0.596±0.062  MCC=0.412±0.093  G-Mean=0.697±0.049  AUC=0.775±0.034
#     QDA                        Acc=0.699±0.033  F1=0.698±0.035  MCC=0.550±0.050  G-Mean=0.770±0.027  AUC=0.858±0.021
#     LightGBM                   Acc=0.730±0.053  F1=0.724±0.056  MCC=0.597±0.081  G-Mean=0.794±0.042  AUC=0.886±0.028
#     XGBoost                    Acc=0.733±0.048  F1=0.725±0.050  MCC=0.604±0.073  G-Mean=0.797±0.038  AUC=0.888±0.029
#     VotingSoft                 Acc=0.744±0.060  F1=0.739±0.063  MCC=0.618±0.090  G-Mean=0.805±0.047  AUC=0.896±0.027
#     VotingHard                 Acc=0.740±0.060  F1=0.737±0.062  MCC=0.612±0.089  G-Mean=0.802±0.047  AUC=N/A
#     Stacking                   Acc=0.751±0.063  F1=0.749±0.065  MCC=0.628±0.095  G-Mean=0.811±0.050  AUC=0.887±0.034
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS1_Correlation  |  shape=(99, 44)
# ======================================================================
#     RandomForest               Acc=0.436±0.085  F1=0.404±0.091  MCC=0.147±0.151  G-Mean=0.550±0.080  AUC=0.657±0.098
#     ExtraTrees                 Acc=0.456±0.097  F1=0.423±0.092  MCC=0.179±0.170  G-Mean=0.565±0.091  AUC=0.629±0.120
#     Bagging                    Acc=0.496±0.115  F1=0.485±0.106  MCC=0.260±0.202  G-Mean=0.608±0.097  AUC=0.668±0.100
#     GradientBoosting           Acc=0.394±0.085  F1=0.378±0.076  MCC=0.090±0.145  G-Mean=0.520±0.078  AUC=0.580±0.114
#     LogisticRegression         Acc=0.434±0.078  F1=0.414±0.083  MCC=0.148±0.125  G-Mean=0.550±0.064  AUC=0.555±0.089
#     RidgeClassifier            Acc=0.444±0.127  F1=0.426±0.129  MCC=0.170±0.201  G-Mean=0.561±0.111  AUC=N/A
#     DecisionTree               Acc=0.374±0.129  F1=0.352±0.130  MCC=0.048±0.199  G-Mean=0.493±0.112  AUC=0.523±0.095
#     NaiveBayes                 Acc=0.464±0.119  F1=0.452±0.107  MCC=0.200±0.209  G-Mean=0.582±0.112  AUC=0.693±0.075
#     Perceptron                 Acc=0.416±0.110  F1=0.360±0.141  MCC=0.149±0.166  G-Mean=0.549±0.089  AUC=N/A
#     SGDClassifier              Acc=0.364±0.095  F1=0.330±0.107  MCC=0.041±0.153  G-Mean=0.493±0.081  AUC=N/A
#     PassiveAggressive          Acc=0.364±0.105  F1=0.343±0.105  MCC=0.059±0.171  G-Mean=0.500±0.098  AUC=N/A
#     LDA                        Acc=0.434±0.141  F1=0.420±0.149  MCC=0.158±0.227  G-Mean=0.552±0.130  AUC=0.586±0.134
#     QDA                        Acc=0.416±0.119  F1=0.346±0.135  MCC=0.122±0.221  G-Mean=0.533±0.103  AUC=0.556±0.092
#     LightGBM                   Acc=0.384±0.109  F1=0.363±0.119  MCC=0.076±0.173  G-Mean=0.511±0.100  AUC=0.551±0.083
#     XGBoost                    Acc=0.424±0.060  F1=0.397±0.070  MCC=0.134±0.096  G-Mean=0.545±0.052  AUC=0.599±0.109
#     VotingSoft                 Acc=0.414±0.095  F1=0.398±0.076  MCC=0.123±0.164  G-Mean=0.537±0.085  AUC=0.613±0.100
#     VotingHard                 Acc=0.436±0.106  F1=0.408±0.104  MCC=0.147±0.185  G-Mean=0.550±0.100  AUC=N/A
#     Stacking                   Acc=0.514±0.100  F1=0.470±0.110  MCC=0.293±0.167  G-Mean=0.619±0.084  AUC=0.652±0.077
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS2_KBest  |  shape=(99, 12)
# ======================================================================
#     RandomForest               Acc=0.413±0.079  F1=0.380±0.070  MCC=0.132±0.155  G-Mean=0.542±0.078  AUC=0.649±0.044
#     ExtraTrees                 Acc=0.392±0.110  F1=0.381±0.108  MCC=0.084±0.173  G-Mean=0.520±0.097  AUC=0.645±0.061
#     Bagging                    Acc=0.422±0.121  F1=0.402±0.126  MCC=0.132±0.180  G-Mean=0.540±0.100  AUC=0.615±0.092
#     GradientBoosting           Acc=0.414±0.071  F1=0.405±0.073  MCC=0.121±0.103  G-Mean=0.537±0.053  AUC=0.628±0.055
#     LogisticRegression         Acc=0.446±0.107  F1=0.426±0.113  MCC=0.173±0.165  G-Mean=0.566±0.091  AUC=0.622±0.092
#     RidgeClassifier            Acc=0.454±0.101  F1=0.438±0.110  MCC=0.190±0.163  G-Mean=0.573±0.091  AUC=N/A
#     DecisionTree               Acc=0.333±0.110  F1=0.296±0.093  MCC=-0.014±0.160  G-Mean=0.458±0.093  AUC=0.517±0.101
#     NaiveBayes                 Acc=0.526±0.117  F1=0.513±0.127  MCC=0.285±0.192  G-Mean=0.629±0.104  AUC=0.706±0.102
#     Perceptron                 Acc=0.426±0.122  F1=0.362±0.131  MCC=0.151±0.230  G-Mean=0.549±0.105  AUC=N/A
#     SGDClassifier              Acc=0.394±0.138  F1=0.326±0.161  MCC=0.081±0.268  G-Mean=0.509±0.130  AUC=N/A
#     PassiveAggressive          Acc=0.384±0.126  F1=0.330±0.110  MCC=0.101±0.220  G-Mean=0.507±0.097  AUC=N/A
#     LDA                        Acc=0.436±0.123  F1=0.420±0.122  MCC=0.158±0.189  G-Mean=0.555±0.108  AUC=0.628±0.069
#     QDA                        Acc=0.347±0.190  F1=0.339±0.190  MCC=0.016±0.298  G-Mean=0.473±0.161  AUC=0.527±0.125
#     LightGBM                   Acc=0.484±0.105  F1=0.467±0.120  MCC=0.240±0.174  G-Mean=0.605±0.095  AUC=0.660±0.115
#     XGBoost                    Acc=0.352±0.099  F1=0.339±0.090  MCC=0.023±0.154  G-Mean=0.481±0.083  AUC=0.568±0.060
#     VotingSoft                 Acc=0.402±0.106  F1=0.386±0.101  MCC=0.109±0.167  G-Mean=0.530±0.093  AUC=0.657±0.071
#     VotingHard                 Acc=0.423±0.114  F1=0.399±0.111  MCC=0.136±0.197  G-Mean=0.546±0.103  AUC=N/A
#     Stacking                   Acc=0.532±0.137  F1=0.507±0.132  MCC=0.304±0.208  G-Mean=0.628±0.110  AUC=0.708±0.059
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS3_RFE  |  shape=(99, 32)
# ======================================================================
#     RandomForest               Acc=0.496±0.115  F1=0.474±0.126  MCC=0.240±0.189  G-Mean=0.597±0.105  AUC=0.675±0.117
#     ExtraTrees                 Acc=0.496±0.139  F1=0.477±0.128  MCC=0.244±0.227  G-Mean=0.600±0.118  AUC=0.661±0.122
#     Bagging                    Acc=0.516±0.152  F1=0.493±0.162  MCC=0.278±0.242  G-Mean=0.619±0.131  AUC=0.671±0.102
#     GradientBoosting           Acc=0.433±0.124  F1=0.412±0.124  MCC=0.148±0.200  G-Mean=0.547±0.112  AUC=0.619±0.123
#     LogisticRegression         Acc=0.414±0.145  F1=0.389±0.118  MCC=0.128±0.227  G-Mean=0.532±0.115  AUC=0.570±0.085
#     RidgeClassifier            Acc=0.364±0.138  F1=0.349±0.122  MCC=0.047±0.206  G-Mean=0.488±0.114  AUC=N/A
#     DecisionTree               Acc=0.377±0.189  F1=0.352±0.198  MCC=0.050±0.297  G-Mean=0.491±0.168  AUC=0.526±0.140
#     NaiveBayes                 Acc=0.516±0.170  F1=0.491±0.166  MCC=0.268±0.282  G-Mean=0.615±0.150  AUC=0.726±0.100
#     Perceptron                 Acc=0.386±0.131  F1=0.314±0.129  MCC=0.073±0.215  G-Mean=0.500±0.110  AUC=N/A
#     SGDClassifier              Acc=0.366±0.142  F1=0.303±0.135  MCC=0.030±0.236  G-Mean=0.484±0.122  AUC=N/A
#     PassiveAggressive          Acc=0.366±0.149  F1=0.339±0.147  MCC=0.062±0.235  G-Mean=0.494±0.121  AUC=N/A
#     LDA                        Acc=0.364±0.138  F1=0.341±0.127  MCC=0.047±0.208  G-Mean=0.488±0.116  AUC=0.550±0.097
#     QDA                        Acc=0.200±0.118  F1=0.177±0.118  MCC=-0.200±0.186  G-Mean=0.328±0.149  AUC=0.403±0.091
#     LightGBM                   Acc=0.434±0.110  F1=0.420±0.112  MCC=0.145±0.168  G-Mean=0.551±0.096  AUC=0.572±0.108
#     XGBoost                    Acc=0.404±0.101  F1=0.382±0.100  MCC=0.098±0.163  G-Mean=0.525±0.090  AUC=0.631±0.102
#     VotingSoft                 Acc=0.464±0.100  F1=0.450±0.100  MCC=0.192±0.159  G-Mean=0.576±0.088  AUC=0.655±0.113
#     VotingHard                 Acc=0.496±0.106  F1=0.472±0.117  MCC=0.241±0.173  G-Mean=0.600±0.095  AUC=N/A
#     Stacking                   Acc=0.453±0.133  F1=0.434±0.135  MCC=0.185±0.200  G-Mean=0.570±0.110  AUC=0.601±0.123
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS4_MutualInfo  |  shape=(99, 4)
# ======================================================================
#     RandomForest               Acc=0.392±0.168  F1=0.357±0.182  MCC=0.094±0.262  G-Mean=0.522±0.142  AUC=0.604±0.150
#     ExtraTrees                 Acc=0.372±0.153  F1=0.347±0.160  MCC=0.065±0.247  G-Mean=0.505±0.137  AUC=0.597±0.146
#     Bagging                    Acc=0.433±0.153  F1=0.410±0.163  MCC=0.173±0.271  G-Mean=0.560±0.135  AUC=0.597±0.149
#     GradientBoosting           Acc=0.372±0.208  F1=0.345±0.215  MCC=0.076±0.344  G-Mean=0.503±0.185  AUC=0.591±0.139
#     LogisticRegression         Acc=0.434±0.110  F1=0.388±0.104  MCC=0.188±0.192  G-Mean=0.566±0.098  AUC=0.644±0.132
#     RidgeClassifier            Acc=0.423±0.114  F1=0.369±0.104  MCC=0.153±0.205  G-Mean=0.551±0.101  AUC=N/A
#     DecisionTree               Acc=0.352±0.161  F1=0.324±0.169  MCC=0.032±0.260  G-Mean=0.484±0.150  AUC=0.595±0.146
#     NaiveBayes                 Acc=0.484±0.131  F1=0.480±0.136  MCC=0.241±0.224  G-Mean=0.601±0.115  AUC=0.674±0.119
#     Perceptron                 Acc=0.404±0.065  F1=0.307±0.076  MCC=0.140±0.106  G-Mean=0.538±0.049  AUC=N/A
#     SGDClassifier              Acc=0.393±0.102  F1=0.307±0.124  MCC=0.103±0.190  G-Mean=0.512±0.084  AUC=N/A
#     PassiveAggressive          Acc=0.443±0.172  F1=0.373±0.194  MCC=0.158±0.280  G-Mean=0.552±0.141  AUC=N/A
#     LDA                        Acc=0.434±0.127  F1=0.398±0.144  MCC=0.183±0.207  G-Mean=0.568±0.105  AUC=0.642±0.135
#     QDA                        Acc=0.423±0.176  F1=0.393±0.189  MCC=0.153±0.289  G-Mean=0.552±0.151  AUC=0.645±0.137
#     LightGBM                   Acc=0.453±0.140  F1=0.433±0.137  MCC=0.200±0.230  G-Mean=0.581±0.119  AUC=0.607±0.070
#     XGBoost                    Acc=0.392±0.173  F1=0.360±0.185  MCC=0.108±0.283  G-Mean=0.528±0.151  AUC=0.597±0.128
#     VotingSoft                 Acc=0.393±0.185  F1=0.360±0.196  MCC=0.110±0.303  G-Mean=0.528±0.160  AUC=0.606±0.135
#     VotingHard                 Acc=0.362±0.154  F1=0.325±0.171  MCC=0.048±0.244  G-Mean=0.498±0.133  AUC=N/A
#     Stacking                   Acc=0.283±0.134  F1=0.255±0.139  MCC=-0.069±0.202  G-Mean=0.425±0.125  AUC=0.532±0.122
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS5_RFImportance  |  shape=(99, 39)
# ======================================================================
#     RandomForest               Acc=0.486±0.119  F1=0.470±0.118  MCC=0.234±0.184  G-Mean=0.598±0.097  AUC=0.660±0.094
#     ExtraTrees                 Acc=0.404±0.135  F1=0.385±0.114  MCC=0.103±0.217  G-Mean=0.527±0.114  AUC=0.665±0.089
#     Bagging                    Acc=0.386±0.106  F1=0.352±0.107  MCC=0.092±0.179  G-Mean=0.518±0.100  AUC=0.634±0.088
#     GradientBoosting           Acc=0.446±0.139  F1=0.425±0.137  MCC=0.173±0.224  G-Mean=0.562±0.123  AUC=0.628±0.134
#     LogisticRegression         Acc=0.414±0.084  F1=0.388±0.099  MCC=0.116±0.130  G-Mean=0.531±0.074  AUC=0.566±0.113
#     RidgeClassifier            Acc=0.414±0.095  F1=0.386±0.103  MCC=0.116±0.148  G-Mean=0.529±0.082  AUC=N/A
#     DecisionTree               Acc=0.334±0.145  F1=0.305±0.147  MCC=-0.021±0.236  G-Mean=0.454±0.135  AUC=0.494±0.107
#     NaiveBayes                 Acc=0.484±0.145  F1=0.470±0.135  MCC=0.229±0.256  G-Mean=0.598±0.136  AUC=0.739±0.089
#     Perceptron                 Acc=0.354±0.096  F1=0.329±0.111  MCC=0.051±0.175  G-Mean=0.496±0.089  AUC=N/A
#     SGDClassifier              Acc=0.364±0.095  F1=0.339±0.092  MCC=0.072±0.175  G-Mean=0.496±0.096  AUC=N/A
#     PassiveAggressive          Acc=0.396±0.136  F1=0.366±0.139  MCC=0.110±0.218  G-Mean=0.519±0.126  AUC=N/A
#     LDA                        Acc=0.426±0.129  F1=0.395±0.132  MCC=0.143±0.211  G-Mean=0.539±0.113  AUC=0.552±0.117
#     QDA                        Acc=0.334±0.104  F1=0.286±0.105  MCC=0.010±0.183  G-Mean=0.463±0.091  AUC=0.496±0.077
#     LightGBM                   Acc=0.394±0.115  F1=0.385±0.114  MCC=0.094±0.177  G-Mean=0.523±0.100  AUC=0.552±0.092
#     XGBoost                    Acc=0.414±0.095  F1=0.384±0.085  MCC=0.119±0.162  G-Mean=0.534±0.086  AUC=0.578±0.090
#     VotingSoft                 Acc=0.434±0.100  F1=0.416±0.090  MCC=0.157±0.167  G-Mean=0.557±0.091  AUC=0.640±0.108
#     VotingHard                 Acc=0.394±0.115  F1=0.384±0.107  MCC=0.094±0.176  G-Mean=0.523±0.099  AUC=N/A
#     Stacking                   Acc=0.473±0.123  F1=0.464±0.130  MCC=0.210±0.195  G-Mean=0.586±0.106  AUC=0.649±0.096
#
# ======================================================================
#   Combo: B4_SMOTE + FS1_Correlation  |  shape=(555, 47)
# ======================================================================
#     RandomForest               Acc=0.706±0.047  F1=0.697±0.049  MCC=0.564±0.070  G-Mean=0.776±0.036  AUC=0.868±0.028
#     ExtraTrees                 Acc=0.728±0.048  F1=0.723±0.051  MCC=0.594±0.071  G-Mean=0.793±0.037  AUC=0.876±0.023
#     Bagging                    Acc=0.688±0.058  F1=0.679±0.061  MCC=0.538±0.085  G-Mean=0.762±0.045  AUC=0.852±0.039
#     GradientBoosting           Acc=0.681±0.046  F1=0.673±0.049  MCC=0.524±0.069  G-Mean=0.756±0.036  AUC=0.841±0.037
#     LogisticRegression         Acc=0.611±0.062  F1=0.607±0.060  MCC=0.419±0.093  G-Mean=0.701±0.049  AUC=0.779±0.043
#     RidgeClassifier            Acc=0.598±0.054  F1=0.583±0.057  MCC=0.405±0.084  G-Mean=0.691±0.044  AUC=N/A
#     DecisionTree               Acc=0.604±0.053  F1=0.590±0.052  MCC=0.410±0.081  G-Mean=0.696±0.041  AUC=0.703±0.039
#     NaiveBayes                 Acc=0.557±0.045  F1=0.550±0.046  MCC=0.341±0.067  G-Mean=0.658±0.036  AUC=0.738±0.054
#     Perceptron                 Acc=0.490±0.060  F1=0.436±0.074  MCC=0.280±0.089  G-Mean=0.603±0.049  AUC=N/A
#     SGDClassifier              Acc=0.551±0.078  F1=0.511±0.096  MCC=0.358±0.114  G-Mean=0.654±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.562±0.040  F1=0.533±0.049  MCC=0.372±0.068  G-Mean=0.663±0.034  AUC=N/A
#     LDA                        Acc=0.587±0.063  F1=0.579±0.063  MCC=0.386±0.097  G-Mean=0.683±0.052  AUC=0.777±0.051
#     QDA                        Acc=0.640±0.060  F1=0.648±0.055  MCC=0.462±0.089  G-Mean=0.724±0.047  AUC=0.810±0.039
#     LightGBM                   Acc=0.681±0.043  F1=0.675±0.043  MCC=0.524±0.065  G-Mean=0.756±0.033  AUC=0.858±0.036
#     XGBoost                    Acc=0.692±0.040  F1=0.687±0.041  MCC=0.540±0.061  G-Mean=0.765±0.032  AUC=0.864±0.025
#     VotingSoft                 Acc=0.697±0.056  F1=0.690±0.058  MCC=0.548±0.085  G-Mean=0.769±0.044  AUC=0.872±0.028
#     VotingHard                 Acc=0.724±0.053  F1=0.718±0.055  MCC=0.590±0.079  G-Mean=0.790±0.041  AUC=N/A
#     Stacking                   Acc=0.710±0.050  F1=0.707±0.052  MCC=0.567±0.075  G-Mean=0.778±0.039  AUC=0.865±0.034
#
# ======================================================================
#   Combo: B4_SMOTE + FS2_KBest  |  shape=(555, 12)
# ======================================================================
#     RandomForest               Acc=0.618±0.050  F1=0.605±0.053  MCC=0.433±0.076  G-Mean=0.706±0.040  AUC=0.816±0.039
#     ExtraTrees                 Acc=0.612±0.056  F1=0.601±0.061  MCC=0.423±0.085  G-Mean=0.702±0.046  AUC=0.801±0.037
#     Bagging                    Acc=0.614±0.042  F1=0.599±0.048  MCC=0.429±0.061  G-Mean=0.704±0.034  AUC=0.797±0.037
#     GradientBoosting           Acc=0.658±0.051  F1=0.652±0.054  MCC=0.491±0.075  G-Mean=0.738±0.040  AUC=0.813±0.029
#     LogisticRegression         Acc=0.528±0.039  F1=0.512±0.044  MCC=0.302±0.064  G-Mean=0.635±0.032  AUC=0.708±0.050
#     RidgeClassifier            Acc=0.496±0.037  F1=0.464±0.050  MCC=0.256±0.057  G-Mean=0.609±0.030  AUC=N/A
#     DecisionTree               Acc=0.616±0.055  F1=0.602±0.061  MCC=0.431±0.086  G-Mean=0.705±0.045  AUC=0.751±0.054
#     NaiveBayes                 Acc=0.533±0.061  F1=0.525±0.064  MCC=0.306±0.096  G-Mean=0.639±0.050  AUC=0.727±0.052
#     Perceptron                 Acc=0.490±0.072  F1=0.445±0.096  MCC=0.277±0.119  G-Mean=0.603±0.058  AUC=N/A
#     SGDClassifier              Acc=0.449±0.072  F1=0.391±0.080  MCC=0.206±0.126  G-Mean=0.569±0.061  AUC=N/A
#     PassiveAggressive          Acc=0.476±0.084  F1=0.396±0.110  MCC=0.250±0.122  G-Mean=0.590±0.069  AUC=N/A
#     LDA                        Acc=0.517±0.031  F1=0.503±0.040  MCC=0.284±0.048  G-Mean=0.626±0.025  AUC=0.706±0.045
#     QDA                        Acc=0.604±0.069  F1=0.592±0.068  MCC=0.411±0.107  G-Mean=0.695±0.055  AUC=0.764±0.042
#     LightGBM                   Acc=0.634±0.067  F1=0.626±0.069  MCC=0.457±0.100  G-Mean=0.719±0.053  AUC=0.807±0.037
#     XGBoost                    Acc=0.614±0.040  F1=0.601±0.043  MCC=0.427±0.062  G-Mean=0.704±0.033  AUC=0.789±0.037
#     VotingSoft                 Acc=0.634±0.052  F1=0.624±0.053  MCC=0.458±0.080  G-Mean=0.719±0.043  AUC=0.823±0.031
#     VotingHard                 Acc=0.621±0.051  F1=0.610±0.053  MCC=0.438±0.079  G-Mean=0.709±0.042  AUC=N/A
#     Stacking                   Acc=0.636±0.067  F1=0.631±0.072  MCC=0.458±0.101  G-Mean=0.720±0.054  AUC=0.826±0.037
#
# ======================================================================
#   Combo: B4_SMOTE + FS3_RFE  |  shape=(555, 32)
# ======================================================================
#     RandomForest               Acc=0.711±0.048  F1=0.699±0.053  MCC=0.574±0.069  G-Mean=0.780±0.038  AUC=0.880±0.024
#     ExtraTrees                 Acc=0.728±0.053  F1=0.718±0.059  MCC=0.596±0.078  G-Mean=0.792±0.043  AUC=0.887±0.025
#     Bagging                    Acc=0.692±0.061  F1=0.677±0.067  MCC=0.546±0.091  G-Mean=0.765±0.048  AUC=0.857±0.035
#     GradientBoosting           Acc=0.690±0.047  F1=0.683±0.051  MCC=0.538±0.071  G-Mean=0.763±0.038  AUC=0.849±0.033
#     LogisticRegression         Acc=0.598±0.055  F1=0.592±0.057  MCC=0.402±0.083  G-Mean=0.691±0.044  AUC=0.768±0.037
#     RidgeClassifier            Acc=0.577±0.051  F1=0.559±0.057  MCC=0.373±0.074  G-Mean=0.674±0.040  AUC=N/A
#     DecisionTree               Acc=0.669±0.047  F1=0.658±0.049  MCC=0.509±0.071  G-Mean=0.747±0.036  AUC=0.752±0.035
#     NaiveBayes                 Acc=0.575±0.065  F1=0.568±0.068  MCC=0.367±0.096  G-Mean=0.672±0.051  AUC=0.741±0.051
#     Perceptron                 Acc=0.514±0.048  F1=0.487±0.066  MCC=0.298±0.072  G-Mean=0.626±0.040  AUC=N/A
#     SGDClassifier              Acc=0.533±0.051  F1=0.489±0.065  MCC=0.340±0.072  G-Mean=0.639±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.535±0.051  F1=0.489±0.054  MCC=0.347±0.082  G-Mean=0.641±0.043  AUC=N/A
#     LDA                        Acc=0.595±0.056  F1=0.585±0.059  MCC=0.397±0.085  G-Mean=0.689±0.045  AUC=0.765±0.038
#     QDA                        Acc=0.677±0.055  F1=0.681±0.058  MCC=0.518±0.082  G-Mean=0.753±0.044  AUC=0.825±0.040
#     LightGBM                   Acc=0.697±0.055  F1=0.690±0.059  MCC=0.549±0.083  G-Mean=0.768±0.044  AUC=0.854±0.027
#     XGBoost                    Acc=0.703±0.043  F1=0.695±0.043  MCC=0.558±0.065  G-Mean=0.773±0.034  AUC=0.869±0.030
#     VotingSoft                 Acc=0.711±0.049  F1=0.704±0.054  MCC=0.570±0.075  G-Mean=0.780±0.040  AUC=0.877±0.027
#     VotingHard                 Acc=0.731±0.052  F1=0.722±0.058  MCC=0.602±0.076  G-Mean=0.795±0.042  AUC=N/A
#     Stacking                   Acc=0.722±0.061  F1=0.717±0.064  MCC=0.587±0.091  G-Mean=0.788±0.048  AUC=0.883±0.029
#
# ======================================================================
#   Combo: B4_SMOTE + FS4_MutualInfo  |  shape=(555, 4)
# ======================================================================
#     RandomForest               Acc=0.505±0.073  F1=0.500±0.071  MCC=0.261±0.113  G-Mean=0.616±0.059  AUC=0.707±0.054
#     ExtraTrees                 Acc=0.497±0.081  F1=0.492±0.080  MCC=0.250±0.125  G-Mean=0.609±0.066  AUC=0.708±0.053
#     Bagging                    Acc=0.499±0.076  F1=0.494±0.074  MCC=0.252±0.115  G-Mean=0.611±0.062  AUC=0.704±0.049
#     GradientBoosting           Acc=0.497±0.081  F1=0.492±0.078  MCC=0.250±0.127  G-Mean=0.609±0.066  AUC=0.710±0.052
#     LogisticRegression         Acc=0.519±0.084  F1=0.517±0.081  MCC=0.285±0.131  G-Mean=0.627±0.068  AUC=0.686±0.047
#     RidgeClassifier            Acc=0.472±0.044  F1=0.436±0.043  MCC=0.234±0.078  G-Mean=0.590±0.036  AUC=N/A
#     DecisionTree               Acc=0.494±0.082  F1=0.489±0.081  MCC=0.244±0.127  G-Mean=0.606±0.067  AUC=0.705±0.055
#     NaiveBayes                 Acc=0.488±0.048  F1=0.456±0.051  MCC=0.256±0.084  G-Mean=0.602±0.040  AUC=0.679±0.050
#     Perceptron                 Acc=0.418±0.056  F1=0.349±0.072  MCC=0.151±0.094  G-Mean=0.544±0.048  AUC=N/A
#     SGDClassifier              Acc=0.421±0.080  F1=0.342±0.102  MCC=0.160±0.156  G-Mean=0.547±0.070  AUC=N/A
#     PassiveAggressive          Acc=0.454±0.069  F1=0.405±0.096  MCC=0.212±0.107  G-Mean=0.575±0.059  AUC=N/A
#     LDA                        Acc=0.517±0.075  F1=0.515±0.071  MCC=0.284±0.118  G-Mean=0.626±0.061  AUC=0.685±0.047
#     QDA                        Acc=0.483±0.048  F1=0.463±0.048  MCC=0.243±0.090  G-Mean=0.597±0.041  AUC=0.687±0.048
#     LightGBM                   Acc=0.494±0.079  F1=0.491±0.074  MCC=0.247±0.126  G-Mean=0.606±0.064  AUC=0.696±0.054
#     XGBoost                    Acc=0.492±0.083  F1=0.487±0.081  MCC=0.244±0.134  G-Mean=0.605±0.068  AUC=0.708±0.057
#     VotingSoft                 Acc=0.501±0.080  F1=0.497±0.077  MCC=0.256±0.125  G-Mean=0.612±0.065  AUC=0.707±0.052
#     VotingHard                 Acc=0.497±0.075  F1=0.493±0.073  MCC=0.250±0.116  G-Mean=0.609±0.061  AUC=N/A
#     Stacking                   Acc=0.524±0.073  F1=0.524±0.075  MCC=0.289±0.110  G-Mean=0.632±0.059  AUC=0.705±0.040
#
# ======================================================================
#   Combo: B4_SMOTE + FS5_RFImportance  |  shape=(555, 40)
# ======================================================================
#     RandomForest               Acc=0.708±0.040  F1=0.699±0.044  MCC=0.566±0.060  G-Mean=0.777±0.032  AUC=0.871±0.029
#     ExtraTrees                 Acc=0.726±0.042  F1=0.719±0.046  MCC=0.593±0.062  G-Mean=0.791±0.034  AUC=0.874±0.031
#     Bagging                    Acc=0.697±0.053  F1=0.687±0.052  MCC=0.552±0.080  G-Mean=0.769±0.041  AUC=0.849±0.039
#     GradientBoosting           Acc=0.686±0.044  F1=0.679±0.045  MCC=0.532±0.067  G-Mean=0.760±0.035  AUC=0.848±0.036
#     LogisticRegression         Acc=0.605±0.068  F1=0.601±0.069  MCC=0.410±0.102  G-Mean=0.697±0.055  AUC=0.780±0.042
#     RidgeClassifier            Acc=0.587±0.048  F1=0.569±0.049  MCC=0.390±0.075  G-Mean=0.683±0.039  AUC=N/A
#     DecisionTree               Acc=0.607±0.051  F1=0.594±0.054  MCC=0.415±0.076  G-Mean=0.698±0.041  AUC=0.705±0.039
#     NaiveBayes                 Acc=0.570±0.057  F1=0.564±0.058  MCC=0.360±0.085  G-Mean=0.668±0.045  AUC=0.748±0.049
#     Perceptron                 Acc=0.562±0.032  F1=0.525±0.038  MCC=0.372±0.055  G-Mean=0.662±0.025  AUC=N/A
#     SGDClassifier              Acc=0.549±0.066  F1=0.516±0.075  MCC=0.355±0.101  G-Mean=0.652±0.054  AUC=N/A
#     PassiveAggressive          Acc=0.548±0.047  F1=0.513±0.063  MCC=0.352±0.069  G-Mean=0.650±0.039  AUC=N/A
#     LDA                        Acc=0.584±0.051  F1=0.577±0.050  MCC=0.378±0.077  G-Mean=0.680±0.041  AUC=0.772±0.047
#     QDA                        Acc=0.659±0.070  F1=0.666±0.065  MCC=0.492±0.102  G-Mean=0.739±0.055  AUC=0.817±0.043
#     LightGBM                   Acc=0.699±0.038  F1=0.693±0.037  MCC=0.551±0.058  G-Mean=0.771±0.029  AUC=0.859±0.030
#     XGBoost                    Acc=0.712±0.044  F1=0.706±0.047  MCC=0.570±0.068  G-Mean=0.780±0.035  AUC=0.869±0.027
#     VotingSoft                 Acc=0.710±0.051  F1=0.702±0.053  MCC=0.568±0.077  G-Mean=0.778±0.040  AUC=0.874±0.031
#     VotingHard                 Acc=0.717±0.047  F1=0.709±0.051  MCC=0.579±0.070  G-Mean=0.784±0.037  AUC=N/A
#     Stacking                   Acc=0.722±0.066  F1=0.720±0.067  MCC=0.586±0.099  G-Mean=0.788±0.052  AUC=0.880±0.037
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS1_Correlation  |  shape=(555, 47)
# ======================================================================
#     RandomForest               Acc=0.728±0.049  F1=0.724±0.049  MCC=0.594±0.073  G-Mean=0.793±0.037  AUC=0.868±0.029
#     ExtraTrees                 Acc=0.724±0.064  F1=0.720±0.065  MCC=0.589±0.097  G-Mean=0.790±0.049  AUC=0.873±0.033
#     Bagging                    Acc=0.706±0.028  F1=0.699±0.031  MCC=0.564±0.040  G-Mean=0.776±0.022  AUC=0.851±0.029
#     GradientBoosting           Acc=0.697±0.072  F1=0.691±0.073  MCC=0.549±0.108  G-Mean=0.769±0.056  AUC=0.860±0.036
#     LogisticRegression         Acc=0.656±0.044  F1=0.646±0.043  MCC=0.488±0.068  G-Mean=0.737±0.035  AUC=0.811±0.049
#     RidgeClassifier            Acc=0.630±0.045  F1=0.611±0.050  MCC=0.455±0.070  G-Mean=0.717±0.037  AUC=N/A
#     DecisionTree               Acc=0.638±0.066  F1=0.628±0.070  MCC=0.462±0.100  G-Mean=0.723±0.052  AUC=0.729±0.049
#     NaiveBayes                 Acc=0.566±0.073  F1=0.557±0.070  MCC=0.355±0.115  G-Mean=0.665±0.059  AUC=0.760±0.065
#     Perceptron                 Acc=0.551±0.078  F1=0.525±0.087  MCC=0.348±0.114  G-Mean=0.653±0.063  AUC=N/A
#     SGDClassifier              Acc=0.618±0.075  F1=0.582±0.090  MCC=0.460±0.097  G-Mean=0.707±0.059  AUC=N/A
#     PassiveAggressive          Acc=0.588±0.045  F1=0.573±0.045  MCC=0.394±0.068  G-Mean=0.682±0.036  AUC=N/A
#     LDA                        Acc=0.641±0.045  F1=0.630±0.043  MCC=0.468±0.069  G-Mean=0.725±0.036  AUC=0.806±0.051
#     QDA                        Acc=0.647±0.047  F1=0.655±0.044  MCC=0.473±0.070  G-Mean=0.729±0.037  AUC=0.818±0.034
#     LightGBM                   Acc=0.692±0.061  F1=0.689±0.058  MCC=0.540±0.093  G-Mean=0.765±0.047  AUC=0.852±0.041
#     XGBoost                    Acc=0.679±0.053  F1=0.674±0.051  MCC=0.521±0.081  G-Mean=0.755±0.041  AUC=0.859±0.035
#     VotingSoft                 Acc=0.699±0.067  F1=0.695±0.066  MCC=0.551±0.101  G-Mean=0.770±0.053  AUC=0.871±0.036
#     VotingHard                 Acc=0.726±0.049  F1=0.723±0.049  MCC=0.590±0.072  G-Mean=0.791±0.037  AUC=N/A
#     Stacking                   Acc=0.710±0.065  F1=0.709±0.064  MCC=0.567±0.098  G-Mean=0.778±0.051  AUC=0.872±0.037
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS2_KBest  |  shape=(555, 12)
# ======================================================================
#     RandomForest               Acc=0.672±0.041  F1=0.664±0.041  MCC=0.513±0.061  G-Mean=0.749±0.031  AUC=0.835±0.023
#     ExtraTrees                 Acc=0.656±0.038  F1=0.650±0.036  MCC=0.488±0.056  G-Mean=0.737±0.029  AUC=0.821±0.023
#     Bagging                    Acc=0.625±0.068  F1=0.614±0.075  MCC=0.442±0.101  G-Mean=0.712±0.054  AUC=0.815±0.035
#     GradientBoosting           Acc=0.653±0.056  F1=0.645±0.052  MCC=0.484±0.084  G-Mean=0.734±0.043  AUC=0.813±0.034
#     LogisticRegression         Acc=0.587±0.026  F1=0.575±0.024  MCC=0.386±0.039  G-Mean=0.683±0.020  AUC=0.754±0.035
#     RidgeClassifier            Acc=0.564±0.044  F1=0.524±0.044  MCC=0.367±0.071  G-Mean=0.664±0.033  AUC=N/A
#     DecisionTree               Acc=0.632±0.039  F1=0.626±0.041  MCC=0.452±0.058  G-Mean=0.718±0.031  AUC=0.733±0.034
#     NaiveBayes                 Acc=0.585±0.067  F1=0.578±0.068  MCC=0.383±0.103  G-Mean=0.680±0.054  AUC=0.764±0.043
#     Perceptron                 Acc=0.492±0.054  F1=0.417±0.064  MCC=0.287±0.072  G-Mean=0.605±0.043  AUC=N/A
#     SGDClassifier              Acc=0.485±0.055  F1=0.437±0.071  MCC=0.271±0.083  G-Mean=0.601±0.044  AUC=N/A
#     PassiveAggressive          Acc=0.434±0.054  F1=0.356±0.082  MCC=0.195±0.073  G-Mean=0.556±0.045  AUC=N/A
#     LDA                        Acc=0.577±0.042  F1=0.568±0.037  MCC=0.369±0.064  G-Mean=0.674±0.033  AUC=0.752±0.037
#     QDA                        Acc=0.614±0.033  F1=0.608±0.031  MCC=0.426±0.052  G-Mean=0.704±0.026  AUC=0.788±0.031
#     LightGBM                   Acc=0.656±0.058  F1=0.648±0.057  MCC=0.489±0.088  G-Mean=0.737±0.044  AUC=0.823±0.030
#     XGBoost                    Acc=0.669±0.057  F1=0.660±0.056  MCC=0.508±0.088  G-Mean=0.747±0.044  AUC=0.819±0.029
#     VotingSoft                 Acc=0.667±0.034  F1=0.659±0.030  MCC=0.505±0.053  G-Mean=0.745±0.025  AUC=0.838±0.026
#     VotingHard                 Acc=0.663±0.043  F1=0.655±0.045  MCC=0.499±0.065  G-Mean=0.742±0.033  AUC=N/A
#     Stacking                   Acc=0.652±0.041  F1=0.644±0.045  MCC=0.484±0.063  G-Mean=0.734±0.032  AUC=0.833±0.020
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS3_RFE  |  shape=(555, 32)
# ======================================================================
#     RandomForest               Acc=0.719±0.055  F1=0.711±0.058  MCC=0.583±0.081  G-Mean=0.786±0.043  AUC=0.878±0.026
#     ExtraTrees                 Acc=0.724±0.050  F1=0.720±0.051  MCC=0.589±0.076  G-Mean=0.790±0.040  AUC=0.882±0.031
#     Bagging                    Acc=0.695±0.026  F1=0.684±0.033  MCC=0.548±0.037  G-Mean=0.768±0.021  AUC=0.847±0.016
#     GradientBoosting           Acc=0.692±0.047  F1=0.685±0.046  MCC=0.541±0.072  G-Mean=0.765±0.037  AUC=0.850±0.039
#     LogisticRegression         Acc=0.613±0.059  F1=0.605±0.061  MCC=0.422±0.089  G-Mean=0.703±0.047  AUC=0.792±0.041
#     RidgeClassifier            Acc=0.598±0.068  F1=0.577±0.071  MCC=0.407±0.102  G-Mean=0.691±0.053  AUC=N/A
#     DecisionTree               Acc=0.654±0.051  F1=0.646±0.050  MCC=0.485±0.076  G-Mean=0.735±0.040  AUC=0.741±0.038
#     NaiveBayes                 Acc=0.577±0.062  F1=0.567±0.066  MCC=0.370±0.094  G-Mean=0.674±0.049  AUC=0.768±0.059
#     Perceptron                 Acc=0.532±0.057  F1=0.497±0.047  MCC=0.328±0.104  G-Mean=0.639±0.045  AUC=N/A
#     SGDClassifier              Acc=0.555±0.054  F1=0.521±0.056  MCC=0.370±0.092  G-Mean=0.657±0.045  AUC=N/A
#     PassiveAggressive          Acc=0.541±0.069  F1=0.513±0.071  MCC=0.340±0.109  G-Mean=0.644±0.056  AUC=N/A
#     LDA                        Acc=0.587±0.060  F1=0.581±0.061  MCC=0.384±0.091  G-Mean=0.683±0.047  AUC=0.784±0.044
#     QDA                        Acc=0.684±0.041  F1=0.687±0.046  MCC=0.529±0.062  G-Mean=0.758±0.033  AUC=0.834±0.027
#     LightGBM                   Acc=0.708±0.050  F1=0.703±0.049  MCC=0.564±0.076  G-Mean=0.777±0.039  AUC=0.859±0.036
#     XGBoost                    Acc=0.708±0.057  F1=0.706±0.054  MCC=0.564±0.087  G-Mean=0.777±0.045  AUC=0.861±0.039
#     VotingSoft                 Acc=0.713±0.058  F1=0.709±0.059  MCC=0.574±0.088  G-Mean=0.782±0.046  AUC=0.876±0.032
#     VotingHard                 Acc=0.712±0.049  F1=0.706±0.050  MCC=0.571±0.073  G-Mean=0.780±0.038  AUC=N/A
#     Stacking                   Acc=0.708±0.064  F1=0.707±0.064  MCC=0.563±0.096  G-Mean=0.777±0.051  AUC=0.876±0.030
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS4_MutualInfo  |  shape=(555, 4)
# ======================================================================
#     RandomForest               Acc=0.514±0.059  F1=0.492±0.051  MCC=0.292±0.103  G-Mean=0.624±0.047  AUC=0.720±0.046
#     ExtraTrees                 Acc=0.521±0.068  F1=0.511±0.075  MCC=0.291±0.104  G-Mean=0.629±0.055  AUC=0.720±0.044
#     Bagging                    Acc=0.507±0.079  F1=0.482±0.072  MCC=0.283±0.132  G-Mean=0.619±0.063  AUC=0.725±0.048
#     GradientBoosting           Acc=0.519±0.080  F1=0.512±0.084  MCC=0.287±0.121  G-Mean=0.628±0.065  AUC=0.717±0.043
#     LogisticRegression         Acc=0.530±0.076  F1=0.525±0.075  MCC=0.299±0.115  G-Mean=0.636±0.061  AUC=0.707±0.054
#     RidgeClassifier            Acc=0.526±0.047  F1=0.431±0.050  MCC=0.339±0.074  G-Mean=0.634±0.036  AUC=N/A
#     DecisionTree               Acc=0.521±0.068  F1=0.511±0.075  MCC=0.291±0.104  G-Mean=0.629±0.055  AUC=0.720±0.043
#     NaiveBayes                 Acc=0.524±0.061  F1=0.510±0.064  MCC=0.296±0.092  G-Mean=0.632±0.049  AUC=0.715±0.046
#     Perceptron                 Acc=0.441±0.075  F1=0.367±0.075  MCC=0.216±0.139  G-Mean=0.563±0.061  AUC=N/A
#     SGDClassifier              Acc=0.479±0.057  F1=0.418±0.069  MCC=0.258±0.087  G-Mean=0.594±0.045  AUC=N/A
#     PassiveAggressive          Acc=0.440±0.064  F1=0.357±0.103  MCC=0.207±0.109  G-Mean=0.558±0.054  AUC=N/A
#     LDA                        Acc=0.535±0.070  F1=0.531±0.069  MCC=0.307±0.106  G-Mean=0.640±0.057  AUC=0.706±0.054
#     QDA                        Acc=0.503±0.062  F1=0.416±0.039  MCC=0.294±0.108  G-Mean=0.614±0.048  AUC=0.713±0.046
#     LightGBM                   Acc=0.530±0.067  F1=0.519±0.075  MCC=0.304±0.101  G-Mean=0.637±0.054  AUC=0.715±0.039
#     XGBoost                    Acc=0.524±0.076  F1=0.515±0.083  MCC=0.296±0.114  G-Mean=0.632±0.061  AUC=0.719±0.046
#     VotingSoft                 Acc=0.521±0.068  F1=0.511±0.075  MCC=0.291±0.104  G-Mean=0.629±0.055  AUC=0.720±0.043
#     VotingHard                 Acc=0.521±0.068  F1=0.511±0.075  MCC=0.291±0.104  G-Mean=0.629±0.055  AUC=N/A
#     Stacking                   Acc=0.514±0.042  F1=0.454±0.044  MCC=0.299±0.078  G-Mean=0.623±0.033  AUC=0.700±0.046
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS5_RFImportance  |  shape=(555, 40)
# ======================================================================
#     RandomForest               Acc=0.722±0.058  F1=0.717±0.060  MCC=0.586±0.087  G-Mean=0.788±0.045  AUC=0.871±0.031
#     ExtraTrees                 Acc=0.724±0.060  F1=0.720±0.062  MCC=0.590±0.089  G-Mean=0.790±0.046  AUC=0.882±0.029
#     Bagging                    Acc=0.692±0.058  F1=0.686±0.060  MCC=0.541±0.086  G-Mean=0.765±0.045  AUC=0.844±0.028
#     GradientBoosting           Acc=0.696±0.064  F1=0.689±0.064  MCC=0.547±0.096  G-Mean=0.768±0.049  AUC=0.854±0.042
#     LogisticRegression         Acc=0.652±0.072  F1=0.644±0.074  MCC=0.482±0.108  G-Mean=0.734±0.057  AUC=0.812±0.053
#     RidgeClassifier            Acc=0.625±0.057  F1=0.606±0.056  MCC=0.448±0.089  G-Mean=0.713±0.046  AUC=N/A
#     DecisionTree               Acc=0.647±0.058  F1=0.639±0.060  MCC=0.474±0.086  G-Mean=0.730±0.044  AUC=0.736±0.042
#     NaiveBayes                 Acc=0.577±0.049  F1=0.565±0.048  MCC=0.371±0.077  G-Mean=0.674±0.038  AUC=0.768±0.064
#     Perceptron                 Acc=0.575±0.075  F1=0.562±0.089  MCC=0.380±0.106  G-Mean=0.671±0.059  AUC=N/A
#     SGDClassifier              Acc=0.600±0.035  F1=0.569±0.044  MCC=0.434±0.050  G-Mean=0.693±0.026  AUC=N/A
#     PassiveAggressive          Acc=0.575±0.051  F1=0.554±0.057  MCC=0.380±0.074  G-Mean=0.672±0.040  AUC=N/A
#     LDA                        Acc=0.634±0.056  F1=0.624±0.056  MCC=0.456±0.085  G-Mean=0.720±0.044  AUC=0.807±0.058
#     QDA                        Acc=0.665±0.045  F1=0.671±0.044  MCC=0.500±0.068  G-Mean=0.743±0.036  AUC=0.827±0.035
#     LightGBM                   Acc=0.677±0.060  F1=0.674±0.059  MCC=0.517±0.091  G-Mean=0.753±0.048  AUC=0.854±0.043
#     XGBoost                    Acc=0.697±0.055  F1=0.693±0.053  MCC=0.549±0.084  G-Mean=0.769±0.043  AUC=0.860±0.043
#     VotingSoft                 Acc=0.712±0.057  F1=0.707±0.058  MCC=0.569±0.086  G-Mean=0.780±0.045  AUC=0.872±0.039
#     VotingHard                 Acc=0.722±0.054  F1=0.718±0.055  MCC=0.586±0.081  G-Mean=0.789±0.042  AUC=N/A
#     Stacking                   Acc=0.706±0.049  F1=0.703±0.052  MCC=0.563±0.072  G-Mean=0.776±0.038  AUC=0.870±0.024
#
# ======================================================================
#   Combo: B6_TomekLinks + FS1_Correlation  |  shape=(366, 47)
# ======================================================================
#     RandomForest               Acc=0.620±0.070  F1=0.528±0.129  MCC=0.321±0.131  G-Mean=0.629±0.079  AUC=0.723±0.102
#     ExtraTrees                 Acc=0.596±0.073  F1=0.496±0.117  MCC=0.274±0.140  G-Mean=0.604±0.076  AUC=0.730±0.099
#     Bagging                    Acc=0.555±0.077  F1=0.451±0.115  MCC=0.205±0.137  G-Mean=0.569±0.075  AUC=0.696±0.082
#     GradientBoosting           Acc=0.591±0.071  F1=0.492±0.116  MCC=0.281±0.125  G-Mean=0.607±0.079  AUC=0.701±0.089
#     LogisticRegression         Acc=0.585±0.070  F1=0.498±0.082  MCC=0.270±0.119  G-Mean=0.609±0.056  AUC=0.698±0.093
#     RidgeClassifier            Acc=0.563±0.078  F1=0.404±0.057  MCC=0.212±0.141  G-Mean=0.555±0.054  AUC=N/A
#     DecisionTree               Acc=0.503±0.076  F1=0.433±0.072  MCC=0.138±0.126  G-Mean=0.552±0.060  AUC=0.571±0.054
#     NaiveBayes                 Acc=0.558±0.129  F1=0.530±0.146  MCC=0.280±0.205  G-Mean=0.655±0.120  AUC=0.720±0.103
#     Perceptron                 Acc=0.473±0.066  F1=0.342±0.089  MCC=0.106±0.119  G-Mean=0.511±0.067  AUC=N/A
#     SGDClassifier              Acc=0.528±0.067  F1=0.465±0.072  MCC=0.205±0.107  G-Mean=0.596±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.519±0.060  F1=0.370±0.081  MCC=0.176±0.141  G-Mean=0.538±0.060  AUC=N/A
#     LDA                        Acc=0.596±0.070  F1=0.524±0.088  MCC=0.287±0.130  G-Mean=0.622±0.067  AUC=0.694±0.099
#     QDA                        Acc=0.506±0.078  F1=0.352±0.057  MCC=0.098±0.156  G-Mean=0.509±0.060  AUC=0.550±0.063
#     LightGBM                   Acc=0.588±0.100  F1=0.487±0.116  MCC=0.274±0.186  G-Mean=0.607±0.098  AUC=0.722±0.103
#     XGBoost                    Acc=0.568±0.099  F1=0.471±0.133  MCC=0.235±0.182  G-Mean=0.591±0.101  AUC=0.687±0.103
#     VotingSoft                 Acc=0.591±0.102  F1=0.491±0.136  MCC=0.276±0.189  G-Mean=0.601±0.097  AUC=0.730±0.096
#     VotingHard                 Acc=0.609±0.060  F1=0.504±0.109  MCC=0.301±0.115  G-Mean=0.614±0.066  AUC=N/A
#     Stacking                   Acc=0.585±0.058  F1=0.459±0.118  MCC=0.251±0.114  G-Mean=0.586±0.072  AUC=0.701±0.089
#
# ======================================================================
# ...
#     LDA                        Acc=0.618±0.087  F1=0.602±0.089  MCC=0.431±0.131  G-Mean=0.704±0.069  AUC=0.790±0.058
#     QDA                        Acc=0.648±0.064  F1=0.651±0.061  MCC=0.478±0.091  G-Mean=0.729±0.050  AUC=0.820±0.030
#     LightGBM                   Acc=0.703±0.068  F1=0.691±0.070  MCC=0.558±0.101  G-Mean=0.771±0.052  AUC=0.879±0.036
#     XGBoost                    Acc=0.704±0.076  F1=0.691±0.081  MCC=0.561±0.114  G-Mean=0.772±0.059  AUC=0.873±0.040
#     VotingSoft                 Acc=0.701±0.058  F1=0.688±0.060  MCC=0.555±0.086  G-Mean=0.769±0.045  AUC=0.892±0.031
#     VotingHard                 Acc=0.746±0.053  F1=0.733±0.055  MCC=0.623±0.080  G-Mean=0.804±0.041  AUC=N/A
#     Stacking                   Acc=0.731±0.046  F1=0.723±0.048  MCC=0.602±0.072  G-Mean=0.793±0.036  AUC=0.894±0.029
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS2_KBest  |  shape=(531, 12)
# ======================================================================
#     RandomForest               Acc=0.627±0.061  F1=0.617±0.065  MCC=0.447±0.091  G-Mean=0.712±0.049  AUC=0.832±0.029
#     ExtraTrees                 Acc=0.629±0.069  F1=0.621±0.072  MCC=0.450±0.106  G-Mean=0.713±0.056  AUC=0.823±0.029
#     Bagging                    Acc=0.603±0.087  F1=0.585±0.091  MCC=0.411±0.132  G-Mean=0.692±0.070  AUC=0.805±0.034
#     GradientBoosting           Acc=0.637±0.048  F1=0.630±0.048  MCC=0.461±0.075  G-Mean=0.720±0.038  AUC=0.805±0.032
#     LogisticRegression         Acc=0.544±0.069  F1=0.528±0.073  MCC=0.323±0.105  G-Mean=0.646±0.055  AUC=0.710±0.071
#     RidgeClassifier            Acc=0.497±0.071  F1=0.462±0.074  MCC=0.255±0.110  G-Mean=0.606±0.057  AUC=N/A
#     DecisionTree               Acc=0.612±0.057  F1=0.600±0.063  MCC=0.424±0.087  G-Mean=0.700±0.046  AUC=0.745±0.042
#     NaiveBayes                 Acc=0.537±0.074  F1=0.525±0.081  MCC=0.310±0.114  G-Mean=0.641±0.061  AUC=0.731±0.057
#     Perceptron                 Acc=0.427±0.083  F1=0.365±0.078  MCC=0.174±0.146  G-Mean=0.552±0.066  AUC=N/A
#     SGDClassifier              Acc=0.429±0.074  F1=0.357±0.092  MCC=0.195±0.107  G-Mean=0.554±0.057  AUC=N/A
#     PassiveAggressive          Acc=0.403±0.072  F1=0.312±0.097  MCC=0.150±0.141  G-Mean=0.532±0.057  AUC=N/A
#     LDA                        Acc=0.535±0.064  F1=0.521±0.066  MCC=0.308±0.098  G-Mean=0.638±0.051  AUC=0.706±0.065
#     QDA                        Acc=0.601±0.053  F1=0.589±0.053  MCC=0.404±0.080  G-Mean=0.691±0.041  AUC=0.769±0.042
#     LightGBM                   Acc=0.629±0.044  F1=0.619±0.046  MCC=0.448±0.066  G-Mean=0.713±0.035  AUC=0.805±0.034
#     XGBoost                    Acc=0.625±0.059  F1=0.614±0.065  MCC=0.443±0.089  G-Mean=0.710±0.048  AUC=0.804±0.025
#     VotingSoft                 Acc=0.635±0.053  F1=0.626±0.056  MCC=0.458±0.082  G-Mean=0.718±0.043  AUC=0.828±0.025
#     VotingHard                 Acc=0.629±0.060  F1=0.619±0.063  MCC=0.450±0.092  G-Mean=0.713±0.049  AUC=N/A
#     Stacking                   Acc=0.657±0.058  F1=0.653±0.058  MCC=0.490±0.087  G-Mean=0.736±0.046  AUC=0.831±0.019
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS3_RFE  |  shape=(531, 32)
# ======================================================================
#     RandomForest               Acc=0.742±0.064  F1=0.728±0.068  MCC=0.620±0.094  G-Mean=0.802±0.049  AUC=0.898±0.034
#     ExtraTrees                 Acc=0.753±0.059  F1=0.740±0.063  MCC=0.635±0.086  G-Mean=0.810±0.045  AUC=0.904±0.026
#     Bagging                    Acc=0.691±0.072  F1=0.677±0.078  MCC=0.543±0.107  G-Mean=0.762±0.055  AUC=0.856±0.044
#     GradientBoosting           Acc=0.687±0.058  F1=0.676±0.062  MCC=0.538±0.084  G-Mean=0.760±0.045  AUC=0.858±0.042
#     LogisticRegression         Acc=0.612±0.073  F1=0.602±0.076  MCC=0.422±0.111  G-Mean=0.700±0.058  AUC=0.774±0.061
#     RidgeClassifier            Acc=0.592±0.079  F1=0.573±0.078  MCC=0.394±0.120  G-Mean=0.683±0.062  AUC=N/A
#     DecisionTree               Acc=0.652±0.051  F1=0.636±0.054  MCC=0.482±0.075  G-Mean=0.731±0.040  AUC=0.736±0.038
#     NaiveBayes                 Acc=0.580±0.063  F1=0.573±0.060  MCC=0.376±0.097  G-Mean=0.676±0.050  AUC=0.748±0.050
#     Perceptron                 Acc=0.537±0.077  F1=0.504±0.096  MCC=0.333±0.104  G-Mean=0.643±0.060  AUC=N/A
#     SGDClassifier              Acc=0.514±0.082  F1=0.478±0.101  MCC=0.315±0.115  G-Mean=0.626±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.510±0.085  F1=0.475±0.125  MCC=0.289±0.125  G-Mean=0.621±0.066  AUC=N/A
#     LDA                        Acc=0.612±0.090  F1=0.602±0.092  MCC=0.422±0.135  G-Mean=0.700±0.071  AUC=0.773±0.059
#     QDA                        Acc=0.667±0.030  F1=0.666±0.031  MCC=0.503±0.044  G-Mean=0.744±0.024  AUC=0.837±0.028
#     LightGBM                   Acc=0.702±0.084  F1=0.690±0.086  MCC=0.558±0.127  G-Mean=0.770±0.065  AUC=0.869±0.049
#     XGBoost                    Acc=0.701±0.083  F1=0.686±0.087  MCC=0.557±0.123  G-Mean=0.769±0.063  AUC=0.868±0.048
#     VotingSoft                 Acc=0.719±0.061  F1=0.706±0.065  MCC=0.584±0.089  G-Mean=0.784±0.047  AUC=0.894±0.039
#     VotingHard                 Acc=0.729±0.067  F1=0.714±0.072  MCC=0.600±0.099  G-Mean=0.791±0.051  AUC=N/A
#     Stacking                   Acc=0.757±0.037  F1=0.750±0.038  MCC=0.640±0.053  G-Mean=0.814±0.028  AUC=0.902±0.027
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS4_MutualInfo  |  shape=(531, 4)
# ======================================================================
#     RandomForest               Acc=0.527±0.062  F1=0.517±0.064  MCC=0.298±0.091  G-Mean=0.633±0.048  AUC=0.710±0.048
#     ExtraTrees                 Acc=0.512±0.061  F1=0.503±0.062  MCC=0.274±0.091  G-Mean=0.621±0.048  AUC=0.713±0.047
#     Bagging                    Acc=0.537±0.064  F1=0.528±0.071  MCC=0.312±0.094  G-Mean=0.641±0.050  AUC=0.702±0.040
#     GradientBoosting           Acc=0.529±0.061  F1=0.519±0.064  MCC=0.301±0.091  G-Mean=0.635±0.048  AUC=0.714±0.048
#     LogisticRegression         Acc=0.486±0.059  F1=0.413±0.064  MCC=0.253±0.098  G-Mean=0.595±0.049  AUC=0.678±0.042
#     RidgeClassifier            Acc=0.478±0.053  F1=0.392±0.052  MCC=0.245±0.090  G-Mean=0.589±0.044  AUC=N/A
#     DecisionTree               Acc=0.512±0.061  F1=0.503±0.062  MCC=0.274±0.091  G-Mean=0.621±0.048  AUC=0.713±0.047
#     NaiveBayes                 Acc=0.520±0.064  F1=0.513±0.068  MCC=0.285±0.094  G-Mean=0.629±0.050  AUC=0.685±0.044
#     Perceptron                 Acc=0.386±0.062  F1=0.296±0.077  MCC=0.104±0.111  G-Mean=0.517±0.049  AUC=N/A
#     SGDClassifier              Acc=0.427±0.069  F1=0.366±0.104  MCC=0.171±0.107  G-Mean=0.553±0.056  AUC=N/A
#     PassiveAggressive          Acc=0.377±0.068  F1=0.273±0.093  MCC=0.093±0.127  G-Mean=0.512±0.053  AUC=N/A
#     LDA                        Acc=0.486±0.059  F1=0.413±0.064  MCC=0.253±0.098  G-Mean=0.595±0.049  AUC=0.678±0.043
#     QDA                        Acc=0.458±0.063  F1=0.440±0.070  MCC=0.193±0.100  G-Mean=0.576±0.054  AUC=0.673±0.046
#     LightGBM                   Acc=0.533±0.061  F1=0.526±0.067  MCC=0.308±0.089  G-Mean=0.640±0.048  AUC=0.711±0.046
#     XGBoost                    Acc=0.524±0.059  F1=0.514±0.062  MCC=0.292±0.087  G-Mean=0.631±0.046  AUC=0.714±0.047
#     VotingSoft                 Acc=0.527±0.061  F1=0.517±0.064  MCC=0.298±0.090  G-Mean=0.634±0.048  AUC=0.711±0.046
#     VotingHard                 Acc=0.524±0.062  F1=0.514±0.064  MCC=0.292±0.091  G-Mean=0.630±0.048  AUC=N/A
#     Stacking                   Acc=0.531±0.060  F1=0.523±0.064  MCC=0.304±0.089  G-Mean=0.637±0.047  AUC=0.720±0.039
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS5_RFImportance  |  shape=(531, 40)
# ======================================================================
#     RandomForest               Acc=0.718±0.059  F1=0.701±0.063  MCC=0.583±0.088  G-Mean=0.782±0.045  AUC=0.883±0.031
#     ExtraTrees                 Acc=0.755±0.047  F1=0.742±0.051  MCC=0.638±0.069  G-Mean=0.812±0.036  AUC=0.902±0.031
#     Bagging                    Acc=0.672±0.040  F1=0.653±0.043  MCC=0.516±0.059  G-Mean=0.747±0.030  AUC=0.846±0.033
#     GradientBoosting           Acc=0.693±0.042  F1=0.681±0.045  MCC=0.544±0.061  G-Mean=0.764±0.033  AUC=0.867±0.040
#     LogisticRegression         Acc=0.612±0.070  F1=0.602±0.067  MCC=0.421±0.105  G-Mean=0.700±0.054  AUC=0.791±0.049
#     RidgeClassifier            Acc=0.620±0.078  F1=0.599±0.074  MCC=0.437±0.121  G-Mean=0.705±0.061  AUC=N/A
#     DecisionTree               Acc=0.603±0.036  F1=0.583±0.042  MCC=0.410±0.053  G-Mean=0.692±0.028  AUC=0.700±0.027
#     NaiveBayes                 Acc=0.576±0.069  F1=0.573±0.068  MCC=0.371±0.106  G-Mean=0.673±0.055  AUC=0.759±0.057
#     Perceptron                 Acc=0.544±0.067  F1=0.506±0.089  MCC=0.348±0.089  G-Mean=0.648±0.053  AUC=N/A
#     SGDClassifier              Acc=0.546±0.092  F1=0.501±0.115  MCC=0.367±0.121  G-Mean=0.649±0.071  AUC=N/A
#     PassiveAggressive          Acc=0.533±0.085  F1=0.501±0.099  MCC=0.327±0.121  G-Mean=0.640±0.065  AUC=N/A
#     LDA                        Acc=0.627±0.080  F1=0.614±0.077  MCC=0.445±0.120  G-Mean=0.712±0.062  AUC=0.790±0.056
#     QDA                        Acc=0.640±0.046  F1=0.643±0.043  MCC=0.465±0.069  G-Mean=0.723±0.036  AUC=0.822±0.031
#     LightGBM                   Acc=0.714±0.076  F1=0.701±0.082  MCC=0.574±0.112  G-Mean=0.779±0.059  AUC=0.875±0.039
#     XGBoost                    Acc=0.701±0.076  F1=0.689±0.079  MCC=0.555±0.112  G-Mean=0.769±0.059  AUC=0.874±0.042
#     VotingSoft                 Acc=0.721±0.053  F1=0.708±0.059  MCC=0.587±0.076  G-Mean=0.785±0.041  AUC=0.892±0.034
#     VotingHard                 Acc=0.736±0.048  F1=0.722±0.051  MCC=0.611±0.071  G-Mean=0.797±0.037  AUC=N/A
#     Stacking                   Acc=0.731±0.052  F1=0.723±0.053  MCC=0.601±0.076  G-Mean=0.793±0.040  AUC=0.896±0.025
#
#
# -- Phase 3 Summary (top 30 combos by Accuracy) --
#                              Balancer+FS   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#          B1_RandomOverSampling + FS3_RFE     Stacking     0.767     0.765 0.653   0.823 0.890
# B1_RandomOverSampling + FS5_RFImportance RandomForest     0.762     0.757 0.646   0.819 0.893
#                  B7_SMOTETomek + FS3_RFE     Stacking     0.757     0.750 0.640   0.814 0.902
#          B1_RandomOverSampling + FS3_RFE RandomForest     0.755     0.747 0.636   0.813 0.893
#         B7_SMOTETomek + FS5_RFImportance   ExtraTrees     0.755     0.742 0.638   0.812 0.902
#                  B7_SMOTETomek + FS3_RFE   ExtraTrees     0.753     0.740 0.635   0.810 0.904
#  B1_RandomOverSampling + FS1_Correlation   ExtraTrees     0.753     0.750 0.630   0.812 0.897
# B1_RandomOverSampling + FS5_RFImportance     Stacking     0.751     0.749 0.628   0.811 0.887
#          B1_RandomOverSampling + FS3_RFE   ExtraTrees     0.751     0.747 0.630   0.811 0.900
#          B1_RandomOverSampling + FS3_RFE   VotingHard     0.749     0.744 0.627   0.809   NaN
#          B7_SMOTETomek + FS1_Correlation   VotingHard     0.746     0.733 0.623   0.804   NaN
# B1_RandomOverSampling + FS5_RFImportance   VotingSoft     0.744     0.739 0.618   0.805 0.896
#          B7_SMOTETomek + FS1_Correlation RandomForest     0.742     0.729 0.618   0.801 0.890
#                  B7_SMOTETomek + FS3_RFE RandomForest     0.742     0.728 0.620   0.802 0.898
# B1_RandomOverSampling + FS5_RFImportance   ExtraTrees     0.740     0.737 0.613   0.802 0.894
# B1_RandomOverSampling + FS5_RFImportance   VotingHard     0.740     0.737 0.612   0.802   NaN
#          B7_SMOTETomek + FS1_Correlation   ExtraTrees     0.740     0.727 0.615   0.800 0.890
#  B1_RandomOverSampling + FS1_Correlation   VotingHard     0.739     0.734 0.609   0.801   NaN
#          B1_RandomOverSampling + FS3_RFE     LightGBM     0.739     0.734 0.610   0.801 0.885
#  B1_RandomOverSampling + FS1_Correlation RandomForest     0.737     0.731 0.608   0.800 0.885
#          B1_RandomOverSampling + FS3_RFE   VotingSoft     0.737     0.731 0.608   0.800 0.895
#         B7_SMOTETomek + FS5_RFImportance   VotingHard     0.736     0.722 0.611   0.797   NaN
#  B1_RandomOverSampling + FS1_Correlation     Stacking     0.735     0.733 0.604   0.798 0.881
# B1_RandomOverSampling + FS5_RFImportance      XGBoost     0.733     0.725 0.604   0.797 0.888
#         B7_SMOTETomek + FS5_RFImportance     Stacking     0.731     0.723 0.601   0.793 0.896
#          B7_SMOTETomek + FS1_Correlation     Stacking     0.731     0.723 0.602   0.793 0.894
#                       B4_SMOTE + FS3_RFE   VotingHard     0.731     0.722 0.602   0.795   NaN
# B1_RandomOverSampling + FS5_RFImportance     LightGBM     0.730     0.724 0.597   0.794 0.886
#                  B7_SMOTETomek + FS3_RFE   VotingHard     0.729     0.714 0.600   0.791   NaN
#               B4_SMOTE + FS1_Correlation   ExtraTrees     0.728     0.723 0.594   0.793 0.876
#
# -- Phase 3: Best Classifier per Balancer+FS combo --
#                               Balancer+FS       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#           B1_RandomOverSampling + FS3_RFE         Stacking     0.767     0.765 0.653   0.823 0.890
#  B1_RandomOverSampling + FS5_RFImportance     RandomForest     0.762     0.757 0.646   0.819 0.893
#                   B7_SMOTETomek + FS3_RFE         Stacking     0.757     0.750 0.640   0.814 0.902
#          B7_SMOTETomek + FS5_RFImportance       ExtraTrees     0.755     0.742 0.638   0.812 0.902
#   B1_RandomOverSampling + FS1_Correlation       ExtraTrees     0.753     0.750 0.630   0.812 0.897
#           B7_SMOTETomek + FS1_Correlation       VotingHard     0.746     0.733 0.623   0.804   NaN
#                        B4_SMOTE + FS3_RFE       VotingHard     0.731     0.722 0.602   0.795   NaN
#      B5_BorderlineSMOTE + FS1_Correlation     RandomForest     0.728     0.724 0.594   0.793 0.868
#                B4_SMOTE + FS1_Correlation       ExtraTrees     0.728     0.723 0.594   0.793 0.876
#               B4_SMOTE + FS5_RFImportance       ExtraTrees     0.726     0.719 0.593   0.791 0.874
#              B5_BorderlineSMOTE + FS3_RFE       ExtraTrees     0.724     0.720 0.589   0.790 0.882
#     B5_BorderlineSMOTE + FS5_RFImportance       ExtraTrees     0.724     0.720 0.590   0.790 0.882
#         B1_RandomOverSampling + FS2_KBest         Stacking     0.715     0.710 0.577   0.783 0.867
#            B5_BorderlineSMOTE + FS2_KBest     RandomForest     0.672     0.664 0.513   0.749 0.835
#                      B4_SMOTE + FS2_KBest GradientBoosting     0.658     0.652 0.491   0.738 0.813
#                 B7_SMOTETomek + FS2_KBest         Stacking     0.657     0.653 0.490   0.736 0.831
#           B6_TomekLinks + FS1_Correlation     RandomForest     0.620     0.528 0.321   0.629 0.723
#                   B6_TomekLinks + FS3_RFE       ExtraTrees     0.612     0.512 0.304   0.619 0.733
#          B6_TomekLinks + FS5_RFImportance       VotingSoft     0.610     0.495 0.304   0.611 0.727
#    B1_RandomOverSampling + FS4_MutualInfo          XGBoost     0.606     0.607 0.412   0.697 0.755
#            B6_TomekLinks + FS4_MutualInfo  RidgeClassifier     0.604     0.420 0.281   0.579   NaN
#                 B6_TomekLinks + FS2_KBest              LDA     0.590     0.527 0.281   0.626 0.710
#            B7_SMOTETomek + FS4_MutualInfo          Bagging     0.537     0.528 0.312   0.641 0.702
#       B5_BorderlineSMOTE + FS4_MutualInfo              LDA     0.535     0.531 0.307   0.640 0.706
#        B2_RandomUnderSampling + FS2_KBest         Stacking     0.532     0.507 0.304   0.628 0.708
#                 B4_SMOTE + FS4_MutualInfo         Stacking     0.524     0.524 0.289   0.632 0.705
#          B2_RandomUnderSampling + FS3_RFE       NaiveBayes     0.516     0.491 0.268   0.615 0.726
#  B2_RandomUnderSampling + FS1_Correlation         Stacking     0.514     0.470 0.293   0.619 0.652
# B2_RandomUnderSampling + FS5_RFImportance     RandomForest     0.486     0.470 0.234   0.598 0.660
#   B2_RandomUnderSampling + FS4_MutualInfo       NaiveBayes     0.484     0.480 0.241   0.601 0.674

# %%
bal_name = "B1_RandomOverSampling"
fs_name = "FS5_RFImportance"

# Get the balanced dataset
balanced_df = balanced_datasets[bal_name]

# Apply the feature selection
fs_function = FEATURE_SELECTORS[fs_name]
processed_df = fs_function(balanced_df)

# Define the filename
filename = f"{bal_name} + {fs_name}.csv"

# Save to CSV
processed_df.to_csv(filename, index=False)

# Download the file
files.download(filename)
print(f"Downloaded: {filename}")
# Out:
# Downloaded: B1_RandomOverSampling + FS5_RFImportance.csv
