# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/CAST/blob/main/CAST_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Core ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.metrics import (
    accuracy_score, classification_report,
    matthews_corrcoef, roc_auc_score
)
from imblearn.metrics import geometric_mean_score
from sklearn.model_selection import StratifiedKFold
# Classifiers
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier,
    GradientBoostingClassifier, VotingClassifier, StackingClassifier
)
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron,
    SGDClassifier, PassiveAggressiveClassifier
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Balancing
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.combine import SMOTETomek


# optimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.feature_selection import RFECV


df = pd.read_csv('https://raw.githubusercontent.com/muajnstu/CAST/refs/heads/main/Perception/perception_category_2.csv')
print(f"Raw dataset shape : {df.shape}")
print(f"Target distribution:\n{df['CAST'].value_counts()}\n")

X_raw = df.drop(columns=['CAST'])
y_raw = df['CAST']
# Out:
# Raw dataset shape : (400, 47)
# Target distribution:
# CAST
# 0    215
# 1    117
# 2     68
# Name: count, dtype: int64

# %%
BALANCERS = {
    "B1_RandomOverSampling":  RandomOverSampler(random_state=42),
    "B2_RandomUnderSampling": RandomUnderSampler(random_state=42),
    "B3_ADASYN":              ADASYN(random_state=42),
    "B4_SMOTE":               SMOTE(random_state=42),
    "B5_BorderlineSMOTE":     BorderlineSMOTE(random_state=42),
    "B6_TomekLinks":          TomekLinks(),
    "B7_SMOTETomek":          SMOTETomek(random_state=42),
}


def apply_balancer(name, sampler, X, y):
    try:
        X_b, y_b = sampler.fit_resample(X, y)
        df_b = pd.DataFrame(X_b, columns=X.columns)
        df_b['CAST'] = y_b
        print(f"  {name:30s} -> shape {df_b.shape}  "
              f"dist: {dict(pd.Series(y_b).value_counts())}")
        return df_b
    except Exception as e:
        print(f"  {name:30s} -> FAILED: {e}")
        return None

# %%
CV      = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
CV_EST  = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
N_TOTAL = X_raw.shape[1]

def _cv_score(X_sel, y):
    """Mean 5-fold CV accuracy for a given feature subset."""
    return cross_val_score(CV_EST, X_sel, y, cv=CV,
                           scoring='accuracy', n_jobs=-1).mean()

def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# Tune FS1
print("\n" + "="*70)
print("  TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)")
print("="*70)

print("\n[FS1] Sweeping correlation threshold...")
thresholds   = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
fs1_results  = {}
for thr in thresholds:
    corr  = X_raw.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= thr)]
    X_sel = X_raw.drop(columns=drop)
    score = _cv_score(X_sel, y_raw)
    fs1_results[thr] = (score, X_sel.shape[1])
    print(f"  threshold={thr:.2f}  features={X_sel.shape[1]:3d}  CV_acc={score:.4f}")

best_fs1_thr   = max(fs1_results, key=lambda t: fs1_results[t][0])
best_fs1_score = fs1_results[best_fs1_thr][0]
best_fs1_feats = fs1_results[best_fs1_thr][1]
print(f"  >> BEST threshold={best_fs1_thr}  features={best_fs1_feats}  CV_acc={best_fs1_score:.4f}")

# Tune FS2: KBest (f_classif)
print("\n[FS2] Sweeping k for SelectKBest (f_classif)...")
k_range     = list(range(1, N_TOTAL + 1))
fs2_results = {}
for k in k_range:
    sel   = SelectKBest(f_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs2_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs2_k     = max(fs2_results, key=fs2_results.get)
best_fs2_score = fs2_results[best_fs2_k]
print(f"  >> BEST k={best_fs2_k}  CV_acc={best_fs2_score:.4f}")

# Tune FS3: RFE
print("\n[FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...")
rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1),
    step=1, cv=CV, scoring='accuracy', n_jobs=-1, min_features_to_select=1
)
rfecv.fit(X_raw, y_raw)
best_fs3_n     = rfecv.n_features_
best_fs3_score = rfecv.cv_results_['mean_test_score'][best_fs3_n - 1]
_rfecv_support = rfecv.support_
print(f"  >> BEST n_features={best_fs3_n}  CV_acc={best_fs3_score:.4f}")

# Tune FS4: Mutual Information
print("\n[FS4] Sweeping k for SelectKBest (mutual_info_classif)...")
fs4_results = {}
for k in k_range:
    sel   = SelectKBest(mutual_info_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs4_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs4_k     = max(fs4_results, key=fs4_results.get)
best_fs4_score = fs4_results[best_fs4_k]
print(f"  >> BEST k={best_fs4_k}  CV_acc={best_fs4_score:.4f}")

# Tune FS5: RF Importance cumulative threshold
print("\n[FS5] Sweeping cumulative importance threshold for RF feature importance...")
_rf_imp  = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
_rf_imp.fit(X_raw, y_raw)
imp_series = pd.Series(_rf_imp.feature_importances_, index=X_raw.columns)\
               .sort_values(ascending=False)
cum_imp = imp_series.cumsum()

cum_thresholds = [0.80, 0.85, 0.90, 0.95, 0.99]
fs5_results    = {}
for ct in cum_thresholds:
    top_feats = cum_imp[cum_imp <= ct].index.tolist()
    if len(top_feats) == 0:
        top_feats = [imp_series.index[0]]
    X_sel = X_raw[top_feats]
    score = _cv_score(X_sel, y_raw)
    fs5_results[ct] = (score, len(top_feats))
    print(f"  cum_threshold={ct:.2f}  features={len(top_feats):3d}  CV_acc={score:.4f}")

best_fs5_ct    = max(fs5_results, key=lambda t: fs5_results[t][0])
best_fs5_score = fs5_results[best_fs5_ct][0]
best_fs5_feats = fs5_results[best_fs5_ct][1]
print(f"  >> BEST cum_threshold={best_fs5_ct}  features={best_fs5_feats}  CV_acc={best_fs5_score:.4f}")

# Summary of tuned parameters
print("\n" + "="*70)
print("  TUNING SUMMARY")
print("="*70)
tuning_summary = pd.DataFrame([
    {"FS": "FS1_Correlation",  "Parameter": "threshold",        "Best_Value": best_fs1_thr,  "n_features": best_fs1_feats, "CV_Accuracy": round(best_fs1_score, 4)},
    {"FS": "FS2_KBest",        "Parameter": "k",                "Best_Value": best_fs2_k,    "n_features": best_fs2_k,     "CV_Accuracy": round(best_fs2_score, 4)},
    {"FS": "FS3_RFE",          "Parameter": "n_features (RFECV)","Best_Value": best_fs3_n,   "n_features": best_fs3_n,     "CV_Accuracy": round(best_fs3_score, 4)},
    {"FS": "FS4_MutualInfo",   "Parameter": "k",                "Best_Value": best_fs4_k,    "n_features": best_fs4_k,     "CV_Accuracy": round(best_fs4_score, 4)},
    {"FS": "FS5_RFImportance", "Parameter": "cum_threshold",    "Best_Value": best_fs5_ct,   "n_features": best_fs5_feats, "CV_Accuracy": round(best_fs5_score, 4)},
])
print(tuning_summary.to_string(index=False))
# Out:
# ======================================================================
#   TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)
# ======================================================================
#
# [FS1] Sweeping correlation threshold...
#   threshold=0.70  features= 14  CV_acc=0.6550
#   threshold=0.75  features= 21  CV_acc=0.6525
#   threshold=0.80  features= 38  CV_acc=0.6700
#   threshold=0.85  features= 43  CV_acc=0.6425
#   threshold=0.90  features= 46  CV_acc=0.6700
#   threshold=0.95  features= 46  CV_acc=0.6700
#   >> BEST threshold=0.8  features=38  CV_acc=0.6700
#
# [FS2] Sweeping k for SelectKBest (f_classif)...
#   k=  1  CV_acc=0.6100
#   k=  2  CV_acc=0.6325
#   k=  3  CV_acc=0.6125
#   k=  4  CV_acc=0.6225
#   k=  5  CV_acc=0.6250
#   k=  6  CV_acc=0.6450
#   k=  7  CV_acc=0.6300
#   k=  8  CV_acc=0.6275
#   k=  9  CV_acc=0.6350
#   k= 10  CV_acc=0.6025
#   k= 11  CV_acc=0.5950
#   k= 12  CV_acc=0.6375
#   k= 13  CV_acc=0.6050
#   k= 14  CV_acc=0.6425
#   k= 15  CV_acc=0.6450
#   k= 16  CV_acc=0.6525
#   k= 17  CV_acc=0.6350
#   k= 18  CV_acc=0.6450
#   k= 19  CV_acc=0.6475
#   k= 20  CV_acc=0.6450
#   k= 21  CV_acc=0.6550
#   k= 22  CV_acc=0.6575
#   k= 23  CV_acc=0.6575
#   k= 24  CV_acc=0.6525
#   k= 25  CV_acc=0.6575
#   k= 26  CV_acc=0.6600
#   k= 27  CV_acc=0.6225
#   k= 28  CV_acc=0.6525
#   k= 29  CV_acc=0.6625
#   k= 30  CV_acc=0.6725
#   k= 31  CV_acc=0.6650
#   k= 32  CV_acc=0.6625
#   k= 33  CV_acc=0.6675
#   k= 34  CV_acc=0.6600
#   k= 35  CV_acc=0.6875
#   k= 36  CV_acc=0.6550
#   k= 37  CV_acc=0.6400
#   k= 38  CV_acc=0.6575
#   k= 39  CV_acc=0.6450
#   k= 40  CV_acc=0.6625
#   k= 41  CV_acc=0.6750
#   k= 42  CV_acc=0.6575
#   k= 43  CV_acc=0.6700
#   k= 44  CV_acc=0.6600
#   k= 45  CV_acc=0.6525
#   k= 46  CV_acc=0.6700
#   >> BEST k=35  CV_acc=0.6875
#
# [FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...
#   >> BEST n_features=19  CV_acc=0.6850
#
# [FS4] Sweeping k for SelectKBest (mutual_info_classif)...
#   k=  1  CV_acc=0.5775
#   k=  2  CV_acc=0.6000
#   k=  3  CV_acc=0.6425
#   k=  4  CV_acc=0.6275
#   k=  5  CV_acc=0.6325
#   k=  6  CV_acc=0.6100
#   k=  7  CV_acc=0.6125
#   k=  8  CV_acc=0.6200
#   k=  9  CV_acc=0.5625
#   k= 10  CV_acc=0.6375
#   k= 11  CV_acc=0.6500
#   k= 12  CV_acc=0.6625
#   k= 13  CV_acc=0.6500
#   k= 14  CV_acc=0.6350
#   k= 15  CV_acc=0.6625
#   k= 16  CV_acc=0.6500
#   k= 17  CV_acc=0.6375
#   k= 18  CV_acc=0.6625
#   k= 19  CV_acc=0.6400
#   k= 20  CV_acc=0.6675
#   k= 21  CV_acc=0.6500
#   k= 22  CV_acc=0.6350
#   k= 23  CV_acc=0.6625
#   k= 24  CV_acc=0.6500
#   k= 25  CV_acc=0.6600
#   k= 26  CV_acc=0.6500
#   k= 27  CV_acc=0.6550
#   k= 28  CV_acc=0.6800
#   k= 29  CV_acc=0.6525
#   k= 30  CV_acc=0.6800
#   k= 31  CV_acc=0.6625
#   k= 32  CV_acc=0.6500
#   k= 33  CV_acc=0.6500
#   k= 34  CV_acc=0.6425
#   k= 35  CV_acc=0.6500
#   k= 36  CV_acc=0.6450
#   k= 37  CV_acc=0.6525
#   k= 38  CV_acc=0.6550
#   k= 39  CV_acc=0.6650
#   k= 40  CV_acc=0.6575
#   k= 41  CV_acc=0.6600
#   k= 42  CV_acc=0.6575
#   k= 43  CV_acc=0.6650
#   k= 44  CV_acc=0.6525
#   k= 45  CV_acc=0.6725
#   k= 46  CV_acc=0.6700
#   >> BEST k=28  CV_acc=0.6800
#
# [FS5] Sweeping cumulative importance threshold for RF feature importance...
#   cum_threshold=0.80  features= 32  CV_acc=0.6550
#   cum_threshold=0.85  features= 35  CV_acc=0.6650
#   cum_threshold=0.90  features= 39  CV_acc=0.6450
#   cum_threshold=0.95  features= 42  CV_acc=0.6625
#   cum_threshold=0.99  features= 45  CV_acc=0.6725
#   >> BEST cum_threshold=0.99  features=45  CV_acc=0.6725
#
# ======================================================================
#   TUNING SUMMARY
# ======================================================================
#               FS          Parameter  Best_Value  n_features  CV_Accuracy
#  FS1_Correlation          threshold        0.80          38       0.6700
#        FS2_KBest                  k       35.00          35       0.6875
#          FS3_RFE n_features (RFECV)       19.00          19       0.6850
#   FS4_MutualInfo                  k       28.00          28       0.6800
# FS5_RFImportance      cum_threshold        0.99          45       0.6725

# %%
def fs_correlation(data, target_col='CAST', threshold=best_fs1_thr):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    corr  = X_.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= threshold)]
    out   = X_.drop(columns=drop).copy(); out[target_col] = y_.values
    return out

def fs_kbest(data, target_col='CAST', k=best_fs2_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(f_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rfe(data, target_col='CAST', support=_rfecv_support):

    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    cols = X_.columns[support] if len(support) == X_.shape[1] else X_.columns
    out  = X_[cols].copy(); out[target_col] = y_.values
    return out

def fs_mi(data, target_col='CAST', k=best_fs4_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(mutual_info_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rf_importance(data, target_col='CAST', cum_threshold=best_fs5_ct):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    rf  = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_, y_)
    imp = pd.Series(rf.feature_importances_, index=X_.columns).sort_values(ascending=False)
    top = imp.cumsum()[imp.cumsum() <= cum_threshold].index.tolist()
    if len(top) == 0:
        top = [imp.index[0]]
    out = X_[top].copy(); out[target_col] = y_.values
    return out

FEATURE_SELECTORS = {
    "FS1_Correlation":  lambda d: fs_correlation(d),
    "FS2_KBest":        lambda d: fs_kbest(d),
    "FS3_RFE":          lambda d: fs_rfe(d),
    "FS4_MutualInfo":   lambda d: fs_mi(d),
    "FS5_RFImportance": lambda d: fs_rf_importance(d),
}

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True, n_splits=10):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    rows = []
    for clf_name, model in build_models().items():
        fold_metrics = {
            'Accuracy': [], 'Macro_F1': [], 'Macro_Precision': [],
            'Macro_Recall': [], 'MCC': [], 'G_Mean': [], 'AUC': []
        }

        for train_idx, test_idx in skf.split(X_, y_):
            X_tr, X_te = X_.iloc[train_idx], X_.iloc[test_idx]
            y_tr, y_te = y_.iloc[train_idx], y_.iloc[test_idx]

            try:
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_te)

                acc   = accuracy_score(y_te, y_pred)
                rep   = classification_report(y_te, y_pred, zero_division=0, output_dict=True)
                mcc   = matthews_corrcoef(y_te, y_pred)
                gmean = geometric_mean_score(y_te, y_pred, average='macro')

                n_classes = len(np.unique(y_te))
                auc = None
                try:
                    if hasattr(model, 'predict_proba'):
                        y_score = model.predict_proba(X_te)
                    else:
                        y_score = model.decision_function(X_te)
                        if n_classes <= 2:
                            y_score = y_score.reshape(-1, 1)

                    if n_classes == 2:
                        prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                        auc = roc_auc_score(y_te, prob)
                    else:
                        auc = roc_auc_score(
                            y_te, y_score,
                            multi_class='ovr', average='macro',
                            labels=np.unique(y_te)
                        )
                except Exception:
                    pass

                fold_metrics['Accuracy'].append(acc)
                fold_metrics['Macro_F1'].append(rep['macro avg']['f1-score'])
                fold_metrics['Macro_Precision'].append(rep['macro avg']['precision'])
                fold_metrics['Macro_Recall'].append(rep['macro avg']['recall'])
                fold_metrics['MCC'].append(mcc)
                fold_metrics['G_Mean'].append(gmean)
                if auc is not None:
                    fold_metrics['AUC'].append(auc)

            except Exception as e:
                if verbose:
                    print(f"    {clf_name:25s}  Fold ERROR: {e}")

        # Aggregate: mean ± std across folds
        def fmt(vals):
            if not vals:
                return None, None
            return round(np.mean(vals), 3), round(np.std(vals), 3)

        acc_m,   acc_s   = fmt(fold_metrics['Accuracy'])
        f1_m,    f1_s    = fmt(fold_metrics['Macro_F1'])
        prec_m,  prec_s  = fmt(fold_metrics['Macro_Precision'])
        rec_m,   rec_s   = fmt(fold_metrics['Macro_Recall'])
        mcc_m,   mcc_s   = fmt(fold_metrics['MCC'])
        gm_m,    gm_s    = fmt(fold_metrics['G_Mean'])
        auc_m,   auc_s   = fmt(fold_metrics['AUC'])

        rows.append({
            'Label':                label,
            'Classifier':           clf_name,
            'Accuracy':             acc_m,  'Accuracy_SD':   acc_s,
            'Macro_F1':             f1_m,   'Macro_F1_SD':   f1_s,
            'Macro_Precision':      prec_m, 'Macro_Prec_SD': prec_s,
            'Macro_Recall':         rec_m,  'Macro_Rec_SD':  rec_s,
            'MCC':                  mcc_m,  'MCC_SD':        mcc_s,
            'G_Mean':               gm_m,   'G_Mean_SD':     gm_s,
            'AUC':                  auc_m,  'AUC_SD':        auc_s,
        })

        if verbose:
            auc_str = f"{auc_m:.3f}±{auc_s:.3f}" if auc_m is not None else "N/A"
            print(f"    {clf_name:25s}  "
                  f"Acc={acc_m:.3f}±{acc_s:.3f}  "
                  f"F1={f1_m:.3f}±{f1_s:.3f}  "
                  f"MCC={mcc_m:.3f}±{mcc_s:.3f}  "
                  f"G-Mean={gm_m:.3f}±{gm_s:.3f}  "
                  f"AUC={auc_str}")

    return rows

# %%
def build_models():
    return {
        "RandomForest":       RandomForestClassifier(random_state=42),
        "ExtraTrees":         ExtraTreesClassifier(random_state=42),
        "Bagging":            BaggingClassifier(random_state=42),
        "GradientBoosting":   GradientBoostingClassifier(random_state=42),
        "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
        "RidgeClassifier":    RidgeClassifier(),
        "DecisionTree":       DecisionTreeClassifier(random_state=42),
        "NaiveBayes":         GaussianNB(),
        "Perceptron":         Perceptron(random_state=42),
        "SGDClassifier":      SGDClassifier(random_state=42),
        "PassiveAggressive":  PassiveAggressiveClassifier(random_state=42),
        "LDA":                LinearDiscriminantAnalysis(),
        "QDA":                QuadraticDiscriminantAnalysis(),
        "LightGBM":           LGBMClassifier(verbosity=-1, random_state=42),
        "XGBoost":            XGBClassifier(n_estimators=100, random_state=42,
                                            eval_metric='mlogloss',
                                            use_label_encoder=False, verbosity=0),
        "VotingSoft": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='soft', n_jobs=-1),
        "VotingHard": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='hard', n_jobs=-1),
        "Stacking": StackingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], final_estimator=LogisticRegression(max_iter=1000, random_state=42),
           cv=5, stack_method='predict_proba', n_jobs=-1),
    }

# %%
section_header("PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)")

print("\nApplying balancers to raw data...")
balanced_datasets = {}
for bal_name, sampler in BALANCERS.items():
    df_b = apply_balancer(bal_name, sampler, X_raw, y_raw)
    if df_b is not None:
        balanced_datasets[bal_name] = df_b

phase1_rows = []
for bal_name, bal_df in balanced_datasets.items():
    sub_header(f"Balancer: {bal_name}  |  shape={bal_df.shape}")
    rows = evaluate_dataset(bal_df, label=bal_name, verbose=True)
    phase1_rows.extend(rows)

phase1_df = pd.DataFrame(phase1_rows).dropna(subset=['Accuracy'])
phase1_df['Phase'] = 'Phase1_BalancingOnly'
phase1_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 1 Summary (top 20 by Accuracy) --")
p1_show = phase1_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer'})
METRICS = ['Accuracy','Macro_F1','MCC','G_Mean','AUC']
print(p1_show[['Balancer','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 1: Best Classifier per Balancer --")
best_p1 = (p1_show.groupby('Balancer', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer','Classifier'] + METRICS])
print(best_p1.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)
# ################################################################################
#
# Applying balancers to raw data...
#   B1_RandomOverSampling          -> shape (645, 47)  dist: {0: np.int64(215), 2: np.int64(215), 1: np.int64(215)}
#   B2_RandomUnderSampling         -> shape (204, 47)  dist: {0: np.int64(68), 1: np.int64(68), 2: np.int64(68)}
#   B3_ADASYN                      -> shape (643, 47)  dist: {0: np.int64(215), 2: np.int64(215), 1: np.int64(213)}
#   B4_SMOTE                       -> shape (645, 47)  dist: {0: np.int64(215), 2: np.int64(215), 1: np.int64(215)}
#   B5_BorderlineSMOTE             -> shape (645, 47)  dist: {0: np.int64(215), 2: np.int64(215), 1: np.int64(215)}
#   B6_TomekLinks                  -> shape (367, 47)  dist: {0: np.int64(199), 1: np.int64(100), 2: np.int64(68)}
#   B7_SMOTETomek                  -> shape (631, 47)  dist: {2: np.int64(214), 1: np.int64(209), 0: np.int64(208)}
#
# ======================================================================
#   Balancer: B1_RandomOverSampling  |  shape=(645, 47)
# ======================================================================
#     RandomForest               Acc=0.842±0.038  F1=0.840±0.039  MCC=0.768±0.057  G-Mean=0.880±0.029  AUC=0.960±0.027
#     ExtraTrees                 Acc=0.865±0.023  F1=0.865±0.023  MCC=0.802±0.033  G-Mean=0.898±0.017  AUC=0.966±0.020
#     Bagging                    Acc=0.826±0.049  F1=0.825±0.050  MCC=0.742±0.074  G-Mean=0.868±0.038  AUC=0.943±0.026
#     GradientBoosting           Acc=0.817±0.027  F1=0.817±0.027  MCC=0.728±0.042  G-Mean=0.861±0.021  AUC=0.930±0.030
#     LogisticRegression         Acc=0.651±0.032  F1=0.648±0.029  MCC=0.481±0.052  G-Mean=0.733±0.026  AUC=0.821±0.035
#     RidgeClassifier            Acc=0.631±0.045  F1=0.622±0.044  MCC=0.454±0.071  G-Mean=0.717±0.036  AUC=N/A
#     DecisionTree               Acc=0.819±0.045  F1=0.815±0.048  MCC=0.735±0.067  G-Mean=0.863±0.035  AUC=0.865±0.034
#     NaiveBayes                 Acc=0.600±0.070  F1=0.587±0.068  MCC=0.408±0.109  G-Mean=0.692±0.056  AUC=0.781±0.056
#     Perceptron                 Acc=0.576±0.061  F1=0.562±0.071  MCC=0.377±0.087  G-Mean=0.673±0.049  AUC=N/A
#     SGDClassifier              Acc=0.584±0.083  F1=0.565±0.096  MCC=0.393±0.120  G-Mean=0.679±0.066  AUC=N/A
#     PassiveAggressive          Acc=0.581±0.067  F1=0.559±0.077  MCC=0.392±0.095  G-Mean=0.678±0.053  AUC=N/A
#     LDA                        Acc=0.637±0.049  F1=0.634±0.047  MCC=0.461±0.076  G-Mean=0.722±0.039  AUC=0.816±0.037
#     QDA                        Acc=0.775±0.056  F1=0.774±0.056  MCC=0.667±0.083  G-Mean=0.829±0.043  AUC=0.898±0.024
#     LightGBM                   Acc=0.843±0.035  F1=0.842±0.036  MCC=0.769±0.054  G-Mean=0.881±0.027  AUC=0.957±0.022
#     XGBoost                    Acc=0.834±0.048  F1=0.833±0.049  MCC=0.756±0.073  G-Mean=0.874±0.037  AUC=0.956±0.027
#     VotingSoft                 Acc=0.851±0.029  F1=0.850±0.030  MCC=0.781±0.045  G-Mean=0.887±0.023  AUC=0.962±0.024
#     VotingHard                 Acc=0.849±0.028  F1=0.849±0.030  MCC=0.778±0.043  G-Mean=0.886±0.022  AUC=N/A
#     Stacking                   Acc=0.871±0.038  F1=0.872±0.037  MCC=0.812±0.056  G-Mean=0.903±0.029  AUC=0.964±0.023
#
# ======================================================================
#   Balancer: B2_RandomUnderSampling  |  shape=(204, 47)
# ======================================================================
#     RandomForest               Acc=0.609±0.104  F1=0.598±0.111  MCC=0.418±0.155  G-Mean=0.697±0.082  AUC=0.794±0.074
#     ExtraTrees                 Acc=0.574±0.092  F1=0.568±0.097  MCC=0.367±0.144  G-Mean=0.671±0.074  AUC=0.771±0.073
#     Bagging                    Acc=0.574±0.068  F1=0.566±0.068  MCC=0.368±0.107  G-Mean=0.670±0.055  AUC=0.752±0.068
#     GradientBoosting           Acc=0.584±0.076  F1=0.576±0.080  MCC=0.382±0.116  G-Mean=0.677±0.062  AUC=0.750±0.069
#     LogisticRegression         Acc=0.530±0.078  F1=0.513±0.091  MCC=0.302±0.120  G-Mean=0.636±0.066  AUC=0.740±0.071
#     RidgeClassifier            Acc=0.486±0.074  F1=0.457±0.083  MCC=0.236±0.113  G-Mean=0.598±0.062  AUC=N/A
#     DecisionTree               Acc=0.525±0.090  F1=0.517±0.099  MCC=0.293±0.136  G-Mean=0.631±0.074  AUC=0.635±0.073
#     NaiveBayes                 Acc=0.608±0.116  F1=0.593±0.118  MCC=0.420±0.176  G-Mean=0.696±0.095  AUC=0.775±0.074
#     Perceptron                 Acc=0.519±0.061  F1=0.481±0.063  MCC=0.306±0.104  G-Mean=0.628±0.051  AUC=N/A
#     SGDClassifier              Acc=0.495±0.074  F1=0.469±0.088  MCC=0.250±0.114  G-Mean=0.605±0.064  AUC=N/A
#     PassiveAggressive          Acc=0.505±0.068  F1=0.469±0.080  MCC=0.284±0.106  G-Mean=0.616±0.056  AUC=N/A
#     LDA                        Acc=0.501±0.071  F1=0.478±0.086  MCC=0.256±0.107  G-Mean=0.610±0.060  AUC=0.720±0.058
#     QDA                        Acc=0.362±0.114  F1=0.345±0.115  MCC=0.058±0.204  G-Mean=0.493±0.106  AUC=0.523±0.115
#     LightGBM                   Acc=0.624±0.099  F1=0.607±0.111  MCC=0.442±0.153  G-Mean=0.707±0.079  AUC=0.776±0.068
#     XGBoost                    Acc=0.594±0.093  F1=0.588±0.096  MCC=0.395±0.144  G-Mean=0.685±0.074  AUC=0.750±0.079
#     VotingSoft                 Acc=0.619±0.082  F1=0.610±0.088  MCC=0.433±0.125  G-Mean=0.705±0.065  AUC=0.788±0.068
#     VotingHard                 Acc=0.604±0.092  F1=0.594±0.099  MCC=0.411±0.141  G-Mean=0.694±0.073  AUC=N/A
#     Stacking                   Acc=0.594±0.071  F1=0.581±0.078  MCC=0.394±0.107  G-Mean=0.684±0.057  AUC=0.771±0.069
#
# ======================================================================
#   Balancer: B3_ADASYN  |  shape=(643, 47)
# ======================================================================
#     RandomForest               Acc=0.792±0.057  F1=0.789±0.058  MCC=0.692±0.083  G-Mean=0.842±0.044  AUC=0.906±0.029
#     ExtraTrees                 Acc=0.806±0.041  F1=0.804±0.042  MCC=0.712±0.062  G-Mean=0.853±0.032  AUC=0.914±0.028
#     Bagging                    Acc=0.739±0.071  F1=0.736±0.070  MCC=0.612±0.107  G-Mean=0.801±0.055  AUC=0.872±0.045
#     GradientBoosting           Acc=0.751±0.051  F1=0.749±0.051  MCC=0.630±0.078  G-Mean=0.811±0.039  AUC=0.881±0.034
#     LogisticRegression         Acc=0.591±0.054  F1=0.588±0.050  MCC=0.390±0.082  G-Mean=0.685±0.043  AUC=0.769±0.044
#     RidgeClassifier            Acc=0.585±0.058  F1=0.575±0.054  MCC=0.384±0.090  G-Mean=0.680±0.046  AUC=N/A
#     DecisionTree               Acc=0.641±0.096  F1=0.638±0.097  MCC=0.465±0.144  G-Mean=0.724±0.076  AUC=0.727±0.070
#     NaiveBayes                 Acc=0.509±0.091  F1=0.488±0.086  MCC=0.272±0.145  G-Mean=0.618±0.075  AUC=0.680±0.074
#     Perceptron                 Acc=0.543±0.083  F1=0.520±0.094  MCC=0.329±0.130  G-Mean=0.645±0.070  AUC=N/A
#     SGDClassifier              Acc=0.560±0.071  F1=0.545±0.067  MCC=0.351±0.110  G-Mean=0.659±0.057  AUC=N/A
#     PassiveAggressive          Acc=0.512±0.052  F1=0.482±0.062  MCC=0.288±0.077  G-Mean=0.622±0.041  AUC=N/A
#     LDA                        Acc=0.591±0.055  F1=0.585±0.051  MCC=0.392±0.084  G-Mean=0.685±0.043  AUC=0.770±0.046
#     QDA                        Acc=0.661±0.055  F1=0.655±0.058  MCC=0.494±0.081  G-Mean=0.740±0.043  AUC=0.839±0.031
#     LightGBM                   Acc=0.767±0.062  F1=0.764±0.063  MCC=0.652±0.093  G-Mean=0.823±0.049  AUC=0.895±0.030
#     XGBoost                    Acc=0.773±0.042  F1=0.771±0.044  MCC=0.663±0.064  G-Mean=0.828±0.033  AUC=0.902±0.030
#     VotingSoft                 Acc=0.785±0.041  F1=0.783±0.044  MCC=0.682±0.059  G-Mean=0.837±0.032  AUC=0.911±0.024
#     VotingHard                 Acc=0.799±0.042  F1=0.797±0.042  MCC=0.703±0.062  G-Mean=0.848±0.032  AUC=N/A
#     Stacking                   Acc=0.795±0.042  F1=0.793±0.043  MCC=0.697±0.062  G-Mean=0.844±0.032  AUC=0.915±0.025
#
# ======================================================================
#   Balancer: B4_SMOTE  |  shape=(645, 47)
# ======================================================================
#     RandomForest               Acc=0.786±0.060  F1=0.785±0.063  MCC=0.683±0.090  G-Mean=0.837±0.047  AUC=0.918±0.036
#     ExtraTrees                 Acc=0.795±0.057  F1=0.794±0.059  MCC=0.697±0.082  G-Mean=0.844±0.044  AUC=0.927±0.029
#     Bagging                    Acc=0.712±0.050  F1=0.709±0.049  MCC=0.571±0.074  G-Mean=0.780±0.039  AUC=0.877±0.050
#     GradientBoosting           Acc=0.744±0.052  F1=0.743±0.054  MCC=0.619±0.079  G-Mean=0.805±0.041  AUC=0.898±0.036
#     LogisticRegression         Acc=0.631±0.051  F1=0.623±0.059  MCC=0.452±0.073  G-Mean=0.717±0.040  AUC=0.788±0.034
#     RidgeClassifier            Acc=0.611±0.065  F1=0.593±0.080  MCC=0.423±0.094  G-Mean=0.701±0.052  AUC=N/A
#     DecisionTree               Acc=0.682±0.038  F1=0.677±0.041  MCC=0.526±0.056  G-Mean=0.757±0.030  AUC=0.758±0.030
#     NaiveBayes                 Acc=0.600±0.056  F1=0.590±0.056  MCC=0.410±0.088  G-Mean=0.692±0.045  AUC=0.755±0.040
#     Perceptron                 Acc=0.540±0.070  F1=0.497±0.097  MCC=0.337±0.099  G-Mean=0.645±0.055  AUC=N/A
#     SGDClassifier              Acc=0.567±0.059  F1=0.542±0.075  MCC=0.366±0.090  G-Mean=0.667±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.485±0.037  F1=0.443±0.040  MCC=0.252±0.051  G-Mean=0.602±0.028  AUC=N/A
#     LDA                        Acc=0.634±0.052  F1=0.626±0.060  MCC=0.456±0.078  G-Mean=0.719±0.042  AUC=0.791±0.030
#     QDA                        Acc=0.684±0.063  F1=0.679±0.068  MCC=0.528±0.092  G-Mean=0.759±0.049  AUC=0.855±0.033
#     LightGBM                   Acc=0.777±0.057  F1=0.775±0.058  MCC=0.668±0.086  G-Mean=0.830±0.044  AUC=0.912±0.037
#     XGBoost                    Acc=0.764±0.046  F1=0.764±0.046  MCC=0.650±0.071  G-Mean=0.821±0.036  AUC=0.906±0.036
#     VotingSoft                 Acc=0.778±0.061  F1=0.777±0.063  MCC=0.670±0.091  G-Mean=0.831±0.047  AUC=0.921±0.035
#     VotingHard                 Acc=0.803±0.062  F1=0.803±0.064  MCC=0.708±0.093  G-Mean=0.850±0.048  AUC=N/A
#     Stacking                   Acc=0.798±0.065  F1=0.797±0.069  MCC=0.703±0.095  G-Mean=0.847±0.050  AUC=0.926±0.037
#
# ======================================================================
#   Balancer: B5_BorderlineSMOTE  |  shape=(645, 47)
# ======================================================================
#     RandomForest               Acc=0.783±0.057  F1=0.779±0.062  MCC=0.679±0.083  G-Mean=0.835±0.045  AUC=0.931±0.029
#     ExtraTrees                 Acc=0.822±0.058  F1=0.819±0.061  MCC=0.735±0.084  G-Mean=0.865±0.045  AUC=0.941±0.025
#     Bagging                    Acc=0.742±0.059  F1=0.740±0.062  MCC=0.618±0.088  G-Mean=0.804±0.046  AUC=0.887±0.046
#     GradientBoosting           Acc=0.766±0.071  F1=0.764±0.075  MCC=0.652±0.105  G-Mean=0.822±0.055  AUC=0.906±0.039
#     LogisticRegression         Acc=0.659±0.057  F1=0.655±0.051  MCC=0.494±0.089  G-Mean=0.739±0.045  AUC=0.829±0.031
#     RidgeClassifier            Acc=0.639±0.058  F1=0.624±0.063  MCC=0.466±0.086  G-Mean=0.723±0.046  AUC=N/A
#     DecisionTree               Acc=0.693±0.056  F1=0.690±0.055  MCC=0.544±0.085  G-Mean=0.766±0.044  AUC=0.765±0.044
#     NaiveBayes                 Acc=0.549±0.075  F1=0.522±0.075  MCC=0.334±0.120  G-Mean=0.651±0.061  AUC=0.724±0.066
#     Perceptron                 Acc=0.581±0.073  F1=0.552±0.084  MCC=0.400±0.098  G-Mean=0.678±0.058  AUC=N/A
#     SGDClassifier              Acc=0.591±0.065  F1=0.574±0.071  MCC=0.405±0.095  G-Mean=0.684±0.052  AUC=N/A
#     PassiveAggressive          Acc=0.533±0.048  F1=0.522±0.051  MCC=0.321±0.074  G-Mean=0.638±0.040  AUC=N/A
#     LDA                        Acc=0.642±0.063  F1=0.638±0.061  MCC=0.466±0.097  G-Mean=0.725±0.050  AUC=0.823±0.032
#     QDA                        Acc=0.707±0.055  F1=0.707±0.055  MCC=0.562±0.082  G-Mean=0.776±0.042  AUC=0.863±0.033
#     LightGBM                   Acc=0.784±0.078  F1=0.782±0.082  MCC=0.680±0.116  G-Mean=0.836±0.061  AUC=0.918±0.035
#     XGBoost                    Acc=0.775±0.072  F1=0.773±0.074  MCC=0.665±0.107  G-Mean=0.829±0.056  AUC=0.921±0.041
#     VotingSoft                 Acc=0.812±0.054  F1=0.811±0.057  MCC=0.723±0.079  G-Mean=0.858±0.041  AUC=0.932±0.033
#     VotingHard                 Acc=0.814±0.057  F1=0.811±0.060  MCC=0.725±0.083  G-Mean=0.859±0.044  AUC=N/A
#     Stacking                   Acc=0.822±0.053  F1=0.821±0.056  MCC=0.735±0.078  G-Mean=0.865±0.041  AUC=0.938±0.031
#
# ======================================================================
#   Balancer: B6_TomekLinks  |  shape=(367, 47)
# ======================================================================
#     RandomForest               Acc=0.711±0.047  F1=0.626±0.070  MCC=0.497±0.089  G-Mean=0.711±0.050  AUC=0.822±0.047
#     ExtraTrees                 Acc=0.700±0.046  F1=0.619±0.073  MCC=0.489±0.077  G-Mean=0.714±0.043  AUC=0.821±0.053
#     Bagging                    Acc=0.648±0.051  F1=0.569±0.066  MCC=0.395±0.087  G-Mean=0.669±0.048  AUC=0.781±0.048
#     GradientBoosting           Acc=0.687±0.037  F1=0.612±0.069  MCC=0.464±0.075  G-Mean=0.708±0.051  AUC=0.810±0.041
#     LogisticRegression         Acc=0.656±0.064  F1=0.581±0.086  MCC=0.419±0.113  G-Mean=0.685±0.064  AUC=0.778±0.060
#     RidgeClassifier            Acc=0.629±0.049  F1=0.530±0.063  MCC=0.356±0.092  G-Mean=0.647±0.045  AUC=N/A
#     DecisionTree               Acc=0.599±0.062  F1=0.533±0.054  MCC=0.339±0.089  G-Mean=0.652±0.046  AUC=0.641±0.046
#     NaiveBayes                 Acc=0.629±0.066  F1=0.566±0.075  MCC=0.393±0.109  G-Mean=0.684±0.061  AUC=0.799±0.050
#     Perceptron                 Acc=0.580±0.049  F1=0.457±0.078  MCC=0.285±0.131  G-Mean=0.611±0.069  AUC=N/A
#     SGDClassifier              Acc=0.597±0.070  F1=0.529±0.089  MCC=0.348±0.108  G-Mean=0.648±0.065  AUC=N/A
#     PassiveAggressive          Acc=0.580±0.048  F1=0.479±0.053  MCC=0.294±0.072  G-Mean=0.614±0.036  AUC=N/A
#     LDA                        Acc=0.656±0.054  F1=0.580±0.066  MCC=0.415±0.096  G-Mean=0.684±0.051  AUC=0.781±0.059
#     QDA                        Acc=0.586±0.056  F1=0.445±0.080  MCC=0.249±0.118  G-Mean=0.580±0.058  AUC=0.605±0.053
#     LightGBM                   Acc=0.687±0.057  F1=0.611±0.067  MCC=0.461±0.096  G-Mean=0.701±0.050  AUC=0.809±0.065
#     XGBoost                    Acc=0.679±0.059  F1=0.613±0.065  MCC=0.451±0.096  G-Mean=0.701±0.046  AUC=0.792±0.052
#     VotingSoft                 Acc=0.687±0.056  F1=0.610±0.080  MCC=0.461±0.100  G-Mean=0.700±0.055  AUC=0.826±0.049
#     VotingHard                 Acc=0.711±0.039  F1=0.634±0.055  MCC=0.504±0.068  G-Mean=0.719±0.038  AUC=N/A
#     Stacking                   Acc=0.689±0.047  F1=0.605±0.075  MCC=0.458±0.092  G-Mean=0.692±0.052  AUC=0.816±0.050
#
# ======================================================================
#   Balancer: B7_SMOTETomek  |  shape=(631, 47)
# ======================================================================
#     RandomForest               Acc=0.778±0.041  F1=0.777±0.040  MCC=0.671±0.062  G-Mean=0.831±0.031  AUC=0.914±0.021
#     ExtraTrees                 Acc=0.791±0.037  F1=0.791±0.038  MCC=0.689±0.055  G-Mean=0.841±0.028  AUC=0.924±0.017
#     Bagging                    Acc=0.729±0.054  F1=0.726±0.053  MCC=0.598±0.079  G-Mean=0.793±0.042  AUC=0.886±0.027
#     GradientBoosting           Acc=0.754±0.034  F1=0.753±0.036  MCC=0.635±0.052  G-Mean=0.813±0.026  AUC=0.902±0.020
#     LogisticRegression         Acc=0.639±0.048  F1=0.632±0.048  MCC=0.461±0.073  G-Mean=0.723±0.037  AUC=0.794±0.038
#     RidgeClassifier            Acc=0.621±0.056  F1=0.608±0.060  MCC=0.437±0.085  G-Mean=0.709±0.044  AUC=N/A
#     DecisionTree               Acc=0.694±0.054  F1=0.691±0.053  MCC=0.546±0.083  G-Mean=0.766±0.042  AUC=0.767±0.042
#     NaiveBayes                 Acc=0.612±0.031  F1=0.604±0.031  MCC=0.427±0.047  G-Mean=0.702±0.024  AUC=0.760±0.025
#     Perceptron                 Acc=0.518±0.054  F1=0.468±0.091  MCC=0.308±0.068  G-Mean=0.626±0.043  AUC=N/A
#     SGDClassifier              Acc=0.537±0.068  F1=0.506±0.093  MCC=0.324±0.097  G-Mean=0.641±0.057  AUC=N/A
#     PassiveAggressive          Acc=0.501±0.088  F1=0.477±0.096  MCC=0.273±0.129  G-Mean=0.612±0.070  AUC=N/A
#     LDA                        Acc=0.645±0.039  F1=0.640±0.041  MCC=0.470±0.059  G-Mean=0.728±0.031  AUC=0.792±0.033
#     QDA                        Acc=0.651±0.056  F1=0.647±0.055  MCC=0.482±0.083  G-Mean=0.732±0.044  AUC=0.844±0.029
#     LightGBM                   Acc=0.761±0.051  F1=0.758±0.052  MCC=0.643±0.076  G-Mean=0.817±0.040  AUC=0.912±0.026
#     XGBoost                    Acc=0.761±0.066  F1=0.759±0.065  MCC=0.643±0.100  G-Mean=0.817±0.051  AUC=0.907±0.029
#     VotingSoft                 Acc=0.780±0.049  F1=0.778±0.048  MCC=0.672±0.073  G-Mean=0.832±0.037  AUC=0.921±0.018
#     VotingHard                 Acc=0.791±0.043  F1=0.790±0.043  MCC=0.689±0.065  G-Mean=0.841±0.033  AUC=N/A
#     Stacking                   Acc=0.788±0.044  F1=0.787±0.044  MCC=0.685±0.066  G-Mean=0.839±0.034  AUC=0.923±0.019
#
#
# -- Phase 1 Summary (top 20 by Accuracy) --
#              Balancer       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
# B1_RandomOverSampling         Stacking     0.871     0.872 0.812   0.903 0.964
# B1_RandomOverSampling       ExtraTrees     0.865     0.865 0.802   0.898 0.966
# B1_RandomOverSampling       VotingSoft     0.851     0.850 0.781   0.887 0.962
# B1_RandomOverSampling       VotingHard     0.849     0.849 0.778   0.886   NaN
# B1_RandomOverSampling         LightGBM     0.843     0.842 0.769   0.881 0.957
# B1_RandomOverSampling     RandomForest     0.842     0.840 0.768   0.880 0.960
# B1_RandomOverSampling          XGBoost     0.834     0.833 0.756   0.874 0.956
# B1_RandomOverSampling          Bagging     0.826     0.825 0.742   0.868 0.943
#    B5_BorderlineSMOTE         Stacking     0.822     0.821 0.735   0.865 0.938
#    B5_BorderlineSMOTE       ExtraTrees     0.822     0.819 0.735   0.865 0.941
# B1_RandomOverSampling     DecisionTree     0.819     0.815 0.735   0.863 0.865
# B1_RandomOverSampling GradientBoosting     0.817     0.817 0.728   0.861 0.930
#    B5_BorderlineSMOTE       VotingHard     0.814     0.811 0.725   0.859   NaN
#    B5_BorderlineSMOTE       VotingSoft     0.812     0.811 0.723   0.858 0.932
#             B3_ADASYN       ExtraTrees     0.806     0.804 0.712   0.853 0.914
#              B4_SMOTE       VotingHard     0.803     0.803 0.708   0.850   NaN
#             B3_ADASYN       VotingHard     0.799     0.797 0.703   0.848   NaN
#              B4_SMOTE         Stacking     0.798     0.797 0.703   0.847 0.926
#              B4_SMOTE       ExtraTrees     0.795     0.794 0.697   0.844 0.927
#             B3_ADASYN         Stacking     0.795     0.793 0.697   0.844 0.915
#
# -- Phase 1: Best Classifier per Balancer --
#               Balancer Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling   Stacking     0.871     0.872 0.812   0.903 0.964
# B2_RandomUnderSampling   LightGBM     0.624     0.607 0.442   0.707 0.776
#              B3_ADASYN ExtraTrees     0.806     0.804 0.712   0.853 0.914
#               B4_SMOTE VotingHard     0.803     0.803 0.708   0.850   NaN
#     B5_BorderlineSMOTE   Stacking     0.822     0.821 0.735   0.865 0.938
#          B6_TomekLinks VotingHard     0.711     0.634 0.504   0.719   NaN
#          B7_SMOTETomek VotingHard     0.791     0.790 0.689   0.841   NaN

# %%
section_header("PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)")

phase2_rows = []
for fs_name, fs_fn in FEATURE_SELECTORS.items():
    try:
        fs_df = fs_fn(df)
        sub_header(f"Feature Selector: {fs_name}  |  features={fs_df.shape[1]-1}")
        rows = evaluate_dataset(fs_df, label=fs_name, verbose=True)
        phase2_rows.extend(rows)
    except Exception as e:
        print(f"  {fs_name} FAILED: {e}")

phase2_df = pd.DataFrame(phase2_rows).dropna(subset=['Accuracy'])
phase2_df['Phase'] = 'Phase2_FeatureSelectionOnly'
phase2_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 2 Summary (top 20 by Accuracy) --")
p2_show = phase2_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'FeatureSelector'})
print(p2_show[['FeatureSelector','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 2: Best Classifier per Feature Selector --")
best_p2 = (p2_show.groupby('FeatureSelector', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['FeatureSelector','Classifier'] + METRICS])
print(best_p2.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)
# ################################################################################
#
# ======================================================================
#   Feature Selector: FS1_Correlation  |  features=38
# ======================================================================
#     RandomForest               Acc=0.662±0.048  F1=0.578±0.066  MCC=0.412±0.083  G-Mean=0.674±0.039  AUC=0.795±0.066
#     ExtraTrees                 Acc=0.658±0.082  F1=0.598±0.085  MCC=0.410±0.146  G-Mean=0.685±0.070  AUC=0.792±0.059
#     Bagging                    Acc=0.582±0.074  F1=0.492±0.080  MCC=0.281±0.120  G-Mean=0.610±0.058  AUC=0.746±0.064
#     GradientBoosting           Acc=0.645±0.061  F1=0.583±0.054  MCC=0.396±0.097  G-Mean=0.677±0.044  AUC=0.778±0.049
#     LogisticRegression         Acc=0.653±0.047  F1=0.574±0.059  MCC=0.408±0.078  G-Mean=0.680±0.040  AUC=0.756±0.042
#     RidgeClassifier            Acc=0.630±0.058  F1=0.531±0.074  MCC=0.356±0.098  G-Mean=0.644±0.045  AUC=N/A
#     DecisionTree               Acc=0.615±0.106  F1=0.568±0.105  MCC=0.369±0.154  G-Mean=0.673±0.077  AUC=0.662±0.073
#     NaiveBayes                 Acc=0.605±0.104  F1=0.555±0.099  MCC=0.363±0.164  G-Mean=0.674±0.081  AUC=0.780±0.066
#     Perceptron                 Acc=0.560±0.055  F1=0.461±0.084  MCC=0.259±0.086  G-Mean=0.603±0.057  AUC=N/A
#     SGDClassifier              Acc=0.572±0.054  F1=0.489±0.122  MCC=0.274±0.142  G-Mean=0.625±0.078  AUC=N/A
#     PassiveAggressive          Acc=0.552±0.058  F1=0.443±0.073  MCC=0.267±0.111  G-Mean=0.601±0.060  AUC=N/A
#     LDA                        Acc=0.645±0.058  F1=0.557±0.071  MCC=0.394±0.096  G-Mean=0.671±0.046  AUC=0.756±0.044
#     QDA                        Acc=0.552±0.069  F1=0.441±0.074  MCC=0.206±0.127  G-Mean=0.570±0.057  AUC=0.603±0.065
#     LightGBM                   Acc=0.630±0.087  F1=0.575±0.095  MCC=0.376±0.141  G-Mean=0.672±0.067  AUC=0.777±0.061
#     XGBoost                    Acc=0.635±0.067  F1=0.572±0.065  MCC=0.378±0.108  G-Mean=0.669±0.047  AUC=0.759±0.054
#     VotingSoft                 Acc=0.653±0.075  F1=0.590±0.074  MCC=0.406±0.122  G-Mean=0.684±0.054  AUC=0.797±0.059
#     VotingHard                 Acc=0.668±0.078  F1=0.610±0.076  MCC=0.424±0.137  G-Mean=0.691±0.063  AUC=N/A
#     Stacking                   Acc=0.645±0.052  F1=0.554±0.038  MCC=0.381±0.085  G-Mean=0.655±0.029  AUC=0.786±0.072
#
# ======================================================================
#   Feature Selector: FS2_KBest  |  features=35
# ======================================================================
#     RandomForest               Acc=0.652±0.056  F1=0.573±0.078  MCC=0.403±0.107  G-Mean=0.676±0.057  AUC=0.789±0.063
#     ExtraTrees                 Acc=0.660±0.057  F1=0.582±0.058  MCC=0.418±0.096  G-Mean=0.678±0.044  AUC=0.785±0.075
#     Bagging                    Acc=0.605±0.052  F1=0.515±0.047  MCC=0.320±0.082  G-Mean=0.630±0.033  AUC=0.738±0.057
#     GradientBoosting           Acc=0.640±0.070  F1=0.579±0.070  MCC=0.387±0.121  G-Mean=0.676±0.060  AUC=0.760±0.070
#     LogisticRegression         Acc=0.642±0.079  F1=0.563±0.079  MCC=0.387±0.129  G-Mean=0.669±0.061  AUC=0.751±0.055
#     RidgeClassifier            Acc=0.625±0.052  F1=0.532±0.053  MCC=0.349±0.086  G-Mean=0.644±0.037  AUC=N/A
#     DecisionTree               Acc=0.547±0.120  F1=0.491±0.118  MCC=0.256±0.170  G-Mean=0.609±0.090  AUC=0.596±0.084
#     NaiveBayes                 Acc=0.622±0.102  F1=0.571±0.092  MCC=0.386±0.162  G-Mean=0.688±0.079  AUC=0.789±0.064
#     Perceptron                 Acc=0.543±0.075  F1=0.439±0.111  MCC=0.215±0.157  G-Mean=0.586±0.089  AUC=N/A
#     SGDClassifier              Acc=0.565±0.111  F1=0.473±0.122  MCC=0.256±0.166  G-Mean=0.604±0.083  AUC=N/A
#     PassiveAggressive          Acc=0.528±0.096  F1=0.392±0.128  MCC=0.182±0.202  G-Mean=0.560±0.100  AUC=N/A
#     LDA                        Acc=0.648±0.080  F1=0.572±0.078  MCC=0.401±0.127  G-Mean=0.678±0.061  AUC=0.753±0.059
#     QDA                        Acc=0.540±0.067  F1=0.456±0.077  MCC=0.212±0.105  G-Mean=0.583±0.061  AUC=0.606±0.073
#     LightGBM                   Acc=0.630±0.053  F1=0.550±0.051  MCC=0.369±0.095  G-Mean=0.660±0.043  AUC=0.747±0.073
#     XGBoost                    Acc=0.625±0.061  F1=0.565±0.056  MCC=0.364±0.103  G-Mean=0.664±0.044  AUC=0.733±0.070
#     VotingSoft                 Acc=0.640±0.073  F1=0.573±0.069  MCC=0.387±0.123  G-Mean=0.671±0.057  AUC=0.787±0.065
#     VotingHard                 Acc=0.650±0.056  F1=0.562±0.070  MCC=0.399±0.105  G-Mean=0.669±0.053  AUC=N/A
#     Stacking                   Acc=0.665±0.039  F1=0.579±0.042  MCC=0.419±0.073  G-Mean=0.673±0.033  AUC=0.779±0.062
#
# ======================================================================
#   Feature Selector: FS3_RFE  |  features=19
# ======================================================================
#     RandomForest               Acc=0.688±0.059  F1=0.622±0.067  MCC=0.464±0.105  G-Mean=0.705±0.052  AUC=0.809±0.053
#     ExtraTrees                 Acc=0.667±0.062  F1=0.595±0.061  MCC=0.430±0.097  G-Mean=0.686±0.046  AUC=0.796±0.062
#     Bagging                    Acc=0.642±0.045  F1=0.565±0.071  MCC=0.387±0.084  G-Mean=0.667±0.047  AUC=0.763±0.058
#     GradientBoosting           Acc=0.670±0.077  F1=0.605±0.079  MCC=0.444±0.124  G-Mean=0.699±0.055  AUC=0.779±0.059
#     LogisticRegression         Acc=0.652±0.048  F1=0.562±0.062  MCC=0.397±0.093  G-Mean=0.669±0.051  AUC=0.787±0.048
#     RidgeClassifier            Acc=0.648±0.045  F1=0.551±0.057  MCC=0.386±0.082  G-Mean=0.660±0.043  AUC=N/A
#     DecisionTree               Acc=0.605±0.062  F1=0.545±0.063  MCC=0.340±0.095  G-Mean=0.655±0.048  AUC=0.632±0.053
#     NaiveBayes                 Acc=0.640±0.082  F1=0.597±0.069  MCC=0.414±0.124  G-Mean=0.705±0.057  AUC=0.797±0.055
#     Perceptron                 Acc=0.607±0.077  F1=0.517±0.107  MCC=0.354±0.126  G-Mean=0.651±0.078  AUC=N/A
#     SGDClassifier              Acc=0.583±0.082  F1=0.437±0.149  MCC=0.252±0.225  G-Mean=0.607±0.109  AUC=N/A
#     PassiveAggressive          Acc=0.552±0.096  F1=0.455±0.091  MCC=0.282±0.130  G-Mean=0.611±0.066  AUC=N/A
#     LDA                        Acc=0.662±0.061  F1=0.581±0.067  MCC=0.419±0.108  G-Mean=0.684±0.057  AUC=0.782±0.052
#     QDA                        Acc=0.540±0.080  F1=0.470±0.080  MCC=0.224±0.117  G-Mean=0.591±0.062  AUC=0.681±0.055
#     LightGBM                   Acc=0.660±0.073  F1=0.609±0.077  MCC=0.431±0.120  G-Mean=0.702±0.058  AUC=0.775±0.061
#     XGBoost                    Acc=0.670±0.052  F1=0.607±0.067  MCC=0.438±0.081  G-Mean=0.695±0.043  AUC=0.772±0.060
#     VotingSoft                 Acc=0.688±0.070  F1=0.628±0.078  MCC=0.470±0.119  G-Mean=0.713±0.059  AUC=0.800±0.058
#     VotingHard                 Acc=0.690±0.051  F1=0.625±0.061  MCC=0.466±0.094  G-Mean=0.707±0.049  AUC=N/A
#     Stacking                   Acc=0.692±0.053  F1=0.614±0.065  MCC=0.467±0.088  G-Mean=0.697±0.040  AUC=0.806±0.055
#
# ======================================================================
#   Feature Selector: FS4_MutualInfo  |  features=28
# ======================================================================
#     RandomForest               Acc=0.685±0.065  F1=0.620±0.064  MCC=0.461±0.111  G-Mean=0.702±0.050  AUC=0.803±0.065
#     ExtraTrees                 Acc=0.678±0.051  F1=0.601±0.060  MCC=0.450±0.093  G-Mean=0.698±0.049  AUC=0.800±0.066
#     Bagging                    Acc=0.612±0.071  F1=0.529±0.090  MCC=0.331±0.111  G-Mean=0.636±0.059  AUC=0.749±0.066
#     GradientBoosting           Acc=0.662±0.064  F1=0.592±0.059  MCC=0.425±0.115  G-Mean=0.690±0.051  AUC=0.776±0.060
#     LogisticRegression         Acc=0.655±0.062  F1=0.579±0.063  MCC=0.410±0.101  G-Mean=0.681±0.047  AUC=0.771±0.046
#     RidgeClassifier            Acc=0.648±0.051  F1=0.552±0.054  MCC=0.389±0.086  G-Mean=0.659±0.042  AUC=N/A
#     DecisionTree               Acc=0.540±0.072  F1=0.473±0.066  MCC=0.236±0.104  G-Mean=0.601±0.050  AUC=0.589±0.050
#     NaiveBayes                 Acc=0.617±0.113  F1=0.574±0.100  MCC=0.383±0.178  G-Mean=0.687±0.087  AUC=0.787±0.062
#     Perceptron                 Acc=0.565±0.054  F1=0.481±0.061  MCC=0.295±0.088  G-Mean=0.626±0.054  AUC=N/A
#     SGDClassifier              Acc=0.562±0.101  F1=0.517±0.099  MCC=0.312±0.130  G-Mean=0.638±0.066  AUC=N/A
#     PassiveAggressive          Acc=0.530±0.079  F1=0.394±0.074  MCC=0.228±0.094  G-Mean=0.572±0.055  AUC=N/A
#     LDA                        Acc=0.625±0.075  F1=0.541±0.065  MCC=0.361±0.113  G-Mean=0.653±0.051  AUC=0.765±0.049
#     QDA                        Acc=0.502±0.072  F1=0.433±0.088  MCC=0.158±0.107  G-Mean=0.564±0.063  AUC=0.591±0.071
#     LightGBM                   Acc=0.638±0.085  F1=0.560±0.073  MCC=0.393±0.125  G-Mean=0.671±0.055  AUC=0.759±0.058
#     XGBoost                    Acc=0.633±0.063  F1=0.574±0.057  MCC=0.376±0.097  G-Mean=0.668±0.040  AUC=0.750±0.077
#     VotingSoft                 Acc=0.665±0.071  F1=0.594±0.076  MCC=0.429±0.123  G-Mean=0.692±0.058  AUC=0.797±0.060
#     VotingHard                 Acc=0.692±0.045  F1=0.619±0.055  MCC=0.475±0.084  G-Mean=0.709±0.042  AUC=N/A
#     Stacking                   Acc=0.675±0.051  F1=0.595±0.058  MCC=0.435±0.091  G-Mean=0.684±0.045  AUC=0.790±0.068
#
# ======================================================================
#   Feature Selector: FS5_RFImportance  |  features=45
# ======================================================================
#     RandomForest               Acc=0.670±0.053  F1=0.586±0.050  MCC=0.430±0.100  G-Mean=0.683±0.048  AUC=0.793±0.057
#     ExtraTrees                 Acc=0.660±0.060  F1=0.562±0.068  MCC=0.415±0.107  G-Mean=0.671±0.051  AUC=0.782±0.061
#     Bagging                    Acc=0.622±0.068  F1=0.526±0.090  MCC=0.345±0.124  G-Mean=0.639±0.064  AUC=0.737±0.066
#     GradientBoosting           Acc=0.658±0.086  F1=0.588±0.101  MCC=0.412±0.149  G-Mean=0.683±0.077  AUC=0.772±0.062
#     LogisticRegression         Acc=0.660±0.058  F1=0.583±0.069  MCC=0.419±0.099  G-Mean=0.686±0.049  AUC=0.757±0.045
#     RidgeClassifier            Acc=0.628±0.049  F1=0.524±0.060  MCC=0.348±0.091  G-Mean=0.640±0.046  AUC=N/A
#     DecisionTree               Acc=0.542±0.099  F1=0.464±0.077  MCC=0.242±0.140  G-Mean=0.594±0.059  AUC=0.584±0.059
#     NaiveBayes                 Acc=0.617±0.098  F1=0.563±0.097  MCC=0.380±0.158  G-Mean=0.684±0.080  AUC=0.779±0.066
#     Perceptron                 Acc=0.575±0.066  F1=0.460±0.065  MCC=0.295±0.113  G-Mean=0.609±0.054  AUC=N/A
#     SGDClassifier              Acc=0.582±0.063  F1=0.464±0.080  MCC=0.299±0.116  G-Mean=0.615±0.068  AUC=N/A
#     PassiveAggressive          Acc=0.590±0.070  F1=0.490±0.075  MCC=0.319±0.116  G-Mean=0.633±0.054  AUC=N/A
#     LDA                        Acc=0.640±0.059  F1=0.562±0.067  MCC=0.383±0.104  G-Mean=0.669±0.051  AUC=0.757±0.046
#     QDA                        Acc=0.580±0.065  F1=0.437±0.090  MCC=0.242±0.132  G-Mean=0.580±0.065  AUC=0.596±0.057
#     LightGBM                   Acc=0.658±0.073  F1=0.587±0.069  MCC=0.419±0.118  G-Mean=0.685±0.053  AUC=0.779±0.056
#     XGBoost                    Acc=0.660±0.060  F1=0.593±0.058  MCC=0.422±0.109  G-Mean=0.689±0.050  AUC=0.762±0.070
#     VotingSoft                 Acc=0.665±0.048  F1=0.596±0.041  MCC=0.423±0.086  G-Mean=0.687±0.038  AUC=0.793±0.060
#     VotingHard                 Acc=0.665±0.051  F1=0.576±0.055  MCC=0.424±0.095  G-Mean=0.679±0.046  AUC=N/A
#     Stacking                   Acc=0.670±0.046  F1=0.567±0.050  MCC=0.423±0.082  G-Mean=0.671±0.038  AUC=0.786±0.061
#
#
# -- Phase 2 Summary (top 20 by Accuracy) --
#  FeatureSelector       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#   FS4_MutualInfo       VotingHard     0.692     0.619 0.475   0.709   NaN
#          FS3_RFE         Stacking     0.692     0.614 0.467   0.697 0.806
#          FS3_RFE       VotingHard     0.690     0.625 0.466   0.707   NaN
#          FS3_RFE     RandomForest     0.688     0.622 0.464   0.705 0.809
#          FS3_RFE       VotingSoft     0.688     0.628 0.470   0.713 0.800
#   FS4_MutualInfo     RandomForest     0.685     0.620 0.461   0.702 0.803
#   FS4_MutualInfo       ExtraTrees     0.678     0.601 0.450   0.698 0.800
#   FS4_MutualInfo         Stacking     0.675     0.595 0.435   0.684 0.790
# FS5_RFImportance     RandomForest     0.670     0.586 0.430   0.683 0.793
# FS5_RFImportance         Stacking     0.670     0.567 0.423   0.671 0.786
#          FS3_RFE GradientBoosting     0.670     0.605 0.444   0.699 0.779
#          FS3_RFE          XGBoost     0.670     0.607 0.438   0.695 0.772
#  FS1_Correlation       VotingHard     0.668     0.610 0.424   0.691   NaN
#          FS3_RFE       ExtraTrees     0.667     0.595 0.430   0.686 0.796
# FS5_RFImportance       VotingSoft     0.665     0.596 0.423   0.687 0.793
# FS5_RFImportance       VotingHard     0.665     0.576 0.424   0.679   NaN
#        FS2_KBest         Stacking     0.665     0.579 0.419   0.673 0.779
#   FS4_MutualInfo       VotingSoft     0.665     0.594 0.429   0.692 0.797
#   FS4_MutualInfo GradientBoosting     0.662     0.592 0.425   0.690 0.776
#          FS3_RFE              LDA     0.662     0.581 0.419   0.684 0.782
#
# -- Phase 2: Best Classifier per Feature Selector --
#  FeatureSelector   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  FS1_Correlation   VotingHard     0.668     0.610 0.424   0.691   NaN
#        FS2_KBest     Stacking     0.665     0.579 0.419   0.673 0.779
#          FS3_RFE     Stacking     0.692     0.614 0.467   0.697 0.806
#   FS4_MutualInfo   VotingHard     0.692     0.619 0.475   0.709   NaN
# FS5_RFImportance RandomForest     0.670     0.586 0.430   0.683 0.793

# %%
section_header("PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)")

phase3_rows = []
for bal_name, bal_df in balanced_datasets.items():
    for fs_name, fs_fn in FEATURE_SELECTORS.items():
        combo = f"{bal_name} + {fs_name}"
        try:
            fs_df = fs_fn(bal_df)
            sub_header(f"Combo: {combo}  |  shape={fs_df.shape}")
            rows = evaluate_dataset(fs_df, label=combo, verbose=True)
            phase3_rows.extend(rows)
        except Exception as e:
            print(f"  {combo} FAILED: {e}")

phase3_df = pd.DataFrame(phase3_rows).dropna(subset=['Accuracy'])
phase3_df['Phase'] = 'Phase3_Balancing+FS'
phase3_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 3 Summary (top 30 combos by Accuracy) --")
p3_show = phase3_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer+FS'})
print(p3_show[['Balancer+FS','Classifier'] + METRICS].head(30).to_string(index=False))

print("\n-- Phase 3: Best Classifier per Balancer+FS combo --")
best_p3 = (p3_show.groupby('Balancer+FS', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer+FS','Classifier'] + METRICS]
           .sort_values('Accuracy', ascending=False))
print(best_p3.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)
# ################################################################################
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS1_Correlation  |  shape=(645, 33)
# ======================================================================
#     RandomForest               Acc=0.843±0.037  F1=0.842±0.040  MCC=0.768±0.056  G-Mean=0.881±0.029  AUC=0.956±0.025
#     ExtraTrees                 Acc=0.860±0.037  F1=0.860±0.039  MCC=0.794±0.056  G-Mean=0.894±0.029  AUC=0.965±0.018
#     Bagging                    Acc=0.825±0.052  F1=0.823±0.055  MCC=0.740±0.078  G-Mean=0.867±0.040  AUC=0.948±0.021
#     GradientBoosting           Acc=0.823±0.040  F1=0.822±0.042  MCC=0.737±0.060  G-Mean=0.866±0.031  AUC=0.931±0.033
#     LogisticRegression         Acc=0.639±0.044  F1=0.637±0.045  MCC=0.461±0.066  G-Mean=0.723±0.035  AUC=0.811±0.040
#     RidgeClassifier            Acc=0.622±0.030  F1=0.610±0.031  MCC=0.441±0.049  G-Mean=0.710±0.024  AUC=N/A
#     DecisionTree               Acc=0.805±0.056  F1=0.800±0.062  MCC=0.713±0.080  G-Mean=0.852±0.043  AUC=0.857±0.041
#     NaiveBayes                 Acc=0.603±0.065  F1=0.591±0.065  MCC=0.412±0.100  G-Mean=0.695±0.053  AUC=0.784±0.059
#     Perceptron                 Acc=0.546±0.069  F1=0.517±0.073  MCC=0.346±0.117  G-Mean=0.648±0.056  AUC=N/A
#     SGDClassifier              Acc=0.531±0.078  F1=0.509±0.097  MCC=0.316±0.111  G-Mean=0.637±0.064  AUC=N/A
#     PassiveAggressive          Acc=0.533±0.050  F1=0.519±0.062  MCC=0.312±0.071  G-Mean=0.639±0.040  AUC=N/A
#     LDA                        Acc=0.643±0.037  F1=0.642±0.039  MCC=0.468±0.056  G-Mean=0.727±0.030  AUC=0.810±0.037
#     QDA                        Acc=0.730±0.060  F1=0.730±0.061  MCC=0.599±0.090  G-Mean=0.794±0.047  AUC=0.877±0.032
#     LightGBM                   Acc=0.840±0.045  F1=0.838±0.046  MCC=0.765±0.067  G-Mean=0.879±0.034  AUC=0.952±0.025
#     XGBoost                    Acc=0.846±0.040  F1=0.844±0.042  MCC=0.774±0.059  G-Mean=0.884±0.031  AUC=0.955±0.027
#     VotingSoft                 Acc=0.851±0.039  F1=0.850±0.041  MCC=0.780±0.059  G-Mean=0.887±0.030  AUC=0.961±0.026
#     VotingHard                 Acc=0.860±0.031  F1=0.860±0.032  MCC=0.793±0.046  G-Mean=0.894±0.024  AUC=N/A
#     Stacking                   Acc=0.882±0.040  F1=0.882±0.040  MCC=0.828±0.059  G-Mean=0.911±0.031  AUC=0.964±0.020
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS2_KBest  |  shape=(645, 36)
# ======================================================================
#     RandomForest               Acc=0.849±0.036  F1=0.848±0.037  MCC=0.778±0.054  G-Mean=0.886±0.028  AUC=0.961±0.027
#     ExtraTrees                 Acc=0.868±0.032  F1=0.868±0.033  MCC=0.806±0.047  G-Mean=0.900±0.024  AUC=0.966±0.026
#     Bagging                    Acc=0.821±0.042  F1=0.820±0.044  MCC=0.735±0.064  G-Mean=0.865±0.033  AUC=0.937±0.032
#     GradientBoosting           Acc=0.822±0.033  F1=0.821±0.034  MCC=0.736±0.049  G-Mean=0.865±0.025  AUC=0.928±0.028
#     LogisticRegression         Acc=0.634±0.049  F1=0.630±0.050  MCC=0.455±0.075  G-Mean=0.719±0.039  AUC=0.808±0.040
#     RidgeClassifier            Acc=0.615±0.042  F1=0.602±0.046  MCC=0.433±0.067  G-Mean=0.705±0.034  AUC=N/A
#     DecisionTree               Acc=0.819±0.043  F1=0.815±0.042  MCC=0.735±0.065  G-Mean=0.863±0.033  AUC=0.865±0.032
#     NaiveBayes                 Acc=0.611±0.076  F1=0.597±0.082  MCC=0.422±0.115  G-Mean=0.701±0.061  AUC=0.790±0.055
#     Perceptron                 Acc=0.543±0.096  F1=0.507±0.129  MCC=0.338±0.154  G-Mean=0.646±0.080  AUC=N/A
#     SGDClassifier              Acc=0.573±0.052  F1=0.548±0.055  MCC=0.384±0.077  G-Mean=0.671±0.041  AUC=N/A
#     PassiveAggressive          Acc=0.512±0.081  F1=0.482±0.095  MCC=0.287±0.125  G-Mean=0.620±0.066  AUC=N/A
#     LDA                        Acc=0.626±0.049  F1=0.619±0.053  MCC=0.445±0.076  G-Mean=0.713±0.040  AUC=0.806±0.037
#     QDA                        Acc=0.739±0.058  F1=0.738±0.060  MCC=0.612±0.086  G-Mean=0.801±0.046  AUC=0.869±0.032
#     LightGBM                   Acc=0.846±0.021  F1=0.846±0.023  MCC=0.774±0.033  G-Mean=0.884±0.016  AUC=0.950±0.025
#     XGBoost                    Acc=0.857±0.024  F1=0.857±0.024  MCC=0.791±0.038  G-Mean=0.892±0.019  AUC=0.951±0.028
#     VotingSoft                 Acc=0.848±0.029  F1=0.847±0.030  MCC=0.777±0.045  G-Mean=0.885±0.023  AUC=0.961±0.026
#     VotingHard                 Acc=0.856±0.029  F1=0.855±0.030  MCC=0.788±0.043  G-Mean=0.891±0.022  AUC=N/A
#     Stacking                   Acc=0.874±0.036  F1=0.875±0.036  MCC=0.816±0.054  G-Mean=0.905±0.027  AUC=0.965±0.024
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS3_RFE  |  shape=(645, 20)
# ======================================================================
#     RandomForest               Acc=0.867±0.050  F1=0.865±0.053  MCC=0.804±0.075  G-Mean=0.899±0.038  AUC=0.962±0.028
#     ExtraTrees                 Acc=0.868±0.031  F1=0.868±0.032  MCC=0.807±0.047  G-Mean=0.900±0.024  AUC=0.967±0.024
#     Bagging                    Acc=0.843±0.047  F1=0.841±0.050  MCC=0.770±0.071  G-Mean=0.881±0.037  AUC=0.938±0.024
#     GradientBoosting           Acc=0.811±0.054  F1=0.810±0.056  MCC=0.719±0.083  G-Mean=0.856±0.042  AUC=0.914±0.031
#     LogisticRegression         Acc=0.612±0.066  F1=0.604±0.067  MCC=0.422±0.099  G-Mean=0.702±0.053  AUC=0.799±0.046
#     RidgeClassifier            Acc=0.607±0.059  F1=0.585±0.070  MCC=0.422±0.089  G-Mean=0.698±0.049  AUC=N/A
#     DecisionTree               Acc=0.828±0.041  F1=0.825±0.043  MCC=0.747±0.061  G-Mean=0.869±0.032  AUC=0.871±0.032
#     NaiveBayes                 Acc=0.597±0.071  F1=0.581±0.072  MCC=0.402±0.108  G-Mean=0.690±0.057  AUC=0.795±0.054
#     Perceptron                 Acc=0.546±0.037  F1=0.499±0.049  MCC=0.344±0.056  G-Mean=0.648±0.031  AUC=N/A
#     SGDClassifier              Acc=0.536±0.104  F1=0.498±0.130  MCC=0.326±0.158  G-Mean=0.639±0.086  AUC=N/A
#     PassiveAggressive          Acc=0.484±0.075  F1=0.444±0.099  MCC=0.244±0.114  G-Mean=0.597±0.062  AUC=N/A
#     LDA                        Acc=0.609±0.059  F1=0.599±0.060  MCC=0.418±0.089  G-Mean=0.700±0.048  AUC=0.798±0.047
#     QDA                        Acc=0.671±0.083  F1=0.668±0.085  MCC=0.510±0.126  G-Mean=0.748±0.066  AUC=0.821±0.048
#     LightGBM                   Acc=0.848±0.043  F1=0.847±0.044  MCC=0.775±0.065  G-Mean=0.885±0.033  AUC=0.947±0.024
#     XGBoost                    Acc=0.845±0.040  F1=0.843±0.041  MCC=0.772±0.063  G-Mean=0.882±0.031  AUC=0.948±0.032
#     VotingSoft                 Acc=0.868±0.031  F1=0.867±0.032  MCC=0.807±0.048  G-Mean=0.900±0.024  AUC=0.958±0.029
#     VotingHard                 Acc=0.863±0.040  F1=0.863±0.041  MCC=0.799±0.060  G-Mean=0.896±0.031  AUC=N/A
#     Stacking                   Acc=0.874±0.040  F1=0.875±0.040  MCC=0.816±0.058  G-Mean=0.905±0.030  AUC=0.967±0.024
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS4_MutualInfo  |  shape=(645, 29)
# ======================================================================
#     RandomForest               Acc=0.848±0.034  F1=0.847±0.037  MCC=0.775±0.051  G-Mean=0.885±0.026  AUC=0.955±0.028
#     ExtraTrees                 Acc=0.854±0.031  F1=0.854±0.033  MCC=0.784±0.046  G-Mean=0.890±0.024  AUC=0.962±0.023
#     Bagging                    Acc=0.826±0.030  F1=0.825±0.031  MCC=0.743±0.045  G-Mean=0.869±0.023  AUC=0.937±0.031
#     GradientBoosting           Acc=0.817±0.035  F1=0.816±0.035  MCC=0.728±0.051  G-Mean=0.861±0.027  AUC=0.923±0.030
#     LogisticRegression         Acc=0.622±0.057  F1=0.616±0.059  MCC=0.437±0.086  G-Mean=0.709±0.045  AUC=0.808±0.044
#     RidgeClassifier            Acc=0.611±0.047  F1=0.593±0.054  MCC=0.426±0.071  G-Mean=0.701±0.038  AUC=N/A
#     DecisionTree               Acc=0.818±0.050  F1=0.817±0.052  MCC=0.732±0.074  G-Mean=0.862±0.039  AUC=0.871±0.037
#     NaiveBayes                 Acc=0.597±0.071  F1=0.583±0.073  MCC=0.401±0.108  G-Mean=0.690±0.057  AUC=0.793±0.054
#     Perceptron                 Acc=0.580±0.060  F1=0.553±0.075  MCC=0.392±0.091  G-Mean=0.676±0.048  AUC=N/A
#     SGDClassifier              Acc=0.547±0.060  F1=0.523±0.075  MCC=0.340±0.090  G-Mean=0.649±0.048  AUC=N/A
#     PassiveAggressive          Acc=0.546±0.079  F1=0.514±0.095  MCC=0.342±0.128  G-Mean=0.647±0.066  AUC=N/A
#     LDA                        Acc=0.621±0.051  F1=0.612±0.055  MCC=0.438±0.076  G-Mean=0.709±0.040  AUC=0.808±0.040
#     QDA                        Acc=0.694±0.062  F1=0.693±0.064  MCC=0.545±0.092  G-Mean=0.766±0.049  AUC=0.835±0.038
#     LightGBM                   Acc=0.846±0.036  F1=0.845±0.037  MCC=0.773±0.054  G-Mean=0.884±0.027  AUC=0.946±0.025
#     XGBoost                    Acc=0.836±0.033  F1=0.834±0.035  MCC=0.758±0.048  G-Mean=0.875±0.025  AUC=0.951±0.027
#     VotingSoft                 Acc=0.853±0.025  F1=0.852±0.026  MCC=0.781±0.037  G-Mean=0.888±0.019  AUC=0.955±0.027
#     VotingHard                 Acc=0.856±0.028  F1=0.855±0.029  MCC=0.786±0.042  G-Mean=0.891±0.021  AUC=N/A
#     Stacking                   Acc=0.853±0.036  F1=0.853±0.036  MCC=0.782±0.053  G-Mean=0.888±0.027  AUC=0.960±0.023
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS5_RFImportance  |  shape=(645, 46)
# ======================================================================
#     RandomForest               Acc=0.848±0.019  F1=0.847±0.021  MCC=0.777±0.030  G-Mean=0.885±0.015  AUC=0.959±0.025
#     ExtraTrees                 Acc=0.862±0.028  F1=0.862±0.030  MCC=0.798±0.043  G-Mean=0.896±0.022  AUC=0.968±0.021
#     Bagging                    Acc=0.840±0.044  F1=0.839±0.046  MCC=0.763±0.065  G-Mean=0.879±0.034  AUC=0.945±0.026
#     GradientBoosting           Acc=0.817±0.032  F1=0.816±0.033  MCC=0.728±0.049  G-Mean=0.861±0.025  AUC=0.930±0.031
#     LogisticRegression         Acc=0.643±0.040  F1=0.641±0.038  MCC=0.469±0.064  G-Mean=0.727±0.032  AUC=0.821±0.036
#     RidgeClassifier            Acc=0.631±0.046  F1=0.623±0.044  MCC=0.453±0.071  G-Mean=0.717±0.036  AUC=N/A
#     DecisionTree               Acc=0.817±0.040  F1=0.814±0.042  MCC=0.733±0.062  G-Mean=0.861±0.031  AUC=0.864±0.031
#     NaiveBayes                 Acc=0.590±0.072  F1=0.576±0.069  MCC=0.394±0.112  G-Mean=0.685±0.058  AUC=0.781±0.056
#     Perceptron                 Acc=0.566±0.065  F1=0.549±0.069  MCC=0.368±0.094  G-Mean=0.665±0.052  AUC=N/A
#     SGDClassifier              Acc=0.536±0.113  F1=0.518±0.124  MCC=0.321±0.166  G-Mean=0.640±0.092  AUC=N/A
#     PassiveAggressive          Acc=0.558±0.064  F1=0.534±0.075  MCC=0.356±0.092  G-Mean=0.659±0.051  AUC=N/A
#     LDA                        Acc=0.642±0.046  F1=0.640±0.043  MCC=0.467±0.071  G-Mean=0.726±0.036  AUC=0.814±0.033
#     QDA                        Acc=0.780±0.046  F1=0.780±0.047  MCC=0.673±0.070  G-Mean=0.833±0.036  AUC=0.900±0.025
#     LightGBM                   Acc=0.845±0.032  F1=0.844±0.032  MCC=0.771±0.048  G-Mean=0.883±0.025  AUC=0.957±0.021
#     XGBoost                    Acc=0.834±0.044  F1=0.832±0.046  MCC=0.756±0.067  G-Mean=0.874±0.034  AUC=0.956±0.026
#     VotingSoft                 Acc=0.848±0.033  F1=0.847±0.034  MCC=0.776±0.051  G-Mean=0.885±0.026  AUC=0.962±0.024
#     VotingHard                 Acc=0.851±0.025  F1=0.851±0.026  MCC=0.781±0.038  G-Mean=0.887±0.019  AUC=N/A
#     Stacking                   Acc=0.874±0.032  F1=0.875±0.031  MCC=0.817±0.046  G-Mean=0.905±0.024  AUC=0.965±0.023
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS1_Correlation  |  shape=(204, 32)
# ======================================================================
#     RandomForest               Acc=0.638±0.101  F1=0.626±0.109  MCC=0.468±0.152  G-Mean=0.721±0.080  AUC=0.806±0.084
#     ExtraTrees                 Acc=0.594±0.091  F1=0.589±0.092  MCC=0.399±0.135  G-Mean=0.685±0.072  AUC=0.784±0.077
#     Bagging                    Acc=0.589±0.120  F1=0.580±0.119  MCC=0.397±0.183  G-Mean=0.681±0.099  AUC=0.777±0.073
#     GradientBoosting           Acc=0.579±0.058  F1=0.567±0.061  MCC=0.375±0.085  G-Mean=0.673±0.046  AUC=0.773±0.075
#     LogisticRegression         Acc=0.535±0.086  F1=0.518±0.102  MCC=0.310±0.132  G-Mean=0.639±0.071  AUC=0.754±0.067
#     RidgeClassifier            Acc=0.510±0.065  F1=0.473±0.074  MCC=0.276±0.109  G-Mean=0.619±0.057  AUC=N/A
#     DecisionTree               Acc=0.564±0.088  F1=0.553±0.094  MCC=0.352±0.133  G-Mean=0.660±0.073  AUC=0.663±0.064
#     NaiveBayes                 Acc=0.608±0.093  F1=0.592±0.093  MCC=0.420±0.141  G-Mean=0.696±0.076  AUC=0.779±0.079
#     Perceptron                 Acc=0.495±0.089  F1=0.460±0.097  MCC=0.274±0.151  G-Mean=0.609±0.075  AUC=N/A
#     SGDClassifier              Acc=0.544±0.109  F1=0.504±0.119  MCC=0.339±0.173  G-Mean=0.647±0.088  AUC=N/A
#     PassiveAggressive          Acc=0.495±0.077  F1=0.455±0.089  MCC=0.266±0.132  G-Mean=0.606±0.066  AUC=N/A
#     LDA                        Acc=0.535±0.116  F1=0.509±0.131  MCC=0.313±0.177  G-Mean=0.639±0.092  AUC=0.745±0.072
#     QDA                        Acc=0.418±0.085  F1=0.411±0.091  MCC=0.129±0.134  G-Mean=0.542±0.074  AUC=0.585±0.064
#     LightGBM                   Acc=0.599±0.090  F1=0.588±0.093  MCC=0.404±0.136  G-Mean=0.689±0.072  AUC=0.774±0.075
#     XGBoost                    Acc=0.609±0.098  F1=0.602±0.101  MCC=0.419±0.149  G-Mean=0.697±0.079  AUC=0.770±0.086
#     VotingSoft                 Acc=0.594±0.080  F1=0.584±0.084  MCC=0.396±0.122  G-Mean=0.685±0.064  AUC=0.790±0.066
#     VotingHard                 Acc=0.628±0.097  F1=0.618±0.103  MCC=0.453±0.148  G-Mean=0.713±0.077  AUC=N/A
#     Stacking                   Acc=0.580±0.112  F1=0.562±0.123  MCC=0.374±0.172  G-Mean=0.671±0.090  AUC=0.779±0.078
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS2_KBest  |  shape=(204, 36)
# ======================================================================
#     RandomForest               Acc=0.599±0.101  F1=0.591±0.106  MCC=0.404±0.152  G-Mean=0.690±0.081  AUC=0.783±0.076
#     ExtraTrees                 Acc=0.589±0.098  F1=0.583±0.099  MCC=0.392±0.151  G-Mean=0.683±0.078  AUC=0.779±0.085
#     Bagging                    Acc=0.565±0.127  F1=0.556±0.133  MCC=0.352±0.192  G-Mean=0.661±0.104  AUC=0.745±0.093
#     GradientBoosting           Acc=0.565±0.064  F1=0.558±0.063  MCC=0.349±0.095  G-Mean=0.662±0.052  AUC=0.741±0.060
#     LogisticRegression         Acc=0.551±0.115  F1=0.526±0.124  MCC=0.337±0.178  G-Mean=0.651±0.095  AUC=0.760±0.074
#     RidgeClassifier            Acc=0.521±0.093  F1=0.491±0.096  MCC=0.289±0.140  G-Mean=0.626±0.076  AUC=N/A
#     DecisionTree               Acc=0.506±0.095  F1=0.491±0.096  MCC=0.268±0.154  G-Mean=0.615±0.081  AUC=0.616±0.080
#     NaiveBayes                 Acc=0.603±0.085  F1=0.586±0.084  MCC=0.413±0.130  G-Mean=0.692±0.070  AUC=0.785±0.086
#     Perceptron                 Acc=0.495±0.096  F1=0.442±0.107  MCC=0.276±0.149  G-Mean=0.609±0.079  AUC=N/A
#     SGDClassifier              Acc=0.520±0.083  F1=0.485±0.083  MCC=0.300±0.142  G-Mean=0.627±0.069  AUC=N/A
#     PassiveAggressive          Acc=0.531±0.100  F1=0.479±0.111  MCC=0.317±0.165  G-Mean=0.634±0.084  AUC=N/A
#     LDA                        Acc=0.531±0.102  F1=0.499±0.107  MCC=0.304±0.155  G-Mean=0.634±0.084  AUC=0.755±0.059
#     QDA                        Acc=0.417±0.088  F1=0.412±0.098  MCC=0.127±0.142  G-Mean=0.542±0.075  AUC=0.575±0.083
#     LightGBM                   Acc=0.604±0.104  F1=0.590±0.115  MCC=0.409±0.158  G-Mean=0.692±0.084  AUC=0.772±0.071
#     XGBoost                    Acc=0.560±0.095  F1=0.550±0.091  MCC=0.348±0.146  G-Mean=0.658±0.075  AUC=0.743±0.075
#     VotingSoft                 Acc=0.608±0.102  F1=0.597±0.100  MCC=0.418±0.156  G-Mean=0.696±0.082  AUC=0.779±0.067
#     VotingHard                 Acc=0.609±0.106  F1=0.600±0.107  MCC=0.421±0.162  G-Mean=0.697±0.084  AUC=N/A
#     Stacking                   Acc=0.579±0.106  F1=0.568±0.117  MCC=0.374±0.161  G-Mean=0.673±0.086  AUC=0.776±0.075
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS3_RFE  |  shape=(204, 20)
# ======================================================================
#     RandomForest               Acc=0.648±0.086  F1=0.641±0.090  MCC=0.477±0.131  G-Mean=0.729±0.069  AUC=0.819±0.058
#     ExtraTrees                 Acc=0.623±0.095  F1=0.616±0.095  MCC=0.442±0.143  G-Mean=0.709±0.075  AUC=0.800±0.052
#     Bagging                    Acc=0.604±0.105  F1=0.584±0.106  MCC=0.413±0.157  G-Mean=0.692±0.084  AUC=0.786±0.074
#     GradientBoosting           Acc=0.618±0.091  F1=0.604±0.105  MCC=0.437±0.141  G-Mean=0.705±0.073  AUC=0.773±0.054
#     LogisticRegression         Acc=0.594±0.100  F1=0.576±0.114  MCC=0.396±0.152  G-Mean=0.684±0.082  AUC=0.771±0.068
#     RidgeClassifier            Acc=0.579±0.097  F1=0.541±0.111  MCC=0.386±0.148  G-Mean=0.673±0.079  AUC=N/A
#     DecisionTree               Acc=0.544±0.097  F1=0.519±0.107  MCC=0.323±0.147  G-Mean=0.645±0.079  AUC=0.635±0.085
#     NaiveBayes                 Acc=0.613±0.104  F1=0.595±0.114  MCC=0.427±0.158  G-Mean=0.700±0.086  AUC=0.798±0.069
#     Perceptron                 Acc=0.554±0.090  F1=0.499±0.095  MCC=0.364±0.146  G-Mean=0.654±0.073  AUC=N/A
#     SGDClassifier              Acc=0.514±0.076  F1=0.449±0.087  MCC=0.322±0.136  G-Mean=0.623±0.065  AUC=N/A
#     PassiveAggressive          Acc=0.495±0.064  F1=0.461±0.082  MCC=0.278±0.111  G-Mean=0.609±0.054  AUC=N/A
#     LDA                        Acc=0.589±0.111  F1=0.565±0.128  MCC=0.391±0.170  G-Mean=0.681±0.092  AUC=0.771±0.074
#     QDA                        Acc=0.524±0.082  F1=0.503±0.098  MCC=0.296±0.134  G-Mean=0.631±0.073  AUC=0.675±0.083
#     LightGBM                   Acc=0.637±0.107  F1=0.623±0.125  MCC=0.461±0.165  G-Mean=0.719±0.087  AUC=0.787±0.071
#     XGBoost                    Acc=0.618±0.088  F1=0.608±0.092  MCC=0.431±0.134  G-Mean=0.703±0.070  AUC=0.776±0.071
#     VotingSoft                 Acc=0.647±0.095  F1=0.637±0.103  MCC=0.479±0.146  G-Mean=0.728±0.075  AUC=0.804±0.062
#     VotingHard                 Acc=0.667±0.093  F1=0.657±0.098  MCC=0.508±0.140  G-Mean=0.744±0.074  AUC=N/A
#     Stacking                   Acc=0.628±0.101  F1=0.618±0.104  MCC=0.448±0.153  G-Mean=0.712±0.080  AUC=0.811±0.066
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS4_MutualInfo  |  shape=(204, 29)
# ======================================================================
#     RandomForest               Acc=0.618±0.105  F1=0.608±0.104  MCC=0.434±0.160  G-Mean=0.704±0.084  AUC=0.805±0.073
#     ExtraTrees                 Acc=0.618±0.088  F1=0.608±0.086  MCC=0.439±0.137  G-Mean=0.706±0.070  AUC=0.793±0.083
#     Bagging                    Acc=0.588±0.094  F1=0.582±0.110  MCC=0.395±0.143  G-Mean=0.683±0.079  AUC=0.754±0.087
#     GradientBoosting           Acc=0.598±0.079  F1=0.581±0.082  MCC=0.407±0.121  G-Mean=0.688±0.064  AUC=0.760±0.059
#     LogisticRegression         Acc=0.599±0.124  F1=0.582±0.140  MCC=0.404±0.189  G-Mean=0.690±0.098  AUC=0.782±0.076
#     RidgeClassifier            Acc=0.569±0.073  F1=0.545±0.090  MCC=0.360±0.112  G-Mean=0.667±0.061  AUC=N/A
#     DecisionTree               Acc=0.544±0.047  F1=0.536±0.057  MCC=0.325±0.078  G-Mean=0.647±0.041  AUC=0.646±0.040
#     NaiveBayes                 Acc=0.599±0.082  F1=0.578±0.085  MCC=0.410±0.129  G-Mean=0.688±0.066  AUC=0.785±0.076
#     Perceptron                 Acc=0.535±0.093  F1=0.480±0.096  MCC=0.336±0.148  G-Mean=0.638±0.071  AUC=N/A
#     SGDClassifier              Acc=0.555±0.090  F1=0.516±0.114  MCC=0.353±0.141  G-Mean=0.654±0.074  AUC=N/A
#     PassiveAggressive          Acc=0.496±0.065  F1=0.452±0.070  MCC=0.268±0.120  G-Mean=0.607±0.055  AUC=N/A
#     LDA                        Acc=0.565±0.098  F1=0.545±0.116  MCC=0.349±0.150  G-Mean=0.662±0.081  AUC=0.781±0.072
#     QDA                        Acc=0.436±0.098  F1=0.424±0.095  MCC=0.157±0.151  G-Mean=0.557±0.083  AUC=0.576±0.070
#     LightGBM                   Acc=0.657±0.064  F1=0.647±0.071  MCC=0.493±0.097  G-Mean=0.736±0.051  AUC=0.774±0.066
#     XGBoost                    Acc=0.618±0.086  F1=0.604±0.102  MCC=0.434±0.126  G-Mean=0.705±0.069  AUC=0.752±0.074
#     VotingSoft                 Acc=0.647±0.093  F1=0.639±0.095  MCC=0.478±0.138  G-Mean=0.728±0.074  AUC=0.791±0.069
#     VotingHard                 Acc=0.628±0.103  F1=0.619±0.098  MCC=0.451±0.158  G-Mean=0.712±0.082  AUC=N/A
#     Stacking                   Acc=0.618±0.102  F1=0.610±0.102  MCC=0.435±0.155  G-Mean=0.705±0.082  AUC=0.799±0.071
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS5_RFImportance  |  shape=(204, 45)
# ======================================================================
#     RandomForest               Acc=0.622±0.093  F1=0.615±0.095  MCC=0.442±0.139  G-Mean=0.709±0.073  AUC=0.804±0.068
#     ExtraTrees                 Acc=0.594±0.107  F1=0.577±0.120  MCC=0.400±0.163  G-Mean=0.685±0.086  AUC=0.777±0.080
#     Bagging                    Acc=0.550±0.101  F1=0.542±0.101  MCC=0.329±0.153  G-Mean=0.651±0.083  AUC=0.749±0.077
#     GradientBoosting           Acc=0.575±0.075  F1=0.558±0.091  MCC=0.369±0.111  G-Mean=0.669±0.061  AUC=0.755±0.072
#     LogisticRegression         Acc=0.531±0.089  F1=0.507±0.100  MCC=0.302±0.134  G-Mean=0.634±0.072  AUC=0.734±0.075
#     RidgeClassifier            Acc=0.492±0.071  F1=0.457±0.073  MCC=0.247±0.109  G-Mean=0.602±0.057  AUC=N/A
#     DecisionTree               Acc=0.524±0.084  F1=0.511±0.096  MCC=0.294±0.133  G-Mean=0.630±0.073  AUC=0.636±0.067
#     NaiveBayes                 Acc=0.598±0.119  F1=0.584±0.120  MCC=0.408±0.181  G-Mean=0.688±0.096  AUC=0.774±0.075
#     Perceptron                 Acc=0.485±0.074  F1=0.435±0.079  MCC=0.251±0.129  G-Mean=0.599±0.063  AUC=N/A
#     SGDClassifier              Acc=0.466±0.093  F1=0.428±0.103  MCC=0.214±0.149  G-Mean=0.584±0.079  AUC=N/A
#     PassiveAggressive          Acc=0.485±0.094  F1=0.465±0.101  MCC=0.250±0.146  G-Mean=0.601±0.075  AUC=N/A
#     LDA                        Acc=0.477±0.054  F1=0.445±0.061  MCC=0.222±0.082  G-Mean=0.591±0.044  AUC=0.703±0.059
#     QDA                        Acc=0.366±0.120  F1=0.357±0.127  MCC=0.053±0.191  G-Mean=0.496±0.107  AUC=0.529±0.105
#     LightGBM                   Acc=0.629±0.112  F1=0.615±0.125  MCC=0.449±0.171  G-Mean=0.712±0.089  AUC=0.785±0.073
#     XGBoost                    Acc=0.589±0.090  F1=0.581±0.096  MCC=0.387±0.139  G-Mean=0.680±0.072  AUC=0.745±0.079
#     VotingSoft                 Acc=0.609±0.094  F1=0.597±0.108  MCC=0.418±0.144  G-Mean=0.696±0.076  AUC=0.791±0.067
#     VotingHard                 Acc=0.613±0.086  F1=0.595±0.103  MCC=0.431±0.131  G-Mean=0.701±0.069  AUC=N/A
#     Stacking                   Acc=0.604±0.080  F1=0.595±0.085  MCC=0.410±0.121  G-Mean=0.693±0.064  AUC=0.782±0.065
#
# ======================================================================
#   Combo: B3_ADASYN + FS1_Correlation  |  shape=(643, 33)
# ======================================================================
#     RandomForest               Acc=0.750±0.066  F1=0.747±0.068  MCC=0.629±0.098  G-Mean=0.809±0.052  AUC=0.895±0.039
#     ExtraTrees                 Acc=0.762±0.051  F1=0.761±0.050  MCC=0.646±0.076  G-Mean=0.819±0.040  AUC=0.901±0.034
#     Bagging                    Acc=0.700±0.095  F1=0.698±0.094  MCC=0.554±0.143  G-Mean=0.771±0.074  AUC=0.852±0.048
#     GradientBoosting           Acc=0.714±0.062  F1=0.712±0.060  MCC=0.575±0.093  G-Mean=0.782±0.048  AUC=0.859±0.040
#     LogisticRegression         Acc=0.568±0.058  F1=0.562±0.054  MCC=0.356±0.090  G-Mean=0.666±0.047  AUC=0.755±0.048
#     RidgeClassifier            Acc=0.572±0.060  F1=0.556±0.061  MCC=0.368±0.092  G-Mean=0.670±0.048  AUC=N/A
#     DecisionTree               Acc=0.644±0.059  F1=0.642±0.059  MCC=0.469±0.087  G-Mean=0.727±0.046  AUC=0.732±0.042
#     NaiveBayes                 Acc=0.531±0.090  F1=0.511±0.088  MCC=0.305±0.140  G-Mean=0.636±0.073  AUC=0.685±0.075
#     Perceptron                 Acc=0.501±0.071  F1=0.478±0.072  MCC=0.271±0.115  G-Mean=0.613±0.059  AUC=N/A
#     SGDClassifier              Acc=0.526±0.072  F1=0.505±0.079  MCC=0.303±0.109  G-Mean=0.633±0.058  AUC=N/A
#     PassiveAggressive          Acc=0.492±0.063  F1=0.467±0.067  MCC=0.262±0.105  G-Mean=0.606±0.051  AUC=N/A
#     LDA                        Acc=0.566±0.053  F1=0.559±0.050  MCC=0.354±0.081  G-Mean=0.665±0.042  AUC=0.755±0.049
#     QDA                        Acc=0.622±0.065  F1=0.618±0.065  MCC=0.435±0.098  G-Mean=0.710±0.051  AUC=0.807±0.052
#     LightGBM                   Acc=0.732±0.062  F1=0.731±0.061  MCC=0.601±0.093  G-Mean=0.796±0.048  AUC=0.886±0.039
#     XGBoost                    Acc=0.753±0.054  F1=0.751±0.056  MCC=0.633±0.082  G-Mean=0.812±0.043  AUC=0.895±0.037
#     VotingSoft                 Acc=0.745±0.064  F1=0.744±0.063  MCC=0.620±0.096  G-Mean=0.806±0.050  AUC=0.898±0.037
#     VotingHard                 Acc=0.756±0.064  F1=0.754±0.064  MCC=0.637±0.094  G-Mean=0.814±0.050  AUC=N/A
#     Stacking                   Acc=0.761±0.057  F1=0.760±0.057  MCC=0.644±0.084  G-Mean=0.818±0.044  AUC=0.901±0.033
#
# ======================================================================
#   Combo: B3_ADASYN + FS2_KBest  |  shape=(643, 36)
# ======================================================================
#     RandomForest               Acc=0.770±0.056  F1=0.767±0.057  MCC=0.661±0.083  G-Mean=0.825±0.044  AUC=0.895±0.033
#     ExtraTrees                 Acc=0.787±0.053  F1=0.785±0.053  MCC=0.685±0.081  G-Mean=0.838±0.041  AUC=0.903±0.024
#     Bagging                    Acc=0.725±0.072  F1=0.721±0.072  MCC=0.592±0.108  G-Mean=0.790±0.056  AUC=0.864±0.043
#     GradientBoosting           Acc=0.720±0.041  F1=0.716±0.041  MCC=0.585±0.059  G-Mean=0.786±0.032  AUC=0.872±0.024
#     LogisticRegression         Acc=0.574±0.077  F1=0.568±0.078  MCC=0.366±0.117  G-Mean=0.671±0.062  AUC=0.752±0.053
#     RidgeClassifier            Acc=0.569±0.075  F1=0.555±0.075  MCC=0.362±0.116  G-Mean=0.667±0.060  AUC=N/A
#     DecisionTree               Acc=0.636±0.052  F1=0.631±0.049  MCC=0.458±0.079  G-Mean=0.721±0.041  AUC=0.728±0.038
#     NaiveBayes                 Acc=0.531±0.086  F1=0.512±0.082  MCC=0.305±0.136  G-Mean=0.636±0.070  AUC=0.694±0.074
#     Perceptron                 Acc=0.474±0.067  F1=0.439±0.069  MCC=0.234±0.112  G-Mean=0.590±0.055  AUC=N/A
#     SGDClassifier              Acc=0.506±0.076  F1=0.468±0.086  MCC=0.277±0.121  G-Mean=0.614±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.467±0.070  F1=0.443±0.079  MCC=0.218±0.105  G-Mean=0.586±0.057  AUC=N/A
#     LDA                        Acc=0.572±0.075  F1=0.562±0.076  MCC=0.365±0.114  G-Mean=0.669±0.060  AUC=0.751±0.053
#     QDA                        Acc=0.634±0.044  F1=0.629±0.049  MCC=0.456±0.063  G-Mean=0.720±0.034  AUC=0.808±0.030
#     LightGBM                   Acc=0.733±0.059  F1=0.730±0.058  MCC=0.604±0.092  G-Mean=0.797±0.046  AUC=0.877±0.033
#     XGBoost                    Acc=0.737±0.053  F1=0.734±0.054  MCC=0.611±0.080  G-Mean=0.800±0.041  AUC=0.883±0.031
#     VotingSoft                 Acc=0.758±0.043  F1=0.755±0.043  MCC=0.641±0.065  G-Mean=0.816±0.034  AUC=0.897±0.025
#     VotingHard                 Acc=0.768±0.052  F1=0.766±0.051  MCC=0.658±0.078  G-Mean=0.824±0.040  AUC=N/A
#     Stacking                   Acc=0.782±0.049  F1=0.780±0.049  MCC=0.679±0.072  G-Mean=0.835±0.038  AUC=0.901±0.027
#
# ======================================================================
#   Combo: B3_ADASYN + FS3_RFE  |  shape=(643, 20)
# ======================================================================
#     RandomForest               Acc=0.740±0.061  F1=0.737±0.064  MCC=0.615±0.091  G-Mean=0.802±0.048  AUC=0.878±0.037
#     ExtraTrees                 Acc=0.774±0.060  F1=0.772±0.061  MCC=0.665±0.088  G-Mean=0.828±0.046  AUC=0.884±0.038
#     Bagging                    Acc=0.695±0.057  F1=0.692±0.057  MCC=0.547±0.085  G-Mean=0.767±0.045  AUC=0.847±0.044
#     GradientBoosting           Acc=0.698±0.045  F1=0.696±0.044  MCC=0.553±0.068  G-Mean=0.770±0.035  AUC=0.855±0.032
#     LogisticRegression         Acc=0.563±0.066  F1=0.555±0.059  MCC=0.351±0.106  G-Mean=0.663±0.052  AUC=0.744±0.059
#     RidgeClassifier            Acc=0.563±0.056  F1=0.542±0.050  MCC=0.356±0.093  G-Mean=0.662±0.045  AUC=N/A
#     DecisionTree               Acc=0.670±0.065  F1=0.667±0.067  MCC=0.509±0.099  G-Mean=0.748±0.051  AUC=0.751±0.049
#     NaiveBayes                 Acc=0.549±0.075  F1=0.531±0.067  MCC=0.335±0.121  G-Mean=0.651±0.061  AUC=0.714±0.061
#     Perceptron                 Acc=0.457±0.046  F1=0.426±0.066  MCC=0.200±0.066  G-Mean=0.576±0.039  AUC=N/A
#     SGDClassifier              Acc=0.496±0.053  F1=0.459±0.070  MCC=0.264±0.082  G-Mean=0.609±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.478±0.069  F1=0.442±0.093  MCC=0.237±0.105  G-Mean=0.592±0.058  AUC=N/A
#     LDA                        Acc=0.572±0.071  F1=0.563±0.067  MCC=0.365±0.114  G-Mean=0.670±0.057  AUC=0.743±0.060
#     QDA                        Acc=0.616±0.054  F1=0.607±0.055  MCC=0.432±0.080  G-Mean=0.704±0.043  AUC=0.760±0.039
#     LightGBM                   Acc=0.712±0.060  F1=0.711±0.060  MCC=0.572±0.090  G-Mean=0.781±0.047  AUC=0.866±0.040
#     XGBoost                    Acc=0.732±0.059  F1=0.730±0.059  MCC=0.602±0.089  G-Mean=0.796±0.046  AUC=0.875±0.042
#     VotingSoft                 Acc=0.736±0.053  F1=0.732±0.054  MCC=0.608±0.078  G-Mean=0.799±0.041  AUC=0.886±0.034
#     VotingHard                 Acc=0.753±0.055  F1=0.750±0.057  MCC=0.633±0.080  G-Mean=0.812±0.043  AUC=N/A
#     Stacking                   Acc=0.757±0.043  F1=0.754±0.046  MCC=0.640±0.063  G-Mean=0.815±0.034  AUC=0.882±0.046
#
# ======================================================================
#   Combo: B3_ADASYN + FS4_MutualInfo  |  shape=(643, 29)
# ======================================================================
#     RandomForest               Acc=0.750±0.072  F1=0.746±0.073  MCC=0.629±0.105  G-Mean=0.809±0.056  AUC=0.880±0.039
#     ExtraTrees                 Acc=0.765±0.049  F1=0.762±0.050  MCC=0.654±0.070  G-Mean=0.821±0.038  AUC=0.889±0.030
#     Bagging                    Acc=0.703±0.058  F1=0.699±0.056  MCC=0.557±0.087  G-Mean=0.773±0.045  AUC=0.851±0.042
#     GradientBoosting           Acc=0.725±0.043  F1=0.722±0.041  MCC=0.592±0.064  G-Mean=0.790±0.033  AUC=0.868±0.032
#     LogisticRegression         Acc=0.590±0.048  F1=0.579±0.049  MCC=0.391±0.072  G-Mean=0.684±0.037  AUC=0.762±0.049
#     RidgeClassifier            Acc=0.580±0.052  F1=0.559±0.053  MCC=0.384±0.078  G-Mean=0.676±0.041  AUC=N/A
#     DecisionTree               Acc=0.633±0.092  F1=0.630±0.095  MCC=0.453±0.137  G-Mean=0.718±0.073  AUC=0.726±0.064
#     NaiveBayes                 Acc=0.538±0.082  F1=0.517±0.082  MCC=0.317±0.129  G-Mean=0.642±0.066  AUC=0.700±0.072
#     Perceptron                 Acc=0.521±0.079  F1=0.479±0.093  MCC=0.298±0.127  G-Mean=0.627±0.066  AUC=N/A
#     SGDClassifier              Acc=0.479±0.062  F1=0.448±0.084  MCC=0.236±0.093  G-Mean=0.594±0.052  AUC=N/A
#     PassiveAggressive          Acc=0.487±0.081  F1=0.457±0.102  MCC=0.249±0.126  G-Mean=0.601±0.067  AUC=N/A
#     LDA                        Acc=0.580±0.055  F1=0.570±0.055  MCC=0.377±0.083  G-Mean=0.676±0.043  AUC=0.761±0.049
#     QDA                        Acc=0.602±0.046  F1=0.596±0.049  MCC=0.406±0.070  G-Mean=0.694±0.036  AUC=0.789±0.036
#     LightGBM                   Acc=0.728±0.048  F1=0.725±0.046  MCC=0.597±0.072  G-Mean=0.793±0.037  AUC=0.874±0.039
#     XGBoost                    Acc=0.748±0.052  F1=0.746±0.051  MCC=0.626±0.078  G-Mean=0.808±0.040  AUC=0.880±0.035
#     VotingSoft                 Acc=0.753±0.038  F1=0.751±0.037  MCC=0.635±0.056  G-Mean=0.812±0.030  AUC=0.891±0.031
#     VotingHard                 Acc=0.762±0.054  F1=0.760±0.055  MCC=0.649±0.078  G-Mean=0.819±0.042  AUC=N/A
#     Stacking                   Acc=0.761±0.052  F1=0.758±0.053  MCC=0.645±0.076  G-Mean=0.818±0.040  AUC=0.890±0.032
#
# ======================================================================
#   Combo: B3_ADASYN + FS5_RFImportance  |  shape=(643, 46)
# ======================================================================
#     RandomForest               Acc=0.778±0.070  F1=0.776±0.069  MCC=0.672±0.106  G-Mean=0.831±0.054  AUC=0.902±0.033
#     ExtraTrees                 Acc=0.809±0.054  F1=0.807±0.055  MCC=0.717±0.080  G-Mean=0.855±0.042  AUC=0.913±0.026
#     Bagging                    Acc=0.723±0.054  F1=0.720±0.054  MCC=0.589±0.080  G-Mean=0.789±0.042  AUC=0.865±0.040
#     GradientBoosting           Acc=0.754±0.047  F1=0.753±0.047  MCC=0.634±0.072  G-Mean=0.813±0.036  AUC=0.881±0.034
#     LogisticRegression         Acc=0.597±0.056  F1=0.594±0.055  MCC=0.400±0.086  G-Mean=0.690±0.045  AUC=0.771±0.047
#     RidgeClassifier            Acc=0.593±0.058  F1=0.582±0.055  MCC=0.397±0.090  G-Mean=0.686±0.046  AUC=N/A
#     DecisionTree               Acc=0.639±0.085  F1=0.637±0.085  MCC=0.461±0.126  G-Mean=0.723±0.066  AUC=0.728±0.061
#     NaiveBayes                 Acc=0.509±0.099  F1=0.489±0.095  MCC=0.272±0.156  G-Mean=0.617±0.081  AUC=0.683±0.076
#     Perceptron                 Acc=0.538±0.057  F1=0.519±0.063  MCC=0.323±0.087  G-Mean=0.643±0.046  AUC=N/A
#     SGDClassifier              Acc=0.565±0.061  F1=0.550±0.056  MCC=0.360±0.096  G-Mean=0.664±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.524±0.061  F1=0.495±0.073  MCC=0.306±0.089  G-Mean=0.632±0.049  AUC=N/A
#     LDA                        Acc=0.599±0.059  F1=0.592±0.056  MCC=0.404±0.090  G-Mean=0.691±0.046  AUC=0.772±0.047
#     QDA                        Acc=0.664±0.061  F1=0.658±0.065  MCC=0.499±0.091  G-Mean=0.743±0.047  AUC=0.838±0.026
#     LightGBM                   Acc=0.759±0.062  F1=0.757±0.061  MCC=0.642±0.093  G-Mean=0.817±0.048  AUC=0.894±0.031
#     XGBoost                    Acc=0.782±0.030  F1=0.780±0.031  MCC=0.677±0.045  G-Mean=0.835±0.023  AUC=0.903±0.026
#     VotingSoft                 Acc=0.784±0.052  F1=0.782±0.052  MCC=0.679±0.077  G-Mean=0.836±0.040  AUC=0.909±0.025
#     VotingHard                 Acc=0.798±0.068  F1=0.796±0.067  MCC=0.701±0.102  G-Mean=0.847±0.052  AUC=N/A
#     Stacking                   Acc=0.792±0.050  F1=0.790±0.052  MCC=0.690±0.074  G-Mean=0.842±0.039  AUC=0.913±0.026
#
# ======================================================================
#   Combo: B4_SMOTE + FS1_Correlation  |  shape=(645, 29)
# ======================================================================
#     RandomForest               Acc=0.764±0.054  F1=0.762±0.056  MCC=0.650±0.080  G-Mean=0.821±0.042  AUC=0.907±0.028
#     ExtraTrees                 Acc=0.784±0.036  F1=0.783±0.038  MCC=0.681±0.054  G-Mean=0.836±0.028  AUC=0.912±0.028
#     Bagging                    Acc=0.719±0.055  F1=0.717±0.056  MCC=0.582±0.085  G-Mean=0.786±0.043  AUC=0.866±0.030
#     GradientBoosting           Acc=0.741±0.059  F1=0.739±0.061  MCC=0.616±0.088  G-Mean=0.803±0.046  AUC=0.888±0.038
#     LogisticRegression         Acc=0.640±0.062  F1=0.634±0.065  MCC=0.465±0.094  G-Mean=0.724±0.049  AUC=0.780±0.036
#     RidgeClassifier            Acc=0.622±0.050  F1=0.608±0.055  MCC=0.440±0.077  G-Mean=0.709±0.040  AUC=N/A
#     DecisionTree               Acc=0.694±0.066  F1=0.693±0.067  MCC=0.544±0.099  G-Mean=0.766±0.052  AUC=0.769±0.051
#     NaiveBayes                 Acc=0.600±0.059  F1=0.591±0.061  MCC=0.408±0.094  G-Mean=0.692±0.048  AUC=0.755±0.040
#     Perceptron                 Acc=0.533±0.075  F1=0.501±0.095  MCC=0.335±0.096  G-Mean=0.639±0.061  AUC=N/A
#     SGDClassifier              Acc=0.538±0.059  F1=0.513±0.078  MCC=0.324±0.085  G-Mean=0.643±0.048  AUC=N/A
#     PassiveAggressive          Acc=0.502±0.066  F1=0.471±0.076  MCC=0.272±0.102  G-Mean=0.615±0.054  AUC=N/A
#     LDA                        Acc=0.642±0.053  F1=0.637±0.055  MCC=0.467±0.081  G-Mean=0.725±0.042  AUC=0.781±0.033
#     QDA                        Acc=0.675±0.057  F1=0.674±0.058  MCC=0.515±0.085  G-Mean=0.751±0.045  AUC=0.832±0.042
#     LightGBM                   Acc=0.752±0.050  F1=0.749±0.051  MCC=0.633±0.076  G-Mean=0.811±0.038  AUC=0.896±0.036
#     XGBoost                    Acc=0.755±0.061  F1=0.752±0.064  MCC=0.638±0.095  G-Mean=0.814±0.048  AUC=0.896±0.037
#     VotingSoft                 Acc=0.770±0.043  F1=0.768±0.044  MCC=0.659±0.066  G-Mean=0.826±0.033  AUC=0.910±0.033
#     VotingHard                 Acc=0.780±0.040  F1=0.779±0.041  MCC=0.673±0.060  G-Mean=0.833±0.031  AUC=N/A
#     Stacking                   Acc=0.784±0.060  F1=0.784±0.063  MCC=0.681±0.088  G-Mean=0.836±0.046  AUC=0.914±0.035
#
# ======================================================================
#   Combo: B4_SMOTE + FS2_KBest  |  shape=(645, 36)
# ======================================================================
#     RandomForest               Acc=0.774±0.056  F1=0.772±0.057  MCC=0.665±0.083  G-Mean=0.828±0.043  AUC=0.911±0.033
#     ExtraTrees                 Acc=0.784±0.052  F1=0.782±0.054  MCC=0.682±0.078  G-Mean=0.836±0.040  AUC=0.920±0.029
#     Bagging                    Acc=0.724±0.067  F1=0.723±0.069  MCC=0.590±0.100  G-Mean=0.790±0.052  AUC=0.865±0.046
#     GradientBoosting           Acc=0.732±0.062  F1=0.731±0.063  MCC=0.602±0.093  G-Mean=0.796±0.048  AUC=0.889±0.041
#     LogisticRegression         Acc=0.600±0.041  F1=0.591±0.046  MCC=0.405±0.063  G-Mean=0.693±0.034  AUC=0.773±0.037
#     RidgeClassifier            Acc=0.578±0.040  F1=0.561±0.047  MCC=0.376±0.062  G-Mean=0.675±0.033  AUC=N/A
#     DecisionTree               Acc=0.681±0.046  F1=0.677±0.048  MCC=0.525±0.070  G-Mean=0.756±0.036  AUC=0.754±0.038
#     NaiveBayes                 Acc=0.600±0.049  F1=0.589±0.049  MCC=0.410±0.077  G-Mean=0.692±0.039  AUC=0.766±0.034
#     Perceptron                 Acc=0.524±0.055  F1=0.490±0.073  MCC=0.310±0.072  G-Mean=0.632±0.044  AUC=N/A
#     SGDClassifier              Acc=0.496±0.050  F1=0.465±0.069  MCC=0.262±0.069  G-Mean=0.608±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.484±0.064  F1=0.448±0.080  MCC=0.245±0.096  G-Mean=0.598±0.052  AUC=N/A
#     LDA                        Acc=0.603±0.046  F1=0.594±0.051  MCC=0.409±0.069  G-Mean=0.695±0.037  AUC=0.774±0.039
#     QDA                        Acc=0.645±0.051  F1=0.641±0.051  MCC=0.473±0.079  G-Mean=0.728±0.040  AUC=0.813±0.035
#     LightGBM                   Acc=0.753±0.052  F1=0.751±0.053  MCC=0.634±0.079  G-Mean=0.813±0.040  AUC=0.900±0.036
#     XGBoost                    Acc=0.746±0.066  F1=0.744±0.067  MCC=0.623±0.098  G-Mean=0.807±0.051  AUC=0.893±0.044
#     VotingSoft                 Acc=0.771±0.049  F1=0.769±0.050  MCC=0.660±0.075  G-Mean=0.826±0.038  AUC=0.914±0.032
#     VotingHard                 Acc=0.785±0.054  F1=0.783±0.055  MCC=0.681±0.080  G-Mean=0.836±0.041  AUC=N/A
#     Stacking                   Acc=0.778±0.057  F1=0.777±0.059  MCC=0.673±0.085  G-Mean=0.831±0.044  AUC=0.917±0.034
#
# ======================================================================
#   Combo: B4_SMOTE + FS3_RFE  |  shape=(645, 20)
# ======================================================================
#     RandomForest               Acc=0.764±0.057  F1=0.762±0.058  MCC=0.651±0.085  G-Mean=0.821±0.044  AUC=0.893±0.038
#     ExtraTrees                 Acc=0.766±0.055  F1=0.764±0.056  MCC=0.653±0.082  G-Mean=0.822±0.042  AUC=0.896±0.032
#     Bagging                    Acc=0.710±0.048  F1=0.708±0.050  MCC=0.570±0.070  G-Mean=0.779±0.037  AUC=0.862±0.039
#     GradientBoosting           Acc=0.727±0.064  F1=0.726±0.065  MCC=0.593±0.096  G-Mean=0.792±0.050  AUC=0.875±0.037
#     LogisticRegression         Acc=0.623±0.050  F1=0.616±0.050  MCC=0.440±0.078  G-Mean=0.711±0.040  AUC=0.776±0.032
#     RidgeClassifier            Acc=0.600±0.047  F1=0.575±0.047  MCC=0.414±0.077  G-Mean=0.693±0.038  AUC=N/A
#     DecisionTree               Acc=0.699±0.047  F1=0.699±0.045  MCC=0.551±0.072  G-Mean=0.770±0.037  AUC=0.774±0.036
#     NaiveBayes                 Acc=0.606±0.044  F1=0.596±0.043  MCC=0.417±0.069  G-Mean=0.698±0.035  AUC=0.775±0.035
#     Perceptron                 Acc=0.546±0.051  F1=0.519±0.063  MCC=0.342±0.078  G-Mean=0.649±0.042  AUC=N/A
#     SGDClassifier              Acc=0.529±0.062  F1=0.501±0.077  MCC=0.313±0.091  G-Mean=0.635±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.470±0.062  F1=0.438±0.071  MCC=0.229±0.097  G-Mean=0.588±0.052  AUC=N/A
#     LDA                        Acc=0.615±0.052  F1=0.608±0.052  MCC=0.429±0.081  G-Mean=0.705±0.042  AUC=0.772±0.036
#     QDA                        Acc=0.645±0.046  F1=0.640±0.046  MCC=0.473±0.067  G-Mean=0.728±0.036  AUC=0.792±0.044
#     LightGBM                   Acc=0.733±0.055  F1=0.732±0.055  MCC=0.604±0.082  G-Mean=0.797±0.042  AUC=0.889±0.037
#     XGBoost                    Acc=0.738±0.047  F1=0.736±0.048  MCC=0.611±0.071  G-Mean=0.801±0.036  AUC=0.887±0.035
#     VotingSoft                 Acc=0.764±0.056  F1=0.763±0.057  MCC=0.650±0.084  G-Mean=0.821±0.043  AUC=0.899±0.034
#     VotingHard                 Acc=0.772±0.048  F1=0.771±0.049  MCC=0.663±0.072  G-Mean=0.827±0.037  AUC=N/A
#     Stacking                   Acc=0.770±0.059  F1=0.770±0.060  MCC=0.661±0.087  G-Mean=0.826±0.045  AUC=0.899±0.037
#
# ======================================================================
#   Combo: B4_SMOTE + FS4_MutualInfo  |  shape=(645, 29)
# ======================================================================
#     RandomForest               Acc=0.772±0.062  F1=0.771±0.064  MCC=0.662±0.092  G-Mean=0.827±0.048  AUC=0.909±0.035
#     ExtraTrees                 Acc=0.769±0.071  F1=0.765±0.076  MCC=0.658±0.103  G-Mean=0.824±0.055  AUC=0.914±0.033
#     Bagging                    Acc=0.721±0.055  F1=0.719±0.056  MCC=0.585±0.083  G-Mean=0.788±0.043  AUC=0.876±0.039
#     GradientBoosting           Acc=0.726±0.072  F1=0.725±0.072  MCC=0.593±0.108  G-Mean=0.791±0.056  AUC=0.877±0.044
#     LogisticRegression         Acc=0.614±0.058  F1=0.606±0.062  MCC=0.426±0.089  G-Mean=0.703±0.047  AUC=0.779±0.042
#     RidgeClassifier            Acc=0.606±0.053  F1=0.591±0.061  MCC=0.419±0.080  G-Mean=0.697±0.043  AUC=N/A
#     DecisionTree               Acc=0.694±0.055  F1=0.693±0.054  MCC=0.547±0.081  G-Mean=0.766±0.043  AUC=0.765±0.042
#     NaiveBayes                 Acc=0.603±0.055  F1=0.592±0.054  MCC=0.412±0.087  G-Mean=0.695±0.044  AUC=0.773±0.036
#     Perceptron                 Acc=0.504±0.068  F1=0.465±0.079  MCC=0.283±0.107  G-Mean=0.615±0.056  AUC=N/A
#     SGDClassifier              Acc=0.549±0.055  F1=0.533±0.064  MCC=0.337±0.082  G-Mean=0.650±0.045  AUC=N/A
#     PassiveAggressive          Acc=0.510±0.045  F1=0.473±0.059  MCC=0.295±0.066  G-Mean=0.621±0.035  AUC=N/A
#     LDA                        Acc=0.612±0.063  F1=0.604±0.066  MCC=0.424±0.097  G-Mean=0.702±0.051  AUC=0.778±0.040
#     QDA                        Acc=0.633±0.055  F1=0.631±0.055  MCC=0.452±0.084  G-Mean=0.718±0.043  AUC=0.795±0.039
#     LightGBM                   Acc=0.744±0.056  F1=0.742±0.057  MCC=0.621±0.086  G-Mean=0.805±0.044  AUC=0.892±0.038
#     XGBoost                    Acc=0.750±0.071  F1=0.749±0.074  MCC=0.631±0.107  G-Mean=0.810±0.056  AUC=0.887±0.044
#     VotingSoft                 Acc=0.760±0.061  F1=0.758±0.063  MCC=0.643±0.092  G-Mean=0.817±0.047  AUC=0.908±0.036
#     VotingHard                 Acc=0.775±0.063  F1=0.773±0.066  MCC=0.666±0.093  G-Mean=0.829±0.049  AUC=N/A
#     Stacking                   Acc=0.780±0.054  F1=0.778±0.057  MCC=0.674±0.079  G-Mean=0.833±0.042  AUC=0.912±0.038
#
# ======================================================================
#   Combo: B4_SMOTE + FS5_RFImportance  |  shape=(645, 46)
# ======================================================================
#     RandomForest               Acc=0.769±0.047  F1=0.767±0.050  MCC=0.658±0.069  G-Mean=0.824±0.036  AUC=0.918±0.031
#     ExtraTrees                 Acc=0.800±0.053  F1=0.800±0.054  MCC=0.703±0.079  G-Mean=0.848±0.041  AUC=0.924±0.030
#     Bagging                    Acc=0.724±0.061  F1=0.722±0.064  MCC=0.590±0.088  G-Mean=0.790±0.047  AUC=0.874±0.056
#     GradientBoosting           Acc=0.747±0.056  F1=0.746±0.057  MCC=0.624±0.084  G-Mean=0.808±0.043  AUC=0.899±0.037
#     LogisticRegression         Acc=0.631±0.049  F1=0.624±0.058  MCC=0.452±0.071  G-Mean=0.717±0.038  AUC=0.788±0.034
#     RidgeClassifier            Acc=0.608±0.058  F1=0.588±0.075  MCC=0.419±0.084  G-Mean=0.698±0.047  AUC=N/A
#     DecisionTree               Acc=0.699±0.043  F1=0.696±0.044  MCC=0.553±0.063  G-Mean=0.770±0.034  AUC=0.772±0.036
#     NaiveBayes                 Acc=0.594±0.052  F1=0.583±0.053  MCC=0.401±0.083  G-Mean=0.688±0.042  AUC=0.756±0.040
#     Perceptron                 Acc=0.505±0.063  F1=0.463±0.085  MCC=0.281±0.086  G-Mean=0.617±0.053  AUC=N/A
#     SGDClassifier              Acc=0.540±0.065  F1=0.517±0.075  MCC=0.327±0.090  G-Mean=0.644±0.051  AUC=N/A
#     PassiveAggressive          Acc=0.481±0.026  F1=0.443±0.034  MCC=0.244±0.041  G-Mean=0.598±0.021  AUC=N/A
#     LDA                        Acc=0.636±0.052  F1=0.629±0.059  MCC=0.458±0.079  G-Mean=0.721±0.042  AUC=0.790±0.032
#     QDA                        Acc=0.676±0.054  F1=0.672±0.059  MCC=0.517±0.080  G-Mean=0.753±0.042  AUC=0.855±0.033
#     LightGBM                   Acc=0.764±0.059  F1=0.763±0.061  MCC=0.649±0.088  G-Mean=0.821±0.045  AUC=0.912±0.036
#     XGBoost                    Acc=0.763±0.046  F1=0.761±0.047  MCC=0.647±0.070  G-Mean=0.820±0.035  AUC=0.906±0.039
#     VotingSoft                 Acc=0.773±0.065  F1=0.772±0.068  MCC=0.663±0.097  G-Mean=0.828±0.050  AUC=0.921±0.032
#     VotingHard                 Acc=0.783±0.057  F1=0.782±0.060  MCC=0.678±0.084  G-Mean=0.835±0.044  AUC=N/A
#     Stacking                   Acc=0.791±0.048  F1=0.790±0.050  MCC=0.692±0.069  G-Mean=0.841±0.037  AUC=0.924±0.033
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS1_Correlation  |  shape=(645, 32)
# ======================================================================
#     RandomForest               Acc=0.786±0.046  F1=0.783±0.048  MCC=0.682±0.068  G-Mean=0.837±0.036  AUC=0.924±0.035
#     ExtraTrees                 Acc=0.806±0.050  F1=0.804±0.051  MCC=0.713±0.074  G-Mean=0.853±0.038  AUC=0.930±0.033
#     Bagging                    Acc=0.738±0.065  F1=0.735±0.066  MCC=0.610±0.097  G-Mean=0.800±0.050  AUC=0.885±0.045
#     GradientBoosting           Acc=0.752±0.065  F1=0.750±0.066  MCC=0.632±0.098  G-Mean=0.811±0.051  AUC=0.892±0.038
#     LogisticRegression         Acc=0.656±0.050  F1=0.647±0.049  MCC=0.491±0.078  G-Mean=0.737±0.039  AUC=0.822±0.035
#     RidgeClassifier            Acc=0.622±0.045  F1=0.597±0.054  MCC=0.446±0.068  G-Mean=0.710±0.036  AUC=N/A
#     DecisionTree               Acc=0.692±0.072  F1=0.688±0.075  MCC=0.542±0.107  G-Mean=0.764±0.056  AUC=0.765±0.056
#     NaiveBayes                 Acc=0.541±0.071  F1=0.511±0.071  MCC=0.323±0.115  G-Mean=0.645±0.058  AUC=0.729±0.070
#     Perceptron                 Acc=0.552±0.079  F1=0.531±0.092  MCC=0.345±0.114  G-Mean=0.653±0.064  AUC=N/A
#     SGDClassifier              Acc=0.589±0.055  F1=0.559±0.082  MCC=0.408±0.070  G-Mean=0.684±0.044  AUC=N/A
#     PassiveAggressive          Acc=0.527±0.068  F1=0.492±0.087  MCC=0.313±0.096  G-Mean=0.633±0.055  AUC=N/A
#     LDA                        Acc=0.645±0.049  F1=0.633±0.053  MCC=0.474±0.076  G-Mean=0.728±0.039  AUC=0.816±0.034
#     QDA                        Acc=0.642±0.049  F1=0.644±0.048  MCC=0.466±0.073  G-Mean=0.726±0.038  AUC=0.822±0.038
#     LightGBM                   Acc=0.763±0.072  F1=0.761±0.075  MCC=0.647±0.108  G-Mean=0.819±0.056  AUC=0.908±0.039
#     XGBoost                    Acc=0.767±0.077  F1=0.766±0.079  MCC=0.655±0.116  G-Mean=0.823±0.060  AUC=0.912±0.045
#     VotingSoft                 Acc=0.786±0.054  F1=0.783±0.056  MCC=0.683±0.080  G-Mean=0.837±0.042  AUC=0.922±0.038
#     VotingHard                 Acc=0.791±0.039  F1=0.788±0.041  MCC=0.689±0.058  G-Mean=0.841±0.030  AUC=N/A
#     Stacking                   Acc=0.801±0.054  F1=0.800±0.058  MCC=0.707±0.079  G-Mean=0.849±0.042  AUC=0.929±0.036
#
# ======================================================================
# ...
#     XGBoost                    Acc=0.751±0.050  F1=0.749±0.050  MCC=0.631±0.077  G-Mean=0.810±0.039  AUC=0.895±0.023
#     VotingSoft                 Acc=0.757±0.062  F1=0.755±0.063  MCC=0.640±0.093  G-Mean=0.815±0.048  AUC=0.910±0.016
#     VotingHard                 Acc=0.769±0.048  F1=0.766±0.048  MCC=0.657±0.072  G-Mean=0.824±0.037  AUC=N/A
#     Stacking                   Acc=0.777±0.057  F1=0.776±0.056  MCC=0.669±0.086  G-Mean=0.830±0.044  AUC=0.914±0.023
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS2_KBest  |  shape=(631, 36)
# ======================================================================
#     RandomForest               Acc=0.770±0.035  F1=0.769±0.034  MCC=0.658±0.053  G-Mean=0.825±0.027  AUC=0.911±0.019
#     ExtraTrees                 Acc=0.783±0.024  F1=0.783±0.023  MCC=0.678±0.035  G-Mean=0.835±0.018  AUC=0.912±0.017
#     Bagging                    Acc=0.746±0.048  F1=0.745±0.046  MCC=0.623±0.072  G-Mean=0.807±0.037  AUC=0.881±0.033
#     GradientBoosting           Acc=0.723±0.046  F1=0.720±0.046  MCC=0.588±0.068  G-Mean=0.789±0.035  AUC=0.877±0.025
#     LogisticRegression         Acc=0.618±0.050  F1=0.609±0.055  MCC=0.432±0.075  G-Mean=0.706±0.040  AUC=0.783±0.027
#     RidgeClassifier            Acc=0.588±0.054  F1=0.571±0.058  MCC=0.390±0.082  G-Mean=0.682±0.043  AUC=N/A
#     DecisionTree               Acc=0.677±0.062  F1=0.675±0.062  MCC=0.518±0.094  G-Mean=0.753±0.048  AUC=0.751±0.050
#     NaiveBayes                 Acc=0.602±0.040  F1=0.595±0.039  MCC=0.409±0.060  G-Mean=0.694±0.031  AUC=0.772±0.020
#     Perceptron                 Acc=0.539±0.065  F1=0.519±0.072  MCC=0.326±0.095  G-Mean=0.644±0.052  AUC=N/A
#     SGDClassifier              Acc=0.553±0.050  F1=0.530±0.066  MCC=0.342±0.072  G-Mean=0.653±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.460±0.057  F1=0.414±0.071  MCC=0.223±0.086  G-Mean=0.578±0.048  AUC=N/A
#     LDA                        Acc=0.615±0.046  F1=0.605±0.050  MCC=0.428±0.069  G-Mean=0.704±0.036  AUC=0.780±0.026
#     QDA                        Acc=0.658±0.049  F1=0.655±0.047  MCC=0.489±0.073  G-Mean=0.738±0.038  AUC=0.811±0.030
#     LightGBM                   Acc=0.738±0.035  F1=0.735±0.036  MCC=0.611±0.052  G-Mean=0.801±0.027  AUC=0.890±0.022
#     XGBoost                    Acc=0.750±0.050  F1=0.746±0.050  MCC=0.628±0.076  G-Mean=0.809±0.039  AUC=0.891±0.026
#     VotingSoft                 Acc=0.762±0.035  F1=0.760±0.037  MCC=0.647±0.052  G-Mean=0.819±0.027  AUC=0.908±0.018
#     VotingHard                 Acc=0.770±0.033  F1=0.769±0.032  MCC=0.658±0.049  G-Mean=0.825±0.025  AUC=N/A
#     Stacking                   Acc=0.781±0.023  F1=0.781±0.023  MCC=0.677±0.035  G-Mean=0.834±0.018  AUC=0.913±0.017
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS3_RFE  |  shape=(631, 20)
# ======================================================================
#     RandomForest               Acc=0.761±0.048  F1=0.759±0.047  MCC=0.646±0.073  G-Mean=0.818±0.037  AUC=0.896±0.027
#     ExtraTrees                 Acc=0.767±0.044  F1=0.765±0.044  MCC=0.655±0.066  G-Mean=0.823±0.033  AUC=0.898±0.027
#     Bagging                    Acc=0.723±0.074  F1=0.720±0.073  MCC=0.588±0.111  G-Mean=0.788±0.057  AUC=0.872±0.032
#     GradientBoosting           Acc=0.721±0.048  F1=0.717±0.047  MCC=0.587±0.072  G-Mean=0.787±0.037  AUC=0.873±0.023
#     LogisticRegression         Acc=0.636±0.058  F1=0.629±0.063  MCC=0.457±0.088  G-Mean=0.720±0.046  AUC=0.791±0.035
#     RidgeClassifier            Acc=0.613±0.039  F1=0.596±0.038  MCC=0.431±0.061  G-Mean=0.703±0.030  AUC=N/A
#     DecisionTree               Acc=0.677±0.043  F1=0.673±0.042  MCC=0.521±0.064  G-Mean=0.753±0.033  AUC=0.754±0.038
#     NaiveBayes                 Acc=0.607±0.039  F1=0.599±0.041  MCC=0.417±0.058  G-Mean=0.698±0.030  AUC=0.781±0.024
#     Perceptron                 Acc=0.536±0.072  F1=0.499±0.096  MCC=0.326±0.098  G-Mean=0.640±0.058  AUC=N/A
#     SGDClassifier              Acc=0.558±0.038  F1=0.512±0.061  MCC=0.361±0.057  G-Mean=0.658±0.030  AUC=N/A
#     PassiveAggressive          Acc=0.499±0.038  F1=0.473±0.045  MCC=0.269±0.058  G-Mean=0.611±0.030  AUC=N/A
#     LDA                        Acc=0.644±0.050  F1=0.637±0.054  MCC=0.469±0.075  G-Mean=0.727±0.039  AUC=0.790±0.035
#     QDA                        Acc=0.643±0.055  F1=0.638±0.052  MCC=0.474±0.086  G-Mean=0.727±0.043  AUC=0.785±0.035
#     LightGBM                   Acc=0.734±0.039  F1=0.732±0.037  MCC=0.605±0.059  G-Mean=0.797±0.030  AUC=0.894±0.019
#     XGBoost                    Acc=0.748±0.045  F1=0.746±0.045  MCC=0.625±0.067  G-Mean=0.808±0.035  AUC=0.890±0.031
#     VotingSoft                 Acc=0.751±0.046  F1=0.749±0.046  MCC=0.632±0.070  G-Mean=0.811±0.036  AUC=0.902±0.022
#     VotingHard                 Acc=0.767±0.043  F1=0.766±0.042  MCC=0.655±0.066  G-Mean=0.823±0.033  AUC=N/A
#     Stacking                   Acc=0.762±0.051  F1=0.761±0.049  MCC=0.649±0.077  G-Mean=0.819±0.039  AUC=0.905±0.028
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS4_MutualInfo  |  shape=(631, 29)
# ======================================================================
#     RandomForest               Acc=0.757±0.030  F1=0.757±0.031  MCC=0.640±0.043  G-Mean=0.816±0.023  AUC=0.905±0.014
#     ExtraTrees                 Acc=0.765±0.033  F1=0.765±0.033  MCC=0.652±0.049  G-Mean=0.822±0.025  AUC=0.907±0.015
#     Bagging                    Acc=0.742±0.040  F1=0.738±0.041  MCC=0.616±0.060  G-Mean=0.803±0.031  AUC=0.871±0.024
#     GradientBoosting           Acc=0.720±0.051  F1=0.717±0.053  MCC=0.583±0.076  G-Mean=0.786±0.040  AUC=0.874±0.032
#     LogisticRegression         Acc=0.616±0.044  F1=0.610±0.043  MCC=0.430±0.068  G-Mean=0.705±0.035  AUC=0.782±0.035
#     RidgeClassifier            Acc=0.588±0.040  F1=0.570±0.042  MCC=0.391±0.062  G-Mean=0.683±0.032  AUC=N/A
#     DecisionTree               Acc=0.645±0.048  F1=0.643±0.049  MCC=0.470±0.071  G-Mean=0.728±0.038  AUC=0.734±0.042
#     NaiveBayes                 Acc=0.618±0.031  F1=0.609±0.029  MCC=0.434±0.047  G-Mean=0.707±0.025  AUC=0.778±0.019
#     Perceptron                 Acc=0.534±0.074  F1=0.495±0.098  MCC=0.331±0.104  G-Mean=0.639±0.061  AUC=N/A
#     SGDClassifier              Acc=0.545±0.062  F1=0.509±0.081  MCC=0.339±0.086  G-Mean=0.648±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.477±0.081  F1=0.435±0.096  MCC=0.243±0.120  G-Mean=0.593±0.066  AUC=N/A
#     LDA                        Acc=0.610±0.044  F1=0.601±0.045  MCC=0.421±0.068  G-Mean=0.700±0.035  AUC=0.782±0.033
#     QDA                        Acc=0.626±0.045  F1=0.619±0.047  MCC=0.443±0.069  G-Mean=0.713±0.036  AUC=0.793±0.031
#     LightGBM                   Acc=0.751±0.040  F1=0.750±0.041  MCC=0.630±0.059  G-Mean=0.811±0.030  AUC=0.891±0.022
#     XGBoost                    Acc=0.742±0.040  F1=0.740±0.042  MCC=0.616±0.060  G-Mean=0.803±0.031  AUC=0.892±0.026
#     VotingSoft                 Acc=0.751±0.034  F1=0.749±0.035  MCC=0.630±0.049  G-Mean=0.811±0.026  AUC=0.905±0.016
#     VotingHard                 Acc=0.764±0.023  F1=0.764±0.023  MCC=0.649±0.034  G-Mean=0.821±0.017  AUC=N/A
#     Stacking                   Acc=0.762±0.038  F1=0.762±0.038  MCC=0.649±0.057  G-Mean=0.820±0.029  AUC=0.909±0.018
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS5_RFImportance  |  shape=(631, 46)
# ======================================================================
#     RandomForest               Acc=0.789±0.055  F1=0.788±0.056  MCC=0.686±0.081  G-Mean=0.839±0.042  AUC=0.918±0.020
#     ExtraTrees                 Acc=0.796±0.033  F1=0.794±0.033  MCC=0.697±0.048  G-Mean=0.845±0.025  AUC=0.918±0.019
#     Bagging                    Acc=0.734±0.058  F1=0.729±0.059  MCC=0.606±0.087  G-Mean=0.797±0.045  AUC=0.884±0.029
#     GradientBoosting           Acc=0.753±0.040  F1=0.751±0.042  MCC=0.633±0.062  G-Mean=0.812±0.031  AUC=0.902±0.020
#     LogisticRegression         Acc=0.637±0.042  F1=0.630±0.043  MCC=0.459±0.064  G-Mean=0.721±0.033  AUC=0.795±0.037
#     RidgeClassifier            Acc=0.618±0.056  F1=0.605±0.059  MCC=0.432±0.086  G-Mean=0.706±0.045  AUC=N/A
#     DecisionTree               Acc=0.688±0.044  F1=0.685±0.046  MCC=0.536±0.066  G-Mean=0.761±0.034  AUC=0.761±0.034
#     NaiveBayes                 Acc=0.612±0.032  F1=0.605±0.033  MCC=0.426±0.048  G-Mean=0.702±0.024  AUC=0.761±0.025
#     Perceptron                 Acc=0.531±0.053  F1=0.501±0.067  MCC=0.313±0.077  G-Mean=0.636±0.043  AUC=N/A
#     SGDClassifier              Acc=0.559±0.083  F1=0.538±0.081  MCC=0.353±0.132  G-Mean=0.658±0.067  AUC=N/A
#     PassiveAggressive          Acc=0.482±0.074  F1=0.463±0.091  MCC=0.245±0.106  G-Mean=0.598±0.060  AUC=N/A
#     LDA                        Acc=0.642±0.046  F1=0.636±0.048  MCC=0.465±0.069  G-Mean=0.725±0.036  AUC=0.793±0.033
#     QDA                        Acc=0.661±0.049  F1=0.657±0.046  MCC=0.495±0.073  G-Mean=0.740±0.038  AUC=0.847±0.030
#     LightGBM                   Acc=0.765±0.050  F1=0.764±0.050  MCC=0.650±0.075  G-Mean=0.821±0.039  AUC=0.913±0.022
#     XGBoost                    Acc=0.753±0.071  F1=0.751±0.071  MCC=0.630±0.107  G-Mean=0.811±0.055  AUC=0.906±0.031
#     VotingSoft                 Acc=0.778±0.051  F1=0.776±0.051  MCC=0.669±0.076  G-Mean=0.831±0.039  AUC=0.920±0.017
#     VotingHard                 Acc=0.792±0.042  F1=0.791±0.042  MCC=0.692±0.063  G-Mean=0.842±0.033  AUC=N/A
#     Stacking                   Acc=0.791±0.043  F1=0.791±0.044  MCC=0.691±0.063  G-Mean=0.841±0.033  AUC=0.922±0.020
#
#
# -- Phase 3 Summary (top 30 combos by Accuracy) --
#                              Balancer+FS   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling + FS1_Correlation     Stacking     0.882     0.882 0.828   0.911 0.964
#        B1_RandomOverSampling + FS2_KBest     Stacking     0.874     0.875 0.816   0.905 0.965
# B1_RandomOverSampling + FS5_RFImportance     Stacking     0.874     0.875 0.817   0.905 0.965
#          B1_RandomOverSampling + FS3_RFE     Stacking     0.874     0.875 0.816   0.905 0.967
#          B1_RandomOverSampling + FS3_RFE   ExtraTrees     0.868     0.868 0.807   0.900 0.967
#          B1_RandomOverSampling + FS3_RFE   VotingSoft     0.868     0.867 0.807   0.900 0.958
#        B1_RandomOverSampling + FS2_KBest   ExtraTrees     0.868     0.868 0.806   0.900 0.966
#          B1_RandomOverSampling + FS3_RFE RandomForest     0.867     0.865 0.804   0.899 0.962
#          B1_RandomOverSampling + FS3_RFE   VotingHard     0.863     0.863 0.799   0.896   NaN
# B1_RandomOverSampling + FS5_RFImportance   ExtraTrees     0.862     0.862 0.798   0.896 0.968
#  B1_RandomOverSampling + FS1_Correlation   ExtraTrees     0.860     0.860 0.794   0.894 0.965
#  B1_RandomOverSampling + FS1_Correlation   VotingHard     0.860     0.860 0.793   0.894   NaN
#        B1_RandomOverSampling + FS2_KBest      XGBoost     0.857     0.857 0.791   0.892 0.951
#        B1_RandomOverSampling + FS2_KBest   VotingHard     0.856     0.855 0.788   0.891   NaN
#   B1_RandomOverSampling + FS4_MutualInfo   VotingHard     0.856     0.855 0.786   0.891   NaN
#   B1_RandomOverSampling + FS4_MutualInfo   ExtraTrees     0.854     0.854 0.784   0.890 0.962
#   B1_RandomOverSampling + FS4_MutualInfo     Stacking     0.853     0.853 0.782   0.888 0.960
#   B1_RandomOverSampling + FS4_MutualInfo   VotingSoft     0.853     0.852 0.781   0.888 0.955
# B1_RandomOverSampling + FS5_RFImportance   VotingHard     0.851     0.851 0.781   0.887   NaN
#  B1_RandomOverSampling + FS1_Correlation   VotingSoft     0.851     0.850 0.780   0.887 0.961
#        B1_RandomOverSampling + FS2_KBest RandomForest     0.849     0.848 0.778   0.886 0.961
# B1_RandomOverSampling + FS5_RFImportance   VotingSoft     0.848     0.847 0.776   0.885 0.962
#        B1_RandomOverSampling + FS2_KBest   VotingSoft     0.848     0.847 0.777   0.885 0.961
#          B1_RandomOverSampling + FS3_RFE     LightGBM     0.848     0.847 0.775   0.885 0.947
# B1_RandomOverSampling + FS5_RFImportance RandomForest     0.848     0.847 0.777   0.885 0.959
#   B1_RandomOverSampling + FS4_MutualInfo RandomForest     0.848     0.847 0.775   0.885 0.955
#  B1_RandomOverSampling + FS1_Correlation      XGBoost     0.846     0.844 0.774   0.884 0.955
#        B1_RandomOverSampling + FS2_KBest     LightGBM     0.846     0.846 0.774   0.884 0.950
#   B1_RandomOverSampling + FS4_MutualInfo     LightGBM     0.846     0.845 0.773   0.884 0.946
#          B1_RandomOverSampling + FS3_RFE      XGBoost     0.845     0.843 0.772   0.882 0.948
#
# -- Phase 3: Best Classifier per Balancer+FS combo --
#                               Balancer+FS   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#   B1_RandomOverSampling + FS1_Correlation     Stacking     0.882     0.882 0.828   0.911 0.964
#         B1_RandomOverSampling + FS2_KBest     Stacking     0.874     0.875 0.816   0.905 0.965
#           B1_RandomOverSampling + FS3_RFE     Stacking     0.874     0.875 0.816   0.905 0.967
#  B1_RandomOverSampling + FS5_RFImportance     Stacking     0.874     0.875 0.817   0.905 0.965
#    B1_RandomOverSampling + FS4_MutualInfo   VotingHard     0.856     0.855 0.786   0.891   NaN
#            B5_BorderlineSMOTE + FS2_KBest     Stacking     0.822     0.820 0.736   0.865 0.933
#     B5_BorderlineSMOTE + FS5_RFImportance   VotingHard     0.812     0.810 0.722   0.858   NaN
#              B3_ADASYN + FS5_RFImportance   ExtraTrees     0.809     0.807 0.717   0.855 0.913
#      B5_BorderlineSMOTE + FS1_Correlation   ExtraTrees     0.806     0.804 0.713   0.853 0.930
#       B5_BorderlineSMOTE + FS4_MutualInfo   ExtraTrees     0.803     0.801 0.708   0.851 0.934
#               B4_SMOTE + FS5_RFImportance   ExtraTrees     0.800     0.800 0.703   0.848 0.924
#          B7_SMOTETomek + FS5_RFImportance   ExtraTrees     0.796     0.794 0.697   0.845 0.918
#              B5_BorderlineSMOTE + FS3_RFE   VotingHard     0.792     0.790 0.693   0.842   NaN
#                     B3_ADASYN + FS2_KBest   ExtraTrees     0.787     0.785 0.685   0.838 0.903
#                      B4_SMOTE + FS2_KBest   VotingHard     0.785     0.783 0.681   0.836   NaN
#                B4_SMOTE + FS1_Correlation   ExtraTrees     0.784     0.783 0.681   0.836 0.912
#                 B7_SMOTETomek + FS2_KBest   ExtraTrees     0.783     0.783 0.678   0.835 0.912
#                 B4_SMOTE + FS4_MutualInfo     Stacking     0.780     0.778 0.674   0.833 0.912
#           B7_SMOTETomek + FS1_Correlation     Stacking     0.777     0.776 0.669   0.830 0.914
#                       B3_ADASYN + FS3_RFE   ExtraTrees     0.774     0.772 0.665   0.828 0.884
#                        B4_SMOTE + FS3_RFE   VotingHard     0.772     0.771 0.663   0.827   NaN
#                   B7_SMOTETomek + FS3_RFE   ExtraTrees     0.767     0.765 0.655   0.823 0.898
#            B7_SMOTETomek + FS4_MutualInfo   ExtraTrees     0.765     0.765 0.652   0.822 0.907
#                B3_ADASYN + FS4_MutualInfo   ExtraTrees     0.765     0.762 0.654   0.821 0.889
#               B3_ADASYN + FS1_Correlation   ExtraTrees     0.762     0.761 0.646   0.819 0.901
#                   B6_TomekLinks + FS3_RFE   VotingSoft     0.714     0.652 0.515   0.735 0.827
#                 B6_TomekLinks + FS2_KBest   ExtraTrees     0.706     0.634 0.497   0.721 0.823
#            B6_TomekLinks + FS4_MutualInfo   ExtraTrees     0.703     0.631 0.492   0.720 0.824
#          B6_TomekLinks + FS5_RFImportance   VotingSoft     0.703     0.627 0.490   0.714 0.823
#           B6_TomekLinks + FS1_Correlation     Stacking     0.698     0.613 0.476   0.703 0.820
#          B2_RandomUnderSampling + FS3_RFE   VotingHard     0.667     0.657 0.508   0.744   NaN
#   B2_RandomUnderSampling + FS4_MutualInfo     LightGBM     0.657     0.647 0.493   0.736 0.774
#  B2_RandomUnderSampling + FS1_Correlation RandomForest     0.638     0.626 0.468   0.721 0.806
# B2_RandomUnderSampling + FS5_RFImportance     LightGBM     0.629     0.615 0.449   0.712 0.785
#        B2_RandomUnderSampling + FS2_KBest   VotingHard     0.609     0.600 0.421   0.697   NaN

# %%
import os

out = '/mnt/user-data/outputs/'
# Create the output directory if it doesn't exist
os.makedirs(out, exist_ok=True)

combined = pd.concat([phase1_df, phase2_df, phase3_df], ignore_index=True)
combined.sort_values(['Phase','Accuracy'], ascending=[True, False], inplace=True)

combined.to_csv(out + 'pipeline_all_results.csv', index=False)
phase1_df.to_csv(out + 'phase1_balancing_results.csv', index=False)
phase2_df.to_csv(out + 'phase2_feature_selection_results.csv', index=False)
phase3_df.to_csv(out + 'phase3_combined_results.csv', index=False)

print("\n\n" + "="*80)
print("  DONE — 4 CSV files saved:")
print("  pipeline_all_results.csv             (all 3 phases combined)")
print("  phase1_balancing_results.csv         (Phase 1 only)")
print("  phase2_feature_selection_results.csv (Phase 2 only)")
print("  phase3_combined_results.csv          (Phase 3 only)")
print("="*80)
# Out:
# ================================================================================
#   DONE — 4 CSV files saved:
#   pipeline_all_results.csv             (all 3 phases combined)
#   phase1_balancing_results.csv         (Phase 1 only)
#   phase2_feature_selection_results.csv (Phase 2 only)
#   phase3_combined_results.csv          (Phase 3 only)
# ================================================================================
