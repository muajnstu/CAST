# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/CAST/blob/main/CAST_full_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Core ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.metrics import (
    accuracy_score, classification_report,
    matthews_corrcoef, roc_auc_score
)
from imblearn.metrics import geometric_mean_score

# Classifiers
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier,
    GradientBoostingClassifier, VotingClassifier, StackingClassifier
)
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron,
    SGDClassifier, PassiveAggressiveClassifier
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Balancing
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.combine import SMOTETomek


# optimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/muajnstu/CAST/refs/heads/main/Perception/Perception_1.csv'
)
print(f"Raw dataset shape : {df.shape}")
print(f"Target distribution:\n{df['CAST'].value_counts()}\n")

X_raw = df.drop(columns=['CAST'])
y_raw = df['CAST']
# Out:
# Raw dataset shape : (400, 47)
# Target distribution:
# CAST
# 0    218
# 1    110
# 2     72
# Name: count, dtype: int64

# %% [markdown]
# ***Data Balancing***

# %%
BALANCERS = {
    "B1_RandomOverSampling":  RandomOverSampler(random_state=42),
    "B2_RandomUnderSampling": RandomUnderSampler(random_state=42),
    "B3_ADASYN":              ADASYN(random_state=42),
    "B4_SMOTE":               SMOTE(random_state=42),
    "B5_BorderlineSMOTE":     BorderlineSMOTE(random_state=42),
    "B6_TomekLinks":          TomekLinks(),
    "B7_SMOTETomek":          SMOTETomek(random_state=42),
}


def apply_balancer(name, sampler, X, y):
    try:
        X_b, y_b = sampler.fit_resample(X, y)
        df_b = pd.DataFrame(X_b, columns=X.columns)
        df_b['CAST'] = y_b
        print(f"  {name:30s} -> shape {df_b.shape}  "
              f"dist: {dict(pd.Series(y_b).value_counts())}")
        return df_b
    except Exception as e:
        print(f"  {name:30s} -> FAILED: {e}")
        return None

# %% [markdown]
# ***Tunning FS Methods***

# %%
CV      = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
CV_EST  = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
N_TOTAL = X_raw.shape[1]

def _cv_score(X_sel, y):
    """Mean 5-fold CV accuracy for a given feature subset."""
    return cross_val_score(CV_EST, X_sel, y, cv=CV,
                           scoring='accuracy', n_jobs=-1).mean()

def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# Tune FS1
print("\n" + "="*70)
print("  TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)")
print("="*70)

print("\n[FS1] Sweeping correlation threshold...")
thresholds   = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
fs1_results  = {}
for thr in thresholds:
    corr  = X_raw.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= thr)]
    X_sel = X_raw.drop(columns=drop)
    score = _cv_score(X_sel, y_raw)
    fs1_results[thr] = (score, X_sel.shape[1])
    print(f"  threshold={thr:.2f}  features={X_sel.shape[1]:3d}  CV_acc={score:.4f}")

best_fs1_thr   = max(fs1_results, key=lambda t: fs1_results[t][0])
best_fs1_score = fs1_results[best_fs1_thr][0]
best_fs1_feats = fs1_results[best_fs1_thr][1]
print(f"  >> BEST threshold={best_fs1_thr}  features={best_fs1_feats}  CV_acc={best_fs1_score:.4f}")

# Tune FS2: KBest (f_classif)
print("\n[FS2] Sweeping k for SelectKBest (f_classif)...")
k_range     = list(range(1, N_TOTAL + 1))
fs2_results = {}
for k in k_range:
    sel   = SelectKBest(f_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs2_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs2_k     = max(fs2_results, key=fs2_results.get)
best_fs2_score = fs2_results[best_fs2_k]
print(f"  >> BEST k={best_fs2_k}  CV_acc={best_fs2_score:.4f}")

# Tune FS3: RFE
print("\n[FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...")
rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1),
    step=1, cv=CV, scoring='accuracy', n_jobs=-1, min_features_to_select=1
)
rfecv.fit(X_raw, y_raw)
best_fs3_n     = rfecv.n_features_
best_fs3_score = rfecv.cv_results_['mean_test_score'][best_fs3_n - 1]
_rfecv_support = rfecv.support_
print(f"  >> BEST n_features={best_fs3_n}  CV_acc={best_fs3_score:.4f}")

# Tune FS4: Mutual Information
print("\n[FS4] Sweeping k for SelectKBest (mutual_info_classif)...")
fs4_results = {}
for k in k_range:
    sel   = SelectKBest(mutual_info_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs4_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs4_k     = max(fs4_results, key=fs4_results.get)
best_fs4_score = fs4_results[best_fs4_k]
print(f"  >> BEST k={best_fs4_k}  CV_acc={best_fs4_score:.4f}")

# Tune FS5: RF Importance cumulative threshold
print("\n[FS5] Sweeping cumulative importance threshold for RF feature importance...")
_rf_imp  = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
_rf_imp.fit(X_raw, y_raw)
imp_series = pd.Series(_rf_imp.feature_importances_, index=X_raw.columns)\
               .sort_values(ascending=False)
cum_imp = imp_series.cumsum()

cum_thresholds = [0.80, 0.85, 0.90, 0.95, 0.99]
fs5_results    = {}
for ct in cum_thresholds:
    top_feats = cum_imp[cum_imp <= ct].index.tolist()
    if len(top_feats) == 0:
        top_feats = [imp_series.index[0]]
    X_sel = X_raw[top_feats]
    score = _cv_score(X_sel, y_raw)
    fs5_results[ct] = (score, len(top_feats))
    print(f"  cum_threshold={ct:.2f}  features={len(top_feats):3d}  CV_acc={score:.4f}")

best_fs5_ct    = max(fs5_results, key=lambda t: fs5_results[t][0])
best_fs5_score = fs5_results[best_fs5_ct][0]
best_fs5_feats = fs5_results[best_fs5_ct][1]
print(f"  >> BEST cum_threshold={best_fs5_ct}  features={best_fs5_feats}  CV_acc={best_fs5_score:.4f}")

# Summary of tuned parameters
print("\n" + "="*70)
print("  TUNING SUMMARY")
print("="*70)
tuning_summary = pd.DataFrame([
    {"FS": "FS1_Correlation",  "Parameter": "threshold",        "Best_Value": best_fs1_thr,  "n_features": best_fs1_feats, "CV_Accuracy": round(best_fs1_score, 4)},
    {"FS": "FS2_KBest",        "Parameter": "k",                "Best_Value": best_fs2_k,    "n_features": best_fs2_k,     "CV_Accuracy": round(best_fs2_score, 4)},
    {"FS": "FS3_RFE",          "Parameter": "n_features (RFECV)","Best_Value": best_fs3_n,   "n_features": best_fs3_n,     "CV_Accuracy": round(best_fs3_score, 4)},
    {"FS": "FS4_MutualInfo",   "Parameter": "k",                "Best_Value": best_fs4_k,    "n_features": best_fs4_k,     "CV_Accuracy": round(best_fs4_score, 4)},
    {"FS": "FS5_RFImportance", "Parameter": "cum_threshold",    "Best_Value": best_fs5_ct,   "n_features": best_fs5_feats, "CV_Accuracy": round(best_fs5_score, 4)},
])
print(tuning_summary.to_string(index=False))
# Out:
# ======================================================================
#   TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)
# ======================================================================
#
# [FS1] Sweeping correlation threshold...
#   threshold=0.70  features= 14  CV_acc=0.6575
#   threshold=0.75  features= 21  CV_acc=0.6450
#   threshold=0.80  features= 38  CV_acc=0.6575
#   threshold=0.85  features= 43  CV_acc=0.6575
#   threshold=0.90  features= 46  CV_acc=0.6450
#   threshold=0.95  features= 46  CV_acc=0.6450
#   >> BEST threshold=0.7  features=14  CV_acc=0.6575
#
# [FS2] Sweeping k for SelectKBest (f_classif)...
#   k=  1  CV_acc=0.6175
#   k=  2  CV_acc=0.6300
#   k=  3  CV_acc=0.6275
#   k=  4  CV_acc=0.6450
#   k=  5  CV_acc=0.6425
#   k=  6  CV_acc=0.6100
#   k=  7  CV_acc=0.6100
#   k=  8  CV_acc=0.6500
#   k=  9  CV_acc=0.6350
#   k= 10  CV_acc=0.6400
#   k= 11  CV_acc=0.6225
#   k= 12  CV_acc=0.6225
#   k= 13  CV_acc=0.6250
#   k= 14  CV_acc=0.6325
#   k= 15  CV_acc=0.6425
#   k= 16  CV_acc=0.6200
#   k= 17  CV_acc=0.6325
#   k= 18  CV_acc=0.6500
#   k= 19  CV_acc=0.6225
#   k= 20  CV_acc=0.6150
#   k= 21  CV_acc=0.6225
#   k= 22  CV_acc=0.6325
#   k= 23  CV_acc=0.6350
#   k= 24  CV_acc=0.6275
#   k= 25  CV_acc=0.6375
#   k= 26  CV_acc=0.6350
#   k= 27  CV_acc=0.6425
#   k= 28  CV_acc=0.6425
#   k= 29  CV_acc=0.6475
#   k= 30  CV_acc=0.6275
#   k= 31  CV_acc=0.6400
#   k= 32  CV_acc=0.6525
#   k= 33  CV_acc=0.6500
#   k= 34  CV_acc=0.6500
#   k= 35  CV_acc=0.6600
#   k= 36  CV_acc=0.6525
#   k= 37  CV_acc=0.6550
#   k= 38  CV_acc=0.6575
#   k= 39  CV_acc=0.6775
#   k= 40  CV_acc=0.6675
#   k= 41  CV_acc=0.6700
#   k= 42  CV_acc=0.6600
#   k= 43  CV_acc=0.6775
#   k= 44  CV_acc=0.6650
#   k= 45  CV_acc=0.6800
#   k= 46  CV_acc=0.6450
#   >> BEST k=45  CV_acc=0.6800
#
# [FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...
#   >> BEST n_features=24  CV_acc=0.6975
#
# [FS4] Sweeping k for SelectKBest (mutual_info_classif)...
#   k=  1  CV_acc=0.6175
#   k=  2  CV_acc=0.6100
#   k=  3  CV_acc=0.6175
#   k=  4  CV_acc=0.5900
#   k=  5  CV_acc=0.6175
#   k=  6  CV_acc=0.5950
#   k=  7  CV_acc=0.6500
#   k=  8  CV_acc=0.6200
#   k=  9  CV_acc=0.6225
#   k= 10  CV_acc=0.6275
#   k= 11  CV_acc=0.6225
#   k= 12  CV_acc=0.6500
#   k= 13  CV_acc=0.6650
#   k= 14  CV_acc=0.6575
#   k= 15  CV_acc=0.6350
#   k= 16  CV_acc=0.6500
#   k= 17  CV_acc=0.6350
#   k= 18  CV_acc=0.6375
#   k= 19  CV_acc=0.6275
#   k= 20  CV_acc=0.6450
#   k= 21  CV_acc=0.6400
#   k= 22  CV_acc=0.6600
#   k= 23  CV_acc=0.6500
#   k= 24  CV_acc=0.6650
#   k= 25  CV_acc=0.6550
#   k= 26  CV_acc=0.6300
#   k= 27  CV_acc=0.6600
#   k= 28  CV_acc=0.6625
#   k= 29  CV_acc=0.6600
#   k= 30  CV_acc=0.6375
#   k= 31  CV_acc=0.6525
#   k= 32  CV_acc=0.6700
#   k= 33  CV_acc=0.6550
#   k= 34  CV_acc=0.6225
#   k= 35  CV_acc=0.6525
#   k= 36  CV_acc=0.6775
#   k= 37  CV_acc=0.6825
#   k= 38  CV_acc=0.6525
#   k= 39  CV_acc=0.6525
#   k= 40  CV_acc=0.6600
#   k= 41  CV_acc=0.6650
#   k= 42  CV_acc=0.6625
#   k= 43  CV_acc=0.6675
#   k= 44  CV_acc=0.6675
#   k= 45  CV_acc=0.6500
#   k= 46  CV_acc=0.6450
#   >> BEST k=37  CV_acc=0.6825
#
# [FS5] Sweeping cumulative importance threshold for RF feature importance...
#   cum_threshold=0.80  features= 32  CV_acc=0.6525
#   cum_threshold=0.85  features= 35  CV_acc=0.6575
#   cum_threshold=0.90  features= 39  CV_acc=0.6375
#   cum_threshold=0.95  features= 42  CV_acc=0.6425
#   cum_threshold=0.99  features= 45  CV_acc=0.6775
#   >> BEST cum_threshold=0.99  features=45  CV_acc=0.6775
#
# ======================================================================
#   TUNING SUMMARY
# ======================================================================
#               FS          Parameter  Best_Value  n_features  CV_Accuracy
#  FS1_Correlation          threshold        0.70          14       0.6575
#        FS2_KBest                  k       45.00          45       0.6800
#          FS3_RFE n_features (RFECV)       24.00          24       0.6975
#   FS4_MutualInfo                  k       37.00          37       0.6825
# FS5_RFImportance      cum_threshold        0.99          45       0.6775

# %% [markdown]
# ***FS Methods***

# %%
def fs_correlation(data, target_col='CAST', threshold=best_fs1_thr):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    corr  = X_.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= threshold)]
    out   = X_.drop(columns=drop).copy(); out[target_col] = y_.values
    return out

def fs_kbest(data, target_col='CAST', k=best_fs2_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(f_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rfe(data, target_col='CAST', support=_rfecv_support):

    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    cols = X_.columns[support] if len(support) == X_.shape[1] else X_.columns
    out  = X_[cols].copy(); out[target_col] = y_.values
    return out

def fs_mi(data, target_col='CAST', k=best_fs4_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(mutual_info_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rf_importance(data, target_col='CAST', cum_threshold=best_fs5_ct):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    rf  = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_, y_)
    imp = pd.Series(rf.feature_importances_, index=X_.columns).sort_values(ascending=False)
    top = imp.cumsum()[imp.cumsum() <= cum_threshold].index.tolist()
    if len(top) == 0:
        top = [imp.index[0]]
    out = X_[top].copy(); out[target_col] = y_.values
    return out

FEATURE_SELECTORS = {
    "FS1_Correlation":  lambda d: fs_correlation(d),
    "FS2_KBest":        lambda d: fs_kbest(d),
    "FS3_RFE":          lambda d: fs_rfe(d),
    "FS4_MutualInfo":   lambda d: fs_mi(d),
    "FS5_RFImportance": lambda d: fs_rf_importance(d),
}

# %% [markdown]
# ***Evaluation Metrics***

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]
    X_tr, X_te, y_tr, y_te = train_test_split(
        X_, y_, test_size=0.25, random_state=42, stratify=y_
    )
    rows = []
    for clf_name, model in build_models().items():
        try:
            model.fit(X_tr, y_tr)
            y_pred = model.predict(X_te)

            # ── Core metrics
            acc     = accuracy_score(y_te, y_pred)
            rep     = classification_report(y_te, y_pred, zero_division=0,
                                            output_dict=True)
            mcc     = matthews_corrcoef(y_te, y_pred)
            gmean   = geometric_mean_score(y_te, y_pred, average='macro')

            # ── AUC:
            n_classes = len(np.unique(y_te))
            try:
                if hasattr(model, 'predict_proba'):
                    y_score = model.predict_proba(X_te)
                else:
                    y_score = model.decision_function(X_te)
                    if n_classes > 2:
                        # decision_function for multiclass → already (n, k)
                        pass
                    else:
                        y_score = y_score.reshape(-1, 1)

                if n_classes == 2:
                    # Binary: use probability of positive class
                    prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                    auc = roc_auc_score(y_te, prob)
                else:
                    auc = roc_auc_score(
                        y_te, y_score,
                        multi_class='ovr', average='macro',
                        labels=np.unique(y_te)
                    )
            except Exception:
                auc = None

            rows.append({
                'Label':           label,
                'Classifier':      clf_name,
                'Accuracy':        round(acc,   4),
                'Macro_F1':        round(rep['macro avg']['f1-score'],   4),
                'Macro_Precision': round(rep['macro avg']['precision'],  4),
                'Macro_Recall':    round(rep['macro avg']['recall'],     4),
                'MCC':             round(mcc,   4),
                'G_Mean':          round(gmean, 4),
                'AUC':             round(auc,   4) if auc is not None else None,
            })
            if verbose:
                auc_str = f"{auc:.4f}" if auc is not None else "  N/A"
                print(f"    {clf_name:25s}  Acc={acc:.4f}  F1={rep['macro avg']['f1-score']:.4f}"
                      f"  MCC={mcc:.4f}  G-Mean={gmean:.4f}  AUC={auc_str}")
        except Exception as e:
            rows.append({'Label': label, 'Classifier': clf_name,
                         'Accuracy': None, 'Macro_F1': None,
                         'Macro_Precision': None, 'Macro_Recall': None,
                         'MCC': None, 'G_Mean': None, 'AUC': None})
            if verbose:
                print(f"    {clf_name:25s}  ERROR: {e}")
    return rows


def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# %% [markdown]
# ***ML Models***

# %%
def build_models():
    return {
        "RandomForest":       RandomForestClassifier(random_state=42),
        "ExtraTrees":         ExtraTreesClassifier(random_state=42),
        "Bagging":            BaggingClassifier(random_state=42),
        "GradientBoosting":   GradientBoostingClassifier(random_state=42),
        "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
        "RidgeClassifier":    RidgeClassifier(),
        "DecisionTree":       DecisionTreeClassifier(random_state=42),
        "NaiveBayes":         GaussianNB(),
        "Perceptron":         Perceptron(random_state=42),
        "SGDClassifier":      SGDClassifier(random_state=42),
        "PassiveAggressive":  PassiveAggressiveClassifier(random_state=42),
        "LDA":                LinearDiscriminantAnalysis(),
        "QDA":                QuadraticDiscriminantAnalysis(),
        "LightGBM":           LGBMClassifier(verbosity=-1, random_state=42),
        "XGBoost":            XGBClassifier(n_estimators=100, random_state=42,
                                            eval_metric='mlogloss',
                                            use_label_encoder=False, verbosity=0),
        "VotingSoft": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='soft', n_jobs=-1),
        "VotingHard": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='hard', n_jobs=-1),
        "Stacking": StackingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], final_estimator=LogisticRegression(max_iter=1000, random_state=42),
           cv=5, stack_method='predict_proba', n_jobs=-1),
    }

# %% [markdown]
# # ***# Experiment 1***

# %%
section_header("PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)")

print("\nApplying balancers to raw data...")
balanced_datasets = {}
for bal_name, sampler in BALANCERS.items():
    df_b = apply_balancer(bal_name, sampler, X_raw, y_raw)
    if df_b is not None:
        balanced_datasets[bal_name] = df_b

phase1_rows = []
for bal_name, bal_df in balanced_datasets.items():
    sub_header(f"Balancer: {bal_name}  |  shape={bal_df.shape}")
    rows = evaluate_dataset(bal_df, label=bal_name, verbose=True)
    phase1_rows.extend(rows)

phase1_df = pd.DataFrame(phase1_rows).dropna(subset=['Accuracy'])
phase1_df['Phase'] = 'Phase1_BalancingOnly'
phase1_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 1 Summary (top 20 by Accuracy) --")
p1_show = phase1_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer'})
METRICS = ['Accuracy','Macro_F1','MCC','G_Mean','AUC']
print(p1_show[['Balancer','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 1: Best Classifier per Balancer --")
best_p1 = (p1_show.groupby('Balancer', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer','Classifier'] + METRICS])
print(best_p1.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)
# ################################################################################
#
# Applying balancers to raw data...
#   B1_RandomOverSampling          -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B2_RandomUnderSampling         -> shape (216, 47)  dist: {0: np.int64(72), 1: np.int64(72), 2: np.int64(72)}
#   B3_ADASYN                      -> shape (655, 47)  dist: {1: np.int64(224), 0: np.int64(218), 2: np.int64(213)}
#   B4_SMOTE                       -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B5_BorderlineSMOTE             -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B6_TomekLinks                  -> shape (369, 47)  dist: {0: np.int64(202), 1: np.int64(95), 2: np.int64(72)}
#   B7_SMOTETomek                  -> shape (642, 47)  dist: {2: np.int64(216), 1: np.int64(214), 0: np.int64(212)}
#
# ======================================================================
#   Balancer: B1_RandomOverSampling  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.8354  F1=0.8291  MCC=0.7595  G-Mean=0.8749  AUC=0.9783
#     ExtraTrees                 Acc=0.8963  F1=0.8936  MCC=0.8480  G-Mean=0.9214  AUC=0.9849
#     Bagging                    Acc=0.8232  F1=0.8174  MCC=0.7392  G-Mean=0.8656  AUC=0.9457
#     GradientBoosting           Acc=0.7988  F1=0.7943  MCC=0.7011  G-Mean=0.8470  AUC=0.9510
#     LogisticRegression         Acc=0.6220  F1=0.6161  MCC=0.4346  G-Mean=0.7105  AUC=0.8263
#     RidgeClassifier            Acc=0.6585  F1=0.6459  MCC=0.4941  G-Mean=0.7394  AUC=  N/A
#     DecisionTree               Acc=0.8232  F1=0.8187  MCC=0.7397  G-Mean=0.8656  AUC=0.8689
#     NaiveBayes                 Acc=0.6707  F1=0.6679  MCC=0.5069  G-Mean=0.7487  AUC=0.8188
#     Perceptron                 Acc=0.4817  F1=0.4431  MCC=0.2438  G-Mean=0.5980  AUC=  N/A
#     SGDClassifier              Acc=0.5976  F1=0.6014  MCC=0.3973  G-Mean=0.6908  AUC=  N/A
#     PassiveAggressive          Acc=0.5549  F1=0.5131  MCC=0.3705  G-Mean=0.6565  AUC=  N/A
#     LDA                        Acc=0.6280  F1=0.6195  MCC=0.4449  G-Mean=0.7154  AUC=0.8326
#     QDA                        Acc=0.8232  F1=0.8231  MCC=0.7352  G-Mean=0.8662  AUC=0.9099
#     LightGBM                   Acc=0.8537  F1=0.8492  MCC=0.7858  G-Mean=0.8889  AUC=0.9789
#     XGBoost                    Acc=0.8598  F1=0.8561  MCC=0.7938  G-Mean=0.8936  AUC=0.9843
#     VotingSoft                 Acc=0.8537  F1=0.8485  MCC=0.7862  G-Mean=0.8889  AUC=0.9795
#     VotingHard                 Acc=0.8537  F1=0.8495  MCC=0.7838  G-Mean=0.8889  AUC=  N/A
#     Stacking                   Acc=0.8902  F1=0.8880  MCC=0.8370  G-Mean=0.9169  AUC=0.9840
#
# ======================================================================
#   Balancer: B2_RandomUnderSampling  |  shape=(216, 47)
# ======================================================================
#     RandomForest               Acc=0.2963  F1=0.3023  MCC=-0.0566  G-Mean=0.4382  AUC=0.6013
#     ExtraTrees                 Acc=0.3704  F1=0.3775  MCC=0.0559  G-Mean=0.5038  AUC=0.6119
#     Bagging                    Acc=0.3519  F1=0.3536  MCC=0.0278  G-Mean=0.4877  AUC=0.5769
#     GradientBoosting           Acc=0.3333  F1=0.3361  MCC=0.0000  G-Mean=0.4714  AUC=0.5417
#     LogisticRegression         Acc=0.3519  F1=0.3451  MCC=0.0279  G-Mean=0.4877  AUC=0.5319
#     RidgeClassifier            Acc=0.3704  F1=0.3515  MCC=0.0568  G-Mean=0.5038  AUC=  N/A
#     DecisionTree               Acc=0.3889  F1=0.3908  MCC=0.0836  G-Mean=0.5197  AUC=0.5239
#     NaiveBayes                 Acc=0.4630  F1=0.4525  MCC=0.1958  G-Mean=0.5819  AUC=0.6425
#     Perceptron                 Acc=0.4815  F1=0.4768  MCC=0.2298  G-Mean=0.5972  AUC=  N/A
#     SGDClassifier              Acc=0.4259  F1=0.4045  MCC=0.1449  G-Mean=0.5511  AUC=  N/A
#     PassiveAggressive          Acc=0.3519  F1=0.3504  MCC=0.0283  G-Mean=0.4877  AUC=  N/A
#     LDA                        Acc=0.3889  F1=0.3742  MCC=0.0851  G-Mean=0.5197  AUC=0.5571
#     QDA                        Acc=0.2963  F1=0.2545  MCC=-0.0639  G-Mean=0.4382  AUC=0.4537
#     LightGBM                   Acc=0.3704  F1=0.3710  MCC=0.0561  G-Mean=0.5038  AUC=0.5514
#     XGBoost                    Acc=0.3704  F1=0.3731  MCC=0.0560  G-Mean=0.5038  AUC=0.5370
#     VotingSoft                 Acc=0.2963  F1=0.2975  MCC=-0.0556  G-Mean=0.4382  AUC=0.5792
#     VotingHard                 Acc=0.3148  F1=0.3208  MCC=-0.0282  G-Mean=0.4549  AUC=  N/A
#     Stacking                   Acc=0.3333  F1=0.3366  MCC=0.0000  G-Mean=0.4714  AUC=0.5910
#
# ======================================================================
#   Balancer: B3_ADASYN  |  shape=(655, 47)
# ======================================================================
#     RandomForest               Acc=0.7317  F1=0.7303  MCC=0.5992  G-Mean=0.7971  AUC=0.8982
#     ExtraTrees                 Acc=0.7683  F1=0.7702  MCC=0.6529  G-Mean=0.8250  AUC=0.9119
#     Bagging                    Acc=0.7134  F1=0.7147  MCC=0.5707  G-Mean=0.7826  AUC=0.8631
#     GradientBoosting           Acc=0.7256  F1=0.7299  MCC=0.5886  G-Mean=0.7920  AUC=0.8922
#     LogisticRegression         Acc=0.5244  F1=0.5234  MCC=0.2884  G-Mean=0.6330  AUC=0.7349
#     RidgeClassifier            Acc=0.5427  F1=0.5409  MCC=0.3156  G-Mean=0.6476  AUC=  N/A
#     DecisionTree               Acc=0.6463  F1=0.6458  MCC=0.4701  G-Mean=0.7300  AUC=0.7495
#     NaiveBayes                 Acc=0.5610  F1=0.5535  MCC=0.3516  G-Mean=0.6628  AUC=0.6924
#     Perceptron                 Acc=0.5183  F1=0.5047  MCC=0.2998  G-Mean=0.6305  AUC=  N/A
#     SGDClassifier              Acc=0.4207  F1=0.3579  MCC=0.1622  G-Mean=0.5412  AUC=  N/A
#     PassiveAggressive          Acc=0.4878  F1=0.4645  MCC=0.2440  G-Mean=0.6061  AUC=  N/A
#     LDA                        Acc=0.5366  F1=0.5352  MCC=0.3068  G-Mean=0.6426  AUC=0.7475
#     QDA                        Acc=0.6890  F1=0.6898  MCC=0.5363  G-Mean=0.7635  AUC=0.8536
#     LightGBM                   Acc=0.7561  F1=0.7559  MCC=0.6345  G-Mean=0.8158  AUC=0.9112
#     XGBoost                    Acc=0.7622  F1=0.7610  MCC=0.6443  G-Mean=0.8207  AUC=0.9169
#     VotingSoft                 Acc=0.7744  F1=0.7764  MCC=0.6615  G-Mean=0.8297  AUC=0.9196
#     VotingHard                 Acc=0.7561  F1=0.7569  MCC=0.6351  G-Mean=0.8157  AUC=  N/A
#     Stacking                   Acc=0.7744  F1=0.7772  MCC=0.6617  G-Mean=0.8297  AUC=0.9190
#
# ======================================================================
#   Balancer: B4_SMOTE  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.7744  F1=0.7726  MCC=0.6626  G-Mean=0.8285  AUC=0.9273
#     ExtraTrees                 Acc=0.7805  F1=0.7781  MCC=0.6726  G-Mean=0.8332  AUC=0.9413
#     Bagging                    Acc=0.7073  F1=0.7058  MCC=0.5617  G-Mean=0.7767  AUC=0.8858
#     GradientBoosting           Acc=0.7683  F1=0.7690  MCC=0.6542  G-Mean=0.8241  AUC=0.9118
#     LogisticRegression         Acc=0.6402  F1=0.6394  MCC=0.4623  G-Mean=0.7249  AUC=0.8109
#     RidgeClassifier            Acc=0.6098  F1=0.6050  MCC=0.4190  G-Mean=0.7010  AUC=  N/A
#     DecisionTree               Acc=0.6768  F1=0.6722  MCC=0.5182  G-Mean=0.7528  AUC=0.7610
#     NaiveBayes                 Acc=0.6037  F1=0.6020  MCC=0.4101  G-Mean=0.6962  AUC=0.7612
#     Perceptron                 Acc=0.4573  F1=0.4450  MCC=0.2069  G-Mean=0.5785  AUC=  N/A
#     SGDClassifier              Acc=0.5122  F1=0.4608  MCC=0.3029  G-Mean=0.6226  AUC=  N/A
#     PassiveAggressive          Acc=0.5000  F1=0.4575  MCC=0.2709  G-Mean=0.6126  AUC=  N/A
#     LDA                        Acc=0.6159  F1=0.6149  MCC=0.4259  G-Mean=0.7057  AUC=0.8046
#     QDA                        Acc=0.7012  F1=0.7025  MCC=0.5559  G-Mean=0.7725  AUC=0.8283
#     LightGBM                   Acc=0.7622  F1=0.7601  MCC=0.6445  G-Mean=0.8191  AUC=0.9253
#     XGBoost                    Acc=0.7744  F1=0.7739  MCC=0.6625  G-Mean=0.8286  AUC=0.9363
#     VotingSoft                 Acc=0.7683  F1=0.7665  MCC=0.6534  G-Mean=0.8238  AUC=0.9365
#     VotingHard                 Acc=0.7683  F1=0.7663  MCC=0.6531  G-Mean=0.8238  AUC=  N/A
#     Stacking                   Acc=0.7927  F1=0.7925  MCC=0.6894  G-Mean=0.8427  AUC=0.9428
#
# ======================================================================
#   Balancer: B5_BorderlineSMOTE  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.7866  F1=0.7807  MCC=0.6861  G-Mean=0.8375  AUC=0.9315
#     ExtraTrees                 Acc=0.8110  F1=0.8066  MCC=0.7217  G-Mean=0.8563  AUC=0.9464
#     Bagging                    Acc=0.7988  F1=0.7957  MCC=0.7003  G-Mean=0.8471  AUC=0.9134
#     GradientBoosting           Acc=0.7561  F1=0.7552  MCC=0.6344  G-Mean=0.8145  AUC=0.9148
#     LogisticRegression         Acc=0.6341  F1=0.6240  MCC=0.4585  G-Mean=0.7202  AUC=0.8034
#     RidgeClassifier            Acc=0.6220  F1=0.6110  MCC=0.4420  G-Mean=0.7108  AUC=  N/A
#     DecisionTree               Acc=0.7439  F1=0.7421  MCC=0.6165  G-Mean=0.8050  AUC=0.8071
#     NaiveBayes                 Acc=0.5854  F1=0.5785  MCC=0.3869  G-Mean=0.6818  AUC=0.7225
#     Perceptron                 Acc=0.4390  F1=0.4105  MCC=0.2043  G-Mean=0.5640  AUC=  N/A
#     SGDClassifier              Acc=0.5671  F1=0.5681  MCC=0.3535  G-Mean=0.6662  AUC=  N/A
#     PassiveAggressive          Acc=0.5854  F1=0.5625  MCC=0.3936  G-Mean=0.6812  AUC=  N/A
#     LDA                        Acc=0.6037  F1=0.5953  MCC=0.4120  G-Mean=0.6963  AUC=0.8141
#     QDA                        Acc=0.7317  F1=0.7326  MCC=0.5980  G-Mean=0.7959  AUC=0.8677
#     LightGBM                   Acc=0.7744  F1=0.7715  MCC=0.6625  G-Mean=0.8285  AUC=0.9353
#     XGBoost                    Acc=0.8232  F1=0.8215  MCC=0.7359  G-Mean=0.8659  AUC=0.9426
#     VotingSoft                 Acc=0.7927  F1=0.7882  MCC=0.6931  G-Mean=0.8423  AUC=0.9406
#     VotingHard                 Acc=0.7988  F1=0.7953  MCC=0.7012  G-Mean=0.8470  AUC=  N/A
#     Stacking                   Acc=0.8415  F1=0.8400  MCC=0.7650  G-Mean=0.8798  AUC=0.9484
#
# ======================================================================
#   Balancer: B6_TomekLinks  |  shape=(369, 47)
# ======================================================================
#     RandomForest               Acc=0.6667  F1=0.5902  MCC=0.4042  G-Mean=0.6672  AUC=0.8158
#     ExtraTrees                 Acc=0.6882  F1=0.6253  MCC=0.4463  G-Mean=0.6903  AUC=0.8136
#     Bagging                    Acc=0.6344  F1=0.5733  MCC=0.3575  G-Mean=0.6601  AUC=0.7343
#     GradientBoosting           Acc=0.6667  F1=0.6242  MCC=0.4213  G-Mean=0.6970  AUC=0.7718
#     LogisticRegression         Acc=0.6559  F1=0.5640  MCC=0.3982  G-Mean=0.6676  AUC=0.7058
#     RidgeClassifier            Acc=0.6559  F1=0.5381  MCC=0.3915  G-Mean=0.6534  AUC=  N/A
#     DecisionTree               Acc=0.5054  F1=0.4554  MCC=0.1702  G-Mean=0.5716  AUC=0.5870
#     NaiveBayes                 Acc=0.7097  F1=0.6574  MCC=0.4982  G-Mean=0.7341  AUC=0.8059
#     Perceptron                 Acc=0.4946  F1=0.3555  MCC=0.1741  G-Mean=0.5367  AUC=  N/A
#     SGDClassifier              Acc=0.5161  F1=0.3967  MCC=0.2123  G-Mean=0.5657  AUC=  N/A
#     PassiveAggressive          Acc=0.5484  F1=0.3321  MCC=0.1258  G-Mean=0.5083  AUC=  N/A
#     LDA                        Acc=0.6452  F1=0.5414  MCC=0.3769  G-Mean=0.6545  AUC=0.7045
#     QDA                        Acc=0.5484  F1=0.3905  MCC=0.1515  G-Mean=0.5343  AUC=0.5471
#     LightGBM                   Acc=0.6022  F1=0.5501  MCC=0.3143  G-Mean=0.6421  AUC=0.7857
#     XGBoost                    Acc=0.6237  F1=0.5718  MCC=0.3388  G-Mean=0.6510  AUC=0.7842
#     VotingSoft                 Acc=0.6882  F1=0.6346  MCC=0.4531  G-Mean=0.7043  AUC=0.7986
#     VotingHard                 Acc=0.6559  F1=0.5712  MCC=0.3817  G-Mean=0.6529  AUC=  N/A
#     Stacking                   Acc=0.7204  F1=0.6626  MCC=0.5082  G-Mean=0.7190  AUC=0.8039
#
# ======================================================================
#   Balancer: B7_SMOTETomek  |  shape=(642, 47)
# ======================================================================
#     RandomForest               Acc=0.8012  F1=0.8020  MCC=0.7028  G-Mean=0.8496  AUC=0.9264
#     ExtraTrees                 Acc=0.8012  F1=0.8019  MCC=0.7027  G-Mean=0.8495  AUC=0.9429
#     Bagging                    Acc=0.7826  F1=0.7817  MCC=0.6746  G-Mean=0.8349  AUC=0.8967
#     GradientBoosting           Acc=0.8012  F1=0.8022  MCC=0.7035  G-Mean=0.8496  AUC=0.9195
#     LogisticRegression         Acc=0.6460  F1=0.6403  MCC=0.4732  G-Mean=0.7296  AUC=0.7743
#     RidgeClassifier            Acc=0.6273  F1=0.6178  MCC=0.4460  G-Mean=0.7149  AUC=  N/A
#     DecisionTree               Acc=0.6708  F1=0.6718  MCC=0.5075  G-Mean=0.7487  AUC=0.7579
#     NaiveBayes                 Acc=0.6398  F1=0.6364  MCC=0.4697  G-Mean=0.7249  AUC=0.7456
#     Perceptron                 Acc=0.5342  F1=0.5370  MCC=0.3088  G-Mean=0.6396  AUC=  N/A
#     SGDClassifier              Acc=0.5590  F1=0.5498  MCC=0.3412  G-Mean=0.6603  AUC=  N/A
#     PassiveAggressive          Acc=0.5590  F1=0.5600  MCC=0.3418  G-Mean=0.6603  AUC=  N/A
#     LDA                        Acc=0.6273  F1=0.6211  MCC=0.4439  G-Mean=0.7149  AUC=0.7806
#     QDA                        Acc=0.6894  F1=0.6821  MCC=0.5455  G-Mean=0.7638  AUC=0.8497
#     LightGBM                   Acc=0.8137  F1=0.8141  MCC=0.7214  G-Mean=0.8590  AUC=0.9236
#     XGBoost                    Acc=0.7764  F1=0.7768  MCC=0.6648  G-Mean=0.8303  AUC=0.9232
#     VotingSoft                 Acc=0.8137  F1=0.8141  MCC=0.7233  G-Mean=0.8591  AUC=0.9400
#     VotingHard                 Acc=0.8261  F1=0.8265  MCC=0.7409  G-Mean=0.8686  AUC=  N/A
#     Stacking                   Acc=0.8012  F1=0.8021  MCC=0.7057  G-Mean=0.8497  AUC=0.9436
#
#
# -- Phase 1 Summary (top 20 by Accuracy) --
#              Balancer       Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
# B1_RandomOverSampling       ExtraTrees    0.8963    0.8936 0.8480  0.9214 0.9849
# B1_RandomOverSampling         Stacking    0.8902    0.8880 0.8370  0.9169 0.9840
# B1_RandomOverSampling          XGBoost    0.8598    0.8561 0.7938  0.8936 0.9843
# B1_RandomOverSampling       VotingSoft    0.8537    0.8485 0.7862  0.8889 0.9795
# B1_RandomOverSampling       VotingHard    0.8537    0.8495 0.7838  0.8889    NaN
# B1_RandomOverSampling         LightGBM    0.8537    0.8492 0.7858  0.8889 0.9789
#    B5_BorderlineSMOTE         Stacking    0.8415    0.8400 0.7650  0.8798 0.9484
# B1_RandomOverSampling     RandomForest    0.8354    0.8291 0.7595  0.8749 0.9783
#         B7_SMOTETomek       VotingHard    0.8261    0.8265 0.7409  0.8686    NaN
# B1_RandomOverSampling          Bagging    0.8232    0.8174 0.7392  0.8656 0.9457
# B1_RandomOverSampling     DecisionTree    0.8232    0.8187 0.7397  0.8656 0.8689
#    B5_BorderlineSMOTE          XGBoost    0.8232    0.8215 0.7359  0.8659 0.9426
# B1_RandomOverSampling              QDA    0.8232    0.8231 0.7352  0.8662 0.9099
#         B7_SMOTETomek         LightGBM    0.8137    0.8141 0.7214  0.8590 0.9236
#         B7_SMOTETomek       VotingSoft    0.8137    0.8141 0.7233  0.8591 0.9400
#    B5_BorderlineSMOTE       ExtraTrees    0.8110    0.8066 0.7217  0.8563 0.9464
#         B7_SMOTETomek GradientBoosting    0.8012    0.8022 0.7035  0.8496 0.9195
#         B7_SMOTETomek       ExtraTrees    0.8012    0.8019 0.7027  0.8495 0.9429
#         B7_SMOTETomek         Stacking    0.8012    0.8021 0.7057  0.8497 0.9436
#         B7_SMOTETomek     RandomForest    0.8012    0.8020 0.7028  0.8496 0.9264
#
# -- Phase 1: Best Classifier per Balancer --
#               Balancer Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
#  B1_RandomOverSampling ExtraTrees    0.8963    0.8936 0.8480  0.9214 0.9849
# B2_RandomUnderSampling Perceptron    0.4815    0.4768 0.2298  0.5972    NaN
#              B3_ADASYN VotingSoft    0.7744    0.7764 0.6615  0.8297 0.9196
#               B4_SMOTE   Stacking    0.7927    0.7925 0.6894  0.8427 0.9428
#     B5_BorderlineSMOTE   Stacking    0.8415    0.8400 0.7650  0.8798 0.9484
#          B6_TomekLinks   Stacking    0.7204    0.6626 0.5082  0.7190 0.8039
#          B7_SMOTETomek VotingHard    0.8261    0.8265 0.7409  0.8686    NaN

# %% [markdown]
# # ***Experiment 2***

# %%
section_header("PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)")

phase2_rows = []
for fs_name, fs_fn in FEATURE_SELECTORS.items():
    try:
        fs_df = fs_fn(df)
        sub_header(f"Feature Selector: {fs_name}  |  features={fs_df.shape[1]-1}")
        rows = evaluate_dataset(fs_df, label=fs_name, verbose=True)
        phase2_rows.extend(rows)
    except Exception as e:
        print(f"  {fs_name} FAILED: {e}")

phase2_df = pd.DataFrame(phase2_rows).dropna(subset=['Accuracy'])
phase2_df['Phase'] = 'Phase2_FeatureSelectionOnly'
phase2_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 2 Summary (top 20 by Accuracy) --")
p2_show = phase2_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'FeatureSelector'})
print(p2_show[['FeatureSelector','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 2: Best Classifier per Feature Selector --")
best_p2 = (p2_show.groupby('FeatureSelector', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['FeatureSelector','Classifier'] + METRICS])
print(best_p2.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)
# ################################################################################
#
# ======================================================================
#   Feature Selector: FS1_Correlation  |  features=14
# ======================================================================
#     RandomForest               Acc=0.7000  F1=0.6399  MCC=0.4749  G-Mean=0.7146  AUC=0.8280
#     ExtraTrees                 Acc=0.6600  F1=0.5694  MCC=0.4034  G-Mean=0.6706  AUC=0.8236
#     Bagging                    Acc=0.6500  F1=0.5550  MCC=0.3780  G-Mean=0.6544  AUC=0.7862
#     GradientBoosting           Acc=0.6400  F1=0.5940  MCC=0.3889  G-Mean=0.6826  AUC=0.8077
#     LogisticRegression         Acc=0.6900  F1=0.6102  MCC=0.4578  G-Mean=0.6999  AUC=0.7998
#     RidgeClassifier            Acc=0.6200  F1=0.4970  MCC=0.3184  G-Mean=0.6191  AUC=  N/A
#     DecisionTree               Acc=0.5800  F1=0.5060  MCC=0.2940  G-Mean=0.6253  AUC=0.6225
#     NaiveBayes                 Acc=0.6100  F1=0.5371  MCC=0.3425  G-Mean=0.6524  AUC=0.7662
#     Perceptron                 Acc=0.6800  F1=0.5940  MCC=0.4656  G-Mean=0.7047  AUC=  N/A
#     SGDClassifier              Acc=0.6000  F1=0.4961  MCC=0.3280  G-Mean=0.6304  AUC=  N/A
#     PassiveAggressive          Acc=0.5300  F1=0.4202  MCC=0.2011  G-Mean=0.5637  AUC=  N/A
#     LDA                        Acc=0.6300  F1=0.5336  MCC=0.3572  G-Mean=0.6487  AUC=0.7937
#     QDA                        Acc=0.5900  F1=0.5177  MCC=0.3038  G-Mean=0.6342  AUC=0.7517
#     LightGBM                   Acc=0.6500  F1=0.5963  MCC=0.3969  G-Mean=0.6834  AUC=0.8210
#     XGBoost                    Acc=0.6900  F1=0.6350  MCC=0.4775  G-Mean=0.7235  AUC=0.8151
#     VotingSoft                 Acc=0.6300  F1=0.5739  MCC=0.3591  G-Mean=0.6639  AUC=0.8330
#     VotingHard                 Acc=0.6600  F1=0.5686  MCC=0.3949  G-Mean=0.6633  AUC=  N/A
#     Stacking                   Acc=0.6700  F1=0.5942  MCC=0.4118  G-Mean=0.6747  AUC=0.8084
#
# ======================================================================
#   Feature Selector: FS2_KBest  |  features=45
# ======================================================================
#     RandomForest               Acc=0.6700  F1=0.5930  MCC=0.4290  G-Mean=0.6898  AUC=0.8048
#     ExtraTrees                 Acc=0.6600  F1=0.5689  MCC=0.4171  G-Mean=0.6793  AUC=0.8003
#     Bagging                    Acc=0.6000  F1=0.5442  MCC=0.3067  G-Mean=0.6386  AUC=0.7180
#     GradientBoosting           Acc=0.6600  F1=0.5882  MCC=0.4203  G-Mean=0.6894  AUC=0.8264
#     LogisticRegression         Acc=0.6200  F1=0.5107  MCC=0.3322  G-Mean=0.6301  AUC=0.7263
#     RidgeClassifier            Acc=0.6300  F1=0.5242  MCC=0.3468  G-Mean=0.6383  AUC=  N/A
#     DecisionTree               Acc=0.5800  F1=0.5184  MCC=0.3102  G-Mean=0.6364  AUC=0.6429
#     NaiveBayes                 Acc=0.6500  F1=0.5967  MCC=0.4277  G-Mean=0.7055  AUC=0.7751
#     Perceptron                 Acc=0.5600  F1=0.4404  MCC=0.2096  G-Mean=0.5694  AUC=  N/A
#     SGDClassifier              Acc=0.5400  F1=0.4349  MCC=0.2069  G-Mean=0.5725  AUC=  N/A
#     PassiveAggressive          Acc=0.6000  F1=0.4959  MCC=0.3014  G-Mean=0.6194  AUC=  N/A
#     LDA                        Acc=0.6100  F1=0.5096  MCC=0.3205  G-Mean=0.6287  AUC=0.7434
#     QDA                        Acc=0.6200  F1=0.4446  MCC=0.2973  G-Mean=0.5909  AUC=0.6317
#     LightGBM                   Acc=0.6400  F1=0.5826  MCC=0.3927  G-Mean=0.6820  AUC=0.8015
#     XGBoost                    Acc=0.6600  F1=0.6051  MCC=0.4402  G-Mean=0.7076  AUC=0.8092
#     VotingSoft                 Acc=0.6800  F1=0.6177  MCC=0.4496  G-Mean=0.7064  AUC=0.8220
#     VotingHard                 Acc=0.6900  F1=0.6136  MCC=0.4690  G-Mean=0.7106  AUC=  N/A
#     Stacking                   Acc=0.6900  F1=0.6153  MCC=0.4605  G-Mean=0.7046  AUC=0.8041
#
# ======================================================================
#   Feature Selector: FS3_RFE  |  features=24
# ======================================================================
#     RandomForest               Acc=0.6700  F1=0.5962  MCC=0.4374  G-Mean=0.6957  AUC=0.8061
#     ExtraTrees                 Acc=0.6600  F1=0.5750  MCC=0.4171  G-Mean=0.6816  AUC=0.8081
#     Bagging                    Acc=0.5800  F1=0.5079  MCC=0.2578  G-Mean=0.6088  AUC=0.7265
#     GradientBoosting           Acc=0.6100  F1=0.5611  MCC=0.3423  G-Mean=0.6605  AUC=0.7799
#     LogisticRegression         Acc=0.6300  F1=0.5155  MCC=0.3534  G-Mean=0.6381  AUC=0.7812
#     RidgeClassifier            Acc=0.6300  F1=0.5080  MCC=0.3412  G-Mean=0.6294  AUC=  N/A
#     DecisionTree               Acc=0.5300  F1=0.4710  MCC=0.2238  G-Mean=0.5937  AUC=0.5917
#     NaiveBayes                 Acc=0.6700  F1=0.6069  MCC=0.4557  G-Mean=0.7139  AUC=0.8013
#     Perceptron                 Acc=0.5500  F1=0.4270  MCC=0.2536  G-Mean=0.5943  AUC=  N/A
#     SGDClassifier              Acc=0.6300  F1=0.4820  MCC=0.3479  G-Mean=0.6265  AUC=  N/A
#     PassiveAggressive          Acc=0.5600  F1=0.4639  MCC=0.2047  G-Mean=0.5778  AUC=  N/A
#     LDA                        Acc=0.6500  F1=0.5490  MCC=0.3888  G-Mean=0.6606  AUC=0.7779
#     QDA                        Acc=0.6000  F1=0.5309  MCC=0.3139  G-Mean=0.6377  AUC=0.6983
#     LightGBM                   Acc=0.6400  F1=0.5742  MCC=0.3968  G-Mean=0.6812  AUC=0.7695
#     XGBoost                    Acc=0.6700  F1=0.6126  MCC=0.4442  G-Mean=0.7084  AUC=0.7703
#     VotingSoft                 Acc=0.6300  F1=0.5699  MCC=0.3826  G-Mean=0.6752  AUC=0.8019
#     VotingHard                 Acc=0.6500  F1=0.5791  MCC=0.4028  G-Mean=0.6798  AUC=  N/A
#     Stacking                   Acc=0.6900  F1=0.6070  MCC=0.4615  G-Mean=0.7018  AUC=0.8045
#
# ======================================================================
#   Feature Selector: FS4_MutualInfo  |  features=37
# ======================================================================
#     RandomForest               Acc=0.6500  F1=0.5863  MCC=0.4005  G-Mean=0.6826  AUC=0.8004
#     ExtraTrees                 Acc=0.6500  F1=0.5822  MCC=0.4239  G-Mean=0.6922  AUC=0.7987
#     Bagging                    Acc=0.6200  F1=0.5294  MCC=0.3474  G-Mean=0.6457  AUC=0.7482
#     GradientBoosting           Acc=0.6600  F1=0.5958  MCC=0.4235  G-Mean=0.6942  AUC=0.7968
#     LogisticRegression         Acc=0.6100  F1=0.4892  MCC=0.3170  G-Mean=0.6180  AUC=0.7348
#     RidgeClassifier            Acc=0.5800  F1=0.4559  MCC=0.2534  G-Mean=0.5885  AUC=  N/A
#     DecisionTree               Acc=0.6100  F1=0.5569  MCC=0.3526  G-Mean=0.6630  AUC=0.6628
#     NaiveBayes                 Acc=0.6300  F1=0.5667  MCC=0.3991  G-Mean=0.6851  AUC=0.7798
#     Perceptron                 Acc=0.5400  F1=0.3927  MCC=0.1318  G-Mean=0.5316  AUC=  N/A
#     SGDClassifier              Acc=0.5900  F1=0.4834  MCC=0.3716  G-Mean=0.6471  AUC=  N/A
#     PassiveAggressive          Acc=0.5600  F1=0.4039  MCC=0.2849  G-Mean=0.5967  AUC=  N/A
#     LDA                        Acc=0.6200  F1=0.5098  MCC=0.3357  G-Mean=0.6314  AUC=0.7528
#     QDA                        Acc=0.6300  F1=0.4683  MCC=0.3335  G-Mean=0.6167  AUC=0.6375
#     LightGBM                   Acc=0.6500  F1=0.5887  MCC=0.4096  G-Mean=0.6887  AUC=0.7878
#     XGBoost                    Acc=0.7100  F1=0.6572  MCC=0.5087  G-Mean=0.7406  AUC=0.8204
#     VotingSoft                 Acc=0.6900  F1=0.6344  MCC=0.4837  G-Mean=0.7288  AUC=0.8087
#     VotingHard                 Acc=0.6800  F1=0.6122  MCC=0.4606  G-Mean=0.7113  AUC=  N/A
#     Stacking                   Acc=0.6600  F1=0.5779  MCC=0.4056  G-Mean=0.6758  AUC=0.7925
#
# ======================================================================
#   Feature Selector: FS5_RFImportance  |  features=45
# ======================================================================
#     RandomForest               Acc=0.7000  F1=0.6319  MCC=0.4816  G-Mean=0.7184  AUC=0.8159
#     ExtraTrees                 Acc=0.6500  F1=0.5700  MCC=0.4095  G-Mean=0.6813  AUC=0.8178
#     Bagging                    Acc=0.6400  F1=0.5657  MCC=0.3889  G-Mean=0.6719  AUC=0.7619
#     GradientBoosting           Acc=0.6600  F1=0.6024  MCC=0.4233  G-Mean=0.6965  AUC=0.8215
#     LogisticRegression         Acc=0.6200  F1=0.5107  MCC=0.3322  G-Mean=0.6301  AUC=0.7317
#     RidgeClassifier            Acc=0.6100  F1=0.4986  MCC=0.3093  G-Mean=0.6183  AUC=  N/A
#     DecisionTree               Acc=0.5800  F1=0.5252  MCC=0.3228  G-Mean=0.6452  AUC=0.6468
#     NaiveBayes                 Acc=0.6500  F1=0.5958  MCC=0.4288  G-Mean=0.7057  AUC=0.7739
#     Perceptron                 Acc=0.5800  F1=0.4643  MCC=0.2661  G-Mean=0.6066  AUC=  N/A
#     SGDClassifier              Acc=0.5300  F1=0.5131  MCC=0.3147  G-Mean=0.6465  AUC=  N/A
#     PassiveAggressive          Acc=0.5700  F1=0.4897  MCC=0.2744  G-Mean=0.6166  AUC=  N/A
#     LDA                        Acc=0.6300  F1=0.5409  MCC=0.3606  G-Mean=0.6535  AUC=0.7510
#     QDA                        Acc=0.6100  F1=0.4372  MCC=0.2808  G-Mean=0.5864  AUC=0.6278
#     LightGBM                   Acc=0.6700  F1=0.5780  MCC=0.4265  G-Mean=0.6827  AUC=0.8065
#     XGBoost                    Acc=0.6800  F1=0.6178  MCC=0.4738  G-Mean=0.7210  AUC=0.8161
#     VotingSoft                 Acc=0.6900  F1=0.6230  MCC=0.4691  G-Mean=0.7141  AUC=0.8281
#     VotingHard                 Acc=0.6900  F1=0.6162  MCC=0.4747  G-Mean=0.7154  AUC=  N/A
#     Stacking                   Acc=0.6800  F1=0.5939  MCC=0.4441  G-Mean=0.6928  AUC=0.8073
#
#
# -- Phase 2 Summary (top 20 by Accuracy) --
#  FeatureSelector         Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
#   FS4_MutualInfo            XGBoost      0.71    0.6572 0.5087  0.7406 0.8204
#  FS1_Correlation       RandomForest      0.70    0.6399 0.4749  0.7146 0.8280
# FS5_RFImportance       RandomForest      0.70    0.6319 0.4816  0.7184 0.8159
#          FS3_RFE           Stacking      0.69    0.6070 0.4615  0.7018 0.8045
#  FS1_Correlation            XGBoost      0.69    0.6350 0.4775  0.7235 0.8151
# FS5_RFImportance         VotingSoft      0.69    0.6230 0.4691  0.7141 0.8281
#        FS2_KBest         VotingHard      0.69    0.6136 0.4690  0.7106    NaN
#        FS2_KBest           Stacking      0.69    0.6153 0.4605  0.7046 0.8041
#   FS4_MutualInfo         VotingSoft      0.69    0.6344 0.4837  0.7288 0.8087
#  FS1_Correlation LogisticRegression      0.69    0.6102 0.4578  0.6999 0.7998
# FS5_RFImportance         VotingHard      0.69    0.6162 0.4747  0.7154    NaN
#  FS1_Correlation         Perceptron      0.68    0.5940 0.4656  0.7047    NaN
# FS5_RFImportance           Stacking      0.68    0.5939 0.4441  0.6928 0.8073
#   FS4_MutualInfo         VotingHard      0.68    0.6122 0.4606  0.7113    NaN
#        FS2_KBest         VotingSoft      0.68    0.6177 0.4496  0.7064 0.8220
# FS5_RFImportance            XGBoost      0.68    0.6178 0.4738  0.7210 0.8161
#          FS3_RFE            XGBoost      0.67    0.6126 0.4442  0.7084 0.7703
#          FS3_RFE         NaiveBayes      0.67    0.6069 0.4557  0.7139 0.8013
# FS5_RFImportance           LightGBM      0.67    0.5780 0.4265  0.6827 0.8065
#          FS3_RFE       RandomForest      0.67    0.5962 0.4374  0.6957 0.8061
#
# -- Phase 2: Best Classifier per Feature Selector --
#  FeatureSelector   Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
#  FS1_Correlation RandomForest      0.70    0.6399 0.4749  0.7146 0.8280
#        FS2_KBest   VotingHard      0.69    0.6136 0.4690  0.7106    NaN
#          FS3_RFE     Stacking      0.69    0.6070 0.4615  0.7018 0.8045
#   FS4_MutualInfo      XGBoost      0.71    0.6572 0.5087  0.7406 0.8204
# FS5_RFImportance RandomForest      0.70    0.6319 0.4816  0.7184 0.8159

# %% [markdown]
# # ***Experiment 3***

# %%
section_header("PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)")

phase3_rows = []
for bal_name, bal_df in balanced_datasets.items():
    for fs_name, fs_fn in FEATURE_SELECTORS.items():
        combo = f"{bal_name} + {fs_name}"
        try:
            fs_df = fs_fn(bal_df)
            sub_header(f"Combo: {combo}  |  shape={fs_df.shape}")
            rows = evaluate_dataset(fs_df, label=combo, verbose=True)
            phase3_rows.extend(rows)
        except Exception as e:
            print(f"  {combo} FAILED: {e}")

phase3_df = pd.DataFrame(phase3_rows).dropna(subset=['Accuracy'])
phase3_df['Phase'] = 'Phase3_Balancing+FS'
phase3_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 3 Summary (top 30 combos by Accuracy) --")
p3_show = phase3_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer+FS'})
print(p3_show[['Balancer+FS','Classifier'] + METRICS].head(30).to_string(index=False))

print("\n-- Phase 3: Best Classifier per Balancer+FS combo --")
best_p3 = (p3_show.groupby('Balancer+FS', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer+FS','Classifier'] + METRICS]
           .sort_values('Accuracy', ascending=False))
print(best_p3.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)
# ################################################################################
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS1_Correlation  |  shape=(654, 14)
# ======================================================================
#     RandomForest               Acc=0.8659  F1=0.8622  MCC=0.8021  G-Mean=0.8983  AUC=0.9719
#     ExtraTrees                 Acc=0.8659  F1=0.8624  MCC=0.8020  G-Mean=0.8983  AUC=0.9734
#     Bagging                    Acc=0.8415  F1=0.8365  MCC=0.7716  G-Mean=0.8795  AUC=0.9588
#     GradientBoosting           Acc=0.7561  F1=0.7538  MCC=0.6350  G-Mean=0.8144  AUC=0.9245
#     LogisticRegression         Acc=0.5549  F1=0.5506  MCC=0.3332  G-Mean=0.6572  AUC=0.8013
#     RidgeClassifier            Acc=0.5610  F1=0.5318  MCC=0.3529  G-Mean=0.6624  AUC=  N/A
#     DecisionTree               Acc=0.7988  F1=0.7916  MCC=0.7048  G-Mean=0.8469  AUC=0.8500
#     NaiveBayes                 Acc=0.6098  F1=0.6008  MCC=0.4175  G-Mean=0.7010  AUC=0.8085
#     Perceptron                 Acc=0.5732  F1=0.5435  MCC=0.4077  G-Mean=0.6713  AUC=  N/A
#     SGDClassifier              Acc=0.5549  F1=0.5494  MCC=0.3405  G-Mean=0.6565  AUC=  N/A
#     PassiveAggressive          Acc=0.5549  F1=0.4882  MCC=0.3754  G-Mean=0.6574  AUC=  N/A
#     LDA                        Acc=0.5793  F1=0.5708  MCC=0.3714  G-Mean=0.6768  AUC=0.8001
#     QDA                        Acc=0.6280  F1=0.6222  MCC=0.4445  G-Mean=0.7152  AUC=0.8035
#     LightGBM                   Acc=0.8293  F1=0.8252  MCC=0.7476  G-Mean=0.8704  AUC=0.9492
#     XGBoost                    Acc=0.8598  F1=0.8552  MCC=0.7961  G-Mean=0.8935  AUC=0.9563
#     VotingSoft                 Acc=0.8476  F1=0.8432  MCC=0.7759  G-Mean=0.8843  AUC=0.9665
#     VotingHard                 Acc=0.8659  F1=0.8624  MCC=0.8020  G-Mean=0.8983  AUC=  N/A
#     Stacking                   Acc=0.8537  F1=0.8522  MCC=0.7820  G-Mean=0.8892  AUC=0.9694
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS2_KBest  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.8720  F1=0.8678  MCC=0.8137  G-Mean=0.9028  AUC=0.9820
#     ExtraTrees                 Acc=0.8598  F1=0.8552  MCC=0.7945  G-Mean=0.8935  AUC=0.9822
#     Bagging                    Acc=0.7988  F1=0.7904  MCC=0.7070  G-Mean=0.8468  AUC=0.9343
#     GradientBoosting           Acc=0.8049  F1=0.7994  MCC=0.7101  G-Mean=0.8517  AUC=0.9537
#     LogisticRegression         Acc=0.5915  F1=0.5850  MCC=0.3896  G-Mean=0.6863  AUC=0.8192
#     RidgeClassifier            Acc=0.6098  F1=0.5975  MCC=0.4207  G-Mean=0.7011  AUC=  N/A
#     DecisionTree               Acc=0.8293  F1=0.8256  MCC=0.7471  G-Mean=0.8704  AUC=0.8734
#     NaiveBayes                 Acc=0.6707  F1=0.6679  MCC=0.5069  G-Mean=0.7487  AUC=0.8205
#     Perceptron                 Acc=0.5610  F1=0.5422  MCC=0.3602  G-Mean=0.6624  AUC=  N/A
#     SGDClassifier              Acc=0.5732  F1=0.5541  MCC=0.3680  G-Mean=0.6717  AUC=  N/A
#     PassiveAggressive          Acc=0.5732  F1=0.5757  MCC=0.3602  G-Mean=0.6717  AUC=  N/A
#     LDA                        Acc=0.6037  F1=0.5927  MCC=0.4103  G-Mean=0.6962  AUC=0.8255
#     QDA                        Acc=0.7927  F1=0.7904  MCC=0.6904  G-Mean=0.8428  AUC=0.9080
#     LightGBM                   Acc=0.8659  F1=0.8595  MCC=0.8094  G-Mean=0.8980  AUC=0.9780
#     XGBoost                    Acc=0.8780  F1=0.8733  MCC=0.8228  G-Mean=0.9074  AUC=0.9840
#     VotingSoft                 Acc=0.8476  F1=0.8418  MCC=0.7780  G-Mean=0.8842  AUC=0.9793
#     VotingHard                 Acc=0.8720  F1=0.8663  MCC=0.8173  G-Mean=0.9027  AUC=  N/A
#     Stacking                   Acc=0.9024  F1=0.9001  MCC=0.8565  G-Mean=0.9261  AUC=0.9852
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS3_RFE  |  shape=(654, 25)
# ======================================================================
#     RandomForest               Acc=0.8415  F1=0.8345  MCC=0.7705  G-Mean=0.8795  AUC=0.9736
#     ExtraTrees                 Acc=0.8780  F1=0.8762  MCC=0.8200  G-Mean=0.9076  AUC=0.9794
#     Bagging                    Acc=0.8049  F1=0.7964  MCC=0.7130  G-Mean=0.8515  AUC=0.9467
#     GradientBoosting           Acc=0.7439  F1=0.7414  MCC=0.6174  G-Mean=0.8049  AUC=0.9237
#     LogisticRegression         Acc=0.5793  F1=0.5715  MCC=0.3708  G-Mean=0.6766  AUC=0.7765
#     RidgeClassifier            Acc=0.5976  F1=0.5744  MCC=0.4058  G-Mean=0.6914  AUC=  N/A
#     DecisionTree               Acc=0.7927  F1=0.7881  MCC=0.6934  G-Mean=0.8423  AUC=0.8444
#     NaiveBayes                 Acc=0.6646  F1=0.6609  MCC=0.4984  G-Mean=0.7441  AUC=0.8302
#     Perceptron                 Acc=0.5122  F1=0.5159  MCC=0.2749  G-Mean=0.6218  AUC=  N/A
#     SGDClassifier              Acc=0.5305  F1=0.5295  MCC=0.2959  G-Mean=0.6376  AUC=  N/A
#     PassiveAggressive          Acc=0.5366  F1=0.4728  MCC=0.3386  G-Mean=0.6424  AUC=  N/A
#     LDA                        Acc=0.6037  F1=0.5926  MCC=0.4086  G-Mean=0.6962  AUC=0.7791
#     QDA                        Acc=0.7195  F1=0.7127  MCC=0.5866  G-Mean=0.7868  AUC=0.8608
#     LightGBM                   Acc=0.8354  F1=0.8292  MCC=0.7606  G-Mean=0.8749  AUC=0.9552
#     XGBoost                    Acc=0.8598  F1=0.8556  MCC=0.7943  G-Mean=0.8936  AUC=0.9775
#     VotingSoft                 Acc=0.8415  F1=0.8335  MCC=0.7729  G-Mean=0.8794  AUC=0.9694
#     VotingHard                 Acc=0.8659  F1=0.8622  MCC=0.8037  G-Mean=0.8982  AUC=  N/A
#     Stacking                   Acc=0.8537  F1=0.8526  MCC=0.7809  G-Mean=0.8894  AUC=0.9767
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS4_MutualInfo  |  shape=(654, 38)
# ======================================================================
#     RandomForest               Acc=0.8780  F1=0.8726  MCC=0.8275  G-Mean=0.9073  AUC=0.9804
#     ExtraTrees                 Acc=0.8598  F1=0.8578  MCC=0.7918  G-Mean=0.8937  AUC=0.9815
#     Bagging                    Acc=0.8049  F1=0.7990  MCC=0.7124  G-Mean=0.8516  AUC=0.9455
#     GradientBoosting           Acc=0.8171  F1=0.8108  MCC=0.7298  G-Mean=0.8610  AUC=0.9537
#     LogisticRegression         Acc=0.6098  F1=0.6042  MCC=0.4162  G-Mean=0.7010  AUC=0.8060
#     RidgeClassifier            Acc=0.6037  F1=0.5871  MCC=0.4135  G-Mean=0.6964  AUC=  N/A
#     DecisionTree               Acc=0.8354  F1=0.8301  MCC=0.7609  G-Mean=0.8749  AUC=0.8784
#     NaiveBayes                 Acc=0.6585  F1=0.6561  MCC=0.4885  G-Mean=0.7393  AUC=0.8218
#     Perceptron                 Acc=0.3963  F1=0.3019  MCC=0.2040  G-Mean=0.5291  AUC=  N/A
#     SGDClassifier              Acc=0.5671  F1=0.5298  MCC=0.3729  G-Mean=0.6669  AUC=  N/A
#     PassiveAggressive          Acc=0.4939  F1=0.4347  MCC=0.3203  G-Mean=0.6067  AUC=  N/A
#     LDA                        Acc=0.6159  F1=0.6071  MCC=0.4271  G-Mean=0.7059  AUC=0.8086
#     QDA                        Acc=0.7500  F1=0.7492  MCC=0.6279  G-Mean=0.8102  AUC=0.8876
#     LightGBM                   Acc=0.8841  F1=0.8789  MCC=0.8349  G-Mean=0.9120  AUC=0.9746
#     XGBoost                    Acc=0.8476  F1=0.8408  MCC=0.7812  G-Mean=0.8841  AUC=0.9793
#     VotingSoft                 Acc=0.8841  F1=0.8789  MCC=0.8349  G-Mean=0.9120  AUC=0.9815
#     VotingHard                 Acc=0.8902  F1=0.8856  MCC=0.8429  G-Mean=0.9166  AUC=  N/A
#     Stacking                   Acc=0.8841  F1=0.8823  MCC=0.8269  G-Mean=0.9124  AUC=0.9830
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS5_RFImportance  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.8354  F1=0.8311  MCC=0.7576  G-Mean=0.8750  AUC=0.9765
#     ExtraTrees                 Acc=0.8537  F1=0.8508  MCC=0.7840  G-Mean=0.8890  AUC=0.9808
#     Bagging                    Acc=0.7866  F1=0.7812  MCC=0.6836  G-Mean=0.8376  AUC=0.9350
#     GradientBoosting           Acc=0.8232  F1=0.8199  MCC=0.7376  G-Mean=0.8657  AUC=0.9539
#     LogisticRegression         Acc=0.6220  F1=0.6163  MCC=0.4347  G-Mean=0.7105  AUC=0.8272
#     RidgeClassifier            Acc=0.6463  F1=0.6363  MCC=0.4743  G-Mean=0.7299  AUC=  N/A
#     DecisionTree               Acc=0.8537  F1=0.8495  MCC=0.7868  G-Mean=0.8889  AUC=0.8922
#     NaiveBayes                 Acc=0.6707  F1=0.6667  MCC=0.5075  G-Mean=0.7488  AUC=0.8200
#     Perceptron                 Acc=0.5549  F1=0.5190  MCC=0.3838  G-Mean=0.6562  AUC=  N/A
#     SGDClassifier              Acc=0.6402  F1=0.6136  MCC=0.4854  G-Mean=0.7247  AUC=  N/A
#     PassiveAggressive          Acc=0.5793  F1=0.5379  MCC=0.4179  G-Mean=0.6762  AUC=  N/A
#     LDA                        Acc=0.6280  F1=0.6212  MCC=0.4441  G-Mean=0.7155  AUC=0.8322
#     QDA                        Acc=0.8049  F1=0.8045  MCC=0.7076  G-Mean=0.8522  AUC=0.9078
#     LightGBM                   Acc=0.8659  F1=0.8623  MCC=0.8046  G-Mean=0.8982  AUC=0.9762
#     XGBoost                    Acc=0.8963  F1=0.8929  MCC=0.8490  G-Mean=0.9214  AUC=0.9838
#     VotingSoft                 Acc=0.8476  F1=0.8426  MCC=0.7760  G-Mean=0.8842  AUC=0.9767
#     VotingHard                 Acc=0.8415  F1=0.8372  MCC=0.7671  G-Mean=0.8796  AUC=  N/A
#     Stacking                   Acc=0.8720  F1=0.8710  MCC=0.8080  G-Mean=0.9032  AUC=0.9793
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS1_Correlation  |  shape=(216, 15)
# ======================================================================
#     RandomForest               Acc=0.4074  F1=0.4106  MCC=0.1116  G-Mean=0.5354  AUC=0.6381
#     ExtraTrees                 Acc=0.5000  F1=0.5014  MCC=0.2521  G-Mean=0.6124  AUC=0.6800
#     Bagging                    Acc=0.4630  F1=0.4670  MCC=0.1951  G-Mean=0.5819  AUC=0.6415
#     GradientBoosting           Acc=0.3889  F1=0.3973  MCC=0.0839  G-Mean=0.5197  AUC=0.5679
#     LogisticRegression         Acc=0.3519  F1=0.3491  MCC=0.0279  G-Mean=0.4877  AUC=0.5761
#     RidgeClassifier            Acc=0.3333  F1=0.3285  MCC=0.0000  G-Mean=0.4714  AUC=  N/A
#     DecisionTree               Acc=0.4815  F1=0.4770  MCC=0.2237  G-Mean=0.5972  AUC=0.5877
#     NaiveBayes                 Acc=0.4259  F1=0.4215  MCC=0.1394  G-Mean=0.5511  AUC=0.6219
#     Perceptron                 Acc=0.3519  F1=0.3466  MCC=0.0279  G-Mean=0.4877  AUC=  N/A
#     SGDClassifier              Acc=0.2963  F1=0.2890  MCC=-0.0598  G-Mean=0.4382  AUC=  N/A
#     PassiveAggressive          Acc=0.3333  F1=0.2843  MCC=0.0000  G-Mean=0.4714  AUC=  N/A
#     LDA                        Acc=0.3519  F1=0.3511  MCC=0.0281  G-Mean=0.4877  AUC=0.5746
#     QDA                        Acc=0.3889  F1=0.3897  MCC=0.0845  G-Mean=0.5197  AUC=0.5592
#     LightGBM                   Acc=0.3889  F1=0.3982  MCC=0.0847  G-Mean=0.5197  AUC=0.5823
#     XGBoost                    Acc=0.3519  F1=0.3544  MCC=0.0278  G-Mean=0.4877  AUC=0.5689
#     VotingSoft                 Acc=0.3519  F1=0.3605  MCC=0.0280  G-Mean=0.4877  AUC=0.6214
#     VotingHard                 Acc=0.4630  F1=0.4658  MCC=0.1948  G-Mean=0.5819  AUC=  N/A
#     Stacking                   Acc=0.3889  F1=0.3958  MCC=0.0840  G-Mean=0.5197  AUC=0.6188
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS2_KBest  |  shape=(216, 46)
# ======================================================================
#     RandomForest               Acc=0.3519  F1=0.3601  MCC=0.0283  G-Mean=0.4877  AUC=0.5846
#     ExtraTrees                 Acc=0.3704  F1=0.3783  MCC=0.0564  G-Mean=0.5038  AUC=0.6165
#     Bagging                    Acc=0.4444  F1=0.4479  MCC=0.1673  G-Mean=0.5666  AUC=0.6008
#     GradientBoosting           Acc=0.3519  F1=0.3535  MCC=0.0278  G-Mean=0.4877  AUC=0.5607
#     LogisticRegression         Acc=0.3333  F1=0.3291  MCC=0.0000  G-Mean=0.4714  AUC=0.5309
#     RidgeClassifier            Acc=0.3889  F1=0.3749  MCC=0.0847  G-Mean=0.5197  AUC=  N/A
#     DecisionTree               Acc=0.3704  F1=0.3684  MCC=0.0562  G-Mean=0.5038  AUC=0.5144
#     NaiveBayes                 Acc=0.5000  F1=0.4968  MCC=0.2505  G-Mean=0.6124  AUC=0.6425
#     Perceptron                 Acc=0.3333  F1=0.3246  MCC=0.0000  G-Mean=0.4714  AUC=  N/A
#     SGDClassifier              Acc=0.4444  F1=0.4276  MCC=0.1772  G-Mean=0.5666  AUC=  N/A
#     PassiveAggressive          Acc=0.3333  F1=0.3368  MCC=0.0000  G-Mean=0.4714  AUC=  N/A
#     LDA                        Acc=0.3704  F1=0.3597  MCC=0.0564  G-Mean=0.5038  AUC=0.5669
#     QDA                        Acc=0.3148  F1=0.2691  MCC=-0.0311  G-Mean=0.4549  AUC=0.4457
#     LightGBM                   Acc=0.3519  F1=0.3504  MCC=0.0281  G-Mean=0.4877  AUC=0.5489
#     XGBoost                    Acc=0.3889  F1=0.3921  MCC=0.0837  G-Mean=0.5197  AUC=0.5185
#     VotingSoft                 Acc=0.3148  F1=0.3174  MCC=-0.0279  G-Mean=0.4549  AUC=0.5844
#     VotingHard                 Acc=0.3148  F1=0.3208  MCC=-0.0282  G-Mean=0.4549  AUC=  N/A
#     Stacking                   Acc=0.2963  F1=0.3006  MCC=-0.0561  G-Mean=0.4382  AUC=0.5947
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS3_RFE  |  shape=(216, 25)
# ======================================================================
#     RandomForest               Acc=0.4259  F1=0.4321  MCC=0.1416  G-Mean=0.5511  AUC=0.5887
#     ExtraTrees                 Acc=0.4074  F1=0.4148  MCC=0.1123  G-Mean=0.5354  AUC=0.5921
#     Bagging                    Acc=0.3519  F1=0.3596  MCC=0.0279  G-Mean=0.4877  AUC=0.5481
#     GradientBoosting           Acc=0.3704  F1=0.3630  MCC=0.0559  G-Mean=0.5038  AUC=0.5412
#     LogisticRegression         Acc=0.3333  F1=0.3256  MCC=0.0000  G-Mean=0.4714  AUC=0.5808
#     RidgeClassifier            Acc=0.3704  F1=0.3461  MCC=0.0574  G-Mean=0.5038  AUC=  N/A
#     DecisionTree               Acc=0.3704  F1=0.3684  MCC=0.0562  G-Mean=0.5038  AUC=0.5072
#     NaiveBayes                 Acc=0.4444  F1=0.4484  MCC=0.1670  G-Mean=0.5666  AUC=0.6445
#     Perceptron                 Acc=0.3519  F1=0.3525  MCC=0.0281  G-Mean=0.4877  AUC=  N/A
#     SGDClassifier              Acc=0.3148  F1=0.2805  MCC=-0.0332  G-Mean=0.4549  AUC=  N/A
#     PassiveAggressive          Acc=0.2778  F1=0.2556  MCC=-0.0891  G-Mean=0.4213  AUC=  N/A
#     LDA                        Acc=0.3148  F1=0.3021  MCC=-0.0281  G-Mean=0.4549  AUC=0.5710
#     QDA                        Acc=0.3148  F1=0.3127  MCC=-0.0280  G-Mean=0.4549  AUC=0.4938
#     LightGBM                   Acc=0.3889  F1=0.3884  MCC=0.0842  G-Mean=0.5197  AUC=0.5520
#     XGBoost                    Acc=0.4074  F1=0.4066  MCC=0.1112  G-Mean=0.5354  AUC=0.5288
#     VotingSoft                 Acc=0.3519  F1=0.3531  MCC=0.0279  G-Mean=0.4877  AUC=0.5802
#     VotingHard                 Acc=0.4074  F1=0.4141  MCC=0.1127  G-Mean=0.5354  AUC=  N/A
#     Stacking                   Acc=0.3889  F1=0.3907  MCC=0.0852  G-Mean=0.5197  AUC=0.5813
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS4_MutualInfo  |  shape=(216, 38)
# ======================================================================
#     RandomForest               Acc=0.3889  F1=0.3921  MCC=0.0837  G-Mean=0.5197  AUC=0.6145
#     ExtraTrees                 Acc=0.3704  F1=0.3762  MCC=0.0561  G-Mean=0.5038  AUC=0.6103
#     Bagging                    Acc=0.3889  F1=0.3927  MCC=0.0835  G-Mean=0.5197  AUC=0.6044
#     GradientBoosting           Acc=0.3519  F1=0.3516  MCC=0.0278  G-Mean=0.4877  AUC=0.5319
#     LogisticRegression         Acc=0.2963  F1=0.2949  MCC=-0.0562  G-Mean=0.4382  AUC=0.5530
#     RidgeClassifier            Acc=0.3704  F1=0.3606  MCC=0.0567  G-Mean=0.5038  AUC=  N/A
#     DecisionTree               Acc=0.2593  F1=0.2589  MCC=-0.1112  G-Mean=0.4040  AUC=0.4321
#     NaiveBayes                 Acc=0.5000  F1=0.4992  MCC=0.2504  G-Mean=0.6124  AUC=0.6564
#     Perceptron                 Acc=0.2778  F1=0.2273  MCC=-0.0930  G-Mean=0.4213  AUC=  N/A
#     SGDClassifier              Acc=0.3704  F1=0.3223  MCC=0.0620  G-Mean=0.5038  AUC=  N/A
#     PassiveAggressive          Acc=0.3889  F1=0.3870  MCC=0.0834  G-Mean=0.5197  AUC=  N/A
#     LDA                        Acc=0.3889  F1=0.3821  MCC=0.0851  G-Mean=0.5197  AUC=0.5725
#     QDA                        Acc=0.3333  F1=0.3332  MCC=0.0000  G-Mean=0.4714  AUC=0.5057
#     LightGBM                   Acc=0.3889  F1=0.3940  MCC=0.0840  G-Mean=0.5197  AUC=0.5252
#     XGBoost                    Acc=0.3519  F1=0.3517  MCC=0.0279  G-Mean=0.4877  AUC=0.5401
#     VotingSoft                 Acc=0.3519  F1=0.3546  MCC=0.0280  G-Mean=0.4877  AUC=0.5838
#     VotingHard                 Acc=0.3704  F1=0.3762  MCC=0.0561  G-Mean=0.5038  AUC=  N/A
#     Stacking                   Acc=0.3704  F1=0.3735  MCC=0.0565  G-Mean=0.5038  AUC=0.6013
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS5_RFImportance  |  shape=(216, 46)
# ======================================================================
#     RandomForest               Acc=0.2963  F1=0.2999  MCC=-0.0557  G-Mean=0.4382  AUC=0.6121
#     ExtraTrees                 Acc=0.3889  F1=0.3942  MCC=0.0846  G-Mean=0.5197  AUC=0.6319
#     Bagging                    Acc=0.3519  F1=0.3579  MCC=0.0279  G-Mean=0.4877  AUC=0.5921
#     GradientBoosting           Acc=0.3333  F1=0.3323  MCC=0.0000  G-Mean=0.4714  AUC=0.5473
#     LogisticRegression         Acc=0.3519  F1=0.3451  MCC=0.0279  G-Mean=0.4877  AUC=0.5334
#     RidgeClassifier            Acc=0.3704  F1=0.3515  MCC=0.0568  G-Mean=0.5038  AUC=  N/A
#     DecisionTree               Acc=0.3333  F1=0.3335  MCC=0.0000  G-Mean=0.4714  AUC=0.4864
#     NaiveBayes                 Acc=0.4815  F1=0.4746  MCC=0.2230  G-Mean=0.5972  AUC=0.6425
#     Perceptron                 Acc=0.3889  F1=0.3680  MCC=0.0885  G-Mean=0.5197  AUC=  N/A
#     SGDClassifier              Acc=0.4074  F1=0.4066  MCC=0.1112  G-Mean=0.5354  AUC=  N/A
#     PassiveAggressive          Acc=0.3519  F1=0.3517  MCC=0.0282  G-Mean=0.4877  AUC=  N/A
#     LDA                        Acc=0.3889  F1=0.3742  MCC=0.0851  G-Mean=0.5197  AUC=0.5597
#     QDA                        Acc=0.2778  F1=0.2417  MCC=-0.0940  G-Mean=0.4213  AUC=0.4720
#     LightGBM                   Acc=0.3519  F1=0.3537  MCC=0.0280  G-Mean=0.4877  AUC=0.5437
#     XGBoost                    Acc=0.3889  F1=0.3921  MCC=0.0837  G-Mean=0.5197  AUC=0.5365
#     VotingSoft                 Acc=0.3148  F1=0.3160  MCC=-0.0278  G-Mean=0.4549  AUC=0.5844
#     VotingHard                 Acc=0.3333  F1=0.3396  MCC=0.0000  G-Mean=0.4714  AUC=  N/A
#     Stacking                   Acc=0.3519  F1=0.3544  MCC=0.0278  G-Mean=0.4877  AUC=0.6055
#
# ======================================================================
#   Combo: B3_ADASYN + FS1_Correlation  |  shape=(655, 13)
# ======================================================================
#     RandomForest               Acc=0.7134  F1=0.7154  MCC=0.5700  G-Mean=0.7824  AUC=0.8587
#     ExtraTrees                 Acc=0.6890  F1=0.6923  MCC=0.5334  G-Mean=0.7635  AUC=0.8528
#     Bagging                    Acc=0.6768  F1=0.6788  MCC=0.5151  G-Mean=0.7539  AUC=0.8135
#     GradientBoosting           Acc=0.6585  F1=0.6645  MCC=0.4895  G-Mean=0.7394  AUC=0.8414
#     LogisticRegression         Acc=0.5366  F1=0.5267  MCC=0.3106  G-Mean=0.6434  AUC=0.7393
#     RidgeClassifier            Acc=0.5244  F1=0.5108  MCC=0.2946  G-Mean=0.6338  AUC=  N/A
#     DecisionTree               Acc=0.5976  F1=0.6015  MCC=0.3974  G-Mean=0.6910  AUC=0.7281
#     NaiveBayes                 Acc=0.5671  F1=0.5616  MCC=0.3613  G-Mean=0.6680  AUC=0.7022
#     Perceptron                 Acc=0.4756  F1=0.4670  MCC=0.2239  G-Mean=0.5949  AUC=  N/A
#     SGDClassifier              Acc=0.4756  F1=0.4338  MCC=0.2434  G-Mean=0.5946  AUC=  N/A
#     PassiveAggressive          Acc=0.4146  F1=0.3577  MCC=0.1465  G-Mean=0.5457  AUC=  N/A
#     LDA                        Acc=0.5427  F1=0.5333  MCC=0.3195  G-Mean=0.6481  AUC=0.7319
#     QDA                        Acc=0.5549  F1=0.5489  MCC=0.3385  G-Mean=0.6580  AUC=0.7591
#     LightGBM                   Acc=0.6707  F1=0.6741  MCC=0.5068  G-Mean=0.7494  AUC=0.8556
#     XGBoost                    Acc=0.6707  F1=0.6735  MCC=0.5085  G-Mean=0.7495  AUC=0.8602
#     VotingSoft                 Acc=0.7073  F1=0.7096  MCC=0.5608  G-Mean=0.7777  AUC=0.8676
#     VotingHard                 Acc=0.7012  F1=0.7042  MCC=0.5517  G-Mean=0.7729  AUC=  N/A
#     Stacking                   Acc=0.7195  F1=0.7242  MCC=0.5794  G-Mean=0.7871  AUC=0.8758
#
# ======================================================================
#   Combo: B3_ADASYN + FS2_KBest  |  shape=(655, 46)
# ======================================================================
#     RandomForest               Acc=0.7439  F1=0.7438  MCC=0.6162  G-Mean=0.8064  AUC=0.9100
#     ExtraTrees                 Acc=0.7561  F1=0.7556  MCC=0.6351  G-Mean=0.8159  AUC=0.9030
#     Bagging                    Acc=0.7012  F1=0.7004  MCC=0.5525  G-Mean=0.7735  AUC=0.8467
#     GradientBoosting           Acc=0.7378  F1=0.7395  MCC=0.6067  G-Mean=0.8018  AUC=0.8948
#     LogisticRegression         Acc=0.5122  F1=0.5066  MCC=0.2713  G-Mean=0.6233  AUC=0.7269
#     RidgeClassifier            Acc=0.5244  F1=0.5195  MCC=0.2903  G-Mean=0.6332  AUC=  N/A
#     DecisionTree               Acc=0.6341  F1=0.6322  MCC=0.4522  G-Mean=0.7209  AUC=0.7446
#     NaiveBayes                 Acc=0.5549  F1=0.5494  MCC=0.3404  G-Mean=0.6579  AUC=0.6935
#     Perceptron                 Acc=0.5061  F1=0.4689  MCC=0.2808  G-Mean=0.6209  AUC=  N/A
#     SGDClassifier              Acc=0.4329  F1=0.3759  MCC=0.1853  G-Mean=0.5516  AUC=  N/A
#     PassiveAggressive          Acc=0.4817  F1=0.4618  MCC=0.2345  G-Mean=0.6008  AUC=  N/A
#     LDA                        Acc=0.5244  F1=0.5201  MCC=0.2900  G-Mean=0.6331  AUC=0.7416
#     QDA                        Acc=0.6768  F1=0.6760  MCC=0.5192  G-Mean=0.7545  AUC=0.8553
#     LightGBM                   Acc=0.7500  F1=0.7489  MCC=0.6258  G-Mean=0.8113  AUC=0.9058
#     XGBoost                    Acc=0.7744  F1=0.7729  MCC=0.6628  G-Mean=0.8301  AUC=0.9179
#     VotingSoft                 Acc=0.7866  F1=0.7870  MCC=0.6800  G-Mean=0.8391  AUC=0.9191
#     VotingHard                 Acc=0.7561  F1=0.7542  MCC=0.6353  G-Mean=0.8160  AUC=  N/A
#     Stacking                   Acc=0.7744  F1=0.7739  MCC=0.6621  G-Mean=0.8297  AUC=0.9225
#
# ======================================================================
#   Combo: B3_ADASYN + FS3_RFE  |  shape=(655, 25)
# ======================================================================
#     RandomForest               Acc=0.7439  F1=0.7426  MCC=0.6168  G-Mean=0.8062  AUC=0.8809
#     ExtraTrees                 Acc=0.7317  F1=0.7315  MCC=0.5981  G-Mean=0.7968  AUC=0.8795
#     Bagging                    Acc=0.6768  F1=0.6769  MCC=0.5158  G-Mean=0.7545  AUC=0.8219
#     GradientBoosting           Acc=0.6829  F1=0.6852  MCC=0.5242  G-Mean=0.7588  AUC=0.8423
#     LogisticRegression         Acc=0.5061  F1=0.5066  MCC=0.2595  G-Mean=0.6176  AUC=0.6932
#     RidgeClassifier            Acc=0.4756  F1=0.4695  MCC=0.2158  G-Mean=0.5937  AUC=  N/A
#     DecisionTree               Acc=0.6280  F1=0.6222  MCC=0.4453  G-Mean=0.7162  AUC=0.7326
#     NaiveBayes                 Acc=0.5915  F1=0.5835  MCC=0.4003  G-Mean=0.6873  AUC=0.7214
#     Perceptron                 Acc=0.5183  F1=0.5075  MCC=0.2915  G-Mean=0.6301  AUC=  N/A
#     SGDClassifier              Acc=0.5244  F1=0.5114  MCC=0.2968  G-Mean=0.6350  AUC=  N/A
#     PassiveAggressive          Acc=0.3963  F1=0.3564  MCC=0.1062  G-Mean=0.5214  AUC=  N/A
#     LDA                        Acc=0.5000  F1=0.4975  MCC=0.2516  G-Mean=0.6133  AUC=0.6911
#     QDA                        Acc=0.6220  F1=0.6204  MCC=0.4353  G-Mean=0.7111  AUC=0.7890
#     LightGBM                   Acc=0.7317  F1=0.7318  MCC=0.5984  G-Mean=0.7966  AUC=0.8718
#     XGBoost                    Acc=0.7317  F1=0.7319  MCC=0.5978  G-Mean=0.7970  AUC=0.8786
#     VotingSoft                 Acc=0.7561  F1=0.7560  MCC=0.6346  G-Mean=0.8157  AUC=0.8852
#     VotingHard                 Acc=0.7317  F1=0.7315  MCC=0.5981  G-Mean=0.7968  AUC=  N/A
#     Stacking                   Acc=0.7622  F1=0.7649  MCC=0.6437  G-Mean=0.8200  AUC=0.8848
#
# ======================================================================
#   Combo: B3_ADASYN + FS4_MutualInfo  |  shape=(655, 38)
# ======================================================================
#     RandomForest               Acc=0.7073  F1=0.7062  MCC=0.5634  G-Mean=0.7778  AUC=0.8898
#     ExtraTrees                 Acc=0.7744  F1=0.7742  MCC=0.6630  G-Mean=0.8294  AUC=0.9008
#     Bagging                    Acc=0.7134  F1=0.7081  MCC=0.5750  G-Mean=0.7829  AUC=0.8470
#     GradientBoosting           Acc=0.7317  F1=0.7340  MCC=0.5977  G-Mean=0.7968  AUC=0.8971
#     LogisticRegression         Acc=0.5122  F1=0.5133  MCC=0.2683  G-Mean=0.6232  AUC=0.7132
#     RidgeClassifier            Acc=0.5122  F1=0.5065  MCC=0.2717  G-Mean=0.6236  AUC=  N/A
#     DecisionTree               Acc=0.6890  F1=0.6890  MCC=0.5338  G-Mean=0.7633  AUC=0.7848
#     NaiveBayes                 Acc=0.5671  F1=0.5546  MCC=0.3645  G-Mean=0.6682  AUC=0.7037
#     Perceptron                 Acc=0.4390  F1=0.4364  MCC=0.1625  G-Mean=0.5627  AUC=  N/A
#     SGDClassifier              Acc=0.4451  F1=0.4215  MCC=0.1812  G-Mean=0.5692  AUC=  N/A
#     PassiveAggressive          Acc=0.5061  F1=0.4917  MCC=0.2684  G-Mean=0.6200  AUC=  N/A
#     LDA                        Acc=0.5244  F1=0.5233  MCC=0.2879  G-Mean=0.6330  AUC=0.7163
#     QDA                        Acc=0.6098  F1=0.6126  MCC=0.4167  G-Mean=0.7005  AUC=0.8091
#     LightGBM                   Acc=0.7378  F1=0.7390  MCC=0.6068  G-Mean=0.8015  AUC=0.9042
#     XGBoost                    Acc=0.7317  F1=0.7308  MCC=0.5984  G-Mean=0.7971  AUC=0.9017
#     VotingSoft                 Acc=0.7622  F1=0.7627  MCC=0.6443  G-Mean=0.8202  AUC=0.9124
#     VotingHard                 Acc=0.7561  F1=0.7556  MCC=0.6360  G-Mean=0.8154  AUC=  N/A
#     Stacking                   Acc=0.7683  F1=0.7694  MCC=0.6526  G-Mean=0.8250  AUC=0.9164
#
# ======================================================================
#   Combo: B3_ADASYN + FS5_RFImportance  |  shape=(655, 46)
# ======================================================================
#     RandomForest               Acc=0.7439  F1=0.7428  MCC=0.6171  G-Mean=0.8063  AUC=0.9021
#     ExtraTrees                 Acc=0.7927  F1=0.7922  MCC=0.6895  G-Mean=0.8438  AUC=0.9171
#     Bagging                    Acc=0.7134  F1=0.7149  MCC=0.5704  G-Mean=0.7828  AUC=0.8668
#     GradientBoosting           Acc=0.7561  F1=0.7585  MCC=0.6344  G-Mean=0.8158  AUC=0.8890
#     LogisticRegression         Acc=0.5183  F1=0.5174  MCC=0.2794  G-Mean=0.6281  AUC=0.7283
#     RidgeClassifier            Acc=0.5366  F1=0.5365  MCC=0.3056  G-Mean=0.6430  AUC=  N/A
#     DecisionTree               Acc=0.6402  F1=0.6412  MCC=0.4605  G-Mean=0.7255  AUC=0.7474
#     NaiveBayes                 Acc=0.5549  F1=0.5484  MCC=0.3413  G-Mean=0.6579  AUC=0.6950
#     Perceptron                 Acc=0.5122  F1=0.4770  MCC=0.3032  G-Mean=0.6270  AUC=  N/A
#     SGDClassifier              Acc=0.3963  F1=0.3292  MCC=0.1070  G-Mean=0.5205  AUC=  N/A
#     PassiveAggressive          Acc=0.4939  F1=0.4677  MCC=0.2560  G-Mean=0.6113  AUC=  N/A
#     LDA                        Acc=0.5366  F1=0.5365  MCC=0.3056  G-Mean=0.6430  AUC=0.7429
#     QDA                        Acc=0.6646  F1=0.6630  MCC=0.5010  G-Mean=0.7450  AUC=0.8486
#     LightGBM                   Acc=0.7195  F1=0.7197  MCC=0.5796  G-Mean=0.7877  AUC=0.8990
#     XGBoost                    Acc=0.7561  F1=0.7544  MCC=0.6354  G-Mean=0.8162  AUC=0.9112
#     VotingSoft                 Acc=0.7622  F1=0.7622  MCC=0.6436  G-Mean=0.8205  AUC=0.9158
#     VotingHard                 Acc=0.7683  F1=0.7670  MCC=0.6532  G-Mean=0.8251  AUC=  N/A
#     Stacking                   Acc=0.7683  F1=0.7694  MCC=0.6525  G-Mean=0.8251  AUC=0.9231
#
# ======================================================================
#   Combo: B4_SMOTE + FS1_Correlation  |  shape=(654, 13)
# ======================================================================
#     RandomForest               Acc=0.7744  F1=0.7713  MCC=0.6630  G-Mean=0.8284  AUC=0.8991
#     ExtraTrees                 Acc=0.7683  F1=0.7661  MCC=0.6539  G-Mean=0.8238  AUC=0.9099
#     Bagging                    Acc=0.7378  F1=0.7371  MCC=0.6079  G-Mean=0.8004  AUC=0.8829
#     GradientBoosting           Acc=0.7256  F1=0.7252  MCC=0.5898  G-Mean=0.7910  AUC=0.8864
#     LogisticRegression         Acc=0.5976  F1=0.5960  MCC=0.3993  G-Mean=0.6913  AUC=0.7632
#     RidgeClassifier            Acc=0.5793  F1=0.5683  MCC=0.3774  G-Mean=0.6769  AUC=  N/A
#     DecisionTree               Acc=0.6707  F1=0.6704  MCC=0.5061  G-Mean=0.7484  AUC=0.7574
#     NaiveBayes                 Acc=0.5976  F1=0.5956  MCC=0.3985  G-Mean=0.6913  AUC=0.7458
#     Perceptron                 Acc=0.4817  F1=0.4605  MCC=0.2336  G-Mean=0.5964  AUC=  N/A
#     SGDClassifier              Acc=0.5549  F1=0.5563  MCC=0.3330  G-Mean=0.6568  AUC=  N/A
#     PassiveAggressive          Acc=0.4146  F1=0.3849  MCC=0.1299  G-Mean=0.5420  AUC=  N/A
#     LDA                        Acc=0.5793  F1=0.5768  MCC=0.3729  G-Mean=0.6769  AUC=0.7577
#     QDA                        Acc=0.6341  F1=0.6341  MCC=0.4554  G-Mean=0.7202  AUC=0.7622
#     LightGBM                   Acc=0.7683  F1=0.7668  MCC=0.6527  G-Mean=0.8240  AUC=0.9092
#     XGBoost                    Acc=0.7378  F1=0.7394  MCC=0.6074  G-Mean=0.8005  AUC=0.9030
#     VotingSoft                 Acc=0.7805  F1=0.7780  MCC=0.6720  G-Mean=0.8331  AUC=0.9102
#     VotingHard                 Acc=0.7744  F1=0.7713  MCC=0.6630  G-Mean=0.8284  AUC=  N/A
#     Stacking                   Acc=0.7744  F1=0.7742  MCC=0.6630  G-Mean=0.8286  AUC=0.9160
#
# ======================================================================
#   Combo: B4_SMOTE + FS2_KBest  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.7866  F1=0.7834  MCC=0.6817  G-Mean=0.8378  AUC=0.9319
#     ExtraTrees                 Acc=0.7927  F1=0.7922  MCC=0.6914  G-Mean=0.8427  AUC=0.9389
#     Bagging                    Acc=0.7439  F1=0.7407  MCC=0.6176  G-Mean=0.8049  AUC=0.8955
#     GradientBoosting           Acc=0.7744  F1=0.7738  MCC=0.6629  G-Mean=0.8286  AUC=0.9134
#     LogisticRegression         Acc=0.6585  F1=0.6584  MCC=0.4894  G-Mean=0.7392  AUC=0.8118
#     RidgeClassifier            Acc=0.6037  F1=0.5980  MCC=0.4105  G-Mean=0.6962  AUC=  N/A
#     DecisionTree               Acc=0.7073  F1=0.7053  MCC=0.5638  G-Mean=0.7768  AUC=0.7841
#     NaiveBayes                 Acc=0.6037  F1=0.6018  MCC=0.4099  G-Mean=0.6962  AUC=0.7637
#     Perceptron                 Acc=0.5549  F1=0.5422  MCC=0.3480  G-Mean=0.6578  AUC=  N/A
#     SGDClassifier              Acc=0.5976  F1=0.5943  MCC=0.3985  G-Mean=0.6910  AUC=  N/A
#     PassiveAggressive          Acc=0.5183  F1=0.4676  MCC=0.3070  G-Mean=0.6277  AUC=  N/A
#     LDA                        Acc=0.6524  F1=0.6524  MCC=0.4802  G-Mean=0.7344  AUC=0.8091
#     QDA                        Acc=0.6951  F1=0.6965  MCC=0.5479  G-Mean=0.7678  AUC=0.8262
#     LightGBM                   Acc=0.7561  F1=0.7546  MCC=0.6350  G-Mean=0.8145  AUC=0.9234
#     XGBoost                    Acc=0.7744  F1=0.7739  MCC=0.6617  G-Mean=0.8287  AUC=0.9333
#     VotingSoft                 Acc=0.7622  F1=0.7594  MCC=0.6450  G-Mean=0.8191  AUC=0.9364
#     VotingHard                 Acc=0.7805  F1=0.7795  MCC=0.6717  G-Mean=0.8333  AUC=  N/A
#     Stacking                   Acc=0.7744  F1=0.7735  MCC=0.6622  G-Mean=0.8286  AUC=0.9433
#
# ======================================================================
#   Combo: B4_SMOTE + FS3_RFE  |  shape=(654, 25)
# ======================================================================
#     RandomForest               Acc=0.7744  F1=0.7722  MCC=0.6626  G-Mean=0.8286  AUC=0.8974
#     ExtraTrees                 Acc=0.7500  F1=0.7495  MCC=0.6257  G-Mean=0.8099  AUC=0.9058
#     Bagging                    Acc=0.7195  F1=0.7191  MCC=0.5811  G-Mean=0.7863  AUC=0.8723
#     GradientBoosting           Acc=0.6768  F1=0.6776  MCC=0.5180  G-Mean=0.7533  AUC=0.8716
#     LogisticRegression         Acc=0.6159  F1=0.6126  MCC=0.4271  G-Mean=0.7059  AUC=0.7519
#     RidgeClassifier            Acc=0.5793  F1=0.5677  MCC=0.3783  G-Mean=0.6770  AUC=  N/A
#     DecisionTree               Acc=0.6341  F1=0.6348  MCC=0.4561  G-Mean=0.7197  AUC=0.7252
#     NaiveBayes                 Acc=0.6463  F1=0.6449  MCC=0.4731  G-Mean=0.7298  AUC=0.7818
#     Perceptron                 Acc=0.3232  F1=0.2490  MCC=-0.0155  G-Mean=0.4648  AUC=  N/A
#     SGDClassifier              Acc=0.5549  F1=0.5545  MCC=0.3323  G-Mean=0.6567  AUC=  N/A
#     PassiveAggressive          Acc=0.4512  F1=0.3867  MCC=0.2000  G-Mean=0.5727  AUC=  N/A
#     LDA                        Acc=0.6280  F1=0.6254  MCC=0.4452  G-Mean=0.7155  AUC=0.7549
#     QDA                        Acc=0.6707  F1=0.6701  MCC=0.5095  G-Mean=0.7488  AUC=0.7741
#     LightGBM                   Acc=0.7134  F1=0.7116  MCC=0.5722  G-Mean=0.7816  AUC=0.8746
#     XGBoost                    Acc=0.7439  F1=0.7431  MCC=0.6182  G-Mean=0.8052  AUC=0.9044
#     VotingSoft                 Acc=0.7439  F1=0.7422  MCC=0.6193  G-Mean=0.8052  AUC=0.8981
#     VotingHard                 Acc=0.7622  F1=0.7604  MCC=0.6440  G-Mean=0.8192  AUC=  N/A
#     Stacking                   Acc=0.7622  F1=0.7626  MCC=0.6447  G-Mean=0.8194  AUC=0.9036
#
# ======================================================================
#   Combo: B4_SMOTE + FS4_MutualInfo  |  shape=(654, 38)
# ======================================================================
#     RandomForest               Acc=0.7561  F1=0.7546  MCC=0.6355  G-Mean=0.8145  AUC=0.9111
#     ExtraTrees                 Acc=0.7683  F1=0.7676  MCC=0.6532  G-Mean=0.8240  AUC=0.9141
#     Bagging                    Acc=0.7195  F1=0.7172  MCC=0.5812  G-Mean=0.7862  AUC=0.8865
#     GradientBoosting           Acc=0.7500  F1=0.7511  MCC=0.6268  G-Mean=0.8101  AUC=0.9014
#     LogisticRegression         Acc=0.6037  F1=0.6021  MCC=0.4087  G-Mean=0.6961  AUC=0.7908
#     RidgeClassifier            Acc=0.5854  F1=0.5814  MCC=0.3831  G-Mean=0.6817  AUC=  N/A
#     DecisionTree               Acc=0.6829  F1=0.6805  MCC=0.5283  G-Mean=0.7578  AUC=0.7688
#     NaiveBayes                 Acc=0.6280  F1=0.6273  MCC=0.4461  G-Mean=0.7154  AUC=0.7692
#     Perceptron                 Acc=0.4573  F1=0.4268  MCC=0.2192  G-Mean=0.5791  AUC=  N/A
#     SGDClassifier              Acc=0.4878  F1=0.4675  MCC=0.2482  G-Mean=0.6020  AUC=  N/A
#     PassiveAggressive          Acc=0.4817  F1=0.4299  MCC=0.2537  G-Mean=0.5976  AUC=  N/A
#     LDA                        Acc=0.6037  F1=0.6010  MCC=0.4097  G-Mean=0.6962  AUC=0.7857
#     QDA                        Acc=0.6585  F1=0.6598  MCC=0.4906  G-Mean=0.7392  AUC=0.8029
#     LightGBM                   Acc=0.7195  F1=0.7175  MCC=0.5798  G-Mean=0.7861  AUC=0.9037
#     XGBoost                    Acc=0.7500  F1=0.7485  MCC=0.6271  G-Mean=0.8097  AUC=0.9136
#     VotingSoft                 Acc=0.7378  F1=0.7364  MCC=0.6079  G-Mean=0.8003  AUC=0.9154
#     VotingHard                 Acc=0.7622  F1=0.7617  MCC=0.6444  G-Mean=0.8192  AUC=  N/A
#     Stacking                   Acc=0.7561  F1=0.7561  MCC=0.6349  G-Mean=0.8146  AUC=0.9165
#
# ======================================================================
#   Combo: B4_SMOTE + FS5_RFImportance  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.7500  F1=0.7485  MCC=0.6262  G-Mean=0.8097  AUC=0.9208
#     ExtraTrees                 Acc=0.8232  F1=0.8219  MCC=0.7362  G-Mean=0.8660  AUC=0.9413
#     Bagging                    Acc=0.7500  F1=0.7479  MCC=0.6266  G-Mean=0.8097  AUC=0.8831
#     GradientBoosting           Acc=0.7683  F1=0.7688  MCC=0.6537  G-Mean=0.8240  AUC=0.9114
#     LogisticRegression         Acc=0.6402  F1=0.6396  MCC=0.4627  G-Mean=0.7249  AUC=0.8119
#     RidgeClassifier            Acc=0.6159  F1=0.6106  MCC=0.4290  G-Mean=0.7058  AUC=  N/A
#     DecisionTree               Acc=0.6524  F1=0.6514  MCC=0.4819  G-Mean=0.7340  AUC=0.7403
#     NaiveBayes                 Acc=0.6037  F1=0.6020  MCC=0.4101  G-Mean=0.6962  AUC=0.7620
#     Perceptron                 Acc=0.4817  F1=0.4426  MCC=0.2437  G-Mean=0.5983  AUC=  N/A
#     SGDClassifier              Acc=0.6159  F1=0.6017  MCC=0.4413  G-Mean=0.7058  AUC=  N/A
#     PassiveAggressive          Acc=0.5061  F1=0.4627  MCC=0.2816  G-Mean=0.6177  AUC=  N/A
#     LDA                        Acc=0.6280  F1=0.6271  MCC=0.4442  G-Mean=0.7153  AUC=0.8067
#     QDA                        Acc=0.6951  F1=0.6960  MCC=0.5449  G-Mean=0.7677  AUC=0.8286
#     LightGBM                   Acc=0.7805  F1=0.7788  MCC=0.6714  G-Mean=0.8332  AUC=0.9243
#     XGBoost                    Acc=0.7561  F1=0.7565  MCC=0.6350  G-Mean=0.8146  AUC=0.9320
#     VotingSoft                 Acc=0.7866  F1=0.7859  MCC=0.6801  G-Mean=0.8380  AUC=0.9341
#     VotingHard                 Acc=0.7683  F1=0.7656  MCC=0.6538  G-Mean=0.8238  AUC=  N/A
#     Stacking                   Acc=0.8110  F1=0.8099  MCC=0.7169  G-Mean=0.8567  AUC=0.9412
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS1_Correlation  |  shape=(654, 13)
# ======================================================================
#     RandomForest               Acc=0.7256  F1=0.7241  MCC=0.5893  G-Mean=0.7909  AUC=0.9035
#     ExtraTrees                 Acc=0.7073  F1=0.7079  MCC=0.5633  G-Mean=0.7766  AUC=0.8941
#     Bagging                    Acc=0.7073  F1=0.7070  MCC=0.5617  G-Mean=0.7767  AUC=0.8662
#     GradientBoosting           Acc=0.7012  F1=0.7015  MCC=0.5523  G-Mean=0.7723  AUC=0.8675
#     LogisticRegression         Acc=0.6280  F1=0.6218  MCC=0.4486  G-Mean=0.7155  AUC=0.7472
#     RidgeClassifier            Acc=0.5915  F1=0.5797  MCC=0.3973  G-Mean=0.6866  AUC=  N/A
#     DecisionTree               Acc=0.6585  F1=0.6584  MCC=0.4907  G-Mean=0.7385  AUC=0.7549
#     NaiveBayes                 Acc=0.5671  F1=0.5525  MCC=0.3628  G-Mean=0.6673  AUC=0.7091
#     Perceptron                 Acc=0.4207  F1=0.3650  MCC=0.1509  G-Mean=0.5473  AUC=  N/A
#     SGDClassifier              Acc=0.5061  F1=0.5067  MCC=0.2624  G-Mean=0.6179  AUC=  N/A
#     PassiveAggressive          Acc=0.4329  F1=0.3795  MCC=0.1704  G-Mean=0.5571  AUC=  N/A
#     LDA                        Acc=0.5976  F1=0.5912  MCC=0.4016  G-Mean=0.6914  AUC=0.7453
#     QDA                        Acc=0.6037  F1=0.6055  MCC=0.4106  G-Mean=0.6960  AUC=0.7790
#     LightGBM                   Acc=0.7378  F1=0.7381  MCC=0.6070  G-Mean=0.8006  AUC=0.8926
#     XGBoost                    Acc=0.7195  F1=0.7212  MCC=0.5798  G-Mean=0.7864  AUC=0.8913
#     VotingSoft                 Acc=0.7317  F1=0.7318  MCC=0.5977  G-Mean=0.7957  AUC=0.9029
#     VotingHard                 Acc=0.7256  F1=0.7257  MCC=0.5890  G-Mean=0.7909  AUC=  N/A
#     Stacking                   Acc=0.7439  F1=0.7441  MCC=0.6160  G-Mean=0.8053  AUC=0.9024
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS2_KBest  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.8049  F1=0.7993  MCC=0.7144  G-Mean=0.8516  AUC=0.9394
#     ExtraTrees                 Acc=0.8049  F1=0.8016  MCC=0.7104  G-Mean=0.8518  AUC=0.9368
#     Bagging                    Acc=0.8110  F1=0.8089  MCC=0.7178  G-Mean=0.8565  AUC=0.9100
#     GradientBoosting           Acc=0.7744  F1=0.7733  MCC=0.6618  G-Mean=0.8286  AUC=0.9072
#     LogisticRegression         Acc=0.6402  F1=0.6308  MCC=0.4667  G-Mean=0.7250  AUC=0.7995
#     RidgeClassifier            Acc=0.6220  F1=0.6082  MCC=0.4438  G-Mean=0.7108  AUC=  N/A
#     DecisionTree               Acc=0.7317  F1=0.7277  MCC=0.5984  G-Mean=0.7956  AUC=0.7969
#     NaiveBayes                 Acc=0.5793  F1=0.5733  MCC=0.3767  G-Mean=0.6769  AUC=0.7235
#     Perceptron                 Acc=0.5488  F1=0.5290  MCC=0.3373  G-Mean=0.6513  AUC=  N/A
#     SGDClassifier              Acc=0.5549  F1=0.5464  MCC=0.3446  G-Mean=0.6559  AUC=  N/A
#     PassiveAggressive          Acc=0.5854  F1=0.5670  MCC=0.3953  G-Mean=0.6810  AUC=  N/A
#     LDA                        Acc=0.5976  F1=0.5901  MCC=0.4020  G-Mean=0.6914  AUC=0.8130
#     QDA                        Acc=0.7195  F1=0.7203  MCC=0.5795  G-Mean=0.7864  AUC=0.8654
#     LightGBM                   Acc=0.8171  F1=0.8138  MCC=0.7272  G-Mean=0.8611  AUC=0.9372
#     XGBoost                    Acc=0.8476  F1=0.8466  MCC=0.7719  G-Mean=0.8846  AUC=0.9460
#     VotingSoft                 Acc=0.7927  F1=0.7888  MCC=0.6911  G-Mean=0.8424  AUC=0.9399
#     VotingHard                 Acc=0.8232  F1=0.8196  MCC=0.7376  G-Mean=0.8657  AUC=  N/A
#     Stacking                   Acc=0.8354  F1=0.8344  MCC=0.7539  G-Mean=0.8753  AUC=0.9421
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS3_RFE  |  shape=(654, 25)
# ======================================================================
#     RandomForest               Acc=0.7378  F1=0.7329  MCC=0.6096  G-Mean=0.8001  AUC=0.9118
#     ExtraTrees                 Acc=0.7805  F1=0.7770  MCC=0.6743  G-Mean=0.8330  AUC=0.9164
#     Bagging                    Acc=0.7805  F1=0.7788  MCC=0.6727  G-Mean=0.8331  AUC=0.8944
#     GradientBoosting           Acc=0.7073  F1=0.7062  MCC=0.5615  G-Mean=0.7766  AUC=0.8745
#     LogisticRegression         Acc=0.5793  F1=0.5730  MCC=0.3745  G-Mean=0.6769  AUC=0.7557
#     RidgeClassifier            Acc=0.5732  F1=0.5608  MCC=0.3688  G-Mean=0.6722  AUC=  N/A
#     DecisionTree               Acc=0.6890  F1=0.6837  MCC=0.5347  G-Mean=0.7623  AUC=0.7642
#     NaiveBayes                 Acc=0.6280  F1=0.6249  MCC=0.4494  G-Mean=0.7155  AUC=0.7499
#     Perceptron                 Acc=0.4268  F1=0.3802  MCC=0.1603  G-Mean=0.5521  AUC=  N/A
#     SGDClassifier              Acc=0.5122  F1=0.5033  MCC=0.2783  G-Mean=0.6231  AUC=  N/A
#     PassiveAggressive          Acc=0.4146  F1=0.3728  MCC=0.1474  G-Mean=0.5435  AUC=  N/A
#     LDA                        Acc=0.5854  F1=0.5787  MCC=0.3842  G-Mean=0.6818  AUC=0.7588
#     QDA                        Acc=0.6524  F1=0.6569  MCC=0.4843  G-Mean=0.7345  AUC=0.8061
#     LightGBM                   Acc=0.7500  F1=0.7489  MCC=0.6254  G-Mean=0.8097  AUC=0.9004
#     XGBoost                    Acc=0.7805  F1=0.7777  MCC=0.6722  G-Mean=0.8331  AUC=0.9128
#     VotingSoft                 Acc=0.7561  F1=0.7511  MCC=0.6363  G-Mean=0.8142  AUC=0.9095
#     VotingHard                 Acc=0.7622  F1=0.7592  MCC=0.6447  G-Mean=0.8190  AUC=  N/A
#     Stacking                   Acc=0.7744  F1=0.7754  MCC=0.6623  G-Mean=0.8286  AUC=0.9109
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS4_MutualInfo  |  shape=(654, 38)
# ======================================================================
#     RandomForest               Acc=0.7927  F1=0.7871  MCC=0.6954  G-Mean=0.8422  AUC=0.9280
#     ExtraTrees                 Acc=0.8110  F1=0.8071  MCC=0.7237  G-Mean=0.8563  AUC=0.9347
#     Bagging                    Acc=0.7805  F1=0.7781  MCC=0.6736  G-Mean=0.8331  AUC=0.8988
#     GradientBoosting           Acc=0.7683  F1=0.7675  MCC=0.6529  G-Mean=0.8239  AUC=0.9070
#     LogisticRegression         Acc=0.6159  F1=0.6105  MCC=0.4279  G-Mean=0.7058  AUC=0.7847
#     RidgeClassifier            Acc=0.5976  F1=0.5828  MCC=0.4057  G-Mean=0.6916  AUC=  N/A
#     DecisionTree               Acc=0.7073  F1=0.7008  MCC=0.5664  G-Mean=0.7763  AUC=0.7786
#     NaiveBayes                 Acc=0.5793  F1=0.5712  MCC=0.3773  G-Mean=0.6769  AUC=0.7270
#     Perceptron                 Acc=0.4573  F1=0.4308  MCC=0.2229  G-Mean=0.5767  AUC=  N/A
#     SGDClassifier              Acc=0.4878  F1=0.4812  MCC=0.2509  G-Mean=0.6023  AUC=  N/A
#     PassiveAggressive          Acc=0.5549  F1=0.4938  MCC=0.3641  G-Mean=0.6576  AUC=  N/A
#     LDA                        Acc=0.6037  F1=0.5953  MCC=0.4120  G-Mean=0.6963  AUC=0.7899
#     QDA                        Acc=0.7500  F1=0.7512  MCC=0.6258  G-Mean=0.8101  AUC=0.8625
#     LightGBM                   Acc=0.8110  F1=0.8082  MCC=0.7179  G-Mean=0.8565  AUC=0.9323
#     XGBoost                    Acc=0.8110  F1=0.8080  MCC=0.7203  G-Mean=0.8564  AUC=0.9414
#     VotingSoft                 Acc=0.8049  F1=0.8026  MCC=0.7084  G-Mean=0.8519  AUC=0.9381
#     VotingHard                 Acc=0.8110  F1=0.8063  MCC=0.7221  G-Mean=0.8563  AUC=  N/A
#     Stacking                   Acc=0.8110  F1=0.8106  MCC=0.7183  G-Mean=0.8566  AUC=0.9339
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS5_RFImportance  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.8049  F1=0.7985  MCC=0.7155  G-Mean=0.8515  AUC=0.9334
#     ExtraTrees                 Acc=0.8232  F1=0.8201  MCC=0.7368  G-Mean=0.8658  AUC=0.9385
#     Bagging                    Acc=0.8110  F1=0.8100  MCC=0.7175  G-Mean=0.8566  AUC=0.9162
#     GradientBoosting           Acc=0.7805  F1=0.7804  MCC=0.6708  G-Mean=0.8334  AUC=0.9185
#     LogisticRegression         Acc=0.6220  F1=0.6132  MCC=0.4387  G-Mean=0.7106  AUC=0.8031
#     RidgeClassifier            Acc=0.6220  F1=0.6087  MCC=0.4421  G-Mean=0.7108  AUC=  N/A
#     DecisionTree               Acc=0.7134  F1=0.7136  MCC=0.5707  G-Mean=0.7815  AUC=0.7826
#     NaiveBayes                 Acc=0.5915  F1=0.5856  MCC=0.3953  G-Mean=0.6866  AUC=0.7242
#     Perceptron                 Acc=0.5305  F1=0.5289  MCC=0.3101  G-Mean=0.6380  AUC=  N/A
#     SGDClassifier              Acc=0.5732  F1=0.5733  MCC=0.3739  G-Mean=0.6708  AUC=  N/A
#     PassiveAggressive          Acc=0.5732  F1=0.5518  MCC=0.3716  G-Mean=0.6715  AUC=  N/A
#     LDA                        Acc=0.6220  F1=0.6151  MCC=0.4386  G-Mean=0.7107  AUC=0.8153
#     QDA                        Acc=0.7317  F1=0.7326  MCC=0.5983  G-Mean=0.7959  AUC=0.8717
#     LightGBM                   Acc=0.7805  F1=0.7761  MCC=0.6728  G-Mean=0.8331  AUC=0.9301
#     XGBoost                    Acc=0.8232  F1=0.8222  MCC=0.7352  G-Mean=0.8660  AUC=0.9476
#     VotingSoft                 Acc=0.8232  F1=0.8208  MCC=0.7367  G-Mean=0.8658  AUC=0.9382
#     VotingHard                 Acc=0.8171  F1=0.8136  MCC=0.7304  G-Mean=0.8610  AUC=  N/A
#     Stacking                   Acc=0.8476  F1=0.8465  MCC=0.7731  G-Mean=0.8845  AUC=0.9454
#
# ======================================================================
#   Combo: B6_TomekLinks + FS1_Correlation  |  shape=(369, 15)
# ======================================================================
#     RandomForest               Acc=0.6774  F1=0.5898  MCC=0.4308  G-Mean=0.6820  AUC=0.8116
#     ExtraTrees                 Acc=0.6882  F1=0.6164  MCC=0.4521  G-Mean=0.6977  AUC=0.8078
#     Bagging                    Acc=0.5806  F1=0.4970  MCC=0.2737  G-Mean=0.6109  AUC=0.7463
#     GradientBoosting           Acc=0.6774  F1=0.6230  MCC=0.4402  G-Mean=0.7017  AUC=0.7937
#     LogisticRegression         Acc=0.6882  F1=0.6067  MCC=0.4527  G-Mean=0.6963  AUC=0.7571
#     RidgeClassifier            Acc=0.6667  F1=0.5709  MCC=0.4126  G-Mean=0.6734  AUC=  N/A
#     DecisionTree               Acc=0.5806  F1=0.5141  MCC=0.2786  G-Mean=0.6217  AUC=0.6241
#     NaiveBayes                 Acc=0.6667  F1=0.6203  MCC=0.4210  G-Mean=0.7007  AUC=0.7930
#     Perceptron                 Acc=0.5591  F1=0.4735  MCC=0.2904  G-Mean=0.6369  AUC=  N/A
#     SGDClassifier              Acc=0.5914  F1=0.4508  MCC=0.2888  G-Mean=0.5982  AUC=  N/A
#     PassiveAggressive          Acc=0.6129  F1=0.4980  MCC=0.3193  G-Mean=0.6198  AUC=  N/A
#     LDA                        Acc=0.6774  F1=0.5907  MCC=0.4320  G-Mean=0.6848  AUC=0.7627
# ...
#     Stacking                   Acc=0.7204  F1=0.6378  MCC=0.5083  G-Mean=0.7136  AUC=0.8177
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS1_Correlation  |  shape=(642, 13)
# ======================================================================
#     RandomForest               Acc=0.8075  F1=0.8074  MCC=0.7112  G-Mean=0.8541  AUC=0.9043
#     ExtraTrees                 Acc=0.7764  F1=0.7763  MCC=0.6650  G-Mean=0.8304  AUC=0.9089
#     Bagging                    Acc=0.7453  F1=0.7453  MCC=0.6187  G-Mean=0.8065  AUC=0.8788
#     GradientBoosting           Acc=0.7205  F1=0.7221  MCC=0.5821  G-Mean=0.7874  AUC=0.8736
#     LogisticRegression         Acc=0.5714  F1=0.5667  MCC=0.3618  G-Mean=0.6707  AUC=0.7594
#     RidgeClassifier            Acc=0.5652  F1=0.5511  MCC=0.3589  G-Mean=0.6660  AUC=  N/A
#     DecisionTree               Acc=0.7267  F1=0.7264  MCC=0.5917  G-Mean=0.7923  AUC=0.8175
#     NaiveBayes                 Acc=0.6273  F1=0.6265  MCC=0.4488  G-Mean=0.7150  AUC=0.7640
#     Perceptron                 Acc=0.5404  F1=0.5352  MCC=0.3160  G-Mean=0.6459  AUC=  N/A
#     SGDClassifier              Acc=0.5093  F1=0.4516  MCC=0.2877  G-Mean=0.6209  AUC=  N/A
#     PassiveAggressive          Acc=0.4783  F1=0.4377  MCC=0.2335  G-Mean=0.5959  AUC=  N/A
#     LDA                        Acc=0.5839  F1=0.5786  MCC=0.3805  G-Mean=0.6805  AUC=0.7670
#     QDA                        Acc=0.6522  F1=0.6507  MCC=0.4836  G-Mean=0.7345  AUC=0.7832
#     LightGBM                   Acc=0.7764  F1=0.7742  MCC=0.6651  G-Mean=0.8302  AUC=0.8864
#     XGBoost                    Acc=0.7702  F1=0.7692  MCC=0.6553  G-Mean=0.8254  AUC=0.8889
#     VotingSoft                 Acc=0.7950  F1=0.7936  MCC=0.6927  G-Mean=0.8445  AUC=0.9044
#     VotingHard                 Acc=0.8075  F1=0.8076  MCC=0.7113  G-Mean=0.8542  AUC=  N/A
#     Stacking                   Acc=0.7826  F1=0.7817  MCC=0.6739  G-Mean=0.8350  AUC=0.9088
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS2_KBest  |  shape=(642, 46)
# ======================================================================
#     RandomForest               Acc=0.8137  F1=0.8130  MCC=0.7208  G-Mean=0.8589  AUC=0.9258
#     ExtraTrees                 Acc=0.7764  F1=0.7769  MCC=0.6652  G-Mean=0.8304  AUC=0.9319
#     Bagging                    Acc=0.7578  F1=0.7581  MCC=0.6369  G-Mean=0.8159  AUC=0.8943
#     GradientBoosting           Acc=0.7950  F1=0.7951  MCC=0.6931  G-Mean=0.8448  AUC=0.9129
#     LogisticRegression         Acc=0.6460  F1=0.6401  MCC=0.4729  G-Mean=0.7296  AUC=0.7752
#     RidgeClassifier            Acc=0.6273  F1=0.6178  MCC=0.4460  G-Mean=0.7149  AUC=  N/A
#     DecisionTree               Acc=0.7019  F1=0.7029  MCC=0.5556  G-Mean=0.7730  AUC=0.7810
#     NaiveBayes                 Acc=0.6335  F1=0.6311  MCC=0.4591  G-Mean=0.7200  AUC=0.7477
#     Perceptron                 Acc=0.5404  F1=0.5299  MCC=0.3199  G-Mean=0.6459  AUC=  N/A
#     SGDClassifier              Acc=0.5155  F1=0.5175  MCC=0.2792  G-Mean=0.6256  AUC=  N/A
#     PassiveAggressive          Acc=0.5155  F1=0.5056  MCC=0.2843  G-Mean=0.6259  AUC=  N/A
#     LDA                        Acc=0.6211  F1=0.6156  MCC=0.4340  G-Mean=0.7100  AUC=0.7809
#     QDA                        Acc=0.6832  F1=0.6764  MCC=0.5349  G-Mean=0.7589  AUC=0.8486
#     LightGBM                   Acc=0.8075  F1=0.8083  MCC=0.7118  G-Mean=0.8543  AUC=0.9374
#     XGBoost                    Acc=0.8012  F1=0.8019  MCC=0.7024  G-Mean=0.8495  AUC=0.9251
#     VotingSoft                 Acc=0.7950  F1=0.7962  MCC=0.6942  G-Mean=0.8449  AUC=0.9416
#     VotingHard                 Acc=0.8012  F1=0.8017  MCC=0.7032  G-Mean=0.8496  AUC=  N/A
#     Stacking                   Acc=0.8012  F1=0.8024  MCC=0.7047  G-Mean=0.8497  AUC=0.9412
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS3_RFE  |  shape=(642, 25)
# ======================================================================
#     RandomForest               Acc=0.7950  F1=0.7962  MCC=0.6939  G-Mean=0.8448  AUC=0.9056
#     ExtraTrees                 Acc=0.8137  F1=0.8145  MCC=0.7214  G-Mean=0.8590  AUC=0.9129
#     Bagging                    Acc=0.7329  F1=0.7353  MCC=0.6006  G-Mean=0.7969  AUC=0.8742
#     GradientBoosting           Acc=0.7453  F1=0.7457  MCC=0.6218  G-Mean=0.8068  AUC=0.8919
#     LogisticRegression         Acc=0.5963  F1=0.5918  MCC=0.4002  G-Mean=0.6906  AUC=0.7560
#     RidgeClassifier            Acc=0.5714  F1=0.5650  MCC=0.3636  G-Mean=0.6708  AUC=  N/A
#     DecisionTree               Acc=0.6832  F1=0.6851  MCC=0.5268  G-Mean=0.7584  AUC=0.7582
#     NaiveBayes                 Acc=0.6273  F1=0.6247  MCC=0.4505  G-Mean=0.7151  AUC=0.7663
#     Perceptron                 Acc=0.5466  F1=0.5498  MCC=0.3228  G-Mean=0.6502  AUC=  N/A
#     SGDClassifier              Acc=0.5093  F1=0.4859  MCC=0.2824  G-Mean=0.6213  AUC=  N/A
#     PassiveAggressive          Acc=0.4658  F1=0.4085  MCC=0.2444  G-Mean=0.5844  AUC=  N/A
#     LDA                        Acc=0.5776  F1=0.5730  MCC=0.3719  G-Mean=0.6757  AUC=0.7548
#     QDA                        Acc=0.6770  F1=0.6797  MCC=0.5247  G-Mean=0.7539  AUC=0.7991
#     LightGBM                   Acc=0.7950  F1=0.7962  MCC=0.6938  G-Mean=0.8448  AUC=0.9027
#     XGBoost                    Acc=0.7764  F1=0.7773  MCC=0.6655  G-Mean=0.8304  AUC=0.9051
#     VotingSoft                 Acc=0.7950  F1=0.7966  MCC=0.6957  G-Mean=0.8449  AUC=0.9158
#     VotingHard                 Acc=0.8323  F1=0.8338  MCC=0.7507  G-Mean=0.8734  AUC=  N/A
#     Stacking                   Acc=0.8199  F1=0.8216  MCC=0.7339  G-Mean=0.8640  AUC=0.9170
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS4_MutualInfo  |  shape=(642, 38)
# ======================================================================
#     RandomForest               Acc=0.7888  F1=0.7890  MCC=0.6840  G-Mean=0.8399  AUC=0.9136
#     ExtraTrees                 Acc=0.8137  F1=0.8141  MCC=0.7208  G-Mean=0.8590  AUC=0.9236
#     Bagging                    Acc=0.7888  F1=0.7885  MCC=0.6837  G-Mean=0.8398  AUC=0.8829
#     GradientBoosting           Acc=0.7640  F1=0.7642  MCC=0.6468  G-Mean=0.8210  AUC=0.9057
#     LogisticRegression         Acc=0.5963  F1=0.5926  MCC=0.3994  G-Mean=0.6905  AUC=0.7613
#     RidgeClassifier            Acc=0.5839  F1=0.5747  MCC=0.3829  G-Mean=0.6808  AUC=  N/A
#     DecisionTree               Acc=0.7019  F1=0.7063  MCC=0.5569  G-Mean=0.7730  AUC=0.7770
#     NaiveBayes                 Acc=0.6211  F1=0.6205  MCC=0.4384  G-Mean=0.7101  AUC=0.7550
#     Perceptron                 Acc=0.5652  F1=0.5635  MCC=0.3570  G-Mean=0.6652  AUC=  N/A
#     SGDClassifier              Acc=0.5963  F1=0.5983  MCC=0.3959  G-Mean=0.6900  AUC=  N/A
#     PassiveAggressive          Acc=0.5217  F1=0.5008  MCC=0.2918  G-Mean=0.6307  AUC=  N/A
#     LDA                        Acc=0.5901  F1=0.5851  MCC=0.3906  G-Mean=0.6856  AUC=0.7676
#     QDA                        Acc=0.6832  F1=0.6795  MCC=0.5386  G-Mean=0.7591  AUC=0.8187
#     LightGBM                   Acc=0.7764  F1=0.7770  MCC=0.6649  G-Mean=0.8302  AUC=0.9165
#     XGBoost                    Acc=0.7888  F1=0.7892  MCC=0.6835  G-Mean=0.8400  AUC=0.9210
#     VotingSoft                 Acc=0.8261  F1=0.8259  MCC=0.7392  G-Mean=0.8684  AUC=0.9261
#     VotingHard                 Acc=0.8012  F1=0.8014  MCC=0.7020  G-Mean=0.8494  AUC=  N/A
#     Stacking                   Acc=0.8075  F1=0.8082  MCC=0.7118  G-Mean=0.8542  AUC=0.9256
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS5_RFImportance  |  shape=(642, 46)
# ======================================================================
#     RandomForest               Acc=0.8075  F1=0.8083  MCC=0.7124  G-Mean=0.8543  AUC=0.9304
#     ExtraTrees                 Acc=0.8199  F1=0.8202  MCC=0.7309  G-Mean=0.8638  AUC=0.9463
#     Bagging                    Acc=0.7516  F1=0.7522  MCC=0.6278  G-Mean=0.8112  AUC=0.8890
#     GradientBoosting           Acc=0.8012  F1=0.8022  MCC=0.7024  G-Mean=0.8495  AUC=0.9163
#     LogisticRegression         Acc=0.6460  F1=0.6403  MCC=0.4740  G-Mean=0.7296  AUC=0.7675
#     RidgeClassifier            Acc=0.6211  F1=0.6119  MCC=0.4379  G-Mean=0.7101  AUC=  N/A
#     DecisionTree               Acc=0.6957  F1=0.6959  MCC=0.5448  G-Mean=0.7681  AUC=0.7780
#     NaiveBayes                 Acc=0.6273  F1=0.6240  MCC=0.4507  G-Mean=0.7151  AUC=0.7478
#     Perceptron                 Acc=0.3851  F1=0.3291  MCC=0.1134  G-Mean=0.5187  AUC=  N/A
#     SGDClassifier              Acc=0.5590  F1=0.5515  MCC=0.3417  G-Mean=0.6601  AUC=  N/A
#     PassiveAggressive          Acc=0.5839  F1=0.5848  MCC=0.3761  G-Mean=0.6799  AUC=  N/A
#     LDA                        Acc=0.6211  F1=0.6151  MCC=0.4351  G-Mean=0.7101  AUC=0.7722
#     QDA                        Acc=0.6957  F1=0.6896  MCC=0.5550  G-Mean=0.7686  AUC=0.8488
#     LightGBM                   Acc=0.8075  F1=0.8087  MCC=0.7124  G-Mean=0.8543  AUC=0.9247
#     XGBoost                    Acc=0.7950  F1=0.7959  MCC=0.6929  G-Mean=0.8446  AUC=0.9234
#     VotingSoft                 Acc=0.8012  F1=0.8024  MCC=0.7045  G-Mean=0.8497  AUC=0.9407
#     VotingHard                 Acc=0.8447  F1=0.8453  MCC=0.7697  G-Mean=0.8829  AUC=  N/A
#     Stacking                   Acc=0.8075  F1=0.8077  MCC=0.7143  G-Mean=0.8544  AUC=0.9441
#
#
# -- Phase 3 Summary (top 30 combos by Accuracy) --
#                              Balancer+FS   Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
#        B1_RandomOverSampling + FS2_KBest     Stacking    0.9024    0.9001 0.8565  0.9261 0.9852
# B1_RandomOverSampling + FS5_RFImportance      XGBoost    0.8963    0.8929 0.8490  0.9214 0.9838
#   B1_RandomOverSampling + FS4_MutualInfo   VotingHard    0.8902    0.8856 0.8429  0.9166    NaN
#   B1_RandomOverSampling + FS4_MutualInfo     LightGBM    0.8841    0.8789 0.8349  0.9120 0.9746
#   B1_RandomOverSampling + FS4_MutualInfo     Stacking    0.8841    0.8823 0.8269  0.9124 0.9830
#   B1_RandomOverSampling + FS4_MutualInfo   VotingSoft    0.8841    0.8789 0.8349  0.9120 0.9815
#        B1_RandomOverSampling + FS2_KBest      XGBoost    0.8780    0.8733 0.8228  0.9074 0.9840
#   B1_RandomOverSampling + FS4_MutualInfo RandomForest    0.8780    0.8726 0.8275  0.9073 0.9804
#          B1_RandomOverSampling + FS3_RFE   ExtraTrees    0.8780    0.8762 0.8200  0.9076 0.9794
#        B1_RandomOverSampling + FS2_KBest RandomForest    0.8720    0.8678 0.8137  0.9028 0.9820
# B1_RandomOverSampling + FS5_RFImportance     Stacking    0.8720    0.8710 0.8080  0.9032 0.9793
#        B1_RandomOverSampling + FS2_KBest   VotingHard    0.8720    0.8663 0.8173  0.9027    NaN
#  B1_RandomOverSampling + FS1_Correlation   ExtraTrees    0.8659    0.8624 0.8020  0.8983 0.9734
#        B1_RandomOverSampling + FS2_KBest     LightGBM    0.8659    0.8595 0.8094  0.8980 0.9780
# B1_RandomOverSampling + FS5_RFImportance     LightGBM    0.8659    0.8623 0.8046  0.8982 0.9762
#          B1_RandomOverSampling + FS3_RFE   VotingHard    0.8659    0.8622 0.8037  0.8982    NaN
#  B1_RandomOverSampling + FS1_Correlation   VotingHard    0.8659    0.8624 0.8020  0.8983    NaN
#  B1_RandomOverSampling + FS1_Correlation RandomForest    0.8659    0.8622 0.8021  0.8983 0.9719
#        B1_RandomOverSampling + FS2_KBest   ExtraTrees    0.8598    0.8552 0.7945  0.8935 0.9822
#          B1_RandomOverSampling + FS3_RFE      XGBoost    0.8598    0.8556 0.7943  0.8936 0.9775
#   B1_RandomOverSampling + FS4_MutualInfo   ExtraTrees    0.8598    0.8578 0.7918  0.8937 0.9815
#  B1_RandomOverSampling + FS1_Correlation      XGBoost    0.8598    0.8552 0.7961  0.8935 0.9563
# B1_RandomOverSampling + FS5_RFImportance   ExtraTrees    0.8537    0.8508 0.7840  0.8890 0.9808
#          B1_RandomOverSampling + FS3_RFE     Stacking    0.8537    0.8526 0.7809  0.8894 0.9767
# B1_RandomOverSampling + FS5_RFImportance DecisionTree    0.8537    0.8495 0.7868  0.8889 0.8922
#  B1_RandomOverSampling + FS1_Correlation     Stacking    0.8537    0.8522 0.7820  0.8892 0.9694
#    B5_BorderlineSMOTE + FS5_RFImportance     Stacking    0.8476    0.8465 0.7731  0.8845 0.9454
#  B1_RandomOverSampling + FS1_Correlation   VotingSoft    0.8476    0.8432 0.7759  0.8843 0.9665
#        B1_RandomOverSampling + FS2_KBest   VotingSoft    0.8476    0.8418 0.7780  0.8842 0.9793
#           B5_BorderlineSMOTE + FS2_KBest      XGBoost    0.8476    0.8466 0.7719  0.8846 0.9460
#
# -- Phase 3: Best Classifier per Balancer+FS combo --
#                               Balancer+FS   Classifier  Accuracy  Macro_F1    MCC  G_Mean    AUC
#         B1_RandomOverSampling + FS2_KBest     Stacking    0.9024    0.9001 0.8565  0.9261 0.9852
#  B1_RandomOverSampling + FS5_RFImportance      XGBoost    0.8963    0.8929 0.8490  0.9214 0.9838
#    B1_RandomOverSampling + FS4_MutualInfo   VotingHard    0.8902    0.8856 0.8429  0.9166    NaN
#           B1_RandomOverSampling + FS3_RFE   ExtraTrees    0.8780    0.8762 0.8200  0.9076 0.9794
#   B1_RandomOverSampling + FS1_Correlation   ExtraTrees    0.8659    0.8624 0.8020  0.8983 0.9734
#     B5_BorderlineSMOTE + FS5_RFImportance     Stacking    0.8476    0.8465 0.7731  0.8845 0.9454
#            B5_BorderlineSMOTE + FS2_KBest      XGBoost    0.8476    0.8466 0.7719  0.8846 0.9460
#          B7_SMOTETomek + FS5_RFImportance   VotingHard    0.8447    0.8453 0.7697  0.8829    NaN
#                   B7_SMOTETomek + FS3_RFE   VotingHard    0.8323    0.8338 0.7507  0.8734    NaN
#            B7_SMOTETomek + FS4_MutualInfo   VotingSoft    0.8261    0.8259 0.7392  0.8684 0.9261
#               B4_SMOTE + FS5_RFImportance   ExtraTrees    0.8232    0.8219 0.7362  0.8660 0.9413
#                 B7_SMOTETomek + FS2_KBest RandomForest    0.8137    0.8130 0.7208  0.8589 0.9258
#       B5_BorderlineSMOTE + FS4_MutualInfo   ExtraTrees    0.8110    0.8071 0.7237  0.8563 0.9347
#           B7_SMOTETomek + FS1_Correlation RandomForest    0.8075    0.8074 0.7112  0.8541 0.9043
#                      B4_SMOTE + FS2_KBest   ExtraTrees    0.7927    0.7922 0.6914  0.8427 0.9389
#              B3_ADASYN + FS5_RFImportance   ExtraTrees    0.7927    0.7922 0.6895  0.8438 0.9171
#                     B3_ADASYN + FS2_KBest   VotingSoft    0.7866    0.7870 0.6800  0.8391 0.9191
#              B5_BorderlineSMOTE + FS3_RFE   ExtraTrees    0.7805    0.7770 0.6743  0.8330 0.9164
#                B4_SMOTE + FS1_Correlation   VotingSoft    0.7805    0.7780 0.6720  0.8331 0.9102
#                        B4_SMOTE + FS3_RFE RandomForest    0.7744    0.7722 0.6626  0.8286 0.8974
#                B3_ADASYN + FS4_MutualInfo   ExtraTrees    0.7744    0.7742 0.6630  0.8294 0.9008
#                 B4_SMOTE + FS4_MutualInfo   ExtraTrees    0.7683    0.7676 0.6532  0.8240 0.9141
#                       B3_ADASYN + FS3_RFE     Stacking    0.7622    0.7649 0.6437  0.8200 0.8848
#      B5_BorderlineSMOTE + FS1_Correlation     Stacking    0.7439    0.7441 0.6160  0.8053 0.9024
#           B6_TomekLinks + FS1_Correlation     LightGBM    0.7419    0.6861 0.5501  0.7462 0.8167
#          B6_TomekLinks + FS5_RFImportance   VotingHard    0.7312    0.6568 0.5282  0.7211    NaN
#                 B6_TomekLinks + FS2_KBest   NaiveBayes    0.7204    0.6728 0.5189  0.7466 0.8074
#            B6_TomekLinks + FS4_MutualInfo   NaiveBayes    0.7204    0.6777 0.5221  0.7523 0.8073
#               B3_ADASYN + FS1_Correlation     Stacking    0.7195    0.7242 0.5794  0.7871 0.8758
#                   B6_TomekLinks + FS3_RFE   NaiveBayes    0.7097    0.6610 0.5033  0.7424 0.7936
#  B2_RandomUnderSampling + FS1_Correlation   ExtraTrees    0.5000    0.5014 0.2521  0.6124 0.6800
#        B2_RandomUnderSampling + FS2_KBest   NaiveBayes    0.5000    0.4968 0.2505  0.6124 0.6425
#   B2_RandomUnderSampling + FS4_MutualInfo   NaiveBayes    0.5000    0.4992 0.2504  0.6124 0.6564
# B2_RandomUnderSampling + FS5_RFImportance   NaiveBayes    0.4815    0.4746 0.2230  0.5972 0.6425
#          B2_RandomUnderSampling + FS3_RFE   NaiveBayes    0.4444    0.4484 0.1670  0.5666 0.6445

# %% [markdown]
# # ***Summary***

# %%
out = '/mnt/user-data/outputs/'
combined = pd.concat([phase1_df, phase2_df, phase3_df], ignore_index=True)
combined.sort_values(['Phase','Accuracy'], ascending=[True, False], inplace=True)

combined.to_csv(out + 'pipeline_all_results.csv', index=False)
phase1_df.to_csv(out + 'phase1_balancing_results.csv', index=False)
phase2_df.to_csv(out + 'phase2_feature_selection_results.csv', index=False)
phase3_df.to_csv(out + 'phase3_combined_results.csv', index=False)

print("\n\n" + "="*80)
print("  DONE — 4 CSV files saved:")
print("  pipeline_all_results.csv             (all 3 phases combined)")
print("  phase1_balancing_results.csv         (Phase 1 only)")
print("  phase2_feature_selection_results.csv (Phase 2 only)")
print("  phase3_combined_results.csv          (Phase 3 only)")
print("="*80)
