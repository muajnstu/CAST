# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/CAST/blob/main/Revised_Implementation_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import io
import math
import csv
import pandas as pd
import numpy as np
import warnings
from google.colab import files
warnings.filterwarnings('ignore')

# Core ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.metrics import (
    accuracy_score, classification_report,
    matthews_corrcoef, roc_auc_score
)
from imblearn.metrics import geometric_mean_score
from sklearn.model_selection import StratifiedKFold

# Classifiers
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier,
    GradientBoostingClassifier, VotingClassifier, StackingClassifier
)
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron,
    SGDClassifier, PassiveAggressiveClassifier
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Balancing
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.combine import SMOTETomek


# optimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv('https://raw.githubusercontent.com/muajnstu/CAST/refs/heads/main/Expectation/Expectation_categorized.csv')
print(f"Raw dataset shape : {df.shape}")
print(f"Target distribution:\n{df['CAST'].value_counts()}\n")

X_raw = df.drop(columns=['CAST'])
y_raw = df['CAST']
# Out:
# Raw dataset shape : (400, 52)
# Target distribution:
# CAST
# 2    318
# 1     52
# 0     30
# Name: count, dtype: int64

# %% [markdown]
# ***Data Balancing***

# %%
BALANCERS = {
    "B1_RandomOverSampling":  RandomOverSampler(random_state=42),
    "B2_RandomUnderSampling": RandomUnderSampler(random_state=42),
    "B3_ADASYN":              ADASYN(random_state=42),
    "B4_SMOTE":               SMOTE(random_state=42),
    "B5_BorderlineSMOTE":     BorderlineSMOTE(random_state=42),
    "B6_TomekLinks":          TomekLinks(),
    "B7_SMOTETomek":          SMOTETomek(random_state=42),
}


def apply_balancer(name, sampler, X, y):
    try:
        X_b, y_b = sampler.fit_resample(X, y)
        df_b = pd.DataFrame(X_b, columns=X.columns)
        df_b['CAST'] = y_b
        print(f"  {name:30s} -> shape {df_b.shape}  "
              f"dist: {dict(pd.Series(y_b).value_counts())}")
        return df_b
    except Exception as e:
        print(f"  {name:30s} -> FAILED: {e}")
        return None

# %% [markdown]
# ***Tunning FS Methods***

# %%
CV      = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
CV_EST  = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
N_TOTAL = X_raw.shape[1]

def _cv_score(X_sel, y):
    """Mean 5-fold CV accuracy for a given feature subset."""
    return cross_val_score(CV_EST, X_sel, y, cv=CV,
                           scoring='accuracy', n_jobs=-1).mean()

def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# Tune FS1
print("\n" + "="*70)
print("  TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)")
print("="*70)

print("\n[FS1] Sweeping correlation threshold...")
thresholds   = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
fs1_results  = {}
for thr in thresholds:
    corr  = X_raw.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= thr)]
    X_sel = X_raw.drop(columns=drop)
    score = _cv_score(X_sel, y_raw)
    fs1_results[thr] = (score, X_sel.shape[1])
    print(f"  threshold={thr:.2f}  features={X_sel.shape[1]:3d}  CV_acc={score:.4f}")

best_fs1_thr   = max(fs1_results, key=lambda t: fs1_results[t][0])
best_fs1_score = fs1_results[best_fs1_thr][0]
best_fs1_feats = fs1_results[best_fs1_thr][1]
print(f"  >> BEST threshold={best_fs1_thr}  features={best_fs1_feats}  CV_acc={best_fs1_score:.4f}")

# Tune FS2: KBest (f_classif)
print("\n[FS2] Sweeping k for SelectKBest (f_classif)...")
k_range     = list(range(1, N_TOTAL + 1))
fs2_results = {}
for k in k_range:
    sel   = SelectKBest(f_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs2_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs2_k     = max(fs2_results, key=fs2_results.get)
best_fs2_score = fs2_results[best_fs2_k]
print(f"  >> BEST k={best_fs2_k}  CV_acc={best_fs2_score:.4f}")

# Tune FS3: RFE
print("\n[FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...")
rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1),
    step=1, cv=CV, scoring='accuracy', n_jobs=-1, min_features_to_select=1
)
rfecv.fit(X_raw, y_raw)
best_fs3_n     = rfecv.n_features_
best_fs3_score = rfecv.cv_results_['mean_test_score'][best_fs3_n - 1]
_rfecv_support = rfecv.support_
print(f"  >> BEST n_features={best_fs3_n}  CV_acc={best_fs3_score:.4f}")

# Tune FS4: Mutual Information
print("\n[FS4] Sweeping k for SelectKBest (mutual_info_classif)...")
fs4_results = {}
for k in k_range:
    sel   = SelectKBest(mutual_info_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs4_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs4_k     = max(fs4_results, key=fs4_results.get)
best_fs4_score = fs4_results[best_fs4_k]
print(f"  >> BEST k={best_fs4_k}  CV_acc={best_fs4_score:.4f}")

# Tune FS5: RF Importance cumulative threshold
print("\n[FS5] Sweeping cumulative importance threshold for RF feature importance...")
_rf_imp  = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
_rf_imp.fit(X_raw, y_raw)
imp_series = pd.Series(_rf_imp.feature_importances_, index=X_raw.columns)\
               .sort_values(ascending=False)
cum_imp = imp_series.cumsum()

cum_thresholds = [0.80, 0.85, 0.90, 0.95, 0.99]
fs5_results    = {}
for ct in cum_thresholds:
    top_feats = cum_imp[cum_imp <= ct].index.tolist()
    if len(top_feats) == 0:
        top_feats = [imp_series.index[0]]
    X_sel = X_raw[top_feats]
    score = _cv_score(X_sel, y_raw)
    fs5_results[ct] = (score, len(top_feats))
    print(f"  cum_threshold={ct:.2f}  features={len(top_feats):3d}  CV_acc={score:.4f}")

best_fs5_ct    = max(fs5_results, key=lambda t: fs5_results[t][0])
best_fs5_score = fs5_results[best_fs5_ct][0]
best_fs5_feats = fs5_results[best_fs5_ct][1]
print(f"  >> BEST cum_threshold={best_fs5_ct}  features={best_fs5_feats}  CV_acc={best_fs5_score:.4f}")

# Summary of tuned parameters
print("\n" + "="*70)
print("  TUNING SUMMARY")
print("="*70)
tuning_summary = pd.DataFrame([
    {"FS": "FS1_Correlation",  "Parameter": "threshold",        "Best_Value": best_fs1_thr,  "n_features": best_fs1_feats, "CV_Accuracy": round(best_fs1_score, 4)},
    {"FS": "FS2_KBest",        "Parameter": "k",                "Best_Value": best_fs2_k,    "n_features": best_fs2_k,     "CV_Accuracy": round(best_fs2_score, 4)},
    {"FS": "FS3_RFE",          "Parameter": "n_features (RFECV)","Best_Value": best_fs3_n,   "n_features": best_fs3_n,     "CV_Accuracy": round(best_fs3_score, 4)},
    {"FS": "FS4_MutualInfo",   "Parameter": "k",                "Best_Value": best_fs4_k,    "n_features": best_fs4_k,     "CV_Accuracy": round(best_fs4_score, 4)},
    {"FS": "FS5_RFImportance", "Parameter": "cum_threshold",    "Best_Value": best_fs5_ct,   "n_features": best_fs5_feats, "CV_Accuracy": round(best_fs5_score, 4)},
])
print(tuning_summary.to_string(index=False))
# Out:
# ======================================================================
#   TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)
# ======================================================================
#
# [FS1] Sweeping correlation threshold...
#   threshold=0.70  features= 26  CV_acc=0.9200
#   threshold=0.75  features= 38  CV_acc=0.9400
#   threshold=0.80  features= 43  CV_acc=0.9500
#   threshold=0.85  features= 49  CV_acc=0.9550
#   threshold=0.90  features= 51  CV_acc=0.9525
#   threshold=0.95  features= 51  CV_acc=0.9525
#   >> BEST threshold=0.85  features=49  CV_acc=0.9550
#
# [FS2] Sweeping k for SelectKBest (f_classif)...
#   k=  1  CV_acc=0.9225
#   k=  2  CV_acc=0.9475
#   k=  3  CV_acc=0.9450
#   k=  4  CV_acc=0.9400
#   k=  5  CV_acc=0.9475
#   k=  6  CV_acc=0.9525
#   k=  7  CV_acc=0.9625
#   k=  8  CV_acc=0.9575
#   k=  9  CV_acc=0.9550
#   k= 10  CV_acc=0.9650
#   k= 11  CV_acc=0.9600
#   k= 12  CV_acc=0.9550
#   k= 13  CV_acc=0.9525
#   k= 14  CV_acc=0.9600
#   k= 15  CV_acc=0.9550
#   k= 16  CV_acc=0.9525
#   k= 17  CV_acc=0.9525
#   k= 18  CV_acc=0.9500
#   k= 19  CV_acc=0.9550
#   k= 20  CV_acc=0.9600
#   k= 21  CV_acc=0.9600
#   k= 22  CV_acc=0.9550
#   k= 23  CV_acc=0.9550
#   k= 24  CV_acc=0.9675
#   k= 25  CV_acc=0.9450
#   k= 26  CV_acc=0.9550
#   k= 27  CV_acc=0.9475
#   k= 28  CV_acc=0.9575
#   k= 29  CV_acc=0.9600
#   k= 30  CV_acc=0.9550
#   k= 31  CV_acc=0.9500
#   k= 32  CV_acc=0.9525
#   k= 33  CV_acc=0.9550
#   k= 34  CV_acc=0.9550
#   k= 35  CV_acc=0.9500
#   k= 36  CV_acc=0.9525
#   k= 37  CV_acc=0.9575
#   k= 38  CV_acc=0.9500
#   k= 39  CV_acc=0.9500
#   k= 40  CV_acc=0.9400
#   k= 41  CV_acc=0.9600
#   k= 42  CV_acc=0.9475
#   k= 43  CV_acc=0.9550
#   k= 44  CV_acc=0.9525
#   k= 45  CV_acc=0.9650
#   k= 46  CV_acc=0.9525
#   k= 47  CV_acc=0.9550
#   k= 48  CV_acc=0.9475
#   k= 49  CV_acc=0.9500
#   k= 50  CV_acc=0.9550
#   k= 51  CV_acc=0.9525
#   >> BEST k=24  CV_acc=0.9675
#
# [FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...
#   >> BEST n_features=21  CV_acc=0.9600
#
# [FS4] Sweeping k for SelectKBest (mutual_info_classif)...
#   k=  1  CV_acc=0.9225
#   k=  2  CV_acc=0.9475
#   k=  3  CV_acc=0.9450
#   k=  4  CV_acc=0.9400
#   k=  5  CV_acc=0.9475
#   k=  6  CV_acc=0.9375
#   k=  7  CV_acc=0.9525
#   k=  8  CV_acc=0.9525
#   k=  9  CV_acc=0.9575
#   k= 10  CV_acc=0.9450
#   k= 11  CV_acc=0.9625
#   k= 12  CV_acc=0.9600
#   k= 13  CV_acc=0.9500
#   k= 14  CV_acc=0.9600
#   k= 15  CV_acc=0.9575
#   k= 16  CV_acc=0.9600
#   k= 17  CV_acc=0.9500
#   k= 18  CV_acc=0.9575
#   k= 19  CV_acc=0.9575
#   k= 20  CV_acc=0.9625
#   k= 21  CV_acc=0.9575
#   k= 22  CV_acc=0.9600
#   k= 23  CV_acc=0.9525
#   k= 24  CV_acc=0.9500
#   k= 25  CV_acc=0.9600
#   k= 26  CV_acc=0.9500
#   k= 27  CV_acc=0.9525
#   k= 28  CV_acc=0.9550
#   k= 29  CV_acc=0.9475
#   k= 30  CV_acc=0.9475
#   k= 31  CV_acc=0.9550
#   k= 32  CV_acc=0.9625
#   k= 33  CV_acc=0.9525
#   k= 34  CV_acc=0.9500
#   k= 35  CV_acc=0.9525
#   k= 36  CV_acc=0.9550
#   k= 37  CV_acc=0.9525
#   k= 38  CV_acc=0.9525
#   k= 39  CV_acc=0.9550
#   k= 40  CV_acc=0.9550
#   k= 41  CV_acc=0.9600
#   k= 42  CV_acc=0.9550
#   k= 43  CV_acc=0.9525
#   k= 44  CV_acc=0.9500
#   k= 45  CV_acc=0.9600
#   k= 46  CV_acc=0.9475
#   k= 47  CV_acc=0.9475
#   k= 48  CV_acc=0.9525
#   k= 49  CV_acc=0.9475
#   k= 50  CV_acc=0.9550
#   k= 51  CV_acc=0.9525
#   >> BEST k=11  CV_acc=0.9625
#
# [FS5] Sweeping cumulative importance threshold for RF feature importance...
#   cum_threshold=0.80  features= 16  CV_acc=0.9550
#   cum_threshold=0.85  features= 21  CV_acc=0.9575
#   cum_threshold=0.90  features= 27  CV_acc=0.9500
#   cum_threshold=0.95  features= 35  CV_acc=0.9525
#   cum_threshold=0.99  features= 46  CV_acc=0.9475
#   >> BEST cum_threshold=0.85  features=21  CV_acc=0.9575
#
# ======================================================================
#   TUNING SUMMARY
# ======================================================================
#               FS          Parameter  Best_Value  n_features  CV_Accuracy
#  FS1_Correlation          threshold        0.85          49       0.9550
#        FS2_KBest                  k       24.00          24       0.9675
#          FS3_RFE n_features (RFECV)       21.00          21       0.9600
#   FS4_MutualInfo                  k       11.00          11       0.9625
# FS5_RFImportance      cum_threshold        0.85          21       0.9575

# %% [markdown]
# ***FS Methods***

# %%
def fs_correlation(data, target_col='CAST', threshold=best_fs1_thr):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    corr  = X_.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= threshold)]
    out   = X_.drop(columns=drop).copy(); out[target_col] = y_.values
    return out

def fs_kbest(data, target_col='CAST', k=best_fs2_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(f_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rfe(data, target_col='CAST', support=_rfecv_support):

    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    cols = X_.columns[support] if len(support) == X_.shape[1] else X_.columns
    out  = X_[cols].copy(); out[target_col] = y_.values
    return out

def fs_mi(data, target_col='CAST', k=best_fs4_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(mutual_info_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rf_importance(data, target_col='CAST', cum_threshold=best_fs5_ct):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    rf  = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_, y_)
    imp = pd.Series(rf.feature_importances_, index=X_.columns).sort_values(ascending=False)
    top = imp.cumsum()[imp.cumsum() <= cum_threshold].index.tolist()
    if len(top) == 0:
        top = [imp.index[0]]
    out = X_[top].copy(); out[target_col] = y_.values
    return out

FEATURE_SELECTORS = {
    "FS1_Correlation":  lambda d: fs_correlation(d),
    "FS2_KBest":        lambda d: fs_kbest(d),
    "FS3_RFE":          lambda d: fs_rfe(d),
    "FS4_MutualInfo":   lambda d: fs_mi(d),
    "FS5_RFImportance": lambda d: fs_rf_importance(d),
}

# %% [markdown]
# ***Evaluation Metrics***

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True, n_splits=10):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    rows = []
    for clf_name, model in build_models().items():
        fold_metrics = {
            'Accuracy': [], 'Macro_F1': [], 'Macro_Precision': [],
            'Macro_Recall': [], 'MCC': [], 'G_Mean': [], 'AUC': []
        }

        for train_idx, test_idx in skf.split(X_, y_):
            X_tr, X_te = X_.iloc[train_idx], X_.iloc[test_idx]
            y_tr, y_te = y_.iloc[train_idx], y_.iloc[test_idx]

            try:
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_te)

                acc   = accuracy_score(y_te, y_pred)
                rep   = classification_report(y_te, y_pred, zero_division=0, output_dict=True)
                mcc   = matthews_corrcoef(y_te, y_pred)
                gmean = geometric_mean_score(y_te, y_pred, average='macro')

                n_classes = len(np.unique(y_te))
                auc = None
                try:
                    if hasattr(model, 'predict_proba'):
                        y_score = model.predict_proba(X_te)
                    else:
                        y_score = model.decision_function(X_te)
                        if n_classes <= 2:
                            y_score = y_score.reshape(-1, 1)

                    if n_classes == 2:
                        prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                        auc = roc_auc_score(y_te, prob)
                    else:
                        auc = roc_auc_score(
                            y_te, y_score,
                            multi_class='ovr', average='macro',
                            labels=np.unique(y_te)
                        )
                except Exception:
                    pass

                fold_metrics['Accuracy'].append(acc)
                fold_metrics['Macro_F1'].append(rep['macro avg']['f1-score'])
                fold_metrics['Macro_Precision'].append(rep['macro avg']['precision'])
                fold_metrics['Macro_Recall'].append(rep['macro avg']['recall'])
                fold_metrics['MCC'].append(mcc)
                fold_metrics['G_Mean'].append(gmean)
                if auc is not None:
                    fold_metrics['AUC'].append(auc)

            except Exception as e:
                if verbose:
                    print(f"    {clf_name:25s}  Fold ERROR: {e}")

        # Aggregate: mean ± std across folds
        def fmt(vals):
            if not vals:
                return None, None
            return round(np.mean(vals), 3), round(np.std(vals), 3)

        acc_m,   acc_s   = fmt(fold_metrics['Accuracy'])
        f1_m,    f1_s    = fmt(fold_metrics['Macro_F1'])
        prec_m,  prec_s  = fmt(fold_metrics['Macro_Precision'])
        rec_m,   rec_s   = fmt(fold_metrics['Macro_Recall'])
        mcc_m,   mcc_s   = fmt(fold_metrics['MCC'])
        gm_m,    gm_s    = fmt(fold_metrics['G_Mean'])
        auc_m,   auc_s   = fmt(fold_metrics['AUC'])

        rows.append({
            'Label':                label,
            'Classifier':           clf_name,
            'Accuracy':             acc_m,  'Accuracy_SD':   acc_s,
            'Macro_F1':             f1_m,   'Macro_F1_SD':   f1_s,
            'Macro_Precision':      prec_m, 'Macro_Prec_SD': prec_s,
            'Macro_Recall':         rec_m,  'Macro_Rec_SD':  rec_s,
            'MCC':                  mcc_m,  'MCC_SD':        mcc_s,
            'G_Mean':               gm_m,   'G_Mean_SD':     gm_s,
            'AUC':                  auc_m,  'AUC_SD':        auc_s,
        })

        if verbose:
            auc_str = f"{auc_m:.3f}±{auc_s:.3f}" if auc_m is not None else "N/A"
            print(f"    {clf_name:25s}  "
                  f"Acc={acc_m:.3f}±{acc_s:.3f}  "
                  f"F1={f1_m:.3f}±{f1_s:.3f}  "
                  f"MCC={mcc_m:.3f}±{mcc_s:.3f}  "
                  f"G-Mean={gm_m:.3f}±{gm_s:.3f}  "
                  f"AUC={auc_str}")

    return rows

# %% [markdown]
# ***ML Models***

# %%
def build_models():
    return {
        "RandomForest":       RandomForestClassifier(random_state=42),
        "ExtraTrees":         ExtraTreesClassifier(random_state=42),
        "Bagging":            BaggingClassifier(random_state=42),
        "GradientBoosting":   GradientBoostingClassifier(random_state=42),
        "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
        "RidgeClassifier":    RidgeClassifier(),
        "DecisionTree":       DecisionTreeClassifier(random_state=42),
        "NaiveBayes":         GaussianNB(),
        "Perceptron":         Perceptron(random_state=42),
        "SGDClassifier":      SGDClassifier(random_state=42),
        "PassiveAggressive":  PassiveAggressiveClassifier(random_state=42),
        "LDA":                LinearDiscriminantAnalysis(),
        "QDA":                QuadraticDiscriminantAnalysis(),
        "LightGBM":           LGBMClassifier(verbosity=-1, random_state=42),
        "XGBoost":            XGBClassifier(n_estimators=100, random_state=42,
                                            eval_metric='mlogloss',
                                            use_label_encoder=False, verbosity=0),
        "VotingSoft": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='soft', n_jobs=-1),
        "VotingHard": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='hard', n_jobs=-1),
        "Stacking": StackingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], final_estimator=LogisticRegression(max_iter=1000, random_state=42),
           cv=5, stack_method='predict_proba', n_jobs=-1),
    }

# %% [markdown]
# # ***Experiment 1***

# %%
section_header("PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)")

print("\nApplying balancers to raw data...")
balanced_datasets = {}
for bal_name, sampler in BALANCERS.items():
    df_b = apply_balancer(bal_name, sampler, X_raw, y_raw)
    if df_b is not None:
        balanced_datasets[bal_name] = df_b

phase1_rows = []
for bal_name, bal_df in balanced_datasets.items():
    sub_header(f"Balancer: {bal_name}  |  shape={bal_df.shape}")
    rows = evaluate_dataset(bal_df, label=bal_name, verbose=True)
    phase1_rows.extend(rows)

phase1_df = pd.DataFrame(phase1_rows).dropna(subset=['Accuracy'])
phase1_df['Phase'] = 'Phase1_BalancingOnly'
phase1_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 1 Summary (top 20 by Accuracy) --")
p1_show = phase1_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer'})
METRICS = ['Accuracy','Macro_F1','MCC','G_Mean','AUC']
print(p1_show[['Balancer','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 1: Best Classifier per Balancer --")
best_p1 = (p1_show.groupby('Balancer', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer','Classifier'] + METRICS])
print(best_p1.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)
# ################################################################################
#
# Applying balancers to raw data...
#   B1_RandomOverSampling          -> shape (954, 52)  dist: {2: np.int64(318), 1: np.int64(318), 0: np.int64(318)}
#   B2_RandomUnderSampling         -> shape (90, 52)  dist: {0: np.int64(30), 1: np.int64(30), 2: np.int64(30)}
#   B3_ADASYN                      -> shape (959, 52)  dist: {1: np.int64(325), 2: np.int64(318), 0: np.int64(316)}
#   B4_SMOTE                       -> shape (954, 52)  dist: {2: np.int64(318), 1: np.int64(318), 0: np.int64(318)}
#   B5_BorderlineSMOTE             -> shape (954, 52)  dist: {2: np.int64(318), 1: np.int64(318), 0: np.int64(318)}
#   B6_TomekLinks                  -> shape (398, 52)  dist: {2: np.int64(317), 1: np.int64(51), 0: np.int64(30)}
#   B7_SMOTETomek                  -> shape (954, 52)  dist: {2: np.int64(318), 1: np.int64(318), 0: np.int64(318)}
#
# ======================================================================
#   Balancer: B1_RandomOverSampling  |  shape=(954, 52)
# ======================================================================
#     RandomForest               Acc=0.994±0.005  F1=0.994±0.005  MCC=0.991±0.008  G-Mean=0.995±0.004  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.999±0.003  F1=0.999±0.003  MCC=0.998±0.005  G-Mean=0.999±0.002  AUC=1.000±0.000
#     Bagging                    Acc=0.990±0.009  F1=0.989±0.009  MCC=0.985±0.014  G-Mean=0.992±0.007  AUC=0.998±0.004
#     GradientBoosting           Acc=0.993±0.005  F1=0.993±0.005  MCC=0.989±0.007  G-Mean=0.995±0.004  AUC=1.000±0.001
#     LogisticRegression         Acc=0.982±0.017  F1=0.982±0.017  MCC=0.974±0.026  G-Mean=0.987±0.013  AUC=0.998±0.003
#     RidgeClassifier            Acc=0.828±0.029  F1=0.817±0.031  MCC=0.754±0.045  G-Mean=0.870±0.022  AUC=N/A
#     DecisionTree               Acc=0.988±0.007  F1=0.988±0.007  MCC=0.983±0.011  G-Mean=0.991±0.006  AUC=0.991±0.006
#     NaiveBayes                 Acc=0.873±0.035  F1=0.874±0.034  MCC=0.813±0.052  G-Mean=0.904±0.027  AUC=0.962±0.019
#     Perceptron                 Acc=0.851±0.066  F1=0.839±0.085  MCC=0.796±0.083  G-Mean=0.888±0.050  AUC=N/A
#     SGDClassifier              Acc=0.959±0.041  F1=0.958±0.042  MCC=0.942±0.056  G-Mean=0.969±0.031  AUC=N/A
#     PassiveAggressive          Acc=0.860±0.105  F1=0.853±0.112  MCC=0.815±0.128  G-Mean=0.894±0.080  AUC=N/A
#     LDA                        Acc=0.962±0.011  F1=0.962±0.011  MCC=0.944±0.016  G-Mean=0.972±0.008  AUC=0.996±0.004
#     QDA                        Acc=0.999±0.003  F1=0.999±0.003  MCC=0.998±0.005  G-Mean=0.999±0.002  AUC=0.999±0.002
#     LightGBM                   Acc=0.992±0.004  F1=0.992±0.004  MCC=0.988±0.006  G-Mean=0.994±0.003  AUC=1.000±0.000
#     XGBoost                    Acc=0.993±0.005  F1=0.993±0.005  MCC=0.989±0.007  G-Mean=0.994±0.004  AUC=1.000±0.000
#     VotingSoft                 Acc=0.992±0.004  F1=0.992±0.004  MCC=0.988±0.006  G-Mean=0.994±0.003  AUC=1.000±0.000
#     VotingHard                 Acc=0.994±0.005  F1=0.994±0.005  MCC=0.991±0.008  G-Mean=0.995±0.004  AUC=N/A
#     Stacking                   Acc=0.999±0.003  F1=0.999±0.003  MCC=0.998±0.005  G-Mean=0.999±0.002  AUC=1.000±0.000
#
# ======================================================================
#   Balancer: B2_RandomUnderSampling  |  shape=(90, 52)
# ======================================================================
#     RandomForest               Acc=0.900±0.078  F1=0.899±0.077  MCC=0.862±0.110  G-Mean=0.924±0.059  AUC=0.990±0.016
#     ExtraTrees                 Acc=0.922±0.087  F1=0.917±0.094  MCC=0.892±0.122  G-Mean=0.941±0.066  AUC=0.983±0.023
#     Bagging                    Acc=0.922±0.087  F1=0.922±0.086  MCC=0.892±0.122  G-Mean=0.941±0.066  AUC=0.979±0.047
#     GradientBoosting           Acc=0.911±0.083  F1=0.910±0.084  MCC=0.873±0.123  G-Mean=0.933±0.063  AUC=0.991±0.015
#     LogisticRegression         Acc=0.856±0.087  F1=0.853±0.088  MCC=0.794±0.132  G-Mean=0.891±0.066  AUC=0.959±0.051
#     RidgeClassifier            Acc=0.700±0.158  F1=0.680±0.162  MCC=0.576±0.244  G-Mean=0.769±0.126  AUC=N/A
#     DecisionTree               Acc=0.922±0.100  F1=0.919±0.104  MCC=0.890±0.142  G-Mean=0.941±0.076  AUC=0.942±0.075
#     NaiveBayes                 Acc=0.800±0.120  F1=0.789±0.138  MCC=0.725±0.173  G-Mean=0.848±0.093  AUC=0.889±0.100
#     Perceptron                 Acc=0.678±0.105  F1=0.633±0.129  MCC=0.557±0.168  G-Mean=0.753±0.083  AUC=N/A
#     SGDClassifier              Acc=0.744±0.165  F1=0.693±0.203  MCC=0.653±0.237  G-Mean=0.804±0.127  AUC=N/A
#     PassiveAggressive          Acc=0.722±0.124  F1=0.680±0.155  MCC=0.632±0.175  G-Mean=0.788±0.096  AUC=N/A
#     LDA                        Acc=0.689±0.185  F1=0.669±0.200  MCC=0.552±0.274  G-Mean=0.760±0.146  AUC=0.812±0.130
#     QDA                        Acc=0.444±0.149  F1=0.411±0.169  MCC=0.184±0.250  G-Mean=0.563±0.125  AUC=0.583±0.112
#     LightGBM                   Acc=0.911±0.083  F1=0.904±0.093  MCC=0.884±0.105  G-Mean=0.933±0.063  AUC=0.989±0.033
#     XGBoost                    Acc=0.900±0.078  F1=0.899±0.077  MCC=0.862±0.110  G-Mean=0.924±0.059  AUC=0.970±0.045
#     VotingSoft                 Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.993±0.015
#     VotingHard                 Acc=0.911±0.083  F1=0.906±0.090  MCC=0.877±0.117  G-Mean=0.933±0.063  AUC=N/A
#     Stacking                   Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.993±0.015
#
# ======================================================================
#   Balancer: B3_ADASYN  |  shape=(959, 52)
# ======================================================================
#     RandomForest               Acc=0.992±0.009  F1=0.992±0.009  MCC=0.988±0.014  G-Mean=0.994±0.007  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.996±0.005  F1=0.996±0.005  MCC=0.994±0.008  G-Mean=0.997±0.004  AUC=1.000±0.000
#     Bagging                    Acc=0.981±0.012  F1=0.981±0.012  MCC=0.972±0.018  G-Mean=0.986±0.009  AUC=0.996±0.005
#     GradientBoosting           Acc=0.979±0.013  F1=0.979±0.013  MCC=0.969±0.020  G-Mean=0.984±0.010  AUC=1.000±0.000
#     LogisticRegression         Acc=0.977±0.015  F1=0.977±0.015  MCC=0.966±0.023  G-Mean=0.983±0.011  AUC=0.999±0.001
#     RidgeClassifier            Acc=0.893±0.023  F1=0.889±0.026  MCC=0.844±0.031  G-Mean=0.920±0.017  AUC=N/A
#     DecisionTree               Acc=0.977±0.013  F1=0.977±0.013  MCC=0.966±0.019  G-Mean=0.983±0.010  AUC=0.983±0.010
#     NaiveBayes                 Acc=0.912±0.022  F1=0.913±0.022  MCC=0.871±0.033  G-Mean=0.934±0.017  AUC=0.982±0.008
#     Perceptron                 Acc=0.896±0.076  F1=0.891±0.082  MCC=0.858±0.094  G-Mean=0.922±0.058  AUC=N/A
#     SGDClassifier              Acc=0.963±0.026  F1=0.964±0.026  MCC=0.947±0.037  G-Mean=0.973±0.020  AUC=N/A
#     PassiveAggressive          Acc=0.943±0.029  F1=0.943±0.029  MCC=0.917±0.040  G-Mean=0.957±0.022  AUC=N/A
#     LDA                        Acc=0.975±0.013  F1=0.975±0.013  MCC=0.963±0.020  G-Mean=0.981±0.010  AUC=0.998±0.003
#     QDA                        Acc=0.931±0.016  F1=0.931±0.016  MCC=0.901±0.022  G-Mean=0.949±0.012  AUC=0.986±0.010
#     LightGBM                   Acc=0.982±0.011  F1=0.982±0.010  MCC=0.974±0.016  G-Mean=0.987±0.008  AUC=1.000±0.000
#     XGBoost                    Acc=0.982±0.009  F1=0.982±0.009  MCC=0.974±0.014  G-Mean=0.987±0.007  AUC=1.000±0.000
#     VotingSoft                 Acc=0.984±0.008  F1=0.984±0.008  MCC=0.977±0.013  G-Mean=0.988±0.006  AUC=1.000±0.000
#     VotingHard                 Acc=0.993±0.008  F1=0.993±0.008  MCC=0.989±0.012  G-Mean=0.995±0.006  AUC=N/A
#     Stacking                   Acc=0.993±0.008  F1=0.993±0.008  MCC=0.989±0.012  G-Mean=0.995±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Balancer: B4_SMOTE  |  shape=(954, 52)
# ======================================================================
#     RandomForest               Acc=0.988±0.006  F1=0.988±0.006  MCC=0.983±0.008  G-Mean=0.991±0.004  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.992±0.010  F1=0.992±0.010  MCC=0.988±0.015  G-Mean=0.994±0.008  AUC=1.000±0.000
#     Bagging                    Acc=0.977±0.008  F1=0.977±0.008  MCC=0.966±0.012  G-Mean=0.983±0.006  AUC=0.995±0.005
#     GradientBoosting           Acc=0.980±0.011  F1=0.980±0.011  MCC=0.970±0.016  G-Mean=0.985±0.008  AUC=0.999±0.001
#     LogisticRegression         Acc=0.978±0.016  F1=0.978±0.017  MCC=0.967±0.025  G-Mean=0.983±0.012  AUC=0.999±0.001
#     RidgeClassifier            Acc=0.910±0.029  F1=0.907±0.032  MCC=0.869±0.041  G-Mean=0.932±0.022  AUC=N/A
#     DecisionTree               Acc=0.972±0.010  F1=0.972±0.010  MCC=0.958±0.016  G-Mean=0.979±0.008  AUC=0.979±0.008
#     NaiveBayes                 Acc=0.926±0.023  F1=0.926±0.022  MCC=0.891±0.033  G-Mean=0.944±0.017  AUC=0.985±0.009
#     Perceptron                 Acc=0.908±0.039  F1=0.905±0.041  MCC=0.870±0.053  G-Mean=0.930±0.030  AUC=N/A
#     SGDClassifier              Acc=0.954±0.028  F1=0.954±0.028  MCC=0.932±0.040  G-Mean=0.965±0.021  AUC=N/A
#     PassiveAggressive          Acc=0.919±0.055  F1=0.919±0.053  MCC=0.886±0.070  G-Mean=0.939±0.041  AUC=N/A
#     LDA                        Acc=0.979±0.016  F1=0.979±0.016  MCC=0.969±0.023  G-Mean=0.984±0.012  AUC=0.998±0.003
#     QDA                        Acc=0.975±0.012  F1=0.975±0.012  MCC=0.963±0.017  G-Mean=0.981±0.009  AUC=0.993±0.004
#     LightGBM                   Acc=0.983±0.008  F1=0.983±0.008  MCC=0.975±0.013  G-Mean=0.987±0.006  AUC=1.000±0.000
#     XGBoost                    Acc=0.979±0.011  F1=0.979±0.011  MCC=0.969±0.017  G-Mean=0.984±0.009  AUC=1.000±0.000
#     VotingSoft                 Acc=0.983±0.008  F1=0.983±0.008  MCC=0.975±0.013  G-Mean=0.987±0.006  AUC=1.000±0.000
#     VotingHard                 Acc=0.990±0.009  F1=0.990±0.009  MCC=0.984±0.014  G-Mean=0.992±0.007  AUC=N/A
#     Stacking                   Acc=0.993±0.008  F1=0.993±0.008  MCC=0.989±0.012  G-Mean=0.994±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Balancer: B5_BorderlineSMOTE  |  shape=(954, 52)
# ======================================================================
#     RandomForest               Acc=0.991±0.010  F1=0.991±0.010  MCC=0.986±0.015  G-Mean=0.993±0.007  AUC=1.000±0.001
#     ExtraTrees                 Acc=0.991±0.009  F1=0.991±0.009  MCC=0.986±0.013  G-Mean=0.993±0.007  AUC=1.000±0.001
#     Bagging                    Acc=0.975±0.010  F1=0.975±0.010  MCC=0.963±0.014  G-Mean=0.981±0.007  AUC=0.997±0.003
#     GradientBoosting           Acc=0.980±0.012  F1=0.980±0.012  MCC=0.971±0.018  G-Mean=0.985±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.977±0.010  F1=0.977±0.010  MCC=0.966±0.015  G-Mean=0.983±0.008  AUC=0.999±0.002
#     RidgeClassifier            Acc=0.921±0.037  F1=0.921±0.037  MCC=0.884±0.054  G-Mean=0.941±0.028  AUC=N/A
#     DecisionTree               Acc=0.971±0.020  F1=0.971±0.020  MCC=0.956±0.030  G-Mean=0.978±0.015  AUC=0.978±0.015
#     NaiveBayes                 Acc=0.932±0.023  F1=0.932±0.023  MCC=0.900±0.033  G-Mean=0.949±0.018  AUC=0.987±0.008
#     Perceptron                 Acc=0.911±0.058  F1=0.905±0.068  MCC=0.875±0.076  G-Mean=0.932±0.044  AUC=N/A
#     SGDClassifier              Acc=0.943±0.055  F1=0.940±0.061  MCC=0.921±0.071  G-Mean=0.957±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.953±0.018  F1=0.952±0.018  MCC=0.931±0.026  G-Mean=0.964±0.013  AUC=N/A
#     LDA                        Acc=0.975±0.018  F1=0.975±0.018  MCC=0.963±0.027  G-Mean=0.981±0.014  AUC=0.998±0.003
#     QDA                        Acc=0.965±0.016  F1=0.965±0.016  MCC=0.949±0.024  G-Mean=0.974±0.012  AUC=0.985±0.013
#     LightGBM                   Acc=0.983±0.008  F1=0.983±0.008  MCC=0.975±0.012  G-Mean=0.987±0.006  AUC=0.999±0.001
#     XGBoost                    Acc=0.980±0.013  F1=0.980±0.013  MCC=0.970±0.019  G-Mean=0.985±0.010  AUC=0.999±0.001
#     VotingSoft                 Acc=0.982±0.008  F1=0.982±0.008  MCC=0.973±0.012  G-Mean=0.987±0.006  AUC=0.999±0.001
#     VotingHard                 Acc=0.990±0.009  F1=0.990±0.009  MCC=0.984±0.014  G-Mean=0.992±0.007  AUC=N/A
#     Stacking                   Acc=0.990±0.008  F1=0.990±0.008  MCC=0.984±0.012  G-Mean=0.992±0.006  AUC=1.000±0.001
#
# ======================================================================
#   Balancer: B6_TomekLinks  |  shape=(398, 52)
# ======================================================================
#     RandomForest               Acc=0.955±0.031  F1=0.908±0.075  MCC=0.863±0.101  G-Mean=0.909±0.057  AUC=0.986±0.011
#     ExtraTrees                 Acc=0.955±0.029  F1=0.899±0.070  MCC=0.863±0.096  G-Mean=0.910±0.058  AUC=0.984±0.018
#     Bagging                    Acc=0.937±0.034  F1=0.868±0.096  MCC=0.819±0.100  G-Mean=0.901±0.066  AUC=0.953±0.048
#     GradientBoosting           Acc=0.932±0.032  F1=0.836±0.081  MCC=0.798±0.102  G-Mean=0.881±0.060  AUC=0.967±0.038
#     LogisticRegression         Acc=0.947±0.031  F1=0.879±0.084  MCC=0.845±0.096  G-Mean=0.904±0.070  AUC=0.987±0.011
#     RidgeClassifier            Acc=0.879±0.044  F1=0.656±0.127  MCC=0.629±0.137  G-Mean=0.765±0.080  AUC=N/A
#     DecisionTree               Acc=0.932±0.057  F1=0.833±0.159  MCC=0.788±0.195  G-Mean=0.876±0.120  AUC=0.880±0.112
#     NaiveBayes                 Acc=0.854±0.066  F1=0.761±0.113  MCC=0.675±0.125  G-Mean=0.878±0.074  AUC=0.931±0.073
#     Perceptron                 Acc=0.884±0.029  F1=0.669±0.085  MCC=0.675±0.056  G-Mean=0.799±0.041  AUC=N/A
#     SGDClassifier              Acc=0.894±0.025  F1=0.739±0.066  MCC=0.691±0.067  G-Mean=0.810±0.052  AUC=N/A
#     PassiveAggressive          Acc=0.894±0.025  F1=0.711±0.095  MCC=0.682±0.085  G-Mean=0.795±0.058  AUC=N/A
#     LDA                        Acc=0.955±0.035  F1=0.903±0.101  MCC=0.861±0.115  G-Mean=0.909±0.081  AUC=0.988±0.013
#     QDA                        Acc=0.812±0.017  F1=0.359±0.068  MCC=0.175±0.180  G-Mean=0.508±0.040  AUC=0.533±0.037
#     LightGBM                   Acc=0.940±0.028  F1=0.856±0.068  MCC=0.821±0.085  G-Mean=0.890±0.049  AUC=0.986±0.008
#     XGBoost                    Acc=0.945±0.029  F1=0.864±0.074  MCC=0.838±0.089  G-Mean=0.903±0.054  AUC=0.990±0.005
#     VotingSoft                 Acc=0.937±0.037  F1=0.842±0.093  MCC=0.810±0.126  G-Mean=0.883±0.073  AUC=0.985±0.011
#     VotingHard                 Acc=0.952±0.032  F1=0.896±0.076  MCC=0.857±0.104  G-Mean=0.911±0.058  AUC=N/A
#     Stacking                   Acc=0.952±0.032  F1=0.887±0.070  MCC=0.858±0.105  G-Mean=0.914±0.059  AUC=0.988±0.012
#
# ======================================================================
#   Balancer: B7_SMOTETomek  |  shape=(954, 52)
# ======================================================================
#     RandomForest               Acc=0.988±0.006  F1=0.988±0.006  MCC=0.983±0.008  G-Mean=0.991±0.004  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.992±0.010  F1=0.992±0.010  MCC=0.988±0.015  G-Mean=0.994±0.008  AUC=1.000±0.000
#     Bagging                    Acc=0.977±0.008  F1=0.977±0.008  MCC=0.966±0.012  G-Mean=0.983±0.006  AUC=0.995±0.005
#     GradientBoosting           Acc=0.980±0.011  F1=0.980±0.011  MCC=0.970±0.016  G-Mean=0.985±0.008  AUC=0.999±0.001
#     LogisticRegression         Acc=0.978±0.016  F1=0.978±0.017  MCC=0.967±0.025  G-Mean=0.983±0.012  AUC=0.999±0.001
#     RidgeClassifier            Acc=0.910±0.029  F1=0.907±0.032  MCC=0.869±0.041  G-Mean=0.932±0.022  AUC=N/A
#     DecisionTree               Acc=0.972±0.010  F1=0.972±0.010  MCC=0.958±0.016  G-Mean=0.979±0.008  AUC=0.979±0.008
#     NaiveBayes                 Acc=0.926±0.023  F1=0.926±0.022  MCC=0.891±0.033  G-Mean=0.944±0.017  AUC=0.985±0.009
#     Perceptron                 Acc=0.908±0.039  F1=0.905±0.041  MCC=0.870±0.053  G-Mean=0.930±0.030  AUC=N/A
#     SGDClassifier              Acc=0.954±0.028  F1=0.954±0.028  MCC=0.932±0.040  G-Mean=0.965±0.021  AUC=N/A
#     PassiveAggressive          Acc=0.919±0.055  F1=0.919±0.053  MCC=0.886±0.070  G-Mean=0.939±0.041  AUC=N/A
#     LDA                        Acc=0.979±0.016  F1=0.979±0.016  MCC=0.969±0.023  G-Mean=0.984±0.012  AUC=0.998±0.003
#     QDA                        Acc=0.975±0.012  F1=0.975±0.012  MCC=0.963±0.017  G-Mean=0.981±0.009  AUC=0.993±0.004
#     LightGBM                   Acc=0.983±0.008  F1=0.983±0.008  MCC=0.975±0.013  G-Mean=0.987±0.006  AUC=1.000±0.000
#     XGBoost                    Acc=0.979±0.011  F1=0.979±0.011  MCC=0.969±0.017  G-Mean=0.984±0.009  AUC=1.000±0.000
#     VotingSoft                 Acc=0.983±0.008  F1=0.983±0.008  MCC=0.975±0.013  G-Mean=0.987±0.006  AUC=1.000±0.000
#     VotingHard                 Acc=0.990±0.009  F1=0.990±0.009  MCC=0.984±0.014  G-Mean=0.992±0.007  AUC=N/A
#     Stacking                   Acc=0.993±0.008  F1=0.993±0.008  MCC=0.989±0.012  G-Mean=0.994±0.006  AUC=1.000±0.000
#
#
# -- Phase 1 Summary (top 20 by Accuracy) --
#              Balancer       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
# B1_RandomOverSampling       ExtraTrees     0.999     0.999 0.998   0.999 1.000
# B1_RandomOverSampling              QDA     0.999     0.999 0.998   0.999 0.999
# B1_RandomOverSampling         Stacking     0.999     0.999 0.998   0.999 1.000
#             B3_ADASYN       ExtraTrees     0.996     0.996 0.994   0.997 1.000
# B1_RandomOverSampling       VotingHard     0.994     0.994 0.991   0.995   NaN
# B1_RandomOverSampling     RandomForest     0.994     0.994 0.991   0.995 1.000
# B1_RandomOverSampling          XGBoost     0.993     0.993 0.989   0.994 1.000
#             B3_ADASYN         Stacking     0.993     0.993 0.989   0.995 1.000
#             B3_ADASYN       VotingHard     0.993     0.993 0.989   0.995   NaN
# B1_RandomOverSampling GradientBoosting     0.993     0.993 0.989   0.995 1.000
#         B7_SMOTETomek         Stacking     0.993     0.993 0.989   0.994 1.000
#              B4_SMOTE         Stacking     0.993     0.993 0.989   0.994 1.000
#             B3_ADASYN     RandomForest     0.992     0.992 0.988   0.994 1.000
# B1_RandomOverSampling       VotingSoft     0.992     0.992 0.988   0.994 1.000
# B1_RandomOverSampling         LightGBM     0.992     0.992 0.988   0.994 1.000
#         B7_SMOTETomek       ExtraTrees     0.992     0.992 0.988   0.994 1.000
#              B4_SMOTE       ExtraTrees     0.992     0.992 0.988   0.994 1.000
#    B5_BorderlineSMOTE     RandomForest     0.991     0.991 0.986   0.993 1.000
#    B5_BorderlineSMOTE       ExtraTrees     0.991     0.991 0.986   0.993 1.000
# B1_RandomOverSampling          Bagging     0.990     0.989 0.985   0.992 0.998
#
# -- Phase 1: Best Classifier per Balancer --
#               Balancer   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling   ExtraTrees     0.999     0.999 0.998   0.999 1.000
# B2_RandomUnderSampling   VotingSoft     0.933     0.932 0.906   0.950 0.993
#              B3_ADASYN   ExtraTrees     0.996     0.996 0.994   0.997 1.000
#               B4_SMOTE     Stacking     0.993     0.993 0.989   0.994 1.000
#     B5_BorderlineSMOTE RandomForest     0.991     0.991 0.986   0.993 1.000
#          B6_TomekLinks   ExtraTrees     0.955     0.899 0.863   0.910 0.984
#          B7_SMOTETomek     Stacking     0.993     0.993 0.989   0.994 1.000

# %%
def fmt_metric(mean_val, std_val):
    """Format mean±std, returning N/A if None or NaN."""
    try:
        if mean_val is None or std_val is None:
            return "N/A"
        if math.isnan(float(mean_val)) or math.isnan(float(std_val)):
            return "N/A"
        return f"{float(mean_val):.3f}\u00b1{float(std_val):.3f}"  # \u00b1 = ±
    except (TypeError, ValueError):
        return "N/A"

COLUMNS = ["Model",
           f"Accuracy (Mean \u00b1 SD)",
           f"MCC (Mean \u00b1 SD)",
           f"G-Mean (Mean \u00b1 SD)",
           f"F1-Score (Mean \u00b1 SD)",
           f"AUROC (Mean \u00b1 SD)"]

output = io.StringIO()
writer = csv.writer(output)

# %%
for bal_name, bal_df in balanced_datasets.items():
    shape_info = bal_df.shape
    group = phase1_df[phase1_df['Variant'] == bal_name]

    # Section heading
    writer.writerow([f"Balancer: {bal_name}  |  shape={shape_info}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

# ── KEY FIX: save with utf-8-sig (adds BOM so Excel reads ± correctly) ──
with open("Phase1_Balancers_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase1_Balancers_Results.csv")
print("Downloaded: Phase1_Balancers_Results.csv")
# Out:
# Downloaded: Phase1_Balancers_Results.csv

# %% [markdown]
# # ***Experiment 2***

# %%
section_header("PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)")

phase2_rows = []
for fs_name, fs_fn in FEATURE_SELECTORS.items():
    try:
        fs_df = fs_fn(df)
        sub_header(f"Feature Selector: {fs_name}  |  features={fs_df.shape[1]-1}")
        rows = evaluate_dataset(fs_df, label=fs_name, verbose=True)
        phase2_rows.extend(rows)
    except Exception as e:
        print(f"  {fs_name} FAILED: {e}")

phase2_df = pd.DataFrame(phase2_rows).dropna(subset=['Accuracy'])
phase2_df['Phase'] = 'Phase2_FeatureSelectionOnly'
phase2_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 2 Summary (top 20 by Accuracy) --")
p2_show = phase2_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'FeatureSelector'})
print(p2_show[['FeatureSelector','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 2: Best Classifier per Feature Selector --")
best_p2 = (p2_show.groupby('FeatureSelector', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['FeatureSelector','Classifier'] + METRICS])
print(best_p2.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)
# ################################################################################
#
# ======================================================================
#   Feature Selector: FS1_Correlation  |  features=49
# ======================================================================
#     RandomForest               Acc=0.957±0.030  F1=0.904±0.073  MCC=0.872±0.093  G-Mean=0.907±0.064  AUC=0.988±0.016
#     ExtraTrees                 Acc=0.962±0.028  F1=0.910±0.068  MCC=0.888±0.084  G-Mean=0.918±0.059  AUC=0.988±0.014
#     Bagging                    Acc=0.945±0.037  F1=0.867±0.110  MCC=0.842±0.109  G-Mean=0.907±0.076  AUC=0.972±0.037
#     GradientBoosting           Acc=0.938±0.034  F1=0.852±0.077  MCC=0.819±0.104  G-Mean=0.888±0.059  AUC=0.981±0.017
#     LogisticRegression         Acc=0.940±0.045  F1=0.859±0.092  MCC=0.821±0.135  G-Mean=0.885±0.079  AUC=0.981±0.015
#     RidgeClassifier            Acc=0.868±0.030  F1=0.607±0.083  MCC=0.584±0.110  G-Mean=0.744±0.071  AUC=N/A
#     DecisionTree               Acc=0.925±0.042  F1=0.827±0.116  MCC=0.781±0.130  G-Mean=0.877±0.090  AUC=0.881±0.085
#     NaiveBayes                 Acc=0.860±0.065  F1=0.779±0.121  MCC=0.687±0.130  G-Mean=0.882±0.074  AUC=0.927±0.072
#     Perceptron                 Acc=0.885±0.041  F1=0.667±0.137  MCC=0.645±0.152  G-Mean=0.783±0.103  AUC=N/A
#     SGDClassifier              Acc=0.905±0.044  F1=0.765±0.115  MCC=0.717±0.141  G-Mean=0.838±0.088  AUC=N/A
#     PassiveAggressive          Acc=0.892±0.040  F1=0.689±0.117  MCC=0.667±0.135  G-Mean=0.786±0.087  AUC=N/A
#     LDA                        Acc=0.943±0.042  F1=0.860±0.110  MCC=0.827±0.131  G-Mean=0.886±0.086  AUC=0.988±0.014
#     QDA                        Acc=0.805±0.022  F1=0.338±0.070  MCC=0.112±0.175  G-Mean=0.496±0.040  AUC=0.527±0.036
#     LightGBM                   Acc=0.940±0.025  F1=0.858±0.062  MCC=0.827±0.074  G-Mean=0.895±0.043  AUC=0.986±0.009
#     XGBoost                    Acc=0.945±0.035  F1=0.863±0.087  MCC=0.841±0.109  G-Mean=0.905±0.067  AUC=0.992±0.007
#     VotingSoft                 Acc=0.948±0.036  F1=0.872±0.078  MCC=0.848±0.111  G-Mean=0.905±0.062  AUC=0.987±0.013
#     VotingHard                 Acc=0.960±0.025  F1=0.906±0.063  MCC=0.881±0.077  G-Mean=0.912±0.054  AUC=N/A
#     Stacking                   Acc=0.952±0.028  F1=0.880±0.067  MCC=0.863±0.084  G-Mean=0.911±0.050  AUC=0.989±0.014
#
# ======================================================================
#   Feature Selector: FS2_KBest  |  features=24
# ======================================================================
#     RandomForest               Acc=0.957±0.030  F1=0.910±0.085  MCC=0.875±0.091  G-Mean=0.917±0.062  AUC=0.986±0.020
#     ExtraTrees                 Acc=0.945±0.024  F1=0.876±0.078  MCC=0.837±0.079  G-Mean=0.903±0.066  AUC=0.982±0.026
#     Bagging                    Acc=0.938±0.030  F1=0.853±0.086  MCC=0.820±0.091  G-Mean=0.895±0.061  AUC=0.966±0.048
#     GradientBoosting           Acc=0.942±0.039  F1=0.849±0.101  MCC=0.831±0.124  G-Mean=0.894±0.079  AUC=0.979±0.022
#     LogisticRegression         Acc=0.942±0.040  F1=0.860±0.124  MCC=0.827±0.136  G-Mean=0.893±0.085  AUC=0.989±0.010
#     RidgeClassifier            Acc=0.872±0.018  F1=0.603±0.055  MCC=0.607±0.074  G-Mean=0.751±0.049  AUC=N/A
#     DecisionTree               Acc=0.935±0.041  F1=0.858±0.112  MCC=0.817±0.121  G-Mean=0.904±0.081  AUC=0.915±0.067
#     NaiveBayes                 Acc=0.870±0.050  F1=0.804±0.069  MCC=0.704±0.099  G-Mean=0.896±0.048  AUC=0.964±0.019
#     Perceptron                 Acc=0.895±0.029  F1=0.679±0.121  MCC=0.683±0.097  G-Mean=0.799±0.071  AUC=N/A
#     SGDClassifier              Acc=0.912±0.032  F1=0.790±0.110  MCC=0.741±0.117  G-Mean=0.854±0.087  AUC=N/A
#     PassiveAggressive          Acc=0.912±0.034  F1=0.763±0.111  MCC=0.728±0.120  G-Mean=0.823±0.082  AUC=N/A
#     LDA                        Acc=0.947±0.038  F1=0.881±0.096  MCC=0.842±0.128  G-Mean=0.898±0.075  AUC=0.985±0.011
#     QDA                        Acc=0.862±0.048  F1=0.616±0.105  MCC=0.643±0.110  G-Mean=0.775±0.059  AUC=0.816±0.075
#     LightGBM                   Acc=0.948±0.031  F1=0.875±0.074  MCC=0.848±0.091  G-Mean=0.911±0.055  AUC=0.991±0.008
#     XGBoost                    Acc=0.948±0.031  F1=0.871±0.071  MCC=0.847±0.098  G-Mean=0.909±0.064  AUC=0.993±0.006
#     VotingSoft                 Acc=0.948±0.036  F1=0.870±0.087  MCC=0.847±0.112  G-Mean=0.907±0.069  AUC=0.990±0.011
#     VotingHard                 Acc=0.955±0.029  F1=0.896±0.087  MCC=0.868±0.089  G-Mean=0.912±0.062  AUC=N/A
#     Stacking                   Acc=0.952±0.032  F1=0.884±0.080  MCC=0.862±0.099  G-Mean=0.916±0.068  AUC=0.984±0.030
#
# ======================================================================
#   Feature Selector: FS3_RFE  |  features=21
# ======================================================================
#     RandomForest               Acc=0.960±0.030  F1=0.910±0.074  MCC=0.880±0.096  G-Mean=0.919±0.071  AUC=0.985±0.020
#     ExtraTrees                 Acc=0.962±0.034  F1=0.916±0.080  MCC=0.888±0.106  G-Mean=0.929±0.076  AUC=0.988±0.019
#     Bagging                    Acc=0.933±0.022  F1=0.853±0.075  MCC=0.810±0.062  G-Mean=0.896±0.047  AUC=0.962±0.052
#     GradientBoosting           Acc=0.935±0.028  F1=0.840±0.076  MCC=0.817±0.082  G-Mean=0.892±0.055  AUC=0.979±0.020
#     LogisticRegression         Acc=0.945±0.043  F1=0.871±0.122  MCC=0.833±0.143  G-Mean=0.894±0.085  AUC=0.990±0.009
#     RidgeClassifier            Acc=0.872±0.021  F1=0.596±0.065  MCC=0.609±0.089  G-Mean=0.756±0.061  AUC=N/A
#     DecisionTree               Acc=0.942±0.027  F1=0.871±0.082  MCC=0.835±0.080  G-Mean=0.911±0.061  AUC=0.912±0.059
#     NaiveBayes                 Acc=0.892±0.048  F1=0.840±0.071  MCC=0.749±0.102  G-Mean=0.916±0.046  AUC=0.967±0.020
#     Perceptron                 Acc=0.875±0.027  F1=0.644±0.089  MCC=0.613±0.105  G-Mean=0.760±0.075  AUC=N/A
#     SGDClassifier              Acc=0.935±0.045  F1=0.823±0.141  MCC=0.801±0.150  G-Mean=0.867±0.098  AUC=N/A
#     PassiveAggressive          Acc=0.898±0.033  F1=0.724±0.113  MCC=0.683±0.117  G-Mean=0.805±0.079  AUC=N/A
#     LDA                        Acc=0.943±0.039  F1=0.849±0.116  MCC=0.824±0.134  G-Mean=0.878±0.091  AUC=0.985±0.015
#     QDA                        Acc=0.862±0.039  F1=0.663±0.137  MCC=0.659±0.100  G-Mean=0.810±0.073  AUC=0.954±0.041
#     LightGBM                   Acc=0.933±0.042  F1=0.852±0.098  MCC=0.804±0.129  G-Mean=0.896±0.080  AUC=0.988±0.011
#     XGBoost                    Acc=0.945±0.022  F1=0.868±0.064  MCC=0.842±0.067  G-Mean=0.904±0.056  AUC=0.992±0.007
#     VotingSoft                 Acc=0.942±0.034  F1=0.865±0.084  MCC=0.835±0.101  G-Mean=0.905±0.064  AUC=0.990±0.010
#     VotingHard                 Acc=0.960±0.036  F1=0.912±0.081  MCC=0.880±0.112  G-Mean=0.924±0.076  AUC=N/A
#     Stacking                   Acc=0.952±0.038  F1=0.893±0.082  MCC=0.860±0.116  G-Mean=0.917±0.076  AUC=0.989±0.012
#
# ======================================================================
#   Feature Selector: FS4_MutualInfo  |  features=11
# ======================================================================
#     RandomForest               Acc=0.952±0.028  F1=0.897±0.079  MCC=0.861±0.087  G-Mean=0.912±0.063  AUC=0.990±0.017
#     ExtraTrees                 Acc=0.965±0.036  F1=0.914±0.077  MCC=0.898±0.107  G-Mean=0.936±0.069  AUC=0.985±0.022
#     Bagging                    Acc=0.945±0.037  F1=0.869±0.102  MCC=0.841±0.111  G-Mean=0.907±0.075  AUC=0.976±0.039
#     GradientBoosting           Acc=0.945±0.038  F1=0.877±0.090  MCC=0.838±0.121  G-Mean=0.905±0.075  AUC=0.985±0.019
#     LogisticRegression         Acc=0.950±0.030  F1=0.889±0.069  MCC=0.852±0.092  G-Mean=0.902±0.061  AUC=0.991±0.009
#     RidgeClassifier            Acc=0.880±0.019  F1=0.627±0.050  MCC=0.640±0.059  G-Mean=0.772±0.041  AUC=N/A
#     DecisionTree               Acc=0.950±0.037  F1=0.892±0.101  MCC=0.855±0.115  G-Mean=0.917±0.076  AUC=0.922±0.064
#     NaiveBayes                 Acc=0.908±0.052  F1=0.868±0.057  MCC=0.784±0.099  G-Mean=0.928±0.038  AUC=0.979±0.015
#     Perceptron                 Acc=0.908±0.034  F1=0.728±0.113  MCC=0.718±0.106  G-Mean=0.814±0.070  AUC=N/A
#     SGDClassifier              Acc=0.935±0.042  F1=0.842±0.108  MCC=0.803±0.141  G-Mean=0.880±0.088  AUC=N/A
#     PassiveAggressive          Acc=0.915±0.039  F1=0.758±0.117  MCC=0.739±0.135  G-Mean=0.838±0.085  AUC=N/A
#     LDA                        Acc=0.950±0.035  F1=0.886±0.100  MCC=0.851±0.114  G-Mean=0.898±0.076  AUC=0.987±0.012
#     QDA                        Acc=0.893±0.056  F1=0.825±0.086  MCC=0.746±0.116  G-Mean=0.898±0.055  AUC=0.965±0.026
#     LightGBM                   Acc=0.955±0.029  F1=0.891±0.079  MCC=0.871±0.086  G-Mean=0.924±0.058  AUC=0.991±0.006
#     XGBoost                    Acc=0.950±0.030  F1=0.881±0.075  MCC=0.855±0.090  G-Mean=0.915±0.064  AUC=0.992±0.009
#     VotingSoft                 Acc=0.952±0.038  F1=0.889±0.093  MCC=0.861±0.119  G-Mean=0.917±0.079  AUC=0.993±0.008
#     VotingHard                 Acc=0.960±0.032  F1=0.903±0.080  MCC=0.886±0.094  G-Mean=0.929±0.058  AUC=N/A
#     Stacking                   Acc=0.957±0.030  F1=0.893±0.080  MCC=0.878±0.087  G-Mean=0.923±0.066  AUC=0.987±0.028
#
# ======================================================================
#   Feature Selector: FS5_RFImportance  |  features=21
# ======================================================================
#     RandomForest               Acc=0.962±0.030  F1=0.919±0.072  MCC=0.888±0.094  G-Mean=0.924±0.065  AUC=0.987±0.020
#     ExtraTrees                 Acc=0.952±0.031  F1=0.898±0.074  MCC=0.861±0.095  G-Mean=0.922±0.072  AUC=0.983±0.023
#     Bagging                    Acc=0.940±0.034  F1=0.867±0.095  MCC=0.822±0.109  G-Mean=0.903±0.079  AUC=0.967±0.045
#     GradientBoosting           Acc=0.942±0.027  F1=0.860±0.067  MCC=0.836±0.081  G-Mean=0.905±0.051  AUC=0.986±0.018
#     LogisticRegression         Acc=0.948±0.041  F1=0.882±0.094  MCC=0.842±0.130  G-Mean=0.897±0.081  AUC=0.987±0.012
#     RidgeClassifier            Acc=0.867±0.020  F1=0.576±0.065  MCC=0.593±0.087  G-Mean=0.745±0.060  AUC=N/A
#     DecisionTree               Acc=0.933±0.027  F1=0.859±0.066  MCC=0.809±0.080  G-Mean=0.900±0.062  AUC=0.906±0.063
#     NaiveBayes                 Acc=0.888±0.050  F1=0.836±0.072  MCC=0.741±0.104  G-Mean=0.914±0.045  AUC=0.968±0.019
#     Perceptron                 Acc=0.885±0.034  F1=0.663±0.107  MCC=0.643±0.118  G-Mean=0.770±0.076  AUC=N/A
#     SGDClassifier              Acc=0.900±0.055  F1=0.760±0.111  MCC=0.710±0.152  G-Mean=0.837±0.093  AUC=N/A
#     PassiveAggressive          Acc=0.910±0.034  F1=0.780±0.106  MCC=0.727±0.110  G-Mean=0.832±0.071  AUC=N/A
#     LDA                        Acc=0.940±0.039  F1=0.838±0.115  MCC=0.816±0.135  G-Mean=0.874±0.091  AUC=0.984±0.016
#     QDA                        Acc=0.867±0.032  F1=0.675±0.112  MCC=0.673±0.082  G-Mean=0.817±0.068  AUC=0.926±0.064
#     LightGBM                   Acc=0.955±0.024  F1=0.898±0.057  MCC=0.871±0.073  G-Mean=0.924±0.052  AUC=0.987±0.010
#     XGBoost                    Acc=0.960±0.023  F1=0.904±0.066  MCC=0.887±0.064  G-Mean=0.934±0.047  AUC=0.991±0.008
#     VotingSoft                 Acc=0.948±0.026  F1=0.873±0.062  MCC=0.849±0.078  G-Mean=0.909±0.048  AUC=0.989±0.011
#     VotingHard                 Acc=0.960±0.032  F1=0.908±0.074  MCC=0.882±0.099  G-Mean=0.926±0.067  AUC=N/A
#     Stacking                   Acc=0.950±0.032  F1=0.883±0.075  MCC=0.854±0.098  G-Mean=0.912±0.072  AUC=0.984±0.031
#
#
# -- Phase 2 Summary (top 20 by Accuracy) --
#  FeatureSelector   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#   FS4_MutualInfo   ExtraTrees     0.965     0.914 0.898   0.936 0.985
#  FS1_Correlation   ExtraTrees     0.962     0.910 0.888   0.918 0.988
#          FS3_RFE   ExtraTrees     0.962     0.916 0.888   0.929 0.988
# FS5_RFImportance RandomForest     0.962     0.919 0.888   0.924 0.987
#          FS3_RFE RandomForest     0.960     0.910 0.880   0.919 0.985
# FS5_RFImportance      XGBoost     0.960     0.904 0.887   0.934 0.991
#          FS3_RFE   VotingHard     0.960     0.912 0.880   0.924   NaN
#   FS4_MutualInfo   VotingHard     0.960     0.903 0.886   0.929   NaN
# FS5_RFImportance   VotingHard     0.960     0.908 0.882   0.926   NaN
#  FS1_Correlation   VotingHard     0.960     0.906 0.881   0.912   NaN
#        FS2_KBest RandomForest     0.957     0.910 0.875   0.917 0.986
#  FS1_Correlation RandomForest     0.957     0.904 0.872   0.907 0.988
#   FS4_MutualInfo     Stacking     0.957     0.893 0.878   0.923 0.987
#        FS2_KBest   VotingHard     0.955     0.896 0.868   0.912   NaN
#   FS4_MutualInfo     LightGBM     0.955     0.891 0.871   0.924 0.991
# FS5_RFImportance     LightGBM     0.955     0.898 0.871   0.924 0.987
#          FS3_RFE     Stacking     0.952     0.893 0.860   0.917 0.989
# FS5_RFImportance   ExtraTrees     0.952     0.898 0.861   0.922 0.983
#        FS2_KBest     Stacking     0.952     0.884 0.862   0.916 0.984
#   FS4_MutualInfo RandomForest     0.952     0.897 0.861   0.912 0.990
#
# -- Phase 2: Best Classifier per Feature Selector --
#  FeatureSelector   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  FS1_Correlation   ExtraTrees     0.962     0.910 0.888   0.918 0.988
#        FS2_KBest RandomForest     0.957     0.910 0.875   0.917 0.986
#          FS3_RFE   ExtraTrees     0.962     0.916 0.888   0.929 0.988
#   FS4_MutualInfo   ExtraTrees     0.965     0.914 0.898   0.936 0.985
# FS5_RFImportance RandomForest     0.962     0.919 0.888   0.924 0.987

# %%
phase2_only = phase2_df[phase2_df['Phase'] == 'Phase2_FeatureSelectionOnly'].copy()

output = io.StringIO()
writer = csv.writer(output)

for fs_name in phase2_only['Variant'].unique():
    group = phase2_only[phase2_only['Variant'] == fs_name]

    try:
        fs_df = FEATURE_SELECTORS[fs_name](df)
        n_features = fs_df.shape[1] - 1
    except:
        n_features = "N/A"

    writer.writerow([f"Feature Selector: {fs_name}  |  features={n_features}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

with open("Phase2_FeatureSelection_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase2_FeatureSelection_Results.csv")
print(" Downloaded: Phase2_FeatureSelection_Results.csv")

# %% [markdown]
# # ***Experiment 3***

# %%
section_header("PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)")

phase3_rows = []
for bal_name, bal_df in balanced_datasets.items():
    for fs_name, fs_fn in FEATURE_SELECTORS.items():
        combo = f"{bal_name} + {fs_name}"
        try:
            fs_df = fs_fn(bal_df)
            sub_header(f"Combo: {combo}  |  shape={fs_df.shape}")
            rows = evaluate_dataset(fs_df, label=combo, verbose=True)
            phase3_rows.extend(rows)
        except Exception as e:
            print(f"  {combo} FAILED: {e}")

phase3_df = pd.DataFrame(phase3_rows).dropna(subset=['Accuracy'])
phase3_df['Phase'] = 'Phase3_Balancing+FS'
phase3_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 3 Summary (top 30 combos by Accuracy) --")
p3_show = phase3_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer+FS'})
print(p3_show[['Balancer+FS','Classifier'] + METRICS].head(30).to_string(index=False))

print("\n-- Phase 3: Best Classifier per Balancer+FS combo --")
best_p3 = (p3_show.groupby('Balancer+FS', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer+FS','Classifier'] + METRICS]
           .sort_values('Accuracy', ascending=False))
print(best_p3.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)
# ################################################################################
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS1_Correlation  |  shape=(954, 48)
# ======================================================================
#     RandomForest               Acc=0.995±0.005  F1=0.995±0.005  MCC=0.992±0.008  G-Mean=0.996±0.004  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.998±0.004  F1=0.998±0.004  MCC=0.997±0.006  G-Mean=0.998±0.003  AUC=1.000±0.000
#     Bagging                    Acc=0.988±0.012  F1=0.988±0.012  MCC=0.983±0.017  G-Mean=0.991±0.009  AUC=0.998±0.004
#     GradientBoosting           Acc=0.992±0.004  F1=0.992±0.004  MCC=0.988±0.006  G-Mean=0.994±0.003  AUC=1.000±0.001
#     LogisticRegression         Acc=0.982±0.015  F1=0.982±0.015  MCC=0.973±0.022  G-Mean=0.987±0.011  AUC=0.998±0.004
#     RidgeClassifier            Acc=0.830±0.024  F1=0.818±0.027  MCC=0.759±0.035  G-Mean=0.872±0.018  AUC=N/A
#     DecisionTree               Acc=0.992±0.006  F1=0.992±0.006  MCC=0.988±0.009  G-Mean=0.994±0.005  AUC=0.994±0.005
#     NaiveBayes                 Acc=0.886±0.042  F1=0.886±0.042  MCC=0.831±0.063  G-Mean=0.914±0.032  AUC=0.962±0.020
#     Perceptron                 Acc=0.852±0.060  F1=0.841±0.073  MCC=0.796±0.077  G-Mean=0.888±0.045  AUC=N/A
#     SGDClassifier              Acc=0.956±0.033  F1=0.955±0.034  MCC=0.936±0.047  G-Mean=0.967±0.025  AUC=N/A
#     PassiveAggressive          Acc=0.855±0.100  F1=0.848±0.106  MCC=0.808±0.121  G-Mean=0.890±0.076  AUC=N/A
#     LDA                        Acc=0.955±0.012  F1=0.955±0.012  MCC=0.933±0.017  G-Mean=0.966±0.009  AUC=0.996±0.004
#     QDA                        Acc=0.963±0.031  F1=0.963±0.032  MCC=0.947±0.044  G-Mean=0.973±0.024  AUC=0.984±0.022
#     LightGBM                   Acc=0.991±0.003  F1=0.991±0.003  MCC=0.986±0.005  G-Mean=0.993±0.002  AUC=1.000±0.000
#     XGBoost                    Acc=0.994±0.005  F1=0.994±0.005  MCC=0.991±0.008  G-Mean=0.995±0.004  AUC=1.000±0.000
#     VotingSoft                 Acc=0.992±0.004  F1=0.992±0.004  MCC=0.988±0.006  G-Mean=0.994±0.003  AUC=1.000±0.000
#     VotingHard                 Acc=0.996±0.005  F1=0.996±0.005  MCC=0.994±0.008  G-Mean=0.997±0.004  AUC=N/A
#     Stacking                   Acc=0.999±0.003  F1=0.999±0.003  MCC=0.998±0.005  G-Mean=0.999±0.002  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS2_KBest  |  shape=(954, 25)
# ======================================================================
#     RandomForest               Acc=0.992±0.008  F1=0.992±0.008  MCC=0.988±0.012  G-Mean=0.994±0.006  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.994±0.007  F1=0.994±0.007  MCC=0.991±0.010  G-Mean=0.995±0.005  AUC=1.000±0.000
#     Bagging                    Acc=0.992±0.008  F1=0.992±0.008  MCC=0.988±0.012  G-Mean=0.994±0.006  AUC=0.998±0.003
#     GradientBoosting           Acc=0.990±0.007  F1=0.990±0.007  MCC=0.985±0.010  G-Mean=0.992±0.005  AUC=1.000±0.000
#     LogisticRegression         Acc=0.980±0.017  F1=0.980±0.017  MCC=0.970±0.026  G-Mean=0.985±0.013  AUC=0.998±0.004
#     RidgeClassifier            Acc=0.775±0.037  F1=0.753±0.041  MCC=0.681±0.057  G-Mean=0.829±0.028  AUC=N/A
#     DecisionTree               Acc=0.992±0.010  F1=0.992±0.010  MCC=0.988±0.015  G-Mean=0.994±0.008  AUC=0.996±0.005
#     NaiveBayes                 Acc=0.873±0.032  F1=0.873±0.033  MCC=0.811±0.049  G-Mean=0.904±0.025  AUC=0.973±0.010
#     Perceptron                 Acc=0.783±0.109  F1=0.765±0.128  MCC=0.713±0.129  G-Mean=0.835±0.084  AUC=N/A
#     SGDClassifier              Acc=0.929±0.054  F1=0.925±0.060  MCC=0.900±0.073  G-Mean=0.946±0.041  AUC=N/A
#     PassiveAggressive          Acc=0.884±0.079  F1=0.875±0.096  MCC=0.842±0.095  G-Mean=0.912±0.060  AUC=N/A
#     LDA                        Acc=0.929±0.011  F1=0.928±0.012  MCC=0.897±0.014  G-Mean=0.946±0.008  AUC=0.991±0.002
#     QDA                        Acc=0.959±0.018  F1=0.959±0.018  MCC=0.940±0.026  G-Mean=0.969±0.013  AUC=0.995±0.003
#     LightGBM                   Acc=0.993±0.007  F1=0.993±0.007  MCC=0.989±0.010  G-Mean=0.995±0.005  AUC=1.000±0.000
#     XGBoost                    Acc=0.991±0.006  F1=0.991±0.006  MCC=0.986±0.008  G-Mean=0.993±0.004  AUC=1.000±0.000
#     VotingSoft                 Acc=0.992±0.006  F1=0.992±0.006  MCC=0.988±0.009  G-Mean=0.994±0.005  AUC=1.000±0.000
#     VotingHard                 Acc=0.992±0.008  F1=0.992±0.008  MCC=0.988±0.012  G-Mean=0.994±0.006  AUC=N/A
#     Stacking                   Acc=0.994±0.007  F1=0.994±0.007  MCC=0.991±0.010  G-Mean=0.995±0.005  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS3_RFE  |  shape=(954, 22)
# ======================================================================
#     RandomForest               Acc=0.994±0.005  F1=0.994±0.005  MCC=0.991±0.008  G-Mean=0.995±0.004  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.996±0.005  F1=0.996±0.005  MCC=0.994±0.008  G-Mean=0.997±0.004  AUC=1.000±0.000
#     Bagging                    Acc=0.990±0.007  F1=0.989±0.007  MCC=0.984±0.010  G-Mean=0.992±0.005  AUC=0.998±0.003
#     GradientBoosting           Acc=0.990±0.008  F1=0.989±0.008  MCC=0.985±0.012  G-Mean=0.992±0.006  AUC=0.999±0.001
#     LogisticRegression         Acc=0.974±0.018  F1=0.974±0.018  MCC=0.961±0.026  G-Mean=0.980±0.013  AUC=0.997±0.003
#     RidgeClassifier            Acc=0.789±0.028  F1=0.765±0.032  MCC=0.708±0.044  G-Mean=0.840±0.022  AUC=N/A
#     DecisionTree               Acc=0.990±0.009  F1=0.989±0.009  MCC=0.985±0.014  G-Mean=0.992±0.007  AUC=0.992±0.007
#     NaiveBayes                 Acc=0.908±0.030  F1=0.907±0.031  MCC=0.863±0.045  G-Mean=0.930±0.023  AUC=0.974±0.013
#     Perceptron                 Acc=0.821±0.082  F1=0.798±0.112  MCC=0.755±0.104  G-Mean=0.864±0.063  AUC=N/A
#     SGDClassifier              Acc=0.947±0.030  F1=0.946±0.031  MCC=0.922±0.044  G-Mean=0.960±0.023  AUC=N/A
#     PassiveAggressive          Acc=0.806±0.126  F1=0.776±0.154  MCC=0.755±0.146  G-Mean=0.853±0.096  AUC=N/A
#     LDA                        Acc=0.925±0.021  F1=0.924±0.022  MCC=0.891±0.031  G-Mean=0.943±0.016  AUC=0.991±0.005
#     QDA                        Acc=0.944±0.019  F1=0.944±0.019  MCC=0.917±0.029  G-Mean=0.958±0.015  AUC=0.991±0.006
#     LightGBM                   Acc=0.991±0.006  F1=0.991±0.006  MCC=0.986±0.008  G-Mean=0.993±0.004  AUC=1.000±0.000
#     XGBoost                    Acc=0.988±0.007  F1=0.988±0.007  MCC=0.983±0.011  G-Mean=0.991±0.006  AUC=1.000±0.000
#     VotingSoft                 Acc=0.992±0.004  F1=0.992±0.004  MCC=0.988±0.006  G-Mean=0.994±0.003  AUC=1.000±0.000
#     VotingHard                 Acc=0.994±0.005  F1=0.994±0.005  MCC=0.991±0.008  G-Mean=0.995±0.004  AUC=N/A
#     Stacking                   Acc=0.996±0.005  F1=0.996±0.005  MCC=0.994±0.008  G-Mean=0.997±0.004  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS4_MutualInfo  |  shape=(954, 12)
# ======================================================================
#     RandomForest               Acc=0.983±0.010  F1=0.983±0.010  MCC=0.975±0.014  G-Mean=0.987±0.007  AUC=0.999±0.001
#     ExtraTrees                 Acc=0.984±0.010  F1=0.984±0.010  MCC=0.977±0.014  G-Mean=0.988±0.007  AUC=0.999±0.001
#     Bagging                    Acc=0.980±0.012  F1=0.980±0.012  MCC=0.971±0.017  G-Mean=0.985±0.009  AUC=0.999±0.002
#     GradientBoosting           Acc=0.979±0.013  F1=0.979±0.013  MCC=0.969±0.019  G-Mean=0.984±0.010  AUC=0.999±0.002
#     LogisticRegression         Acc=0.962±0.019  F1=0.962±0.019  MCC=0.944±0.029  G-Mean=0.972±0.015  AUC=0.996±0.003
#     RidgeClassifier            Acc=0.767±0.019  F1=0.733±0.023  MCC=0.683±0.030  G-Mean=0.823±0.014  AUC=N/A
#     DecisionTree               Acc=0.982±0.013  F1=0.982±0.013  MCC=0.974±0.019  G-Mean=0.987±0.010  AUC=0.997±0.005
#     NaiveBayes                 Acc=0.925±0.028  F1=0.924±0.028  MCC=0.888±0.042  G-Mean=0.943±0.021  AUC=0.984±0.009
#     Perceptron                 Acc=0.822±0.094  F1=0.798±0.117  MCC=0.767±0.111  G-Mean=0.865±0.072  AUC=N/A
#     SGDClassifier              Acc=0.949±0.026  F1=0.949±0.026  MCC=0.925±0.038  G-Mean=0.961±0.019  AUC=N/A
#     PassiveAggressive          Acc=0.818±0.121  F1=0.781±0.160  MCC=0.773±0.136  G-Mean=0.861±0.092  AUC=N/A
#     LDA                        Acc=0.937±0.019  F1=0.936±0.020  MCC=0.910±0.027  G-Mean=0.953±0.014  AUC=0.990±0.003
#     QDA                        Acc=0.942±0.023  F1=0.942±0.023  MCC=0.915±0.035  G-Mean=0.957±0.018  AUC=0.988±0.010
#     LightGBM                   Acc=0.981±0.010  F1=0.981±0.010  MCC=0.972±0.015  G-Mean=0.986±0.008  AUC=0.999±0.001
#     XGBoost                    Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=0.999±0.001
#     VotingSoft                 Acc=0.983±0.010  F1=0.983±0.010  MCC=0.975±0.014  G-Mean=0.987±0.007  AUC=0.999±0.001
#     VotingHard                 Acc=0.983±0.010  F1=0.983±0.010  MCC=0.975±0.014  G-Mean=0.987±0.007  AUC=N/A
#     Stacking                   Acc=0.974±0.013  F1=0.974±0.013  MCC=0.961±0.019  G-Mean=0.980±0.010  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS5_RFImportance  |  shape=(954, 21)
# ======================================================================
#     RandomForest               Acc=0.987±0.009  F1=0.987±0.009  MCC=0.981±0.013  G-Mean=0.991±0.007  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.992±0.008  F1=0.992±0.008  MCC=0.988±0.012  G-Mean=0.994±0.006  AUC=1.000±0.000
#     Bagging                    Acc=0.991±0.007  F1=0.991±0.007  MCC=0.986±0.011  G-Mean=0.993±0.006  AUC=0.999±0.002
#     GradientBoosting           Acc=0.986±0.008  F1=0.986±0.008  MCC=0.980±0.012  G-Mean=0.990±0.006  AUC=0.999±0.001
#     LogisticRegression         Acc=0.976±0.021  F1=0.976±0.021  MCC=0.964±0.031  G-Mean=0.982±0.016  AUC=0.997±0.003
#     RidgeClassifier            Acc=0.762±0.028  F1=0.733±0.028  MCC=0.669±0.047  G-Mean=0.819±0.021  AUC=N/A
#     DecisionTree               Acc=0.990±0.007  F1=0.990±0.007  MCC=0.984±0.010  G-Mean=0.992±0.005  AUC=0.997±0.004
#     NaiveBayes                 Acc=0.895±0.037  F1=0.894±0.037  MCC=0.844±0.055  G-Mean=0.921±0.028  AUC=0.977±0.012
#     Perceptron                 Acc=0.784±0.081  F1=0.750±0.109  MCC=0.714±0.093  G-Mean=0.836±0.063  AUC=N/A
#     SGDClassifier              Acc=0.935±0.033  F1=0.934±0.035  MCC=0.908±0.043  G-Mean=0.951±0.025  AUC=N/A
#     PassiveAggressive          Acc=0.870±0.098  F1=0.857±0.120  MCC=0.828±0.115  G-Mean=0.902±0.075  AUC=N/A
#     LDA                        Acc=0.922±0.013  F1=0.921±0.014  MCC=0.889±0.016  G-Mean=0.942±0.010  AUC=0.991±0.003
#     QDA                        Acc=0.952±0.020  F1=0.952±0.020  MCC=0.928±0.030  G-Mean=0.964±0.015  AUC=0.991±0.005
#     LightGBM                   Acc=0.991±0.006  F1=0.991±0.006  MCC=0.986±0.008  G-Mean=0.993±0.004  AUC=1.000±0.000
#     XGBoost                    Acc=0.993±0.005  F1=0.993±0.005  MCC=0.989±0.007  G-Mean=0.994±0.004  AUC=1.000±0.000
#     VotingSoft                 Acc=0.990±0.007  F1=0.990±0.007  MCC=0.984±0.010  G-Mean=0.992±0.005  AUC=1.000±0.000
#     VotingHard                 Acc=0.991±0.007  F1=0.991±0.007  MCC=0.986±0.011  G-Mean=0.993±0.005  AUC=N/A
#     Stacking                   Acc=0.994±0.007  F1=0.994±0.007  MCC=0.991±0.010  G-Mean=0.995±0.005  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS1_Correlation  |  shape=(90, 45)
# ======================================================================
#     RandomForest               Acc=0.911±0.067  F1=0.905±0.076  MCC=0.880±0.089  G-Mean=0.933±0.050  AUC=0.998±0.006
#     ExtraTrees                 Acc=0.911±0.083  F1=0.906±0.090  MCC=0.881±0.110  G-Mean=0.933±0.063  AUC=0.993±0.015
#     Bagging                    Acc=0.911±0.083  F1=0.910±0.083  MCC=0.877±0.117  G-Mean=0.933±0.063  AUC=0.990±0.012
#     GradientBoosting           Acc=0.922±0.071  F1=0.921±0.072  MCC=0.891±0.103  G-Mean=0.941±0.054  AUC=0.993±0.015
#     LogisticRegression         Acc=0.878±0.078  F1=0.874±0.080  MCC=0.830±0.116  G-Mean=0.908±0.060  AUC=0.961±0.046
#     RidgeClassifier            Acc=0.711±0.151  F1=0.688±0.157  MCC=0.595±0.233  G-Mean=0.778±0.120  AUC=N/A
#     DecisionTree               Acc=0.933±0.054  F1=0.931±0.056  MCC=0.910±0.074  G-Mean=0.950±0.041  AUC=0.950±0.041
#     NaiveBayes                 Acc=0.822±0.113  F1=0.813±0.120  MCC=0.757±0.160  G-Mean=0.865±0.087  AUC=0.896±0.109
#     Perceptron                 Acc=0.700±0.112  F1=0.626±0.152  MCC=0.607±0.157  G-Mean=0.771±0.087  AUC=N/A
#     SGDClassifier              Acc=0.689±0.097  F1=0.620±0.124  MCC=0.590±0.141  G-Mean=0.762±0.075  AUC=N/A
#     PassiveAggressive          Acc=0.711±0.142  F1=0.664±0.176  MCC=0.603±0.210  G-Mean=0.779±0.111  AUC=N/A
#     LDA                        Acc=0.711±0.151  F1=0.705±0.150  MCC=0.584±0.225  G-Mean=0.778±0.117  AUC=0.859±0.119
#     QDA                        Acc=0.467±0.120  F1=0.427±0.137  MCC=0.244±0.197  G-Mean=0.582±0.101  AUC=0.600±0.090
#     LightGBM                   Acc=0.911±0.083  F1=0.904±0.093  MCC=0.884±0.105  G-Mean=0.933±0.063  AUC=0.989±0.033
#     XGBoost                    Acc=0.878±0.105  F1=0.876±0.106  MCC=0.828±0.153  G-Mean=0.907±0.080  AUC=0.978±0.031
#     VotingSoft                 Acc=0.944±0.056  F1=0.943±0.057  MCC=0.925±0.075  G-Mean=0.958±0.042  AUC=0.993±0.015
#     VotingHard                 Acc=0.922±0.071  F1=0.917±0.080  MCC=0.895±0.095  G-Mean=0.941±0.054  AUC=N/A
#     Stacking                   Acc=0.944±0.056  F1=0.943±0.057  MCC=0.925±0.075  G-Mean=0.958±0.042  AUC=0.993±0.015
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS2_KBest  |  shape=(90, 25)
# ======================================================================
#     RandomForest               Acc=0.933±0.054  F1=0.931±0.056  MCC=0.910±0.074  G-Mean=0.950±0.041  AUC=0.987±0.019
#     ExtraTrees                 Acc=0.944±0.075  F1=0.944±0.074  MCC=0.925±0.099  G-Mean=0.958±0.056  AUC=0.993±0.012
#     Bagging                    Acc=0.922±0.087  F1=0.922±0.086  MCC=0.892±0.122  G-Mean=0.941±0.066  AUC=0.976±0.032
#     GradientBoosting           Acc=0.900±0.078  F1=0.898±0.078  MCC=0.858±0.116  G-Mean=0.924±0.059  AUC=0.989±0.015
#     LogisticRegression         Acc=0.867±0.083  F1=0.863±0.085  MCC=0.812±0.126  G-Mean=0.899±0.064  AUC=0.967±0.043
#     RidgeClassifier            Acc=0.744±0.132  F1=0.711±0.154  MCC=0.644±0.197  G-Mean=0.805±0.102  AUC=N/A
#     DecisionTree               Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.950±0.055
#     NaiveBayes                 Acc=0.878±0.105  F1=0.875±0.109  MCC=0.828±0.153  G-Mean=0.907±0.080  AUC=0.961±0.045
#     Perceptron                 Acc=0.667±0.086  F1=0.591±0.104  MCC=0.562±0.144  G-Mean=0.745±0.068  AUC=N/A
#     SGDClassifier              Acc=0.722±0.134  F1=0.672±0.162  MCC=0.627±0.196  G-Mean=0.788±0.103  AUC=N/A
#     PassiveAggressive          Acc=0.722±0.151  F1=0.674±0.178  MCC=0.631±0.223  G-Mean=0.787±0.118  AUC=N/A
#     LDA                        Acc=0.822±0.089  F1=0.815±0.093  MCC=0.752±0.134  G-Mean=0.865±0.068  AUC=0.943±0.049
#     QDA                        Acc=0.333±0.000  F1=0.167±0.000  MCC=0.000±0.000  G-Mean=0.471±0.000  AUC=N/A
#     LightGBM                   Acc=0.911±0.083  F1=0.904±0.093  MCC=0.884±0.105  G-Mean=0.933±0.063  AUC=0.989±0.024
#     XGBoost                    Acc=0.900±0.078  F1=0.898±0.078  MCC=0.858±0.116  G-Mean=0.924±0.059  AUC=0.978±0.025
#     VotingSoft                 Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.993±0.015
#     VotingHard                 Acc=0.933±0.054  F1=0.931±0.056  MCC=0.910±0.074  G-Mean=0.950±0.041  AUC=N/A
#     Stacking                   Acc=0.944±0.075  F1=0.943±0.075  MCC=0.921±0.108  G-Mean=0.958±0.056  AUC=0.993±0.015
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS3_RFE  |  shape=(90, 22)
# ======================================================================
#     RandomForest               Acc=0.922±0.087  F1=0.922±0.086  MCC=0.892±0.122  G-Mean=0.941±0.066  AUC=0.984±0.026
#     ExtraTrees                 Acc=0.922±0.087  F1=0.922±0.086  MCC=0.892±0.122  G-Mean=0.941±0.066  AUC=0.986±0.024
#     Bagging                    Acc=0.900±0.092  F1=0.897±0.096  MCC=0.864±0.126  G-Mean=0.924±0.070  AUC=0.975±0.041
#     GradientBoosting           Acc=0.911±0.083  F1=0.910±0.084  MCC=0.873±0.123  G-Mean=0.933±0.063  AUC=0.991±0.015
#     LogisticRegression         Acc=0.844±0.102  F1=0.841±0.104  MCC=0.782±0.151  G-Mean=0.882±0.078  AUC=0.965±0.044
#     RidgeClassifier            Acc=0.689±0.120  F1=0.661±0.125  MCC=0.564±0.194  G-Mean=0.762±0.095  AUC=N/A
#     DecisionTree               Acc=0.922±0.071  F1=0.921±0.072  MCC=0.891±0.103  G-Mean=0.941±0.054  AUC=0.942±0.053
#     NaiveBayes                 Acc=0.911±0.120  F1=0.906±0.126  MCC=0.877±0.169  G-Mean=0.932±0.091  AUC=0.970±0.046
#     Perceptron                 Acc=0.678±0.092  F1=0.616±0.121  MCC=0.564±0.141  G-Mean=0.753±0.072  AUC=N/A
#     SGDClassifier              Acc=0.689±0.109  F1=0.628±0.143  MCC=0.584±0.165  G-Mean=0.762±0.085  AUC=N/A
#     PassiveAggressive          Acc=0.733±0.151  F1=0.704±0.174  MCC=0.623±0.228  G-Mean=0.796±0.117  AUC=N/A
#     LDA                        Acc=0.878±0.060  F1=0.872±0.065  MCC=0.835±0.081  G-Mean=0.908±0.045  AUC=0.965±0.039
#     QDA                        Acc=0.344±0.033  F1=0.185±0.055  MCC=0.031±0.092  G-Mean=0.481±0.029  AUC=0.750±0.000
#     LightGBM                   Acc=0.911±0.083  F1=0.904±0.093  MCC=0.884±0.105  G-Mean=0.933±0.063  AUC=0.989±0.024
#     XGBoost                    Acc=0.900±0.078  F1=0.898±0.078  MCC=0.858±0.116  G-Mean=0.924±0.059  AUC=0.978±0.026
#     VotingSoft                 Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.993±0.015
#     VotingHard                 Acc=0.911±0.083  F1=0.910±0.083  MCC=0.877±0.117  G-Mean=0.933±0.063  AUC=N/A
#     Stacking                   Acc=0.944±0.075  F1=0.943±0.075  MCC=0.921±0.108  G-Mean=0.958±0.056  AUC=0.993±0.015
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS4_MutualInfo  |  shape=(90, 12)
# ======================================================================
#     RandomForest               Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=0.992±0.017
#     ExtraTrees                 Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=0.998±0.006
#     Bagging                    Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=0.987±0.017
#     GradientBoosting           Acc=0.911±0.067  F1=0.909±0.067  MCC=0.876±0.097  G-Mean=0.933±0.050  AUC=0.996±0.011
#     LogisticRegression         Acc=0.889±0.099  F1=0.886±0.102  MCC=0.842±0.147  G-Mean=0.916±0.076  AUC=0.978±0.031
#     RidgeClassifier            Acc=0.756±0.097  F1=0.712±0.136  MCC=0.678±0.126  G-Mean=0.814±0.075  AUC=N/A
#     DecisionTree               Acc=0.933±0.074  F1=0.929±0.080  MCC=0.912±0.095  G-Mean=0.950±0.056  AUC=0.950±0.055
#     NaiveBayes                 Acc=0.933±0.102  F1=0.931±0.105  MCC=0.906±0.148  G-Mean=0.949±0.078  AUC=0.965±0.044
#     Perceptron                 Acc=0.711±0.200  F1=0.666±0.236  MCC=0.602±0.297  G-Mean=0.777±0.158  AUC=N/A
#     SGDClassifier              Acc=0.744±0.149  F1=0.708±0.177  MCC=0.647±0.221  G-Mean=0.804±0.117  AUC=N/A
#     PassiveAggressive          Acc=0.844±0.102  F1=0.823±0.129  MCC=0.799±0.126  G-Mean=0.882±0.078  AUC=N/A
#     LDA                        Acc=0.900±0.116  F1=0.886±0.143  MCC=0.874±0.141  G-Mean=0.924±0.088  AUC=0.965±0.046
#     QDA                        Acc=0.367±0.100  F1=0.206±0.117  MCC=0.061±0.184  G-Mean=0.499±0.082  AUC=0.667±0.000
#     LightGBM                   Acc=0.922±0.112  F1=0.918±0.118  MCC=0.893±0.158  G-Mean=0.941±0.085  AUC=0.991±0.022
#     XGBoost                    Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.983±0.024
#     VotingSoft                 Acc=0.944±0.056  F1=0.943±0.057  MCC=0.925±0.075  G-Mean=0.958±0.042  AUC=0.993±0.015
#     VotingHard                 Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=N/A
#     Stacking                   Acc=0.956±0.054  F1=0.954±0.056  MCC=0.940±0.074  G-Mean=0.966±0.041  AUC=0.993±0.015
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS5_RFImportance  |  shape=(90, 21)
# ======================================================================
#     RandomForest               Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=0.987±0.020
#     ExtraTrees                 Acc=0.956±0.074  F1=0.955±0.073  MCC=0.941±0.098  G-Mean=0.966±0.056  AUC=0.991±0.019
#     Bagging                    Acc=0.911±0.097  F1=0.908±0.100  MCC=0.879±0.132  G-Mean=0.933±0.073  AUC=0.980±0.037
#     GradientBoosting           Acc=0.900±0.078  F1=0.898±0.078  MCC=0.858±0.116  G-Mean=0.924±0.059  AUC=0.991±0.015
#     LogisticRegression         Acc=0.878±0.060  F1=0.873±0.064  MCC=0.837±0.076  G-Mean=0.908±0.045  AUC=0.967±0.043
#     RidgeClassifier            Acc=0.711±0.113  F1=0.681±0.126  MCC=0.593±0.178  G-Mean=0.779±0.088  AUC=N/A
#     DecisionTree               Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.950±0.055
#     NaiveBayes                 Acc=0.922±0.100  F1=0.920±0.103  MCC=0.891±0.146  G-Mean=0.941±0.076  AUC=0.974±0.040
#     Perceptron                 Acc=0.722±0.114  F1=0.669±0.140  MCC=0.625±0.172  G-Mean=0.788±0.088  AUC=N/A
#     SGDClassifier              Acc=0.678±0.126  F1=0.617±0.152  MCC=0.564±0.195  G-Mean=0.753±0.099  AUC=N/A
#     PassiveAggressive          Acc=0.722±0.134  F1=0.675±0.164  MCC=0.628±0.203  G-Mean=0.787±0.105  AUC=N/A
#     LDA                        Acc=0.833±0.090  F1=0.825±0.095  MCC=0.770±0.130  G-Mean=0.874±0.068  AUC=0.956±0.042
#     QDA                        Acc=0.333±0.000  F1=0.167±0.000  MCC=0.000±0.000  G-Mean=0.471±0.000  AUC=N/A
#     LightGBM                   Acc=0.911±0.083  F1=0.904±0.093  MCC=0.884±0.105  G-Mean=0.933±0.063  AUC=0.989±0.024
#     XGBoost                    Acc=0.889±0.070  F1=0.887±0.070  MCC=0.843±0.106  G-Mean=0.916±0.053  AUC=0.980±0.023
#     VotingSoft                 Acc=0.933±0.074  F1=0.932±0.074  MCC=0.906±0.107  G-Mean=0.950±0.056  AUC=0.993±0.015
#     VotingHard                 Acc=0.933±0.074  F1=0.933±0.073  MCC=0.910±0.098  G-Mean=0.950±0.056  AUC=N/A
#     Stacking                   Acc=0.944±0.075  F1=0.943±0.075  MCC=0.921±0.108  G-Mean=0.958±0.056  AUC=0.993±0.015
#
# ======================================================================
#   Combo: B3_ADASYN + FS1_Correlation  |  shape=(959, 46)
# ======================================================================
#     RandomForest               Acc=0.993±0.007  F1=0.993±0.007  MCC=0.989±0.010  G-Mean=0.995±0.005  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.997±0.005  F1=0.997±0.005  MCC=0.995±0.007  G-Mean=0.998±0.004  AUC=1.000±0.000
#     Bagging                    Acc=0.979±0.008  F1=0.979±0.008  MCC=0.969±0.012  G-Mean=0.984±0.006  AUC=0.995±0.006
#     GradientBoosting           Acc=0.980±0.011  F1=0.980±0.011  MCC=0.970±0.016  G-Mean=0.985±0.008  AUC=0.999±0.002
#     LogisticRegression         Acc=0.980±0.015  F1=0.980±0.015  MCC=0.971±0.022  G-Mean=0.985±0.011  AUC=0.999±0.002
#     RidgeClassifier            Acc=0.894±0.040  F1=0.890±0.044  MCC=0.847±0.055  G-Mean=0.920±0.030  AUC=N/A
#     DecisionTree               Acc=0.966±0.016  F1=0.966±0.016  MCC=0.949±0.024  G-Mean=0.974±0.012  AUC=0.974±0.012
#     NaiveBayes                 Acc=0.923±0.024  F1=0.923±0.023  MCC=0.886±0.034  G-Mean=0.942±0.018  AUC=0.981±0.007
#     Perceptron                 Acc=0.860±0.100  F1=0.854±0.107  MCC=0.812±0.128  G-Mean=0.894±0.077  AUC=N/A
#     SGDClassifier              Acc=0.963±0.024  F1=0.963±0.024  MCC=0.946±0.035  G-Mean=0.973±0.018  AUC=N/A
#     PassiveAggressive          Acc=0.918±0.036  F1=0.917±0.036  MCC=0.884±0.049  G-Mean=0.938±0.028  AUC=N/A
#     LDA                        Acc=0.968±0.019  F1=0.968±0.019  MCC=0.952±0.028  G-Mean=0.976±0.014  AUC=0.998±0.003
#     QDA                        Acc=0.947±0.024  F1=0.947±0.024  MCC=0.922±0.036  G-Mean=0.960±0.018  AUC=0.984±0.012
#     LightGBM                   Acc=0.984±0.010  F1=0.984±0.010  MCC=0.977±0.014  G-Mean=0.988±0.007  AUC=0.999±0.001
#     XGBoost                    Acc=0.979±0.009  F1=0.979±0.009  MCC=0.969±0.014  G-Mean=0.984±0.007  AUC=0.999±0.001
#     VotingSoft                 Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=1.000±0.000
#     VotingHard                 Acc=0.993±0.007  F1=0.993±0.007  MCC=0.989±0.010  G-Mean=0.995±0.005  AUC=N/A
#     Stacking                   Acc=0.992±0.009  F1=0.992±0.009  MCC=0.988±0.014  G-Mean=0.994±0.007  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B3_ADASYN + FS2_KBest  |  shape=(959, 25)
# ======================================================================
#     RandomForest               Acc=0.989±0.003  F1=0.989±0.003  MCC=0.983±0.005  G-Mean=0.991±0.002  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.989±0.007  F1=0.989±0.007  MCC=0.983±0.011  G-Mean=0.991±0.005  AUC=0.996±0.004
#     Bagging                    Acc=0.989±0.006  F1=0.989±0.006  MCC=0.983±0.008  G-Mean=0.991±0.004  AUC=0.998±0.003
#     GradientBoosting           Acc=0.982±0.007  F1=0.982±0.007  MCC=0.974±0.010  G-Mean=0.987±0.005  AUC=1.000±0.000
#     LogisticRegression         Acc=0.975±0.013  F1=0.975±0.013  MCC=0.963±0.018  G-Mean=0.981±0.009  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.867±0.030  F1=0.860±0.032  MCC=0.811±0.042  G-Mean=0.900±0.022  AUC=N/A
#     DecisionTree               Acc=0.973±0.012  F1=0.973±0.012  MCC=0.960±0.017  G-Mean=0.980±0.009  AUC=0.982±0.006
#     NaiveBayes                 Acc=0.917±0.027  F1=0.918±0.027  MCC=0.877±0.040  G-Mean=0.937±0.021  AUC=0.986±0.007
#     Perceptron                 Acc=0.911±0.060  F1=0.911±0.061  MCC=0.875±0.077  G-Mean=0.933±0.046  AUC=N/A
#     SGDClassifier              Acc=0.967±0.019  F1=0.966±0.020  MCC=0.951±0.027  G-Mean=0.975±0.014  AUC=N/A
#     PassiveAggressive          Acc=0.898±0.062  F1=0.894±0.072  MCC=0.858±0.073  G-Mean=0.923±0.048  AUC=N/A
#     LDA                        Acc=0.961±0.022  F1=0.961±0.022  MCC=0.943±0.032  G-Mean=0.971±0.016  AUC=0.997±0.003
#     QDA                        Acc=0.946±0.020  F1=0.946±0.020  MCC=0.921±0.029  G-Mean=0.959±0.015  AUC=0.991±0.004
#     LightGBM                   Acc=0.981±0.009  F1=0.981±0.009  MCC=0.972±0.013  G-Mean=0.986±0.007  AUC=1.000±0.000
#     XGBoost                    Acc=0.979±0.009  F1=0.979±0.009  MCC=0.969±0.014  G-Mean=0.984±0.007  AUC=1.000±0.000
#     VotingSoft                 Acc=0.985±0.005  F1=0.985±0.005  MCC=0.978±0.008  G-Mean=0.989±0.004  AUC=1.000±0.000
#     VotingHard                 Acc=0.989±0.003  F1=0.989±0.003  MCC=0.983±0.005  G-Mean=0.991±0.002  AUC=N/A
#     Stacking                   Acc=0.986±0.005  F1=0.986±0.005  MCC=0.980±0.007  G-Mean=0.990±0.004  AUC=1.000±0.001
#
# ======================================================================
#   Combo: B3_ADASYN + FS3_RFE  |  shape=(959, 22)
# ======================================================================
#     RandomForest               Acc=0.992±0.010  F1=0.992±0.010  MCC=0.988±0.015  G-Mean=0.994±0.008  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.989±0.007  F1=0.989±0.007  MCC=0.983±0.011  G-Mean=0.991±0.005  AUC=1.000±0.001
#     Bagging                    Acc=0.984±0.008  F1=0.984±0.008  MCC=0.977±0.013  G-Mean=0.988±0.006  AUC=0.998±0.003
#     GradientBoosting           Acc=0.981±0.012  F1=0.981±0.012  MCC=0.972±0.018  G-Mean=0.986±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.976±0.010  F1=0.976±0.010  MCC=0.965±0.015  G-Mean=0.982±0.008  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.822±0.033  F1=0.805±0.041  MCC=0.756±0.043  G-Mean=0.867±0.025  AUC=N/A
#     DecisionTree               Acc=0.973±0.013  F1=0.973±0.013  MCC=0.960±0.020  G-Mean=0.980±0.010  AUC=0.980±0.010
#     NaiveBayes                 Acc=0.934±0.028  F1=0.935±0.028  MCC=0.903±0.042  G-Mean=0.950±0.021  AUC=0.987±0.007
#     Perceptron                 Acc=0.877±0.078  F1=0.872±0.093  MCC=0.829±0.097  G-Mean=0.907±0.060  AUC=N/A
#     SGDClassifier              Acc=0.949±0.029  F1=0.949±0.029  MCC=0.926±0.040  G-Mean=0.962±0.022  AUC=N/A
#     PassiveAggressive          Acc=0.871±0.087  F1=0.862±0.102  MCC=0.826±0.105  G-Mean=0.903±0.067  AUC=N/A
#     LDA                        Acc=0.957±0.023  F1=0.957±0.024  MCC=0.937±0.034  G-Mean=0.968±0.017  AUC=0.995±0.004
#     QDA                        Acc=0.949±0.017  F1=0.949±0.017  MCC=0.925±0.026  G-Mean=0.961±0.013  AUC=0.991±0.005
#     LightGBM                   Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=1.000±0.000
#     XGBoost                    Acc=0.983±0.013  F1=0.983±0.012  MCC=0.975±0.019  G-Mean=0.988±0.009  AUC=1.000±0.000
#     VotingSoft                 Acc=0.987±0.009  F1=0.988±0.009  MCC=0.981±0.014  G-Mean=0.991±0.007  AUC=1.000±0.000
#     VotingHard                 Acc=0.990±0.009  F1=0.990±0.009  MCC=0.984±0.014  G-Mean=0.992±0.007  AUC=N/A
#     Stacking                   Acc=0.991±0.009  F1=0.991±0.009  MCC=0.986±0.013  G-Mean=0.993±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B3_ADASYN + FS4_MutualInfo  |  shape=(959, 12)
# ======================================================================
#     RandomForest               Acc=0.979±0.009  F1=0.979±0.009  MCC=0.969±0.014  G-Mean=0.984±0.007  AUC=0.998±0.003
#     ExtraTrees                 Acc=0.981±0.011  F1=0.981±0.011  MCC=0.972±0.016  G-Mean=0.986±0.009  AUC=0.996±0.004
#     Bagging                    Acc=0.983±0.010  F1=0.983±0.010  MCC=0.975±0.014  G-Mean=0.987±0.007  AUC=0.994±0.006
#     GradientBoosting           Acc=0.979±0.008  F1=0.979±0.008  MCC=0.969±0.012  G-Mean=0.984±0.006  AUC=0.999±0.001
#     LogisticRegression         Acc=0.962±0.012  F1=0.963±0.012  MCC=0.944±0.017  G-Mean=0.972±0.009  AUC=0.996±0.002
#     RidgeClassifier            Acc=0.847±0.037  F1=0.834±0.047  MCC=0.789±0.046  G-Mean=0.885±0.028  AUC=N/A
#     DecisionTree               Acc=0.975±0.015  F1=0.975±0.015  MCC=0.963±0.022  G-Mean=0.981±0.011  AUC=0.984±0.009
#     NaiveBayes                 Acc=0.943±0.016  F1=0.943±0.016  MCC=0.915±0.024  G-Mean=0.957±0.012  AUC=0.990±0.004
#     Perceptron                 Acc=0.877±0.063  F1=0.871±0.076  MCC=0.830±0.075  G-Mean=0.907±0.048  AUC=N/A
#     SGDClassifier              Acc=0.947±0.011  F1=0.947±0.011  MCC=0.921±0.016  G-Mean=0.960±0.008  AUC=N/A
#     PassiveAggressive          Acc=0.793±0.127  F1=0.762±0.158  MCC=0.735±0.147  G-Mean=0.842±0.098  AUC=N/A
#     LDA                        Acc=0.938±0.032  F1=0.938±0.034  MCC=0.911±0.046  G-Mean=0.954±0.024  AUC=0.995±0.003
#     QDA                        Acc=0.951±0.017  F1=0.951±0.017  MCC=0.928±0.024  G-Mean=0.963±0.013  AUC=0.991±0.004
#     LightGBM                   Acc=0.979±0.009  F1=0.979±0.009  MCC=0.969±0.014  G-Mean=0.984±0.007  AUC=0.999±0.001
#     XGBoost                    Acc=0.983±0.012  F1=0.983±0.012  MCC=0.975±0.017  G-Mean=0.987±0.009  AUC=0.999±0.000
#     VotingSoft                 Acc=0.983±0.010  F1=0.983±0.009  MCC=0.975±0.014  G-Mean=0.987±0.007  AUC=0.999±0.001
#     VotingHard                 Acc=0.980±0.011  F1=0.980±0.011  MCC=0.971±0.016  G-Mean=0.985±0.008  AUC=N/A
#     Stacking                   Acc=0.980±0.011  F1=0.980±0.011  MCC=0.971±0.016  G-Mean=0.985±0.008  AUC=0.998±0.003
#
# ======================================================================
#   Combo: B3_ADASYN + FS5_RFImportance  |  shape=(959, 18)
# ======================================================================
#     RandomForest               Acc=0.990±0.007  F1=0.990±0.007  MCC=0.985±0.010  G-Mean=0.992±0.005  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.985±0.007  F1=0.985±0.007  MCC=0.978±0.010  G-Mean=0.989±0.005  AUC=0.998±0.003
#     Bagging                    Acc=0.985±0.011  F1=0.985±0.011  MCC=0.978±0.016  G-Mean=0.989±0.008  AUC=0.997±0.004
#     GradientBoosting           Acc=0.981±0.011  F1=0.981±0.011  MCC=0.972±0.017  G-Mean=0.986±0.008  AUC=0.999±0.001
#     LogisticRegression         Acc=0.969±0.017  F1=0.969±0.017  MCC=0.954±0.025  G-Mean=0.977±0.013  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.824±0.026  F1=0.806±0.033  MCC=0.761±0.030  G-Mean=0.868±0.019  AUC=N/A
#     DecisionTree               Acc=0.972±0.012  F1=0.972±0.012  MCC=0.958±0.018  G-Mean=0.979±0.009  AUC=0.983±0.008
#     NaiveBayes                 Acc=0.932±0.031  F1=0.933±0.031  MCC=0.900±0.047  G-Mean=0.949±0.024  AUC=0.988±0.007
#     Perceptron                 Acc=0.837±0.103  F1=0.824±0.120  MCC=0.780±0.127  G-Mean=0.878±0.078  AUC=N/A
#     SGDClassifier              Acc=0.951±0.010  F1=0.951±0.011  MCC=0.928±0.015  G-Mean=0.963±0.008  AUC=N/A
#     PassiveAggressive          Acc=0.857±0.102  F1=0.840±0.128  MCC=0.813±0.117  G-Mean=0.892±0.078  AUC=N/A
#     LDA                        Acc=0.952±0.024  F1=0.952±0.025  MCC=0.930±0.035  G-Mean=0.964±0.018  AUC=0.995±0.005
#     QDA                        Acc=0.944±0.024  F1=0.944±0.023  MCC=0.916±0.035  G-Mean=0.958±0.018  AUC=0.989±0.006
#     LightGBM                   Acc=0.982±0.008  F1=0.982±0.008  MCC=0.974±0.012  G-Mean=0.987±0.006  AUC=0.999±0.001
#     XGBoost                    Acc=0.981±0.012  F1=0.981±0.012  MCC=0.972±0.018  G-Mean=0.986±0.009  AUC=0.999±0.001
#     VotingSoft                 Acc=0.986±0.009  F1=0.986±0.009  MCC=0.980±0.014  G-Mean=0.990±0.007  AUC=1.000±0.000
#     VotingHard                 Acc=0.987±0.006  F1=0.988±0.006  MCC=0.981±0.009  G-Mean=0.991±0.005  AUC=N/A
#     Stacking                   Acc=0.987±0.008  F1=0.988±0.008  MCC=0.981±0.012  G-Mean=0.991±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B4_SMOTE + FS1_Correlation  |  shape=(954, 41)
# ======================================================================
#     RandomForest               Acc=0.986±0.009  F1=0.986±0.009  MCC=0.980±0.014  G-Mean=0.990±0.007  AUC=0.999±0.001
#     ExtraTrees                 Acc=0.987±0.009  F1=0.987±0.009  MCC=0.981±0.014  G-Mean=0.991±0.007  AUC=0.998±0.004
#     Bagging                    Acc=0.979±0.013  F1=0.979±0.013  MCC=0.969±0.020  G-Mean=0.984±0.010  AUC=0.995±0.004
#     GradientBoosting           Acc=0.979±0.012  F1=0.979±0.012  MCC=0.969±0.017  G-Mean=0.984±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.975±0.016  F1=0.975±0.016  MCC=0.963±0.024  G-Mean=0.981±0.012  AUC=0.997±0.003
#     RidgeClassifier            Acc=0.906±0.021  F1=0.903±0.022  MCC=0.863±0.030  G-Mean=0.929±0.016  AUC=N/A
#     DecisionTree               Acc=0.966±0.019  F1=0.966±0.019  MCC=0.951±0.027  G-Mean=0.975±0.014  AUC=0.979±0.014
#     NaiveBayes                 Acc=0.897±0.027  F1=0.898±0.026  MCC=0.848±0.040  G-Mean=0.923±0.020  AUC=0.972±0.013
#     Perceptron                 Acc=0.860±0.069  F1=0.847±0.085  MCC=0.809±0.086  G-Mean=0.895±0.052  AUC=N/A
#     SGDClassifier              Acc=0.952±0.018  F1=0.951±0.018  MCC=0.930±0.024  G-Mean=0.964±0.013  AUC=N/A
#     PassiveAggressive          Acc=0.902±0.057  F1=0.901±0.059  MCC=0.864±0.073  G-Mean=0.927±0.043  AUC=N/A
#     LDA                        Acc=0.972±0.014  F1=0.972±0.014  MCC=0.958±0.021  G-Mean=0.979±0.011  AUC=0.997±0.003
#     QDA                        Acc=0.889±0.024  F1=0.888±0.024  MCC=0.841±0.033  G-Mean=0.916±0.018  AUC=0.973±0.006
#     LightGBM                   Acc=0.981±0.010  F1=0.981±0.010  MCC=0.972±0.015  G-Mean=0.986±0.008  AUC=0.999±0.001
#     XGBoost                    Acc=0.975±0.008  F1=0.975±0.008  MCC=0.963±0.012  G-Mean=0.981±0.006  AUC=0.999±0.001
#     VotingSoft                 Acc=0.981±0.011  F1=0.981±0.011  MCC=0.972±0.017  G-Mean=0.986±0.009  AUC=0.999±0.001
#     VotingHard                 Acc=0.986±0.008  F1=0.986±0.008  MCC=0.980±0.012  G-Mean=0.990±0.006  AUC=N/A
#     Stacking                   Acc=0.987±0.006  F1=0.987±0.006  MCC=0.981±0.009  G-Mean=0.991±0.005  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B4_SMOTE + FS2_KBest  |  shape=(954, 25)
# ======================================================================
#     RandomForest               Acc=0.986±0.012  F1=0.986±0.012  MCC=0.980±0.017  G-Mean=0.990±0.009  AUC=0.999±0.001
#     ExtraTrees                 Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=0.996±0.006
#     Bagging                    Acc=0.975±0.011  F1=0.975±0.011  MCC=0.963±0.016  G-Mean=0.981±0.008  AUC=0.996±0.006
#     GradientBoosting           Acc=0.982±0.012  F1=0.982±0.011  MCC=0.974±0.017  G-Mean=0.987±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.973±0.016  F1=0.973±0.016  MCC=0.960±0.023  G-Mean=0.979±0.012  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.871±0.034  F1=0.866±0.037  MCC=0.815±0.049  G-Mean=0.903±0.025  AUC=N/A
#     DecisionTree               Acc=0.976±0.008  F1=0.976±0.008  MCC=0.964±0.012  G-Mean=0.982±0.006  AUC=0.982±0.006
#     NaiveBayes                 Acc=0.935±0.020  F1=0.935±0.020  MCC=0.904±0.030  G-Mean=0.951±0.015  AUC=0.989±0.005
#     Perceptron                 Acc=0.920±0.036  F1=0.920±0.036  MCC=0.884±0.053  G-Mean=0.940±0.027  AUC=N/A
#     SGDClassifier              Acc=0.941±0.033  F1=0.941±0.033  MCC=0.915±0.048  G-Mean=0.956±0.025  AUC=N/A
#     PassiveAggressive          Acc=0.876±0.086  F1=0.868±0.101  MCC=0.835±0.101  G-Mean=0.907±0.066  AUC=N/A
#     LDA                        Acc=0.971±0.012  F1=0.971±0.012  MCC=0.957±0.018  G-Mean=0.978±0.009  AUC=0.998±0.002
#     QDA                        Acc=0.949±0.019  F1=0.949±0.019  MCC=0.925±0.027  G-Mean=0.961±0.014  AUC=0.994±0.002
#     LightGBM                   Acc=0.980±0.010  F1=0.980±0.010  MCC=0.970±0.015  G-Mean=0.985±0.007  AUC=0.999±0.001
#     XGBoost                    Acc=0.980±0.011  F1=0.980±0.011  MCC=0.970±0.016  G-Mean=0.985±0.008  AUC=0.999±0.001
#     VotingSoft                 Acc=0.981±0.010  F1=0.981±0.010  MCC=0.972±0.015  G-Mean=0.986±0.008  AUC=0.999±0.001
#     VotingHard                 Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=N/A
#     Stacking                   Acc=0.984±0.014  F1=0.984±0.014  MCC=0.977±0.021  G-Mean=0.988±0.011  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B4_SMOTE + FS3_RFE  |  shape=(954, 22)
# ======================================================================
#     RandomForest               Acc=0.988±0.009  F1=0.988±0.009  MCC=0.983±0.013  G-Mean=0.991±0.007  AUC=1.000±0.001
#     ExtraTrees                 Acc=0.985±0.008  F1=0.985±0.008  MCC=0.978±0.012  G-Mean=0.989±0.006  AUC=1.000±0.001
#     Bagging                    Acc=0.977±0.011  F1=0.977±0.011  MCC=0.966±0.017  G-Mean=0.983±0.008  AUC=0.997±0.005
#     GradientBoosting           Acc=0.983±0.012  F1=0.983±0.012  MCC=0.975±0.017  G-Mean=0.987±0.009  AUC=0.999±0.002
#     LogisticRegression         Acc=0.969±0.011  F1=0.968±0.011  MCC=0.953±0.016  G-Mean=0.976±0.008  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.851±0.027  F1=0.842±0.030  MCC=0.789±0.038  G-Mean=0.888±0.020  AUC=N/A
#     DecisionTree               Acc=0.972±0.011  F1=0.972±0.010  MCC=0.958±0.016  G-Mean=0.979±0.008  AUC=0.979±0.008
#     NaiveBayes                 Acc=0.940±0.024  F1=0.941±0.024  MCC=0.912±0.035  G-Mean=0.955±0.018  AUC=0.989±0.006
#     Perceptron                 Acc=0.873±0.089  F1=0.864±0.114  MCC=0.826±0.104  G-Mean=0.904±0.068  AUC=N/A
#     SGDClassifier              Acc=0.969±0.021  F1=0.968±0.021  MCC=0.954±0.030  G-Mean=0.976±0.016  AUC=N/A
#     PassiveAggressive          Acc=0.791±0.122  F1=0.763±0.150  MCC=0.735±0.139  G-Mean=0.841±0.094  AUC=N/A
#     LDA                        Acc=0.963±0.010  F1=0.963±0.010  MCC=0.946±0.014  G-Mean=0.972±0.007  AUC=0.997±0.002
#     QDA                        Acc=0.949±0.015  F1=0.949±0.015  MCC=0.925±0.022  G-Mean=0.961±0.012  AUC=0.993±0.004
#     LightGBM                   Acc=0.984±0.007  F1=0.984±0.007  MCC=0.977±0.010  G-Mean=0.988±0.005  AUC=1.000±0.000
#     XGBoost                    Acc=0.982±0.014  F1=0.982±0.014  MCC=0.973±0.021  G-Mean=0.987±0.011  AUC=1.000±0.001
#     VotingSoft                 Acc=0.984±0.007  F1=0.984±0.007  MCC=0.977±0.010  G-Mean=0.988±0.005  AUC=1.000±0.001
#     VotingHard                 Acc=0.987±0.010  F1=0.987±0.010  MCC=0.981±0.015  G-Mean=0.991±0.008  AUC=N/A
#     Stacking                   Acc=0.990±0.008  F1=0.990±0.008  MCC=0.984±0.012  G-Mean=0.992±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B4_SMOTE + FS4_MutualInfo  |  shape=(954, 12)
# ======================================================================
#     RandomForest               Acc=0.979±0.016  F1=0.979±0.016  MCC=0.969±0.023  G-Mean=0.984±0.012  AUC=0.998±0.003
#     ExtraTrees                 Acc=0.982±0.012  F1=0.982±0.012  MCC=0.973±0.017  G-Mean=0.987±0.009  AUC=0.998±0.003
#     Bagging                    Acc=0.973±0.021  F1=0.973±0.021  MCC=0.959±0.031  G-Mean=0.979±0.016  AUC=0.993±0.008
#     GradientBoosting           Acc=0.979±0.018  F1=0.979±0.018  MCC=0.969±0.027  G-Mean=0.984±0.014  AUC=0.999±0.001
#     LogisticRegression         Acc=0.970±0.011  F1=0.970±0.011  MCC=0.955±0.016  G-Mean=0.977±0.008  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.825±0.026  F1=0.807±0.034  MCC=0.761±0.032  G-Mean=0.868±0.020  AUC=N/A
#     DecisionTree               Acc=0.975±0.017  F1=0.975±0.017  MCC=0.963±0.025  G-Mean=0.981±0.013  AUC=0.987±0.008
#     NaiveBayes                 Acc=0.946±0.015  F1=0.946±0.015  MCC=0.919±0.023  G-Mean=0.959±0.012  AUC=0.991±0.004
#     Perceptron                 Acc=0.785±0.148  F1=0.752±0.179  MCC=0.726±0.176  G-Mean=0.836±0.114  AUC=N/A
#     SGDClassifier              Acc=0.955±0.015  F1=0.955±0.015  MCC=0.934±0.022  G-Mean=0.966±0.011  AUC=N/A
#     PassiveAggressive          Acc=0.836±0.133  F1=0.801±0.176  MCC=0.797±0.151  G-Mean=0.875±0.102  AUC=N/A
#     LDA                        Acc=0.960±0.017  F1=0.960±0.017  MCC=0.942±0.024  G-Mean=0.970±0.013  AUC=0.996±0.002
#     QDA                        Acc=0.954±0.010  F1=0.954±0.010  MCC=0.932±0.014  G-Mean=0.965±0.007  AUC=0.992±0.003
#     LightGBM                   Acc=0.979±0.017  F1=0.979±0.017  MCC=0.969±0.025  G-Mean=0.984±0.013  AUC=0.999±0.001
#     XGBoost                    Acc=0.981±0.019  F1=0.981±0.019  MCC=0.972±0.028  G-Mean=0.986±0.014  AUC=0.999±0.001
#     VotingSoft                 Acc=0.980±0.018  F1=0.980±0.018  MCC=0.971±0.026  G-Mean=0.985±0.014  AUC=0.999±0.001
#     VotingHard                 Acc=0.980±0.015  F1=0.980±0.015  MCC=0.970±0.023  G-Mean=0.985±0.012  AUC=N/A
#     Stacking                   Acc=0.982±0.013  F1=0.982±0.013  MCC=0.974±0.020  G-Mean=0.987±0.010  AUC=0.999±0.002
#
# ======================================================================
#   Combo: B4_SMOTE + FS5_RFImportance  |  shape=(954, 16)
# ======================================================================
#     RandomForest               Acc=0.986±0.012  F1=0.986±0.012  MCC=0.980±0.017  G-Mean=0.990±0.009  AUC=1.000±0.001
#     ExtraTrees                 Acc=0.987±0.014  F1=0.987±0.014  MCC=0.981±0.021  G-Mean=0.991±0.010  AUC=0.996±0.008
#     Bagging                    Acc=0.978±0.017  F1=0.978±0.017  MCC=0.967±0.025  G-Mean=0.983±0.012  AUC=0.996±0.006
#     GradientBoosting           Acc=0.983±0.013  F1=0.983±0.013  MCC=0.975±0.019  G-Mean=0.987±0.009  AUC=0.999±0.002
#     LogisticRegression         Acc=0.970±0.014  F1=0.970±0.014  MCC=0.955±0.020  G-Mean=0.977±0.010  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.847±0.026  F1=0.835±0.030  MCC=0.786±0.035  G-Mean=0.884±0.020  AUC=N/A
#     DecisionTree               Acc=0.971±0.016  F1=0.971±0.016  MCC=0.956±0.024  G-Mean=0.978±0.012  AUC=0.983±0.009
#     NaiveBayes                 Acc=0.948±0.017  F1=0.948±0.017  MCC=0.922±0.025  G-Mean=0.961±0.013  AUC=0.991±0.004
#     Perceptron                 Acc=0.836±0.100  F1=0.816±0.125  MCC=0.782±0.121  G-Mean=0.876±0.076  AUC=N/A
#     SGDClassifier              Acc=0.962±0.019  F1=0.962±0.019  MCC=0.945±0.027  G-Mean=0.971±0.014  AUC=N/A
#     PassiveAggressive          Acc=0.889±0.086  F1=0.885±0.097  MCC=0.847±0.104  G-Mean=0.915±0.067  AUC=N/A
#     LDA                        Acc=0.959±0.014  F1=0.959±0.014  MCC=0.941±0.020  G-Mean=0.969±0.010  AUC=0.997±0.002
#     QDA                        Acc=0.951±0.015  F1=0.951±0.015  MCC=0.928±0.021  G-Mean=0.963±0.011  AUC=0.991±0.003
#     LightGBM                   Acc=0.983±0.013  F1=0.983±0.013  MCC=0.975±0.019  G-Mean=0.987±0.009  AUC=0.999±0.001
#     XGBoost                    Acc=0.985±0.013  F1=0.985±0.013  MCC=0.978±0.020  G-Mean=0.989±0.010  AUC=0.999±0.001
#     VotingSoft                 Acc=0.984±0.013  F1=0.984±0.013  MCC=0.977±0.020  G-Mean=0.988±0.010  AUC=0.999±0.001
#     VotingHard                 Acc=0.988±0.013  F1=0.988±0.013  MCC=0.983±0.019  G-Mean=0.991±0.010  AUC=N/A
#     Stacking                   Acc=0.986±0.014  F1=0.986±0.014  MCC=0.980±0.021  G-Mean=0.990±0.011  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS1_Correlation  |  shape=(954, 42)
# ======================================================================
#     RandomForest               Acc=0.991±0.007  F1=0.991±0.007  MCC=0.986±0.011  G-Mean=0.993±0.006  AUC=1.000±0.000
#     ExtraTrees                 Acc=0.990±0.010  F1=0.990±0.010  MCC=0.984±0.016  G-Mean=0.992±0.008  AUC=1.000±0.001
#     Bagging                    Acc=0.976±0.009  F1=0.976±0.010  MCC=0.964±0.014  G-Mean=0.982±0.007  AUC=0.996±0.004
#     GradientBoosting           Acc=0.979±0.012  F1=0.979±0.012  MCC=0.969±0.019  G-Mean=0.984±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.977±0.010  F1=0.977±0.010  MCC=0.966±0.015  G-Mean=0.983±0.008  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.907±0.032  F1=0.905±0.032  MCC=0.863±0.047  G-Mean=0.930±0.024  AUC=N/A
#     DecisionTree               Acc=0.971±0.012  F1=0.971±0.012  MCC=0.956±0.018  G-Mean=0.978±0.009  AUC=0.978±0.009
#     NaiveBayes                 Acc=0.938±0.019  F1=0.939±0.019  MCC=0.909±0.028  G-Mean=0.953±0.014  AUC=0.986±0.008
#     Perceptron                 Acc=0.876±0.092  F1=0.871±0.100  MCC=0.830±0.112  G-Mean=0.906±0.071  AUC=N/A
#     SGDClassifier              Acc=0.960±0.014  F1=0.960±0.014  MCC=0.941±0.020  G-Mean=0.970±0.011  AUC=N/A
#     PassiveAggressive          Acc=0.927±0.042  F1=0.924±0.045  MCC=0.895±0.058  G-Mean=0.945±0.032  AUC=N/A
#     LDA                        Acc=0.970±0.014  F1=0.969±0.014  MCC=0.955±0.020  G-Mean=0.977±0.010  AUC=0.998±0.002
#     QDA                        Acc=0.949±0.023  F1=0.948±0.023  MCC=0.924±0.033  G-Mean=0.961±0.017  AUC=0.979±0.010
#     LightGBM                   Acc=0.981±0.012  F1=0.981±0.012  MCC=0.972±0.018  G-Mean=0.986±0.009  AUC=1.000±0.001
#     XGBoost                    Acc=0.981±0.015  F1=0.981±0.015  MCC=0.972±0.022  G-Mean=0.986±0.011  AUC=0.999±0.001
#     VotingSoft                 Acc=0.981±0.010  F1=0.981±0.010  MCC=0.972±0.015  G-Mean=0.986±0.008  AUC=1.000±0.001
#     VotingHard                 Acc=0.990±0.008  F1=0.990±0.008  MCC=0.984±0.012  G-Mean=0.992±0.006  AUC=N/A
#     Stacking                   Acc=0.991±0.010  F1=0.991±0.010  MCC=0.986±0.015  G-Mean=0.993±0.007  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS2_KBest  |  shape=(954, 25)
# ...
#     VotingSoft                 Acc=0.981±0.011  F1=0.981±0.011  MCC=0.972±0.017  G-Mean=0.986±0.009  AUC=0.999±0.001
#     VotingHard                 Acc=0.986±0.008  F1=0.986±0.008  MCC=0.980±0.012  G-Mean=0.990±0.006  AUC=N/A
#     Stacking                   Acc=0.987±0.006  F1=0.987±0.006  MCC=0.981±0.009  G-Mean=0.991±0.005  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS2_KBest  |  shape=(954, 25)
# ======================================================================
#     RandomForest               Acc=0.986±0.012  F1=0.986±0.012  MCC=0.980±0.017  G-Mean=0.990±0.009  AUC=0.999±0.001
#     ExtraTrees                 Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=0.996±0.006
#     Bagging                    Acc=0.975±0.011  F1=0.975±0.011  MCC=0.963±0.016  G-Mean=0.981±0.008  AUC=0.996±0.006
#     GradientBoosting           Acc=0.982±0.012  F1=0.982±0.011  MCC=0.974±0.017  G-Mean=0.987±0.009  AUC=0.999±0.001
#     LogisticRegression         Acc=0.973±0.016  F1=0.973±0.016  MCC=0.960±0.023  G-Mean=0.979±0.012  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.871±0.034  F1=0.866±0.037  MCC=0.815±0.049  G-Mean=0.903±0.025  AUC=N/A
#     DecisionTree               Acc=0.976±0.008  F1=0.976±0.008  MCC=0.964±0.012  G-Mean=0.982±0.006  AUC=0.982±0.006
#     NaiveBayes                 Acc=0.935±0.020  F1=0.935±0.020  MCC=0.904±0.030  G-Mean=0.951±0.015  AUC=0.989±0.005
#     Perceptron                 Acc=0.920±0.036  F1=0.920±0.036  MCC=0.884±0.053  G-Mean=0.940±0.027  AUC=N/A
#     SGDClassifier              Acc=0.941±0.033  F1=0.941±0.033  MCC=0.915±0.048  G-Mean=0.956±0.025  AUC=N/A
#     PassiveAggressive          Acc=0.876±0.086  F1=0.868±0.101  MCC=0.835±0.101  G-Mean=0.907±0.066  AUC=N/A
#     LDA                        Acc=0.971±0.012  F1=0.971±0.012  MCC=0.957±0.018  G-Mean=0.978±0.009  AUC=0.998±0.002
#     QDA                        Acc=0.949±0.019  F1=0.949±0.019  MCC=0.925±0.027  G-Mean=0.961±0.014  AUC=0.994±0.002
#     LightGBM                   Acc=0.980±0.010  F1=0.980±0.010  MCC=0.970±0.015  G-Mean=0.985±0.007  AUC=0.999±0.001
#     XGBoost                    Acc=0.980±0.011  F1=0.980±0.011  MCC=0.970±0.016  G-Mean=0.985±0.008  AUC=0.999±0.001
#     VotingSoft                 Acc=0.981±0.010  F1=0.981±0.010  MCC=0.972±0.015  G-Mean=0.986±0.008  AUC=0.999±0.001
#     VotingHard                 Acc=0.984±0.011  F1=0.984±0.011  MCC=0.977±0.016  G-Mean=0.988±0.008  AUC=N/A
#     Stacking                   Acc=0.984±0.014  F1=0.984±0.014  MCC=0.977±0.021  G-Mean=0.988±0.011  AUC=0.999±0.001
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS3_RFE  |  shape=(954, 22)
# ======================================================================
#     RandomForest               Acc=0.988±0.009  F1=0.988±0.009  MCC=0.983±0.013  G-Mean=0.991±0.007  AUC=1.000±0.001
#     ExtraTrees                 Acc=0.985±0.008  F1=0.985±0.008  MCC=0.978±0.012  G-Mean=0.989±0.006  AUC=1.000±0.001
#     Bagging                    Acc=0.977±0.011  F1=0.977±0.011  MCC=0.966±0.017  G-Mean=0.983±0.008  AUC=0.997±0.005
#     GradientBoosting           Acc=0.983±0.012  F1=0.983±0.012  MCC=0.975±0.017  G-Mean=0.987±0.009  AUC=0.999±0.002
#     LogisticRegression         Acc=0.969±0.011  F1=0.968±0.011  MCC=0.953±0.016  G-Mean=0.976±0.008  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.851±0.027  F1=0.842±0.030  MCC=0.789±0.038  G-Mean=0.888±0.020  AUC=N/A
#     DecisionTree               Acc=0.972±0.011  F1=0.972±0.010  MCC=0.958±0.016  G-Mean=0.979±0.008  AUC=0.979±0.008
#     NaiveBayes                 Acc=0.940±0.024  F1=0.941±0.024  MCC=0.912±0.035  G-Mean=0.955±0.018  AUC=0.989±0.006
#     Perceptron                 Acc=0.873±0.089  F1=0.864±0.114  MCC=0.826±0.104  G-Mean=0.904±0.068  AUC=N/A
#     SGDClassifier              Acc=0.969±0.021  F1=0.968±0.021  MCC=0.954±0.030  G-Mean=0.976±0.016  AUC=N/A
#     PassiveAggressive          Acc=0.791±0.122  F1=0.763±0.150  MCC=0.735±0.139  G-Mean=0.841±0.094  AUC=N/A
#     LDA                        Acc=0.963±0.010  F1=0.963±0.010  MCC=0.946±0.014  G-Mean=0.972±0.007  AUC=0.997±0.002
#     QDA                        Acc=0.949±0.015  F1=0.949±0.015  MCC=0.925±0.022  G-Mean=0.961±0.012  AUC=0.993±0.004
#     LightGBM                   Acc=0.984±0.007  F1=0.984±0.007  MCC=0.977±0.010  G-Mean=0.988±0.005  AUC=1.000±0.000
#     XGBoost                    Acc=0.982±0.014  F1=0.982±0.014  MCC=0.973±0.021  G-Mean=0.987±0.011  AUC=1.000±0.001
#     VotingSoft                 Acc=0.984±0.007  F1=0.984±0.007  MCC=0.977±0.010  G-Mean=0.988±0.005  AUC=1.000±0.001
#     VotingHard                 Acc=0.987±0.010  F1=0.987±0.010  MCC=0.981±0.015  G-Mean=0.991±0.008  AUC=N/A
#     Stacking                   Acc=0.990±0.008  F1=0.990±0.008  MCC=0.984±0.012  G-Mean=0.992±0.006  AUC=1.000±0.000
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS4_MutualInfo  |  shape=(954, 12)
# ======================================================================
#     RandomForest               Acc=0.979±0.015  F1=0.979±0.015  MCC=0.969±0.022  G-Mean=0.984±0.011  AUC=0.999±0.003
#     ExtraTrees                 Acc=0.983±0.012  F1=0.983±0.012  MCC=0.975±0.017  G-Mean=0.987±0.009  AUC=0.998±0.003
#     Bagging                    Acc=0.974±0.018  F1=0.974±0.018  MCC=0.961±0.026  G-Mean=0.980±0.013  AUC=0.994±0.007
#     GradientBoosting           Acc=0.979±0.013  F1=0.979±0.013  MCC=0.969±0.020  G-Mean=0.984±0.010  AUC=0.999±0.002
#     LogisticRegression         Acc=0.972±0.012  F1=0.972±0.012  MCC=0.958±0.017  G-Mean=0.979±0.009  AUC=0.998±0.002
#     RidgeClassifier            Acc=0.826±0.032  F1=0.810±0.039  MCC=0.759±0.042  G-Mean=0.868±0.024  AUC=N/A
#     DecisionTree               Acc=0.974±0.016  F1=0.974±0.016  MCC=0.961±0.024  G-Mean=0.980±0.012  AUC=0.986±0.007
#     NaiveBayes                 Acc=0.949±0.016  F1=0.949±0.016  MCC=0.924±0.025  G-Mean=0.961±0.012  AUC=0.991±0.004
#     Perceptron                 Acc=0.907±0.042  F1=0.904±0.047  MCC=0.868±0.056  G-Mean=0.930±0.032  AUC=N/A
#     SGDClassifier              Acc=0.964±0.012  F1=0.964±0.012  MCC=0.948±0.017  G-Mean=0.973±0.009  AUC=N/A
#     PassiveAggressive          Acc=0.876±0.102  F1=0.858±0.135  MCC=0.838±0.116  G-Mean=0.906±0.079  AUC=N/A
#     LDA                        Acc=0.963±0.016  F1=0.963±0.016  MCC=0.947±0.023  G-Mean=0.972±0.012  AUC=0.996±0.002
#     QDA                        Acc=0.952±0.011  F1=0.952±0.011  MCC=0.929±0.015  G-Mean=0.964±0.008  AUC=0.991±0.003
#     LightGBM                   Acc=0.978±0.014  F1=0.978±0.014  MCC=0.967±0.021  G-Mean=0.983±0.011  AUC=0.999±0.001
#     XGBoost                    Acc=0.979±0.014  F1=0.979±0.014  MCC=0.969±0.021  G-Mean=0.984±0.011  AUC=0.999±0.001
#     VotingSoft                 Acc=0.980±0.013  F1=0.980±0.013  MCC=0.970±0.019  G-Mean=0.985±0.010  AUC=0.999±0.001
#     VotingHard                 Acc=0.981±0.013  F1=0.981±0.013  MCC=0.972±0.020  G-Mean=0.986±0.010  AUC=N/A
#     Stacking                   Acc=0.983±0.012  F1=0.983±0.012  MCC=0.975±0.017  G-Mean=0.987±0.009  AUC=0.998±0.003
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS5_RFImportance  |  shape=(954, 16)
# ======================================================================
#     RandomForest               Acc=0.986±0.012  F1=0.986±0.012  MCC=0.980±0.017  G-Mean=0.990±0.009  AUC=1.000±0.001
#     ExtraTrees                 Acc=0.987±0.014  F1=0.987±0.014  MCC=0.981±0.021  G-Mean=0.991±0.010  AUC=0.996±0.008
#     Bagging                    Acc=0.978±0.017  F1=0.978±0.017  MCC=0.967±0.025  G-Mean=0.983±0.012  AUC=0.996±0.006
#     GradientBoosting           Acc=0.983±0.013  F1=0.983±0.013  MCC=0.975±0.019  G-Mean=0.987±0.009  AUC=0.999±0.002
#     LogisticRegression         Acc=0.970±0.014  F1=0.970±0.014  MCC=0.955±0.020  G-Mean=0.977±0.010  AUC=0.998±0.001
#     RidgeClassifier            Acc=0.847±0.026  F1=0.835±0.030  MCC=0.786±0.035  G-Mean=0.884±0.020  AUC=N/A
#     DecisionTree               Acc=0.971±0.016  F1=0.971±0.016  MCC=0.956±0.024  G-Mean=0.978±0.012  AUC=0.983±0.009
#     NaiveBayes                 Acc=0.948±0.017  F1=0.948±0.017  MCC=0.922±0.025  G-Mean=0.961±0.013  AUC=0.991±0.004
#     Perceptron                 Acc=0.836±0.100  F1=0.816±0.125  MCC=0.782±0.121  G-Mean=0.876±0.076  AUC=N/A
#     SGDClassifier              Acc=0.962±0.019  F1=0.962±0.019  MCC=0.945±0.027  G-Mean=0.971±0.014  AUC=N/A
#     PassiveAggressive          Acc=0.889±0.086  F1=0.885±0.097  MCC=0.847±0.104  G-Mean=0.915±0.067  AUC=N/A
#     LDA                        Acc=0.959±0.014  F1=0.959±0.014  MCC=0.941±0.020  G-Mean=0.969±0.010  AUC=0.997±0.002
#     QDA                        Acc=0.951±0.015  F1=0.951±0.015  MCC=0.928±0.021  G-Mean=0.963±0.011  AUC=0.991±0.003
#     LightGBM                   Acc=0.983±0.013  F1=0.983±0.013  MCC=0.975±0.019  G-Mean=0.987±0.009  AUC=0.999±0.001
#     XGBoost                    Acc=0.985±0.013  F1=0.985±0.013  MCC=0.978±0.020  G-Mean=0.989±0.010  AUC=0.999±0.001
#     VotingSoft                 Acc=0.984±0.013  F1=0.984±0.013  MCC=0.977±0.020  G-Mean=0.988±0.010  AUC=0.999±0.001
#     VotingHard                 Acc=0.988±0.013  F1=0.988±0.013  MCC=0.983±0.019  G-Mean=0.991±0.010  AUC=N/A
#     Stacking                   Acc=0.986±0.014  F1=0.986±0.014  MCC=0.980±0.021  G-Mean=0.990±0.011  AUC=0.999±0.001
#
#
# -- Phase 3 Summary (top 30 combos by Accuracy) --
#                              Balancer+FS       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling + FS1_Correlation         Stacking     0.999     0.999 0.998   0.999 1.000
#  B1_RandomOverSampling + FS1_Correlation       ExtraTrees     0.998     0.998 0.997   0.998 1.000
#              B3_ADASYN + FS1_Correlation       ExtraTrees     0.997     0.997 0.995   0.998 1.000
#          B1_RandomOverSampling + FS3_RFE         Stacking     0.996     0.996 0.994   0.997 1.000
#  B1_RandomOverSampling + FS1_Correlation       VotingHard     0.996     0.996 0.994   0.997   NaN
#          B1_RandomOverSampling + FS3_RFE       ExtraTrees     0.996     0.996 0.994   0.997 1.000
#  B1_RandomOverSampling + FS1_Correlation     RandomForest     0.995     0.995 0.992   0.996 1.000
#          B1_RandomOverSampling + FS3_RFE       VotingHard     0.994     0.994 0.991   0.995   NaN
#          B1_RandomOverSampling + FS3_RFE     RandomForest     0.994     0.994 0.991   0.995 1.000
# B1_RandomOverSampling + FS5_RFImportance         Stacking     0.994     0.994 0.991   0.995 1.000
#        B1_RandomOverSampling + FS2_KBest       ExtraTrees     0.994     0.994 0.991   0.995 1.000
#  B1_RandomOverSampling + FS1_Correlation          XGBoost     0.994     0.994 0.991   0.995 1.000
#        B1_RandomOverSampling + FS2_KBest         Stacking     0.994     0.994 0.991   0.995 1.000
#        B1_RandomOverSampling + FS2_KBest         LightGBM     0.993     0.993 0.989   0.995 1.000
#              B3_ADASYN + FS1_Correlation     RandomForest     0.993     0.993 0.989   0.995 1.000
#              B3_ADASYN + FS1_Correlation       VotingHard     0.993     0.993 0.989   0.995   NaN
# B1_RandomOverSampling + FS5_RFImportance          XGBoost     0.993     0.993 0.989   0.994 1.000
# B1_RandomOverSampling + FS5_RFImportance       ExtraTrees     0.992     0.992 0.988   0.994 1.000
#          B1_RandomOverSampling + FS3_RFE       VotingSoft     0.992     0.992 0.988   0.994 1.000
#  B1_RandomOverSampling + FS1_Correlation       VotingSoft     0.992     0.992 0.988   0.994 1.000
#        B1_RandomOverSampling + FS2_KBest       VotingSoft     0.992     0.992 0.988   0.994 1.000
#              B3_ADASYN + FS1_Correlation         Stacking     0.992     0.992 0.988   0.994 1.000
#        B1_RandomOverSampling + FS2_KBest       VotingHard     0.992     0.992 0.988   0.994   NaN
#        B1_RandomOverSampling + FS2_KBest          Bagging     0.992     0.992 0.988   0.994 0.998
#  B1_RandomOverSampling + FS1_Correlation GradientBoosting     0.992     0.992 0.988   0.994 1.000
#                      B3_ADASYN + FS3_RFE     RandomForest     0.992     0.992 0.988   0.994 1.000
#  B1_RandomOverSampling + FS1_Correlation     DecisionTree     0.992     0.992 0.988   0.994 0.994
#        B1_RandomOverSampling + FS2_KBest     RandomForest     0.992     0.992 0.988   0.994 1.000
#        B1_RandomOverSampling + FS2_KBest     DecisionTree     0.992     0.992 0.988   0.994 0.996
#                      B3_ADASYN + FS3_RFE         Stacking     0.991     0.991 0.986   0.993 1.000
#
# -- Phase 3: Best Classifier per Balancer+FS combo --
#                               Balancer+FS   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#   B1_RandomOverSampling + FS1_Correlation     Stacking     0.999     0.999 0.998   0.999 1.000
#               B3_ADASYN + FS1_Correlation   ExtraTrees     0.997     0.997 0.995   0.998 1.000
#           B1_RandomOverSampling + FS3_RFE     Stacking     0.996     0.996 0.994   0.997 1.000
#         B1_RandomOverSampling + FS2_KBest   ExtraTrees     0.994     0.994 0.991   0.995 1.000
#  B1_RandomOverSampling + FS5_RFImportance     Stacking     0.994     0.994 0.991   0.995 1.000
#                       B3_ADASYN + FS3_RFE RandomForest     0.992     0.992 0.988   0.994 1.000
#      B5_BorderlineSMOTE + FS1_Correlation RandomForest     0.991     0.991 0.986   0.993 1.000
#              B5_BorderlineSMOTE + FS3_RFE   ExtraTrees     0.991     0.991 0.986   0.993 1.000
#                   B7_SMOTETomek + FS3_RFE     Stacking     0.990     0.990 0.984   0.992 1.000
#                        B4_SMOTE + FS3_RFE     Stacking     0.990     0.990 0.984   0.992 1.000
#              B3_ADASYN + FS5_RFImportance RandomForest     0.990     0.990 0.985   0.992 1.000
#                     B3_ADASYN + FS2_KBest   ExtraTrees     0.989     0.989 0.983   0.991 0.996
#               B4_SMOTE + FS5_RFImportance   VotingHard     0.988     0.988 0.983   0.991   NaN
#            B5_BorderlineSMOTE + FS2_KBest     Stacking     0.988     0.988 0.983   0.991 1.000
#       B5_BorderlineSMOTE + FS4_MutualInfo   ExtraTrees     0.988     0.988 0.983   0.991 0.996
#          B7_SMOTETomek + FS5_RFImportance   VotingHard     0.988     0.988 0.983   0.991   NaN
#           B7_SMOTETomek + FS1_Correlation   ExtraTrees     0.987     0.987 0.981   0.991 0.998
#                B4_SMOTE + FS1_Correlation     Stacking     0.987     0.987 0.981   0.991 0.999
#                      B4_SMOTE + FS2_KBest RandomForest     0.986     0.986 0.980   0.990 0.999
#                 B7_SMOTETomek + FS2_KBest RandomForest     0.986     0.986 0.980   0.990 0.999
#     B5_BorderlineSMOTE + FS5_RFImportance     Stacking     0.985     0.985 0.978   0.989 0.999
#    B1_RandomOverSampling + FS4_MutualInfo   ExtraTrees     0.984     0.984 0.977   0.988 0.999
#            B7_SMOTETomek + FS4_MutualInfo     Stacking     0.983     0.983 0.975   0.987 0.998
#                B3_ADASYN + FS4_MutualInfo      Bagging     0.983     0.983 0.975   0.987 0.994
#                 B4_SMOTE + FS4_MutualInfo     Stacking     0.982     0.982 0.974   0.987 0.999
#            B6_TomekLinks + FS4_MutualInfo   ExtraTrees     0.972     0.925 0.917   0.939 0.992
#          B6_TomekLinks + FS5_RFImportance RandomForest     0.962     0.911 0.886   0.918 0.984
#                 B6_TomekLinks + FS2_KBest RandomForest     0.960     0.906 0.878   0.912 0.985
#           B6_TomekLinks + FS1_Correlation   ExtraTrees     0.957     0.901 0.871   0.909 0.985
#   B2_RandomUnderSampling + FS4_MutualInfo     Stacking     0.956     0.954 0.940   0.966 0.993
# B2_RandomUnderSampling + FS5_RFImportance   ExtraTrees     0.956     0.955 0.941   0.966 0.991
#                   B6_TomekLinks + FS3_RFE     Stacking     0.955     0.890 0.867   0.915 0.983
#        B2_RandomUnderSampling + FS2_KBest     Stacking     0.944     0.943 0.921   0.958 0.993
#          B2_RandomUnderSampling + FS3_RFE     Stacking     0.944     0.943 0.921   0.958 0.993
#  B2_RandomUnderSampling + FS1_Correlation   VotingSoft     0.944     0.943 0.925   0.958 0.993

# %%
bal_name = "B1_RandomOverSampling"
fs_name = "FS1_Correlation"

# Get the balanced dataset
balanced_df = balanced_datasets[bal_name]

# Apply the feature selection
fs_function = FEATURE_SELECTORS[fs_name]
processed_df = fs_function(balanced_df)

# Define the filename
filename = f"{bal_name} + {fs_name}.csv"

# Save to CSV
processed_df.to_csv(filename, index=False)

# Download the file
files.download(filename)
print(f"Downloaded: {filename}")
# Out:
# Downloaded: B1_RandomOverSampling + FS1_Correlation.csv
