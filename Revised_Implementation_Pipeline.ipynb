# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/CAST/blob/main/Revised_Implementation_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import io
import math
import csv
import pandas as pd
import numpy as np
import warnings
from google.colab import files
warnings.filterwarnings('ignore')

# Core ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.metrics import (
    accuracy_score, classification_report,
    matthews_corrcoef, roc_auc_score
)
from imblearn.metrics import geometric_mean_score
from sklearn.model_selection import StratifiedKFold

# Classifiers
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier,
    GradientBoostingClassifier, VotingClassifier, StackingClassifier
)
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron,
    SGDClassifier, PassiveAggressiveClassifier
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Balancing
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.combine import SMOTETomek


# optimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/muajnstu/CAST/refs/heads/main/Perception/Perception_1.csv'
)
print(f"Raw dataset shape : {df.shape}")
print(f"Target distribution:\n{df['CAST'].value_counts()}\n")

X_raw = df.drop(columns=['CAST'])
y_raw = df['CAST']
# Out:
# Raw dataset shape : (400, 47)
# Target distribution:
# CAST
# 0    218
# 1    110
# 2     72
# Name: count, dtype: int64

# %% [markdown]
# ***Data Balancing***

# %%
BALANCERS = {
    "B1_RandomOverSampling":  RandomOverSampler(random_state=42),
    "B2_RandomUnderSampling": RandomUnderSampler(random_state=42),
    "B3_ADASYN":              ADASYN(random_state=42),
    "B4_SMOTE":               SMOTE(random_state=42),
    "B5_BorderlineSMOTE":     BorderlineSMOTE(random_state=42),
    "B6_TomekLinks":          TomekLinks(),
    "B7_SMOTETomek":          SMOTETomek(random_state=42),
}


def apply_balancer(name, sampler, X, y):
    try:
        X_b, y_b = sampler.fit_resample(X, y)
        df_b = pd.DataFrame(X_b, columns=X.columns)
        df_b['CAST'] = y_b
        print(f"  {name:30s} -> shape {df_b.shape}  "
              f"dist: {dict(pd.Series(y_b).value_counts())}")
        return df_b
    except Exception as e:
        print(f"  {name:30s} -> FAILED: {e}")
        return None

# %% [markdown]
# ***Tunning FS Methods***

# %%
CV      = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
CV_EST  = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
N_TOTAL = X_raw.shape[1]

def _cv_score(X_sel, y):
    """Mean 5-fold CV accuracy for a given feature subset."""
    return cross_val_score(CV_EST, X_sel, y, cv=CV,
                           scoring='accuracy', n_jobs=-1).mean()

def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# Tune FS1
print("\n" + "="*70)
print("  TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)")
print("="*70)

print("\n[FS1] Sweeping correlation threshold...")
thresholds   = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
fs1_results  = {}
for thr in thresholds:
    corr  = X_raw.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= thr)]
    X_sel = X_raw.drop(columns=drop)
    score = _cv_score(X_sel, y_raw)
    fs1_results[thr] = (score, X_sel.shape[1])
    print(f"  threshold={thr:.2f}  features={X_sel.shape[1]:3d}  CV_acc={score:.4f}")

best_fs1_thr   = max(fs1_results, key=lambda t: fs1_results[t][0])
best_fs1_score = fs1_results[best_fs1_thr][0]
best_fs1_feats = fs1_results[best_fs1_thr][1]
print(f"  >> BEST threshold={best_fs1_thr}  features={best_fs1_feats}  CV_acc={best_fs1_score:.4f}")

# Tune FS2: KBest (f_classif)
print("\n[FS2] Sweeping k for SelectKBest (f_classif)...")
k_range     = list(range(1, N_TOTAL + 1))
fs2_results = {}
for k in k_range:
    sel   = SelectKBest(f_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs2_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs2_k     = max(fs2_results, key=fs2_results.get)
best_fs2_score = fs2_results[best_fs2_k]
print(f"  >> BEST k={best_fs2_k}  CV_acc={best_fs2_score:.4f}")

# Tune FS3: RFE
print("\n[FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...")
rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1),
    step=1, cv=CV, scoring='accuracy', n_jobs=-1, min_features_to_select=1
)
rfecv.fit(X_raw, y_raw)
best_fs3_n     = rfecv.n_features_
best_fs3_score = rfecv.cv_results_['mean_test_score'][best_fs3_n - 1]
_rfecv_support = rfecv.support_
print(f"  >> BEST n_features={best_fs3_n}  CV_acc={best_fs3_score:.4f}")

# Tune FS4: Mutual Information
print("\n[FS4] Sweeping k for SelectKBest (mutual_info_classif)...")
fs4_results = {}
for k in k_range:
    sel   = SelectKBest(mutual_info_classif, k=k).fit(X_raw, y_raw)
    X_sel = X_raw.iloc[:, sel.get_support()]
    score = _cv_score(X_sel, y_raw)
    fs4_results[k] = score
    print(f"  k={k:3d}  CV_acc={score:.4f}")

best_fs4_k     = max(fs4_results, key=fs4_results.get)
best_fs4_score = fs4_results[best_fs4_k]
print(f"  >> BEST k={best_fs4_k}  CV_acc={best_fs4_score:.4f}")

# Tune FS5: RF Importance cumulative threshold
print("\n[FS5] Sweeping cumulative importance threshold for RF feature importance...")
_rf_imp  = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
_rf_imp.fit(X_raw, y_raw)
imp_series = pd.Series(_rf_imp.feature_importances_, index=X_raw.columns)\
               .sort_values(ascending=False)
cum_imp = imp_series.cumsum()

cum_thresholds = [0.80, 0.85, 0.90, 0.95, 0.99]
fs5_results    = {}
for ct in cum_thresholds:
    top_feats = cum_imp[cum_imp <= ct].index.tolist()
    if len(top_feats) == 0:
        top_feats = [imp_series.index[0]]
    X_sel = X_raw[top_feats]
    score = _cv_score(X_sel, y_raw)
    fs5_results[ct] = (score, len(top_feats))
    print(f"  cum_threshold={ct:.2f}  features={len(top_feats):3d}  CV_acc={score:.4f}")

best_fs5_ct    = max(fs5_results, key=lambda t: fs5_results[t][0])
best_fs5_score = fs5_results[best_fs5_ct][0]
best_fs5_feats = fs5_results[best_fs5_ct][1]
print(f"  >> BEST cum_threshold={best_fs5_ct}  features={best_fs5_feats}  CV_acc={best_fs5_score:.4f}")

# Summary of tuned parameters
print("\n" + "="*70)
print("  TUNING SUMMARY")
print("="*70)
tuning_summary = pd.DataFrame([
    {"FS": "FS1_Correlation",  "Parameter": "threshold",        "Best_Value": best_fs1_thr,  "n_features": best_fs1_feats, "CV_Accuracy": round(best_fs1_score, 4)},
    {"FS": "FS2_KBest",        "Parameter": "k",                "Best_Value": best_fs2_k,    "n_features": best_fs2_k,     "CV_Accuracy": round(best_fs2_score, 4)},
    {"FS": "FS3_RFE",          "Parameter": "n_features (RFECV)","Best_Value": best_fs3_n,   "n_features": best_fs3_n,     "CV_Accuracy": round(best_fs3_score, 4)},
    {"FS": "FS4_MutualInfo",   "Parameter": "k",                "Best_Value": best_fs4_k,    "n_features": best_fs4_k,     "CV_Accuracy": round(best_fs4_score, 4)},
    {"FS": "FS5_RFImportance", "Parameter": "cum_threshold",    "Best_Value": best_fs5_ct,   "n_features": best_fs5_feats, "CV_Accuracy": round(best_fs5_score, 4)},
])
print(tuning_summary.to_string(index=False))
# Out:
# ======================================================================
#   TUNING FEATURE SELECTORS ON RAW DATA (5-fold CV)
# ======================================================================
#
# [FS1] Sweeping correlation threshold...
#   threshold=0.70  features= 14  CV_acc=0.6575
#   threshold=0.75  features= 21  CV_acc=0.6450
#   threshold=0.80  features= 38  CV_acc=0.6575
#   threshold=0.85  features= 43  CV_acc=0.6575
#   threshold=0.90  features= 46  CV_acc=0.6450
#   threshold=0.95  features= 46  CV_acc=0.6450
#   >> BEST threshold=0.7  features=14  CV_acc=0.6575
#
# [FS2] Sweeping k for SelectKBest (f_classif)...
#   k=  1  CV_acc=0.6175
#   k=  2  CV_acc=0.6300
#   k=  3  CV_acc=0.6275
#   k=  4  CV_acc=0.6450
#   k=  5  CV_acc=0.6425
#   k=  6  CV_acc=0.6100
#   k=  7  CV_acc=0.6100
#   k=  8  CV_acc=0.6500
#   k=  9  CV_acc=0.6350
#   k= 10  CV_acc=0.6400
#   k= 11  CV_acc=0.6225
#   k= 12  CV_acc=0.6225
#   k= 13  CV_acc=0.6250
#   k= 14  CV_acc=0.6325
#   k= 15  CV_acc=0.6425
#   k= 16  CV_acc=0.6200
#   k= 17  CV_acc=0.6325
#   k= 18  CV_acc=0.6500
#   k= 19  CV_acc=0.6225
#   k= 20  CV_acc=0.6150
#   k= 21  CV_acc=0.6225
#   k= 22  CV_acc=0.6325
#   k= 23  CV_acc=0.6350
#   k= 24  CV_acc=0.6275
#   k= 25  CV_acc=0.6375
#   k= 26  CV_acc=0.6350
#   k= 27  CV_acc=0.6425
#   k= 28  CV_acc=0.6425
#   k= 29  CV_acc=0.6475
#   k= 30  CV_acc=0.6275
#   k= 31  CV_acc=0.6400
#   k= 32  CV_acc=0.6525
#   k= 33  CV_acc=0.6500
#   k= 34  CV_acc=0.6500
#   k= 35  CV_acc=0.6600
#   k= 36  CV_acc=0.6525
#   k= 37  CV_acc=0.6550
#   k= 38  CV_acc=0.6575
#   k= 39  CV_acc=0.6775
#   k= 40  CV_acc=0.6675
#   k= 41  CV_acc=0.6700
#   k= 42  CV_acc=0.6600
#   k= 43  CV_acc=0.6775
#   k= 44  CV_acc=0.6650
#   k= 45  CV_acc=0.6800
#   k= 46  CV_acc=0.6450
#   >> BEST k=45  CV_acc=0.6800
#
# [FS3] Running RFECV (RFE with built-in CV) to find optimal n_features...
#   >> BEST n_features=24  CV_acc=0.6975
#
# [FS4] Sweeping k for SelectKBest (mutual_info_classif)...
#   k=  1  CV_acc=0.5750
#   k=  2  CV_acc=0.6325
#   k=  3  CV_acc=0.6400
#   k=  4  CV_acc=0.6475
#   k=  5  CV_acc=0.6450
#   k=  6  CV_acc=0.5825
#   k=  7  CV_acc=0.6050
#   k=  8  CV_acc=0.6200
#   k=  9  CV_acc=0.5825
#   k= 10  CV_acc=0.6325
#   k= 11  CV_acc=0.6075
#   k= 12  CV_acc=0.6050
#   k= 13  CV_acc=0.6600
#   k= 14  CV_acc=0.6525
#   k= 15  CV_acc=0.6275
#   k= 16  CV_acc=0.6350
#   k= 17  CV_acc=0.6475
#   k= 18  CV_acc=0.6400
#   k= 19  CV_acc=0.6300
#   k= 20  CV_acc=0.6675
#   k= 21  CV_acc=0.6600
#   k= 22  CV_acc=0.6800
#   k= 23  CV_acc=0.6300
#   k= 24  CV_acc=0.6225
#   k= 25  CV_acc=0.6550
#   k= 26  CV_acc=0.6500
#   k= 27  CV_acc=0.6500
#   k= 28  CV_acc=0.6775
#   k= 29  CV_acc=0.6475
#   k= 30  CV_acc=0.6500
#   k= 31  CV_acc=0.6825
#   k= 32  CV_acc=0.6600
#   k= 33  CV_acc=0.6550
#   k= 34  CV_acc=0.6575
#   k= 35  CV_acc=0.6475
#   k= 36  CV_acc=0.6675
#   k= 37  CV_acc=0.6275
#   k= 38  CV_acc=0.6650
#   k= 39  CV_acc=0.6600
#   k= 40  CV_acc=0.6475
#   k= 41  CV_acc=0.6550
#   k= 42  CV_acc=0.6500
#   k= 43  CV_acc=0.6375
#   k= 44  CV_acc=0.6375
#   k= 45  CV_acc=0.6500
#   k= 46  CV_acc=0.6450
#   >> BEST k=31  CV_acc=0.6825
#
# [FS5] Sweeping cumulative importance threshold for RF feature importance...
#   cum_threshold=0.80  features= 32  CV_acc=0.6525
#   cum_threshold=0.85  features= 35  CV_acc=0.6575
#   cum_threshold=0.90  features= 39  CV_acc=0.6375
#   cum_threshold=0.95  features= 42  CV_acc=0.6425
#   cum_threshold=0.99  features= 45  CV_acc=0.6775
#   >> BEST cum_threshold=0.99  features=45  CV_acc=0.6775
#
# ======================================================================
#   TUNING SUMMARY
# ======================================================================
#               FS          Parameter  Best_Value  n_features  CV_Accuracy
#  FS1_Correlation          threshold        0.70          14       0.6575
#        FS2_KBest                  k       45.00          45       0.6800
#          FS3_RFE n_features (RFECV)       24.00          24       0.6975
#   FS4_MutualInfo                  k       31.00          31       0.6825
# FS5_RFImportance      cum_threshold        0.99          45       0.6775

# %% [markdown]
# ***FS Methods***

# %%
def fs_correlation(data, target_col='CAST', threshold=best_fs1_thr):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    corr  = X_.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = [c for c in upper.columns if any(upper[c] >= threshold)]
    out   = X_.drop(columns=drop).copy(); out[target_col] = y_.values
    return out

def fs_kbest(data, target_col='CAST', k=best_fs2_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(f_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rfe(data, target_col='CAST', support=_rfecv_support):

    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    cols = X_.columns[support] if len(support) == X_.shape[1] else X_.columns
    out  = X_[cols].copy(); out[target_col] = y_.values
    return out

def fs_mi(data, target_col='CAST', k=best_fs4_k):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    sel = SelectKBest(mutual_info_classif, k=min(k, X_.shape[1])).fit(X_, y_)
    out = X_[X_.columns[sel.get_support()]].copy(); out[target_col] = y_.values
    return out

def fs_rf_importance(data, target_col='CAST', cum_threshold=best_fs5_ct):
    X_ = data.drop(columns=[target_col]); y_ = data[target_col]
    rf  = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_, y_)
    imp = pd.Series(rf.feature_importances_, index=X_.columns).sort_values(ascending=False)
    top = imp.cumsum()[imp.cumsum() <= cum_threshold].index.tolist()
    if len(top) == 0:
        top = [imp.index[0]]
    out = X_[top].copy(); out[target_col] = y_.values
    return out

FEATURE_SELECTORS = {
    "FS1_Correlation":  lambda d: fs_correlation(d),
    "FS2_KBest":        lambda d: fs_kbest(d),
    "FS3_RFE":          lambda d: fs_rfe(d),
    "FS4_MutualInfo":   lambda d: fs_mi(d),
    "FS5_RFImportance": lambda d: fs_rf_importance(d),
}

# %% [markdown]
# ***Evaluation Metrics***

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True, n_splits=10):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    rows = []
    for clf_name, model in build_models().items():
        fold_metrics = {
            'Accuracy': [], 'Macro_F1': [], 'Macro_Precision': [],
            'Macro_Recall': [], 'MCC': [], 'G_Mean': [], 'AUC': []
        }

        for train_idx, test_idx in skf.split(X_, y_):
            X_tr, X_te = X_.iloc[train_idx], X_.iloc[test_idx]
            y_tr, y_te = y_.iloc[train_idx], y_.iloc[test_idx]

            try:
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_te)

                acc   = accuracy_score(y_te, y_pred)
                rep   = classification_report(y_te, y_pred, zero_division=0, output_dict=True)
                mcc   = matthews_corrcoef(y_te, y_pred)
                gmean = geometric_mean_score(y_te, y_pred, average='macro')

                n_classes = len(np.unique(y_te))
                auc = None
                try:
                    if hasattr(model, 'predict_proba'):
                        y_score = model.predict_proba(X_te)
                    else:
                        y_score = model.decision_function(X_te)
                        if n_classes <= 2:
                            y_score = y_score.reshape(-1, 1)

                    if n_classes == 2:
                        prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                        auc = roc_auc_score(y_te, prob)
                    else:
                        auc = roc_auc_score(
                            y_te, y_score,
                            multi_class='ovr', average='macro',
                            labels=np.unique(y_te)
                        )
                except Exception:
                    pass

                fold_metrics['Accuracy'].append(acc)
                fold_metrics['Macro_F1'].append(rep['macro avg']['f1-score'])
                fold_metrics['Macro_Precision'].append(rep['macro avg']['precision'])
                fold_metrics['Macro_Recall'].append(rep['macro avg']['recall'])
                fold_metrics['MCC'].append(mcc)
                fold_metrics['G_Mean'].append(gmean)
                if auc is not None:
                    fold_metrics['AUC'].append(auc)

            except Exception as e:
                if verbose:
                    print(f"    {clf_name:25s}  Fold ERROR: {e}")

        # Aggregate: mean ± std across folds
        def fmt(vals):
            if not vals:
                return None, None
            return round(np.mean(vals), 3), round(np.std(vals), 3)

        acc_m,   acc_s   = fmt(fold_metrics['Accuracy'])
        f1_m,    f1_s    = fmt(fold_metrics['Macro_F1'])
        prec_m,  prec_s  = fmt(fold_metrics['Macro_Precision'])
        rec_m,   rec_s   = fmt(fold_metrics['Macro_Recall'])
        mcc_m,   mcc_s   = fmt(fold_metrics['MCC'])
        gm_m,    gm_s    = fmt(fold_metrics['G_Mean'])
        auc_m,   auc_s   = fmt(fold_metrics['AUC'])

        rows.append({
            'Label':                label,
            'Classifier':           clf_name,
            'Accuracy':             acc_m,  'Accuracy_SD':   acc_s,
            'Macro_F1':             f1_m,   'Macro_F1_SD':   f1_s,
            'Macro_Precision':      prec_m, 'Macro_Prec_SD': prec_s,
            'Macro_Recall':         rec_m,  'Macro_Rec_SD':  rec_s,
            'MCC':                  mcc_m,  'MCC_SD':        mcc_s,
            'G_Mean':               gm_m,   'G_Mean_SD':     gm_s,
            'AUC':                  auc_m,  'AUC_SD':        auc_s,
        })

        if verbose:
            auc_str = f"{auc_m:.3f}±{auc_s:.3f}" if auc_m is not None else "N/A"
            print(f"    {clf_name:25s}  "
                  f"Acc={acc_m:.3f}±{acc_s:.3f}  "
                  f"F1={f1_m:.3f}±{f1_s:.3f}  "
                  f"MCC={mcc_m:.3f}±{mcc_s:.3f}  "
                  f"G-Mean={gm_m:.3f}±{gm_s:.3f}  "
                  f"AUC={auc_str}")

    return rows

# %%
def evaluate_dataset(data, target_col='CAST', label="", verbose=True):
    X_ = data.drop(columns=[target_col])
    y_ = data[target_col]
    X_tr, X_te, y_tr, y_te = train_test_split(
        X_, y_, test_size=0.25, random_state=42, stratify=y_
    )
    rows = []
    for clf_name, model in build_models().items():
        try:
            model.fit(X_tr, y_tr)
            y_pred = model.predict(X_te)

            # ── Core metrics
            acc     = accuracy_score(y_te, y_pred)
            rep     = classification_report(y_te, y_pred, zero_division=0,
                                            output_dict=True)
            mcc     = matthews_corrcoef(y_te, y_pred)
            gmean   = geometric_mean_score(y_te, y_pred, average='macro')

            # ── AUC:
            n_classes = len(np.unique(y_te))
            try:
                if hasattr(model, 'predict_proba'):
                    y_score = model.predict_proba(X_te)
                else:
                    y_score = model.decision_function(X_te)
                    if n_classes > 2:
                        # decision_function for multiclass → already (n, k)
                        pass
                    else:
                        y_score = y_score.reshape(-1, 1)

                if n_classes == 2:
                    # Binary: use probability of positive class
                    prob = y_score[:, 1] if y_score.ndim == 2 else y_score
                    auc = roc_auc_score(y_te, prob)
                else:
                    auc = roc_auc_score(
                        y_te, y_score,
                        multi_class='ovr', average='macro',
                        labels=np.unique(y_te)
                    )
            except Exception:
                auc = None

            rows.append({
                'Label':           label,
                'Classifier':      clf_name,
                'Accuracy':        round(acc,   4),
                'Macro_F1':        round(rep['macro avg']['f1-score'],   4),
                'Macro_Precision': round(rep['macro avg']['precision'],  4),
                'Macro_Recall':    round(rep['macro avg']['recall'],     4),
                'MCC':             round(mcc,   4),
                'G_Mean':          round(gmean, 4),
                'AUC':             round(auc,   4) if auc is not None else None,
            })
            if verbose:
                auc_str = f"{auc:.4f}" if auc is not None else "  N/A"
                print(f"    {clf_name:25s}  Acc={acc:.4f}  F1={rep['macro avg']['f1-score']:.4f}"
                      f"  MCC={mcc:.4f}  G-Mean={gmean:.4f}  AUC={auc_str}")
        except Exception as e:
            rows.append({'Label': label, 'Classifier': clf_name,
                         'Accuracy': None, 'Macro_F1': None,
                         'Macro_Precision': None, 'Macro_Recall': None,
                         'MCC': None, 'G_Mean': None, 'AUC': None})
            if verbose:
                print(f"    {clf_name:25s}  ERROR: {e}")
    return rows


def section_header(title):
    print("\n" + "#"*80)
    print(f"  {title}")
    print("#"*80)

def sub_header(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print("="*70)

# %% [markdown]
# ***ML Models***

# %%
def build_models():
    return {
        "RandomForest":       RandomForestClassifier(random_state=42),
        "ExtraTrees":         ExtraTreesClassifier(random_state=42),
        "Bagging":            BaggingClassifier(random_state=42),
        "GradientBoosting":   GradientBoostingClassifier(random_state=42),
        "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
        "RidgeClassifier":    RidgeClassifier(),
        "DecisionTree":       DecisionTreeClassifier(random_state=42),
        "NaiveBayes":         GaussianNB(),
        "Perceptron":         Perceptron(random_state=42),
        "SGDClassifier":      SGDClassifier(random_state=42),
        "PassiveAggressive":  PassiveAggressiveClassifier(random_state=42),
        "LDA":                LinearDiscriminantAnalysis(),
        "QDA":                QuadraticDiscriminantAnalysis(),
        "LightGBM":           LGBMClassifier(verbosity=-1, random_state=42),
        "XGBoost":            XGBClassifier(n_estimators=100, random_state=42,
                                            eval_metric='mlogloss',
                                            use_label_encoder=False, verbosity=0),
        "VotingSoft": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='soft', n_jobs=-1),
        "VotingHard": VotingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], voting='hard', n_jobs=-1),
        "Stacking": StackingClassifier(estimators=[
            ('rf',   RandomForestClassifier(n_estimators=100, random_state=42)),
            ('gb',   GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('et',   ExtraTreesClassifier(n_estimators=100, random_state=42)),
            ('lgbm', LGBMClassifier(verbosity=-1, n_estimators=100, random_state=42)),
        ], final_estimator=LogisticRegression(max_iter=1000, random_state=42),
           cv=5, stack_method='predict_proba', n_jobs=-1),
    }

# %% [markdown]
# # ***Experiment 1***

# %%
section_header("PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)")

print("\nApplying balancers to raw data...")
balanced_datasets = {}
for bal_name, sampler in BALANCERS.items():
    df_b = apply_balancer(bal_name, sampler, X_raw, y_raw)
    if df_b is not None:
        balanced_datasets[bal_name] = df_b

phase1_rows = []
for bal_name, bal_df in balanced_datasets.items():
    sub_header(f"Balancer: {bal_name}  |  shape={bal_df.shape}")
    rows = evaluate_dataset(bal_df, label=bal_name, verbose=True)
    phase1_rows.extend(rows)

phase1_df = pd.DataFrame(phase1_rows).dropna(subset=['Accuracy'])
phase1_df['Phase'] = 'Phase1_BalancingOnly'
phase1_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 1 Summary (top 20 by Accuracy) --")
p1_show = phase1_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer'})
METRICS = ['Accuracy','Macro_F1','MCC','G_Mean','AUC']
print(p1_show[['Balancer','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 1: Best Classifier per Balancer --")
best_p1 = (p1_show.groupby('Balancer', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer','Classifier'] + METRICS])
print(best_p1.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 1 — 7 Balancing Variants  (all raw features, no feature selection)
# ################################################################################
#
# Applying balancers to raw data...
#   B1_RandomOverSampling          -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B2_RandomUnderSampling         -> shape (216, 47)  dist: {0: np.int64(72), 1: np.int64(72), 2: np.int64(72)}
#   B3_ADASYN                      -> shape (655, 47)  dist: {1: np.int64(224), 0: np.int64(218), 2: np.int64(213)}
#   B4_SMOTE                       -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B5_BorderlineSMOTE             -> shape (654, 47)  dist: {0: np.int64(218), 2: np.int64(218), 1: np.int64(218)}
#   B6_TomekLinks                  -> shape (369, 47)  dist: {0: np.int64(202), 1: np.int64(95), 2: np.int64(72)}
#   B7_SMOTETomek                  -> shape (642, 47)  dist: {2: np.int64(216), 1: np.int64(214), 0: np.int64(212)}
#
# ======================================================================
#   Balancer: B1_RandomOverSampling  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.885±0.033  F1=0.884±0.034  MCC=0.831±0.048  G-Mean=0.913±0.025  AUC=0.970±0.015
#     ExtraTrees                 Acc=0.888±0.031  F1=0.888±0.032  MCC=0.834±0.046  G-Mean=0.916±0.023  AUC=0.974±0.011
#     Bagging                    Acc=0.863±0.039  F1=0.861±0.040  MCC=0.798±0.058  G-Mean=0.896±0.030  AUC=0.953±0.023
#     GradientBoosting           Acc=0.853±0.035  F1=0.851±0.037  MCC=0.781±0.053  G-Mean=0.889±0.027  AUC=0.950±0.016
#     LogisticRegression         Acc=0.624±0.056  F1=0.617±0.056  MCC=0.440±0.084  G-Mean=0.711±0.044  AUC=0.800±0.047
#     RidgeClassifier            Acc=0.624±0.051  F1=0.613±0.054  MCC=0.443±0.076  G-Mean=0.712±0.040  AUC=N/A
#     DecisionTree               Acc=0.858±0.037  F1=0.855±0.038  MCC=0.791±0.054  G-Mean=0.893±0.028  AUC=0.898±0.027
#     NaiveBayes                 Acc=0.630±0.053  F1=0.622±0.051  MCC=0.452±0.082  G-Mean=0.716±0.042  AUC=0.788±0.044
#     Perceptron                 Acc=0.577±0.072  F1=0.561±0.082  MCC=0.385±0.101  G-Mean=0.673±0.058  AUC=N/A
#     SGDClassifier              Acc=0.568±0.048  F1=0.551±0.047  MCC=0.370±0.075  G-Mean=0.666±0.038  AUC=N/A
#     PassiveAggressive          Acc=0.528±0.087  F1=0.507±0.092  MCC=0.315±0.137  G-Mean=0.635±0.071  AUC=N/A
#     LDA                        Acc=0.612±0.058  F1=0.603±0.060  MCC=0.422±0.088  G-Mean=0.702±0.046  AUC=0.803±0.046
#     QDA                        Acc=0.795±0.045  F1=0.796±0.044  MCC=0.697±0.068  G-Mean=0.845±0.035  AUC=0.921±0.026
#     LightGBM                   Acc=0.884±0.040  F1=0.882±0.041  MCC=0.828±0.060  G-Mean=0.912±0.031  AUC=0.968±0.014
#     XGBoost                    Acc=0.872±0.026  F1=0.870±0.027  MCC=0.811±0.038  G-Mean=0.903±0.020  AUC=0.967±0.013
#     VotingSoft                 Acc=0.878±0.046  F1=0.877±0.047  MCC=0.818±0.069  G-Mean=0.908±0.035  AUC=0.972±0.012
#     VotingHard                 Acc=0.884±0.040  F1=0.883±0.041  MCC=0.828±0.058  G-Mean=0.912±0.030  AUC=N/A
#     Stacking                   Acc=0.905±0.033  F1=0.906±0.033  MCC=0.861±0.049  G-Mean=0.929±0.025  AUC=0.973±0.016
#
# ======================================================================
#   Balancer: B2_RandomUnderSampling  |  shape=(216, 47)
# ======================================================================
#     RandomForest               Acc=0.573±0.109  F1=0.564±0.106  MCC=0.366±0.169  G-Mean=0.670±0.087  AUC=0.773±0.075
#     ExtraTrees                 Acc=0.579±0.105  F1=0.577±0.107  MCC=0.376±0.158  G-Mean=0.676±0.084  AUC=0.771±0.076
#     Bagging                    Acc=0.487±0.058  F1=0.478±0.058  MCC=0.241±0.091  G-Mean=0.603±0.048  AUC=0.702±0.069
#     GradientBoosting           Acc=0.565±0.128  F1=0.557±0.121  MCC=0.356±0.200  G-Mean=0.663±0.103  AUC=0.741±0.063
#     LogisticRegression         Acc=0.499±0.091  F1=0.488±0.093  MCC=0.253±0.141  G-Mean=0.611±0.076  AUC=0.635±0.065
#     RidgeClassifier            Acc=0.485±0.088  F1=0.471±0.088  MCC=0.233±0.136  G-Mean=0.600±0.074  AUC=N/A
#     DecisionTree               Acc=0.506±0.128  F1=0.500±0.129  MCC=0.261±0.194  G-Mean=0.615±0.104  AUC=0.624±0.091
#     NaiveBayes                 Acc=0.587±0.066  F1=0.571±0.064  MCC=0.390±0.104  G-Mean=0.682±0.053  AUC=0.762±0.075
#     Perceptron                 Acc=0.481±0.055  F1=0.456±0.060  MCC=0.237±0.090  G-Mean=0.595±0.043  AUC=N/A
#     SGDClassifier              Acc=0.485±0.087  F1=0.475±0.099  MCC=0.235±0.133  G-Mean=0.601±0.073  AUC=N/A
#     PassiveAggressive          Acc=0.486±0.065  F1=0.468±0.068  MCC=0.238±0.102  G-Mean=0.601±0.054  AUC=N/A
#     LDA                        Acc=0.485±0.089  F1=0.475±0.090  MCC=0.231±0.136  G-Mean=0.600±0.075  AUC=0.635±0.081
#     QDA                        Acc=0.431±0.097  F1=0.406±0.108  MCC=0.156±0.155  G-Mean=0.555±0.083  AUC=0.587±0.050
#     LightGBM                   Acc=0.550±0.103  F1=0.540±0.101  MCC=0.334±0.157  G-Mean=0.652±0.083  AUC=0.733±0.082
#     XGBoost                    Acc=0.578±0.115  F1=0.573±0.115  MCC=0.374±0.176  G-Mean=0.674±0.091  AUC=0.746±0.072
#     VotingSoft                 Acc=0.568±0.119  F1=0.558±0.111  MCC=0.361±0.185  G-Mean=0.666±0.095  AUC=0.762±0.079
#     VotingHard                 Acc=0.583±0.121  F1=0.577±0.117  MCC=0.380±0.185  G-Mean=0.677±0.096  AUC=N/A
#     Stacking                   Acc=0.583±0.131  F1=0.577±0.128  MCC=0.381±0.201  G-Mean=0.678±0.105  AUC=0.755±0.076
#
# ======================================================================
#   Balancer: B3_ADASYN  |  shape=(655, 47)
# ======================================================================
#     RandomForest               Acc=0.759±0.065  F1=0.756±0.067  MCC=0.645±0.095  G-Mean=0.817±0.050  AUC=0.908±0.031
#     ExtraTrees                 Acc=0.782±0.054  F1=0.780±0.055  MCC=0.678±0.079  G-Mean=0.834±0.042  AUC=0.918±0.032
#     Bagging                    Acc=0.728±0.038  F1=0.728±0.038  MCC=0.599±0.058  G-Mean=0.794±0.030  AUC=0.880±0.024
#     GradientBoosting           Acc=0.762±0.050  F1=0.762±0.050  MCC=0.647±0.074  G-Mean=0.820±0.039  AUC=0.893±0.038
#     LogisticRegression         Acc=0.540±0.045  F1=0.534±0.044  MCC=0.315±0.070  G-Mean=0.646±0.037  AUC=0.737±0.029
#     RidgeClassifier            Acc=0.554±0.045  F1=0.546±0.049  MCC=0.337±0.068  G-Mean=0.657±0.037  AUC=N/A
#     DecisionTree               Acc=0.658±0.058  F1=0.656±0.061  MCC=0.490±0.086  G-Mean=0.739±0.046  AUC=0.753±0.041
#     NaiveBayes                 Acc=0.536±0.057  F1=0.520±0.062  MCC=0.317±0.083  G-Mean=0.643±0.045  AUC=0.687±0.050
#     Perceptron                 Acc=0.508±0.045  F1=0.483±0.068  MCC=0.287±0.056  G-Mean=0.620±0.034  AUC=N/A
#     SGDClassifier              Acc=0.474±0.057  F1=0.455±0.059  MCC=0.228±0.089  G-Mean=0.591±0.048  AUC=N/A
#     PassiveAggressive          Acc=0.434±0.079  F1=0.417±0.080  MCC=0.155±0.125  G-Mean=0.555±0.067  AUC=N/A
#     LDA                        Acc=0.547±0.035  F1=0.540±0.038  MCC=0.324±0.053  G-Mean=0.651±0.029  AUC=0.739±0.031
#     QDA                        Acc=0.676±0.040  F1=0.674±0.043  MCC=0.518±0.061  G-Mean=0.753±0.032  AUC=0.858±0.032
#     LightGBM                   Acc=0.766±0.046  F1=0.766±0.046  MCC=0.653±0.068  G-Mean=0.823±0.035  AUC=0.909±0.027
#     XGBoost                    Acc=0.768±0.058  F1=0.765±0.060  MCC=0.657±0.084  G-Mean=0.824±0.045  AUC=0.913±0.037
#     VotingSoft                 Acc=0.770±0.047  F1=0.769±0.047  MCC=0.659±0.069  G-Mean=0.825±0.036  AUC=0.919±0.028
#     VotingHard                 Acc=0.774±0.055  F1=0.773±0.056  MCC=0.667±0.080  G-Mean=0.829±0.043  AUC=N/A
#     Stacking                   Acc=0.788±0.051  F1=0.788±0.051  MCC=0.686±0.076  G-Mean=0.839±0.040  AUC=0.916±0.026
#
# ======================================================================
#   Balancer: B4_SMOTE  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.781±0.059  F1=0.780±0.059  MCC=0.674±0.090  G-Mean=0.834±0.046  AUC=0.922±0.025
#     ExtraTrees                 Acc=0.798±0.049  F1=0.798±0.048  MCC=0.699±0.073  G-Mean=0.847±0.037  AUC=0.929±0.024
#     Bagging                    Acc=0.742±0.052  F1=0.740±0.053  MCC=0.615±0.078  G-Mean=0.804±0.040  AUC=0.890±0.029
#     GradientBoosting           Acc=0.765±0.045  F1=0.763±0.045  MCC=0.649±0.067  G-Mean=0.821±0.034  AUC=0.905±0.026
#     LogisticRegression         Acc=0.610±0.052  F1=0.607±0.052  MCC=0.419±0.079  G-Mean=0.701±0.042  AUC=0.775±0.047
#     RidgeClassifier            Acc=0.595±0.055  F1=0.588±0.056  MCC=0.398±0.083  G-Mean=0.689±0.044  AUC=N/A
#     DecisionTree               Acc=0.687±0.053  F1=0.686±0.053  MCC=0.533±0.080  G-Mean=0.761±0.041  AUC=0.771±0.040
#     NaiveBayes                 Acc=0.598±0.061  F1=0.592±0.063  MCC=0.402±0.093  G-Mean=0.691±0.048  AUC=0.760±0.044
#     Perceptron                 Acc=0.517±0.050  F1=0.484±0.058  MCC=0.301±0.078  G-Mean=0.626±0.040  AUC=N/A
#     SGDClassifier              Acc=0.512±0.077  F1=0.484±0.081  MCC=0.287±0.117  G-Mean=0.621±0.063  AUC=N/A
#     PassiveAggressive          Acc=0.514±0.072  F1=0.474±0.071  MCC=0.296±0.114  G-Mean=0.623±0.060  AUC=N/A
#     LDA                        Acc=0.615±0.067  F1=0.611±0.067  MCC=0.426±0.103  G-Mean=0.704±0.054  AUC=0.780±0.049
#     QDA                        Acc=0.707±0.052  F1=0.706±0.052  MCC=0.563±0.079  G-Mean=0.776±0.041  AUC=0.864±0.024
#     LightGBM                   Acc=0.772±0.049  F1=0.770±0.049  MCC=0.661±0.073  G-Mean=0.827±0.037  AUC=0.913±0.025
#     XGBoost                    Acc=0.783±0.048  F1=0.781±0.048  MCC=0.676±0.071  G-Mean=0.835±0.037  AUC=0.926±0.022
#     VotingSoft                 Acc=0.777±0.050  F1=0.775±0.050  MCC=0.667±0.075  G-Mean=0.831±0.039  AUC=0.928±0.024
#     VotingHard                 Acc=0.792±0.048  F1=0.791±0.047  MCC=0.690±0.073  G-Mean=0.842±0.037  AUC=N/A
#     Stacking                   Acc=0.807±0.032  F1=0.808±0.032  MCC=0.714±0.049  G-Mean=0.854±0.025  AUC=0.932±0.025
#
# ======================================================================
#   Balancer: B5_BorderlineSMOTE  |  shape=(654, 47)
# ======================================================================
#     RandomForest               Acc=0.792±0.061  F1=0.790±0.061  MCC=0.691±0.091  G-Mean=0.843±0.047  AUC=0.924±0.029
#     ExtraTrees                 Acc=0.806±0.059  F1=0.805±0.059  MCC=0.711±0.088  G-Mean=0.853±0.046  AUC=0.933±0.025
#     Bagging                    Acc=0.766±0.059  F1=0.765±0.058  MCC=0.652±0.087  G-Mean=0.823±0.045  AUC=0.904±0.035
#     GradientBoosting           Acc=0.749±0.064  F1=0.748±0.064  MCC=0.626±0.095  G-Mean=0.809±0.049  AUC=0.897±0.036
#     LogisticRegression         Acc=0.587±0.069  F1=0.585±0.067  MCC=0.384±0.105  G-Mean=0.682±0.056  AUC=0.772±0.057
#     RidgeClassifier            Acc=0.595±0.070  F1=0.588±0.068  MCC=0.398±0.108  G-Mean=0.688±0.057  AUC=N/A
#     DecisionTree               Acc=0.711±0.048  F1=0.711±0.049  MCC=0.569±0.071  G-Mean=0.780±0.037  AUC=0.786±0.035
#     NaiveBayes                 Acc=0.557±0.036  F1=0.539±0.043  MCC=0.346±0.056  G-Mean=0.658±0.030  AUC=0.716±0.040
#     Perceptron                 Acc=0.547±0.053  F1=0.530±0.067  MCC=0.336±0.077  G-Mean=0.650±0.044  AUC=N/A
#     SGDClassifier              Acc=0.547±0.043  F1=0.538±0.047  MCC=0.337±0.066  G-Mean=0.651±0.034  AUC=N/A
#     PassiveAggressive          Acc=0.531±0.063  F1=0.515±0.066  MCC=0.305±0.097  G-Mean=0.637±0.051  AUC=N/A
#     LDA                        Acc=0.598±0.066  F1=0.595±0.063  MCC=0.401±0.100  G-Mean=0.691±0.053  AUC=0.771±0.058
#     QDA                        Acc=0.710±0.065  F1=0.708±0.063  MCC=0.569±0.099  G-Mean=0.779±0.050  AUC=0.863±0.046
#     LightGBM                   Acc=0.803±0.061  F1=0.802±0.060  MCC=0.706±0.091  G-Mean=0.851±0.047  AUC=0.922±0.036
#     XGBoost                    Acc=0.786±0.057  F1=0.785±0.056  MCC=0.682±0.084  G-Mean=0.838±0.044  AUC=0.921±0.030
#     VotingSoft                 Acc=0.794±0.072  F1=0.792±0.072  MCC=0.693±0.108  G-Mean=0.844±0.056  AUC=0.931±0.030
#     VotingHard                 Acc=0.808±0.064  F1=0.806±0.064  MCC=0.713±0.095  G-Mean=0.854±0.049  AUC=N/A
#     Stacking                   Acc=0.818±0.053  F1=0.817±0.053  MCC=0.729±0.080  G-Mean=0.862±0.041  AUC=0.931±0.029
#
# ======================================================================
#   Balancer: B6_TomekLinks  |  shape=(369, 47)
# ======================================================================
#     RandomForest               Acc=0.702±0.059  F1=0.641±0.068  MCC=0.489±0.102  G-Mean=0.720±0.050  AUC=0.823±0.057
#     ExtraTrees                 Acc=0.707±0.064  F1=0.651±0.076  MCC=0.496±0.111  G-Mean=0.726±0.058  AUC=0.819±0.056
#     Bagging                    Acc=0.618±0.090  F1=0.546±0.118  MCC=0.337±0.173  G-Mean=0.645±0.092  AUC=0.768±0.077
#     GradientBoosting           Acc=0.667±0.063  F1=0.613±0.074  MCC=0.436±0.114  G-Mean=0.702±0.057  AUC=0.809±0.045
#     LogisticRegression         Acc=0.639±0.033  F1=0.558±0.039  MCC=0.390±0.057  G-Mean=0.671±0.029  AUC=0.746±0.062
#     RidgeClassifier            Acc=0.637±0.032  F1=0.535±0.042  MCC=0.369±0.057  G-Mean=0.651±0.030  AUC=N/A
#     DecisionTree               Acc=0.580±0.086  F1=0.518±0.084  MCC=0.295±0.142  G-Mean=0.629±0.067  AUC=0.629±0.065
#     NaiveBayes                 Acc=0.664±0.077  F1=0.600±0.089  MCC=0.453±0.123  G-Mean=0.714±0.067  AUC=0.806±0.062
#     Perceptron                 Acc=0.585±0.035  F1=0.490±0.071  MCC=0.295±0.106  G-Mean=0.627±0.064  AUC=N/A
#     SGDClassifier              Acc=0.596±0.062  F1=0.493±0.086  MCC=0.317±0.117  G-Mean=0.626±0.067  AUC=N/A
#     PassiveAggressive          Acc=0.596±0.072  F1=0.497±0.088  MCC=0.325±0.158  G-Mean=0.636±0.077  AUC=N/A
#     LDA                        Acc=0.645±0.039  F1=0.558±0.050  MCC=0.393±0.072  G-Mean=0.671±0.039  AUC=0.751±0.064
#     QDA                        Acc=0.569±0.074  F1=0.451±0.094  MCC=0.226±0.147  G-Mean=0.576±0.067  AUC=0.584±0.052
#     LightGBM                   Acc=0.680±0.049  F1=0.624±0.048  MCC=0.462±0.080  G-Mean=0.716±0.042  AUC=0.810±0.032
#     XGBoost                    Acc=0.664±0.044  F1=0.606±0.058  MCC=0.427±0.082  G-Mean=0.697±0.046  AUC=0.792±0.044
#     VotingSoft                 Acc=0.691±0.057  F1=0.634±0.066  MCC=0.471±0.102  G-Mean=0.715±0.051  AUC=0.825±0.042
#     VotingHard                 Acc=0.713±0.051  F1=0.653±0.061  MCC=0.507±0.088  G-Mean=0.728±0.046  AUC=N/A
#     Stacking                   Acc=0.683±0.068  F1=0.620±0.088  MCC=0.452±0.124  G-Mean=0.705±0.068  AUC=0.818±0.063
#
# ======================================================================
#   Balancer: B7_SMOTETomek  |  shape=(642, 47)
# ======================================================================
#     RandomForest               Acc=0.791±0.037  F1=0.788±0.038  MCC=0.691±0.055  G-Mean=0.841±0.029  AUC=0.929±0.025
#     ExtraTrees                 Acc=0.808±0.036  F1=0.807±0.036  MCC=0.715±0.054  G-Mean=0.855±0.027  AUC=0.933±0.025
#     Bagging                    Acc=0.754±0.048  F1=0.751±0.048  MCC=0.633±0.072  G-Mean=0.812±0.037  AUC=0.897±0.034
#     GradientBoosting           Acc=0.776±0.040  F1=0.773±0.040  MCC=0.668±0.059  G-Mean=0.829±0.031  AUC=0.908±0.024
#     LogisticRegression         Acc=0.625±0.071  F1=0.620±0.074  MCC=0.439±0.107  G-Mean=0.712±0.056  AUC=0.776±0.047
#     RidgeClassifier            Acc=0.606±0.056  F1=0.596±0.057  MCC=0.414±0.085  G-Mean=0.697±0.044  AUC=N/A
#     DecisionTree               Acc=0.685±0.030  F1=0.682±0.030  MCC=0.531±0.043  G-Mean=0.759±0.023  AUC=0.768±0.024
#     NaiveBayes                 Acc=0.601±0.049  F1=0.594±0.052  MCC=0.407±0.072  G-Mean=0.694±0.038  AUC=0.766±0.044
#     Perceptron                 Acc=0.518±0.068  F1=0.499±0.086  MCC=0.296±0.090  G-Mean=0.627±0.054  AUC=N/A
#     SGDClassifier              Acc=0.547±0.064  F1=0.519±0.069  MCC=0.344±0.093  G-Mean=0.650±0.050  AUC=N/A
#     PassiveAggressive          Acc=0.492±0.061  F1=0.475±0.077  MCC=0.253±0.092  G-Mean=0.605±0.050  AUC=N/A
#     LDA                        Acc=0.619±0.058  F1=0.613±0.059  MCC=0.431±0.088  G-Mean=0.707±0.046  AUC=0.783±0.048
#     QDA                        Acc=0.713±0.049  F1=0.713±0.049  MCC=0.573±0.074  G-Mean=0.781±0.038  AUC=0.860±0.022
#     LightGBM                   Acc=0.790±0.041  F1=0.787±0.042  MCC=0.689±0.061  G-Mean=0.840±0.032  AUC=0.921±0.028
#     XGBoost                    Acc=0.790±0.050  F1=0.787±0.051  MCC=0.689±0.077  G-Mean=0.840±0.039  AUC=0.924±0.026
#     VotingSoft                 Acc=0.798±0.035  F1=0.795±0.035  MCC=0.701±0.052  G-Mean=0.846±0.026  AUC=0.933±0.023
#     VotingHard                 Acc=0.804±0.040  F1=0.802±0.041  MCC=0.709±0.059  G-Mean=0.851±0.030  AUC=N/A
#     Stacking                   Acc=0.824±0.041  F1=0.823±0.042  MCC=0.740±0.057  G-Mean=0.866±0.031  AUC=0.937±0.023
#
#
# -- Phase 1 Summary (top 20 by Accuracy) --
#              Balancer       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
# B1_RandomOverSampling         Stacking     0.905     0.906 0.861   0.929 0.973
# B1_RandomOverSampling       ExtraTrees     0.888     0.888 0.834   0.916 0.974
# B1_RandomOverSampling     RandomForest     0.885     0.884 0.831   0.913 0.970
# B1_RandomOverSampling         LightGBM     0.884     0.882 0.828   0.912 0.968
# B1_RandomOverSampling       VotingHard     0.884     0.883 0.828   0.912   NaN
# B1_RandomOverSampling       VotingSoft     0.878     0.877 0.818   0.908 0.972
# B1_RandomOverSampling          XGBoost     0.872     0.870 0.811   0.903 0.967
# B1_RandomOverSampling          Bagging     0.863     0.861 0.798   0.896 0.953
# B1_RandomOverSampling     DecisionTree     0.858     0.855 0.791   0.893 0.898
# B1_RandomOverSampling GradientBoosting     0.853     0.851 0.781   0.889 0.950
#         B7_SMOTETomek         Stacking     0.824     0.823 0.740   0.866 0.937
#    B5_BorderlineSMOTE         Stacking     0.818     0.817 0.729   0.862 0.931
#    B5_BorderlineSMOTE       VotingHard     0.808     0.806 0.713   0.854   NaN
#         B7_SMOTETomek       ExtraTrees     0.808     0.807 0.715   0.855 0.933
#              B4_SMOTE         Stacking     0.807     0.808 0.714   0.854 0.932
#    B5_BorderlineSMOTE       ExtraTrees     0.806     0.805 0.711   0.853 0.933
#         B7_SMOTETomek       VotingHard     0.804     0.802 0.709   0.851   NaN
#    B5_BorderlineSMOTE         LightGBM     0.803     0.802 0.706   0.851 0.922
#              B4_SMOTE       ExtraTrees     0.798     0.798 0.699   0.847 0.929
#         B7_SMOTETomek       VotingSoft     0.798     0.795 0.701   0.846 0.933
#
# -- Phase 1: Best Classifier per Balancer --
#               Balancer Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  B1_RandomOverSampling   Stacking     0.905     0.906 0.861   0.929 0.973
# B2_RandomUnderSampling NaiveBayes     0.587     0.571 0.390   0.682 0.762
#              B3_ADASYN   Stacking     0.788     0.788 0.686   0.839 0.916
#               B4_SMOTE   Stacking     0.807     0.808 0.714   0.854 0.932
#     B5_BorderlineSMOTE   Stacking     0.818     0.817 0.729   0.862 0.931
#          B6_TomekLinks VotingHard     0.713     0.653 0.507   0.728   NaN
#          B7_SMOTETomek   Stacking     0.824     0.823 0.740   0.866 0.937

# %%
def fmt_metric(mean_val, std_val):
    """Format mean±std, returning N/A if None or NaN."""
    try:
        if mean_val is None or std_val is None:
            return "N/A"
        if math.isnan(float(mean_val)) or math.isnan(float(std_val)):
            return "N/A"
        return f"{float(mean_val):.3f}\u00b1{float(std_val):.3f}"  # \u00b1 = ±
    except (TypeError, ValueError):
        return "N/A"

COLUMNS = ["Model",
           f"Accuracy (Mean \u00b1 SD)",
           f"MCC (Mean \u00b1 SD)",
           f"G-Mean (Mean \u00b1 SD)",
           f"F1-Score (Mean \u00b1 SD)",
           f"AUROC (Mean \u00b1 SD)"]

output = io.StringIO()
writer = csv.writer(output)

# %%
for bal_name, bal_df in balanced_datasets.items():
    shape_info = bal_df.shape
    group = phase1_df[phase1_df['Variant'] == bal_name]

    # Section heading
    writer.writerow([f"Balancer: {bal_name}  |  shape={shape_info}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

# ── KEY FIX: save with utf-8-sig (adds BOM so Excel reads ± correctly) ──
with open("Phase1_Balancers_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase1_Balancers_Results.csv")
print("Downloaded: Phase1_Balancers_Results.csv")
# Out:
# Downloaded: Phase1_Balancers_Results.csv

# %% [markdown]
# # ***Experiment 2***

# %%
section_header("PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)")

phase2_rows = []
for fs_name, fs_fn in FEATURE_SELECTORS.items():
    try:
        fs_df = fs_fn(df)
        sub_header(f"Feature Selector: {fs_name}  |  features={fs_df.shape[1]-1}")
        rows = evaluate_dataset(fs_df, label=fs_name, verbose=True)
        phase2_rows.extend(rows)
    except Exception as e:
        print(f"  {fs_name} FAILED: {e}")

phase2_df = pd.DataFrame(phase2_rows).dropna(subset=['Accuracy'])
phase2_df['Phase'] = 'Phase2_FeatureSelectionOnly'
phase2_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 2 Summary (top 20 by Accuracy) --")
p2_show = phase2_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'FeatureSelector'})
print(p2_show[['FeatureSelector','Classifier'] + METRICS].head(20).to_string(index=False))

print("\n-- Phase 2: Best Classifier per Feature Selector --")
best_p2 = (p2_show.groupby('FeatureSelector', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['FeatureSelector','Classifier'] + METRICS])
print(best_p2.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 2 — 5 Feature Selection Variants  (raw unbalanced data, no balancing)
# ################################################################################
#
# ======================================================================
#   Feature Selector: FS1_Correlation  |  features=14
# ======================================================================
#     RandomForest               Acc=0.638±0.065  F1=0.571±0.071  MCC=0.372±0.125  G-Mean=0.667±0.063  AUC=0.801±0.041
#     ExtraTrees                 Acc=0.623±0.045  F1=0.555±0.056  MCC=0.351±0.084  G-Mean=0.658±0.046  AUC=0.791±0.040
#     Bagging                    Acc=0.600±0.057  F1=0.536±0.083  MCC=0.310±0.112  G-Mean=0.641±0.066  AUC=0.771±0.044
#     GradientBoosting           Acc=0.652±0.054  F1=0.592±0.056  MCC=0.419±0.088  G-Mean=0.692±0.042  AUC=0.792±0.047
#     LogisticRegression         Acc=0.622±0.039  F1=0.522±0.077  MCC=0.342±0.082  G-Mean=0.642±0.057  AUC=0.784±0.033
#     RidgeClassifier            Acc=0.628±0.041  F1=0.517±0.084  MCC=0.338±0.094  G-Mean=0.634±0.061  AUC=N/A
#     DecisionTree               Acc=0.560±0.049  F1=0.494±0.055  MCC=0.259±0.083  G-Mean=0.612±0.046  AUC=0.595±0.050
#     NaiveBayes                 Acc=0.622±0.058  F1=0.562±0.063  MCC=0.379±0.092  G-Mean=0.679±0.051  AUC=0.781±0.036
#     Perceptron                 Acc=0.568±0.046  F1=0.433±0.063  MCC=0.290±0.066  G-Mean=0.601±0.051  AUC=N/A
#     SGDClassifier              Acc=0.572±0.072  F1=0.452±0.111  MCC=0.275±0.151  G-Mean=0.613±0.081  AUC=N/A
#     PassiveAggressive          Acc=0.558±0.070  F1=0.472±0.094  MCC=0.289±0.101  G-Mean=0.615±0.069  AUC=N/A
#     LDA                        Acc=0.617±0.034  F1=0.518±0.074  MCC=0.338±0.072  G-Mean=0.642±0.055  AUC=0.784±0.032
#     QDA                        Acc=0.578±0.039  F1=0.499±0.071  MCC=0.285±0.077  G-Mean=0.623±0.054  AUC=0.736±0.043
#     LightGBM                   Acc=0.660±0.065  F1=0.619±0.068  MCC=0.422±0.109  G-Mean=0.704±0.054  AUC=0.797±0.052
#     XGBoost                    Acc=0.635±0.055  F1=0.593±0.057  MCC=0.388±0.088  G-Mean=0.688±0.047  AUC=0.776±0.048
#     VotingSoft                 Acc=0.652±0.059  F1=0.594±0.053  MCC=0.414±0.094  G-Mean=0.691±0.046  AUC=0.813±0.042
#     VotingHard                 Acc=0.653±0.056  F1=0.590±0.074  MCC=0.401±0.109  G-Mean=0.683±0.062  AUC=N/A
#     Stacking                   Acc=0.648±0.044  F1=0.579±0.078  MCC=0.382±0.086  G-Mean=0.669±0.056  AUC=0.795±0.044
#
# ======================================================================
#   Feature Selector: FS2_KBest  |  features=45
# ======================================================================
#     RandomForest               Acc=0.665±0.034  F1=0.593±0.038  MCC=0.420±0.046  G-Mean=0.683±0.020  AUC=0.808±0.047
#     ExtraTrees                 Acc=0.658±0.068  F1=0.579±0.103  MCC=0.404±0.126  G-Mean=0.676±0.073  AUC=0.802±0.052
#     Bagging                    Acc=0.600±0.061  F1=0.517±0.082  MCC=0.302±0.108  G-Mean=0.625±0.061  AUC=0.756±0.048
#     GradientBoosting           Acc=0.650±0.065  F1=0.584±0.050  MCC=0.410±0.090  G-Mean=0.684±0.035  AUC=0.809±0.041
#     LogisticRegression         Acc=0.592±0.056  F1=0.501±0.082  MCC=0.305±0.104  G-Mean=0.627±0.059  AUC=0.714±0.048
#     RidgeClassifier            Acc=0.615±0.046  F1=0.511±0.071  MCC=0.328±0.090  G-Mean=0.632±0.052  AUC=N/A
#     DecisionTree               Acc=0.577±0.066  F1=0.517±0.076  MCC=0.299±0.111  G-Mean=0.632±0.062  AUC=0.633±0.063
#     NaiveBayes                 Acc=0.635±0.077  F1=0.579±0.091  MCC=0.402±0.132  G-Mean=0.693±0.076  AUC=0.780±0.054
#     Perceptron                 Acc=0.538±0.082  F1=0.443±0.094  MCC=0.283±0.109  G-Mean=0.607±0.065  AUC=N/A
#     SGDClassifier              Acc=0.545±0.048  F1=0.429±0.096  MCC=0.210±0.109  G-Mean=0.580±0.069  AUC=N/A
#     PassiveAggressive          Acc=0.502±0.053  F1=0.407±0.086  MCC=0.184±0.117  G-Mean=0.566±0.069  AUC=N/A
#     LDA                        Acc=0.610±0.039  F1=0.519±0.061  MCC=0.333±0.075  G-Mean=0.641±0.044  AUC=0.724±0.039
#     QDA                        Acc=0.580±0.053  F1=0.433±0.076  MCC=0.237±0.105  G-Mean=0.573±0.052  AUC=0.599±0.078
#     LightGBM                   Acc=0.652±0.063  F1=0.578±0.070  MCC=0.404±0.107  G-Mean=0.677±0.057  AUC=0.785±0.053
#     XGBoost                    Acc=0.665±0.068  F1=0.597±0.065  MCC=0.431±0.111  G-Mean=0.693±0.055  AUC=0.790±0.053
#     VotingSoft                 Acc=0.678±0.055  F1=0.608±0.061  MCC=0.448±0.099  G-Mean=0.700±0.051  AUC=0.813±0.049
#     VotingHard                 Acc=0.662±0.042  F1=0.589±0.063  MCC=0.414±0.080  G-Mean=0.680±0.047  AUC=N/A
#     Stacking                   Acc=0.670±0.048  F1=0.591±0.070  MCC=0.422±0.090  G-Mean=0.679±0.053  AUC=0.802±0.058
#
# ======================================================================
#   Feature Selector: FS3_RFE  |  features=24
# ======================================================================
#     RandomForest               Acc=0.683±0.030  F1=0.612±0.057  MCC=0.453±0.048  G-Mean=0.701±0.035  AUC=0.817±0.047
#     ExtraTrees                 Acc=0.685±0.036  F1=0.621±0.054  MCC=0.458±0.069  G-Mean=0.706±0.043  AUC=0.814±0.044
#     Bagging                    Acc=0.620±0.059  F1=0.530±0.065  MCC=0.341±0.106  G-Mean=0.640±0.049  AUC=0.746±0.055
#     GradientBoosting           Acc=0.645±0.042  F1=0.574±0.060  MCC=0.391±0.077  G-Mean=0.671±0.046  AUC=0.777±0.044
#     LogisticRegression         Acc=0.610±0.039  F1=0.515±0.055  MCC=0.321±0.064  G-Mean=0.632±0.036  AUC=0.752±0.031
#     RidgeClassifier            Acc=0.605±0.043  F1=0.486±0.090  MCC=0.296±0.090  G-Mean=0.613±0.058  AUC=N/A
#     DecisionTree               Acc=0.605±0.072  F1=0.553±0.076  MCC=0.356±0.110  G-Mean=0.666±0.057  AUC=0.663±0.064
#     NaiveBayes                 Acc=0.668±0.054  F1=0.619±0.060  MCC=0.463±0.078  G-Mean=0.725±0.048  AUC=0.808±0.033
#     Perceptron                 Acc=0.550±0.067  F1=0.406±0.088  MCC=0.217±0.151  G-Mean=0.568±0.062  AUC=N/A
#     SGDClassifier              Acc=0.555±0.051  F1=0.408±0.072  MCC=0.234±0.097  G-Mean=0.578±0.055  AUC=N/A
#     PassiveAggressive          Acc=0.508±0.083  F1=0.388±0.088  MCC=0.215±0.156  G-Mean=0.571±0.080  AUC=N/A
#     LDA                        Acc=0.610±0.037  F1=0.517±0.066  MCC=0.323±0.064  G-Mean=0.635±0.044  AUC=0.754±0.035
#     QDA                        Acc=0.565±0.059  F1=0.472±0.080  MCC=0.250±0.113  G-Mean=0.600±0.062  AUC=0.647±0.084
#     LightGBM                   Acc=0.665±0.078  F1=0.600±0.099  MCC=0.429±0.134  G-Mean=0.694±0.075  AUC=0.774±0.053
#     XGBoost                    Acc=0.660±0.068  F1=0.594±0.078  MCC=0.424±0.109  G-Mean=0.691±0.057  AUC=0.775±0.068
#     VotingSoft                 Acc=0.678±0.058  F1=0.612±0.072  MCC=0.450±0.099  G-Mean=0.701±0.054  AUC=0.808±0.047
#     VotingHard                 Acc=0.680±0.042  F1=0.609±0.069  MCC=0.448±0.076  G-Mean=0.698±0.048  AUC=N/A
#     Stacking                   Acc=0.672±0.042  F1=0.588±0.075  MCC=0.427±0.077  G-Mean=0.678±0.047  AUC=0.807±0.033
#
# ======================================================================
#   Feature Selector: FS4_MutualInfo  |  features=31
# ======================================================================
#     RandomForest               Acc=0.660±0.055  F1=0.581±0.054  MCC=0.414±0.100  G-Mean=0.680±0.045  AUC=0.801±0.051
#     ExtraTrees                 Acc=0.662±0.056  F1=0.593±0.082  MCC=0.427±0.105  G-Mean=0.691±0.060  AUC=0.804±0.048
#     Bagging                    Acc=0.615±0.082  F1=0.532±0.096  MCC=0.339±0.140  G-Mean=0.646±0.075  AUC=0.747±0.061
#     GradientBoosting           Acc=0.650±0.055  F1=0.587±0.077  MCC=0.404±0.098  G-Mean=0.686±0.061  AUC=0.787±0.048
#     LogisticRegression         Acc=0.620±0.048  F1=0.532±0.077  MCC=0.352±0.080  G-Mean=0.649±0.053  AUC=0.737±0.032
#     RidgeClassifier            Acc=0.620±0.042  F1=0.517±0.072  MCC=0.332±0.081  G-Mean=0.633±0.055  AUC=N/A
#     DecisionTree               Acc=0.558±0.042  F1=0.497±0.049  MCC=0.263±0.070  G-Mean=0.615±0.040  AUC=0.615±0.046
#     NaiveBayes                 Acc=0.628±0.067  F1=0.569±0.079  MCC=0.391±0.107  G-Mean=0.686±0.061  AUC=0.788±0.043
#     Perceptron                 Acc=0.578±0.060  F1=0.498±0.074  MCC=0.315±0.087  G-Mean=0.633±0.053  AUC=N/A
#     SGDClassifier              Acc=0.537±0.046  F1=0.424±0.095  MCC=0.229±0.140  G-Mean=0.595±0.070  AUC=N/A
#     PassiveAggressive          Acc=0.518±0.072  F1=0.411±0.078  MCC=0.217±0.139  G-Mean=0.576±0.069  AUC=N/A
#     LDA                        Acc=0.620±0.038  F1=0.537±0.063  MCC=0.353±0.066  G-Mean=0.653±0.045  AUC=0.738±0.035
#     QDA                        Acc=0.560±0.080  F1=0.470±0.088  MCC=0.245±0.141  G-Mean=0.596±0.076  AUC=0.622±0.117
#     LightGBM                   Acc=0.665±0.065  F1=0.600±0.080  MCC=0.437±0.110  G-Mean=0.700±0.063  AUC=0.798±0.048
#     XGBoost                    Acc=0.650±0.062  F1=0.591±0.071  MCC=0.409±0.096  G-Mean=0.687±0.053  AUC=0.769±0.049
#     VotingSoft                 Acc=0.660±0.053  F1=0.588±0.070  MCC=0.420±0.088  G-Mean=0.687±0.054  AUC=0.811±0.047
#     VotingHard                 Acc=0.665±0.053  F1=0.586±0.066  MCC=0.427±0.095  G-Mean=0.687±0.050  AUC=N/A
#     Stacking                   Acc=0.678±0.060  F1=0.587±0.067  MCC=0.436±0.113  G-Mean=0.682±0.052  AUC=0.800±0.057
#
# ======================================================================
#   Feature Selector: FS5_RFImportance  |  features=45
# ======================================================================
#     RandomForest               Acc=0.667±0.051  F1=0.583±0.078  MCC=0.423±0.093  G-Mean=0.681±0.054  AUC=0.805±0.054
#     ExtraTrees                 Acc=0.673±0.061  F1=0.601±0.094  MCC=0.432±0.116  G-Mean=0.690±0.066  AUC=0.806±0.048
#     Bagging                    Acc=0.610±0.042  F1=0.523±0.074  MCC=0.316±0.085  G-Mean=0.633±0.053  AUC=0.751±0.062
#     GradientBoosting           Acc=0.655±0.047  F1=0.585±0.054  MCC=0.411±0.076  G-Mean=0.684±0.038  AUC=0.807±0.042
#     LogisticRegression         Acc=0.620±0.046  F1=0.540±0.062  MCC=0.349±0.081  G-Mean=0.652±0.040  AUC=0.723±0.041
#     RidgeClassifier            Acc=0.628±0.048  F1=0.534±0.063  MCC=0.351±0.090  G-Mean=0.647±0.047  AUC=N/A
#     DecisionTree               Acc=0.568±0.072  F1=0.497±0.088  MCC=0.276±0.116  G-Mean=0.616±0.065  AUC=0.618±0.064
#     NaiveBayes                 Acc=0.635±0.069  F1=0.576±0.080  MCC=0.401±0.120  G-Mean=0.693±0.069  AUC=0.783±0.052
#     Perceptron                 Acc=0.565±0.056  F1=0.446±0.085  MCC=0.271±0.104  G-Mean=0.602±0.068  AUC=N/A
#     SGDClassifier              Acc=0.580±0.047  F1=0.487±0.066  MCC=0.287±0.085  G-Mean=0.619±0.043  AUC=N/A
#     PassiveAggressive          Acc=0.485±0.058  F1=0.393±0.073  MCC=0.169±0.107  G-Mean=0.556±0.068  AUC=N/A
#     LDA                        Acc=0.625±0.060  F1=0.542±0.078  MCC=0.358±0.106  G-Mean=0.655±0.058  AUC=0.732±0.035
#     QDA                        Acc=0.602±0.053  F1=0.466±0.066  MCC=0.284±0.104  G-Mean=0.598±0.050  AUC=0.617±0.088
#     LightGBM                   Acc=0.658±0.040  F1=0.590±0.043  MCC=0.418±0.066  G-Mean=0.688±0.035  AUC=0.786±0.049
#     XGBoost                    Acc=0.645±0.058  F1=0.585±0.067  MCC=0.395±0.102  G-Mean=0.680±0.055  AUC=0.796±0.046
#     VotingSoft                 Acc=0.682±0.047  F1=0.619±0.050  MCC=0.454±0.078  G-Mean=0.702±0.039  AUC=0.818±0.047
#     VotingHard                 Acc=0.678±0.041  F1=0.601±0.070  MCC=0.443±0.078  G-Mean=0.692±0.049  AUC=N/A
#     Stacking                   Acc=0.662±0.050  F1=0.579±0.071  MCC=0.407±0.094  G-Mean=0.670±0.051  AUC=0.805±0.054
#
#
# -- Phase 2 Summary (top 20 by Accuracy) --
#  FeatureSelector   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#          FS3_RFE   ExtraTrees     0.685     0.621 0.458   0.706 0.814
#          FS3_RFE RandomForest     0.683     0.612 0.453   0.701 0.817
# FS5_RFImportance   VotingSoft     0.682     0.619 0.454   0.702 0.818
#          FS3_RFE   VotingHard     0.680     0.609 0.448   0.698   NaN
# FS5_RFImportance   VotingHard     0.678     0.601 0.443   0.692   NaN
#          FS3_RFE   VotingSoft     0.678     0.612 0.450   0.701 0.808
#        FS2_KBest   VotingSoft     0.678     0.608 0.448   0.700 0.813
#   FS4_MutualInfo     Stacking     0.678     0.587 0.436   0.682 0.800
# FS5_RFImportance   ExtraTrees     0.673     0.601 0.432   0.690 0.806
#          FS3_RFE     Stacking     0.672     0.588 0.427   0.678 0.807
#        FS2_KBest     Stacking     0.670     0.591 0.422   0.679 0.802
#          FS3_RFE   NaiveBayes     0.668     0.619 0.463   0.725 0.808
# FS5_RFImportance RandomForest     0.667     0.583 0.423   0.681 0.805
#        FS2_KBest      XGBoost     0.665     0.597 0.431   0.693 0.790
#          FS3_RFE     LightGBM     0.665     0.600 0.429   0.694 0.774
#   FS4_MutualInfo     LightGBM     0.665     0.600 0.437   0.700 0.798
#        FS2_KBest RandomForest     0.665     0.593 0.420   0.683 0.808
#   FS4_MutualInfo   VotingHard     0.665     0.586 0.427   0.687   NaN
#        FS2_KBest   VotingHard     0.662     0.589 0.414   0.680   NaN
#   FS4_MutualInfo   ExtraTrees     0.662     0.593 0.427   0.691 0.804
#
# -- Phase 2: Best Classifier per Feature Selector --
#  FeatureSelector Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#  FS1_Correlation   LightGBM     0.660     0.619 0.422   0.704 0.797
#        FS2_KBest VotingSoft     0.678     0.608 0.448   0.700 0.813
#          FS3_RFE ExtraTrees     0.685     0.621 0.458   0.706 0.814
#   FS4_MutualInfo   Stacking     0.678     0.587 0.436   0.682 0.800
# FS5_RFImportance VotingSoft     0.682     0.619 0.454   0.702 0.818

# %%
phase2_only = phase2_df[phase2_df['Phase'] == 'Phase2_FeatureSelectionOnly'].copy()

output = io.StringIO()
writer = csv.writer(output)

for fs_name in phase2_only['Variant'].unique():
    group = phase2_only[phase2_only['Variant'] == fs_name]

    try:
        fs_df = FEATURE_SELECTORS[fs_name](df)
        n_features = fs_df.shape[1] - 1
    except:
        n_features = "N/A"

    writer.writerow([f"Feature Selector: {fs_name}  |  features={n_features}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

with open("Phase2_FeatureSelection_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase2_FeatureSelection_Results.csv")
print(" Downloaded: Phase2_FeatureSelection_Results.csv")
# Out:
# ✅ Downloaded: Phase2_FeatureSelection_Results.csv

# %% [markdown]
# # ***Experiment 3***

# %%
section_header("PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)")

phase3_rows = []
for bal_name, bal_df in balanced_datasets.items():
    for fs_name, fs_fn in FEATURE_SELECTORS.items():
        combo = f"{bal_name} + {fs_name}"
        try:
            fs_df = fs_fn(bal_df)
            sub_header(f"Combo: {combo}  |  shape={fs_df.shape}")
            rows = evaluate_dataset(fs_df, label=combo, verbose=True)
            phase3_rows.extend(rows)
        except Exception as e:
            print(f"  {combo} FAILED: {e}")

phase3_df = pd.DataFrame(phase3_rows).dropna(subset=['Accuracy'])
phase3_df['Phase'] = 'Phase3_Balancing+FS'
phase3_df.rename(columns={'Label': 'Variant'}, inplace=True)

print("\n\n-- Phase 3 Summary (top 30 combos by Accuracy) --")
p3_show = phase3_df.sort_values('Accuracy', ascending=False).rename(
    columns={'Variant': 'Balancer+FS'})
print(p3_show[['Balancer+FS','Classifier'] + METRICS].head(30).to_string(index=False))

print("\n-- Phase 3: Best Classifier per Balancer+FS combo --")
best_p3 = (p3_show.groupby('Balancer+FS', group_keys=False)
           .apply(lambda g: g.nlargest(1, 'Accuracy'))
           [['Balancer+FS','Classifier'] + METRICS]
           .sort_values('Accuracy', ascending=False))
print(best_p3.to_string(index=False))
# Out:
# ################################################################################
#   PHASE 3 — Balancing x Feature Selection  (7 x 5 = 35 combos)
# ################################################################################
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS1_Correlation  |  shape=(654, 14)
# ======================================================================
#     RandomForest               Acc=0.847±0.042  F1=0.845±0.044  MCC=0.775±0.060  G-Mean=0.884±0.032  AUC=0.957±0.015
#     ExtraTrees                 Acc=0.850±0.044  F1=0.848±0.046  MCC=0.779±0.065  G-Mean=0.887±0.034  AUC=0.964±0.013
#     Bagging                    Acc=0.843±0.045  F1=0.840±0.048  MCC=0.769±0.064  G-Mean=0.881±0.034  AUC=0.942±0.016
#     GradientBoosting           Acc=0.794±0.062  F1=0.793±0.062  MCC=0.693±0.091  G-Mean=0.843±0.047  AUC=0.914±0.028
#     LogisticRegression         Acc=0.613±0.054  F1=0.603±0.050  MCC=0.427±0.088  G-Mean=0.703±0.043  AUC=0.795±0.044
#     RidgeClassifier            Acc=0.593±0.055  F1=0.575±0.053  MCC=0.402±0.088  G-Mean=0.687±0.044  AUC=N/A
#     DecisionTree               Acc=0.843±0.060  F1=0.839±0.065  MCC=0.770±0.086  G-Mean=0.881±0.046  AUC=0.894±0.047
#     NaiveBayes                 Acc=0.612±0.045  F1=0.602±0.043  MCC=0.423±0.070  G-Mean=0.702±0.036  AUC=0.792±0.048
#     Perceptron                 Acc=0.541±0.093  F1=0.486±0.109  MCC=0.354±0.145  G-Mean=0.645±0.076  AUC=N/A
#     SGDClassifier              Acc=0.555±0.062  F1=0.530±0.070  MCC=0.361±0.091  G-Mean=0.658±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.494±0.069  F1=0.451±0.083  MCC=0.267±0.106  G-Mean=0.606±0.056  AUC=N/A
#     LDA                        Acc=0.604±0.057  F1=0.593±0.055  MCC=0.414±0.089  G-Mean=0.695±0.045  AUC=0.796±0.044
#     QDA                        Acc=0.650±0.051  F1=0.645±0.054  MCC=0.478±0.077  G-Mean=0.732±0.040  AUC=0.813±0.041
#     LightGBM                   Acc=0.830±0.045  F1=0.826±0.048  MCC=0.750±0.063  G-Mean=0.872±0.034  AUC=0.939±0.024
#     XGBoost                    Acc=0.841±0.043  F1=0.839±0.044  MCC=0.766±0.063  G-Mean=0.880±0.033  AUC=0.947±0.024
#     VotingSoft                 Acc=0.846±0.046  F1=0.843±0.047  MCC=0.772±0.067  G-Mean=0.883±0.035  AUC=0.957±0.016
#     VotingHard                 Acc=0.844±0.041  F1=0.841±0.043  MCC=0.770±0.060  G-Mean=0.882±0.031  AUC=N/A
#     Stacking                   Acc=0.866±0.037  F1=0.865±0.037  MCC=0.800±0.055  G-Mean=0.898±0.028  AUC=0.965±0.014
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS2_KBest  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.876±0.036  F1=0.875±0.038  MCC=0.818±0.053  G-Mean=0.907±0.028  AUC=0.969±0.014
#     ExtraTrees                 Acc=0.889±0.046  F1=0.887±0.047  MCC=0.835±0.068  G-Mean=0.916±0.035  AUC=0.975±0.012
#     Bagging                    Acc=0.856±0.057  F1=0.854±0.061  MCC=0.788±0.082  G-Mean=0.891±0.043  AUC=0.957±0.019
#     GradientBoosting           Acc=0.858±0.035  F1=0.855±0.037  MCC=0.790±0.051  G-Mean=0.892±0.027  AUC=0.951±0.012
#     LogisticRegression         Acc=0.609±0.045  F1=0.602±0.044  MCC=0.418±0.066  G-Mean=0.699±0.035  AUC=0.790±0.046
#     RidgeClassifier            Acc=0.616±0.049  F1=0.605±0.048  MCC=0.431±0.075  G-Mean=0.705±0.039  AUC=N/A
#     DecisionTree               Acc=0.853±0.035  F1=0.851±0.035  MCC=0.785±0.052  G-Mean=0.889±0.027  AUC=0.895±0.028
#     NaiveBayes                 Acc=0.627±0.053  F1=0.618±0.051  MCC=0.447±0.081  G-Mean=0.714±0.042  AUC=0.789±0.044
#     Perceptron                 Acc=0.564±0.045  F1=0.544±0.057  MCC=0.364±0.064  G-Mean=0.664±0.035  AUC=N/A
#     SGDClassifier              Acc=0.573±0.047  F1=0.559±0.049  MCC=0.384±0.063  G-Mean=0.672±0.036  AUC=N/A
#     PassiveAggressive          Acc=0.540±0.087  F1=0.520±0.084  MCC=0.332±0.141  G-Mean=0.644±0.070  AUC=N/A
#     LDA                        Acc=0.624±0.062  F1=0.616±0.062  MCC=0.442±0.093  G-Mean=0.711±0.049  AUC=0.793±0.046
#     QDA                        Acc=0.783±0.047  F1=0.784±0.047  MCC=0.678±0.070  G-Mean=0.835±0.036  AUC=0.916±0.024
#     LightGBM                   Acc=0.881±0.040  F1=0.878±0.044  MCC=0.825±0.056  G-Mean=0.910±0.030  AUC=0.967±0.014
#     XGBoost                    Acc=0.879±0.033  F1=0.877±0.034  MCC=0.822±0.047  G-Mean=0.909±0.025  AUC=0.967±0.011
#     VotingSoft                 Acc=0.884±0.038  F1=0.882±0.040  MCC=0.829±0.056  G-Mean=0.912±0.029  AUC=0.972±0.012
#     VotingHard                 Acc=0.884±0.045  F1=0.882±0.047  MCC=0.829±0.067  G-Mean=0.912±0.034  AUC=N/A
#     Stacking                   Acc=0.905±0.045  F1=0.906±0.045  MCC=0.861±0.068  G-Mean=0.929±0.034  AUC=0.973±0.016
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS3_RFE  |  shape=(654, 25)
# ======================================================================
#     RandomForest               Acc=0.870±0.043  F1=0.868±0.044  MCC=0.809±0.064  G-Mean=0.902±0.033  AUC=0.969±0.017
#     ExtraTrees                 Acc=0.884±0.041  F1=0.883±0.042  MCC=0.828±0.060  G-Mean=0.912±0.031  AUC=0.975±0.012
#     Bagging                    Acc=0.844±0.032  F1=0.840±0.034  MCC=0.772±0.047  G-Mean=0.882±0.025  AUC=0.952±0.022
#     GradientBoosting           Acc=0.827±0.036  F1=0.825±0.038  MCC=0.743±0.054  G-Mean=0.869±0.028  AUC=0.929±0.025
#     LogisticRegression         Acc=0.596±0.052  F1=0.590±0.053  MCC=0.398±0.078  G-Mean=0.690±0.041  AUC=0.776±0.037
#     RidgeClassifier            Acc=0.615±0.052  F1=0.602±0.054  MCC=0.432±0.080  G-Mean=0.704±0.041  AUC=N/A
#     DecisionTree               Acc=0.830±0.039  F1=0.826±0.039  MCC=0.752±0.059  G-Mean=0.872±0.029  AUC=0.877±0.028
#     NaiveBayes                 Acc=0.647±0.053  F1=0.638±0.051  MCC=0.476±0.083  G-Mean=0.729±0.042  AUC=0.803±0.043
#     Perceptron                 Acc=0.506±0.044  F1=0.459±0.042  MCC=0.291±0.076  G-Mean=0.617±0.036  AUC=N/A
#     SGDClassifier              Acc=0.518±0.059  F1=0.487±0.079  MCC=0.313±0.073  G-Mean=0.626±0.049  AUC=N/A
#     PassiveAggressive          Acc=0.511±0.048  F1=0.458±0.044  MCC=0.294±0.079  G-Mean=0.620±0.038  AUC=N/A
#     LDA                        Acc=0.601±0.040  F1=0.591±0.039  MCC=0.407±0.063  G-Mean=0.693±0.032  AUC=0.776±0.042
#     QDA                        Acc=0.677±0.056  F1=0.675±0.056  MCC=0.520±0.085  G-Mean=0.753±0.044  AUC=0.831±0.032
#     LightGBM                   Acc=0.884±0.032  F1=0.881±0.035  MCC=0.830±0.045  G-Mean=0.912±0.025  AUC=0.957±0.019
#     XGBoost                    Acc=0.869±0.039  F1=0.866±0.040  MCC=0.806±0.057  G-Mean=0.901±0.029  AUC=0.959±0.017
#     VotingSoft                 Acc=0.878±0.044  F1=0.875±0.047  MCC=0.820±0.064  G-Mean=0.908±0.034  AUC=0.969±0.016
#     VotingHard                 Acc=0.879±0.041  F1=0.878±0.042  MCC=0.821±0.062  G-Mean=0.909±0.031  AUC=N/A
#     Stacking                   Acc=0.899±0.049  F1=0.900±0.049  MCC=0.851±0.073  G-Mean=0.924±0.037  AUC=0.976±0.013
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS4_MutualInfo  |  shape=(654, 32)
# ======================================================================
#     RandomForest               Acc=0.860±0.044  F1=0.857±0.045  MCC=0.793±0.064  G-Mean=0.894±0.033  AUC=0.965±0.017
#     ExtraTrees                 Acc=0.867±0.032  F1=0.866±0.032  MCC=0.803±0.048  G-Mean=0.900±0.024  AUC=0.971±0.012
#     Bagging                    Acc=0.857±0.051  F1=0.855±0.053  MCC=0.789±0.074  G-Mean=0.891±0.039  AUC=0.954±0.019
#     GradientBoosting           Acc=0.826±0.033  F1=0.824±0.033  MCC=0.740±0.049  G-Mean=0.868±0.025  AUC=0.933±0.017
#     LogisticRegression         Acc=0.612±0.059  F1=0.608±0.058  MCC=0.420±0.089  G-Mean=0.702±0.046  AUC=0.785±0.050
#     RidgeClassifier            Acc=0.603±0.059  F1=0.586±0.059  MCC=0.414±0.091  G-Mean=0.694±0.047  AUC=N/A
#     DecisionTree               Acc=0.831±0.048  F1=0.827±0.049  MCC=0.751±0.072  G-Mean=0.872±0.036  AUC=0.876±0.032
#     NaiveBayes                 Acc=0.653±0.053  F1=0.646±0.051  MCC=0.485±0.082  G-Mean=0.734±0.042  AUC=0.798±0.046
#     Perceptron                 Acc=0.544±0.061  F1=0.519±0.070  MCC=0.340±0.089  G-Mean=0.648±0.048  AUC=N/A
#     SGDClassifier              Acc=0.515±0.066  F1=0.495±0.077  MCC=0.286±0.096  G-Mean=0.624±0.053  AUC=N/A
#     PassiveAggressive          Acc=0.479±0.068  F1=0.449±0.076  MCC=0.233±0.106  G-Mean=0.594±0.055  AUC=N/A
#     LDA                        Acc=0.609±0.055  F1=0.600±0.053  MCC=0.418±0.085  G-Mean=0.699±0.043  AUC=0.788±0.052
#     QDA                        Acc=0.731±0.041  F1=0.730±0.040  MCC=0.600±0.062  G-Mean=0.795±0.032  AUC=0.869±0.024
#     LightGBM                   Acc=0.860±0.044  F1=0.855±0.048  MCC=0.794±0.063  G-Mean=0.894±0.034  AUC=0.954±0.012
#     XGBoost                    Acc=0.859±0.036  F1=0.857±0.037  MCC=0.792±0.053  G-Mean=0.894±0.027  AUC=0.957±0.016
#     VotingSoft                 Acc=0.872±0.037  F1=0.869±0.039  MCC=0.810±0.055  G-Mean=0.903±0.028  AUC=0.967±0.014
#     VotingHard                 Acc=0.861±0.045  F1=0.859±0.046  MCC=0.795±0.066  G-Mean=0.895±0.034  AUC=N/A
#     Stacking                   Acc=0.893±0.032  F1=0.893±0.032  MCC=0.841±0.048  G-Mean=0.919±0.025  AUC=0.971±0.014
#
# ======================================================================
#   Combo: B1_RandomOverSampling + FS5_RFImportance  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.881±0.038  F1=0.879±0.040  MCC=0.824±0.055  G-Mean=0.910±0.029  AUC=0.971±0.014
#     ExtraTrees                 Acc=0.878±0.030  F1=0.877±0.031  MCC=0.818±0.045  G-Mean=0.908±0.023  AUC=0.973±0.011
#     Bagging                    Acc=0.862±0.029  F1=0.860±0.031  MCC=0.798±0.042  G-Mean=0.896±0.022  AUC=0.958±0.021
#     GradientBoosting           Acc=0.859±0.035  F1=0.857±0.036  MCC=0.791±0.050  G-Mean=0.894±0.026  AUC=0.952±0.017
#     LogisticRegression         Acc=0.629±0.058  F1=0.622±0.057  MCC=0.447±0.088  G-Mean=0.715±0.046  AUC=0.799±0.048
#     RidgeClassifier            Acc=0.615±0.045  F1=0.605±0.047  MCC=0.429±0.066  G-Mean=0.704±0.035  AUC=N/A
#     DecisionTree               Acc=0.844±0.035  F1=0.840±0.038  MCC=0.773±0.050  G-Mean=0.882±0.027  AUC=0.888±0.026
#     NaiveBayes                 Acc=0.635±0.054  F1=0.626±0.052  MCC=0.460±0.084  G-Mean=0.720±0.043  AUC=0.789±0.044
#     Perceptron                 Acc=0.578±0.073  F1=0.554±0.074  MCC=0.389±0.114  G-Mean=0.675±0.059  AUC=N/A
#     SGDClassifier              Acc=0.559±0.086  F1=0.534±0.104  MCC=0.359±0.128  G-Mean=0.658±0.070  AUC=N/A
#     PassiveAggressive          Acc=0.528±0.073  F1=0.508±0.080  MCC=0.310±0.113  G-Mean=0.635±0.059  AUC=N/A
#     LDA                        Acc=0.613±0.060  F1=0.606±0.062  MCC=0.424±0.089  G-Mean=0.703±0.047  AUC=0.803±0.048
#     QDA                        Acc=0.789±0.039  F1=0.790±0.039  MCC=0.687±0.060  G-Mean=0.840±0.030  AUC=0.916±0.025
#     LightGBM                   Acc=0.872±0.031  F1=0.869±0.033  MCC=0.811±0.046  G-Mean=0.903±0.024  AUC=0.968±0.011
#     XGBoost                    Acc=0.875±0.034  F1=0.873±0.035  MCC=0.815±0.049  G-Mean=0.905±0.025  AUC=0.968±0.015
#     VotingSoft                 Acc=0.875±0.036  F1=0.873±0.038  MCC=0.816±0.053  G-Mean=0.905±0.027  AUC=0.972±0.011
#     VotingHard                 Acc=0.881±0.033  F1=0.880±0.034  MCC=0.824±0.049  G-Mean=0.910±0.025  AUC=N/A
#     Stacking                   Acc=0.895±0.037  F1=0.895±0.037  MCC=0.844±0.055  G-Mean=0.920±0.028  AUC=0.973±0.015
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS1_Correlation  |  shape=(216, 15)
# ======================================================================
#     RandomForest               Acc=0.606±0.112  F1=0.604±0.107  MCC=0.413±0.169  G-Mean=0.695±0.089  AUC=0.766±0.075
#     ExtraTrees                 Acc=0.592±0.099  F1=0.590±0.098  MCC=0.391±0.148  G-Mean=0.685±0.078  AUC=0.743±0.073
#     Bagging                    Acc=0.546±0.093  F1=0.538±0.101  MCC=0.326±0.141  G-Mean=0.648±0.076  AUC=0.728±0.079
#     GradientBoosting           Acc=0.532±0.094  F1=0.530±0.092  MCC=0.306±0.148  G-Mean=0.639±0.080  AUC=0.735±0.074
#     LogisticRegression         Acc=0.550±0.109  F1=0.538±0.112  MCC=0.332±0.170  G-Mean=0.651±0.090  AUC=0.724±0.091
#     RidgeClassifier            Acc=0.550±0.091  F1=0.535±0.095  MCC=0.334±0.142  G-Mean=0.653±0.075  AUC=N/A
#     DecisionTree               Acc=0.503±0.148  F1=0.501±0.141  MCC=0.262±0.229  G-Mean=0.612±0.123  AUC=0.610±0.116
#     NaiveBayes                 Acc=0.569±0.065  F1=0.552±0.064  MCC=0.361±0.103  G-Mean=0.667±0.051  AUC=0.754±0.073
#     Perceptron                 Acc=0.522±0.117  F1=0.482±0.130  MCC=0.315±0.186  G-Mean=0.627±0.097  AUC=N/A
#     SGDClassifier              Acc=0.466±0.123  F1=0.425±0.130  MCC=0.223±0.193  G-Mean=0.583±0.099  AUC=N/A
#     PassiveAggressive          Acc=0.448±0.104  F1=0.396±0.141  MCC=0.177±0.167  G-Mean=0.564±0.087  AUC=N/A
#     LDA                        Acc=0.568±0.107  F1=0.559±0.108  MCC=0.359±0.165  G-Mean=0.667±0.087  AUC=0.725±0.095
#     QDA                        Acc=0.541±0.066  F1=0.529±0.066  MCC=0.322±0.099  G-Mean=0.646±0.053  AUC=0.706±0.069
#     LightGBM                   Acc=0.577±0.110  F1=0.568±0.109  MCC=0.373±0.170  G-Mean=0.673±0.089  AUC=0.755±0.090
#     XGBoost                    Acc=0.560±0.073  F1=0.559±0.079  MCC=0.347±0.112  G-Mean=0.661±0.061  AUC=0.733±0.074
#     VotingSoft                 Acc=0.578±0.112  F1=0.576±0.110  MCC=0.376±0.174  G-Mean=0.675±0.091  AUC=0.765±0.083
#     VotingHard                 Acc=0.601±0.102  F1=0.598±0.097  MCC=0.405±0.153  G-Mean=0.691±0.081  AUC=N/A
#     Stacking                   Acc=0.587±0.105  F1=0.582±0.103  MCC=0.389±0.164  G-Mean=0.681±0.085  AUC=0.761±0.076
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS2_KBest  |  shape=(216, 46)
# ======================================================================
#     RandomForest               Acc=0.560±0.104  F1=0.553±0.107  MCC=0.346±0.159  G-Mean=0.660±0.084  AUC=0.772±0.078
#     ExtraTrees                 Acc=0.574±0.099  F1=0.566±0.104  MCC=0.372±0.153  G-Mean=0.671±0.080  AUC=0.767±0.086
#     Bagging                    Acc=0.514±0.089  F1=0.512±0.088  MCC=0.278±0.140  G-Mean=0.624±0.073  AUC=0.721±0.084
#     GradientBoosting           Acc=0.547±0.099  F1=0.538±0.096  MCC=0.328±0.157  G-Mean=0.649±0.081  AUC=0.739±0.057
#     LogisticRegression         Acc=0.513±0.096  F1=0.504±0.098  MCC=0.273±0.147  G-Mean=0.623±0.080  AUC=0.638±0.069
#     RidgeClassifier            Acc=0.495±0.098  F1=0.483±0.098  MCC=0.247±0.151  G-Mean=0.607±0.083  AUC=N/A
#     DecisionTree               Acc=0.459±0.103  F1=0.453±0.106  MCC=0.191±0.159  G-Mean=0.577±0.088  AUC=0.587±0.075
#     NaiveBayes                 Acc=0.587±0.066  F1=0.571±0.065  MCC=0.390±0.104  G-Mean=0.682±0.053  AUC=0.763±0.076
#     Perceptron                 Acc=0.481±0.093  F1=0.468±0.101  MCC=0.228±0.141  G-Mean=0.596±0.074  AUC=N/A
#     SGDClassifier              Acc=0.453±0.101  F1=0.446±0.099  MCC=0.184±0.156  G-Mean=0.571±0.082  AUC=N/A
#     PassiveAggressive          Acc=0.495±0.053  F1=0.477±0.047  MCC=0.253±0.082  G-Mean=0.609±0.040  AUC=N/A
#     LDA                        Acc=0.494±0.105  F1=0.487±0.106  MCC=0.245±0.162  G-Mean=0.607±0.089  AUC=0.640±0.076
#     QDA                        Acc=0.445±0.070  F1=0.420±0.086  MCC=0.178±0.107  G-Mean=0.567±0.059  AUC=0.596±0.058
#     LightGBM                   Acc=0.536±0.107  F1=0.523±0.109  MCC=0.313±0.166  G-Mean=0.641±0.088  AUC=0.742±0.075
#     XGBoost                    Acc=0.546±0.112  F1=0.539±0.111  MCC=0.325±0.171  G-Mean=0.648±0.090  AUC=0.743±0.066
#     VotingSoft                 Acc=0.564±0.111  F1=0.550±0.106  MCC=0.356±0.175  G-Mean=0.663±0.090  AUC=0.761±0.081
#     VotingHard                 Acc=0.574±0.115  F1=0.564±0.112  MCC=0.369±0.176  G-Mean=0.671±0.092  AUC=N/A
#     Stacking                   Acc=0.555±0.122  F1=0.549±0.115  MCC=0.340±0.189  G-Mean=0.656±0.098  AUC=0.754±0.082
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS3_RFE  |  shape=(216, 25)
# ======================================================================
#     RandomForest               Acc=0.611±0.110  F1=0.611±0.109  MCC=0.423±0.165  G-Mean=0.701±0.086  AUC=0.783±0.081
#     ExtraTrees                 Acc=0.611±0.118  F1=0.611±0.118  MCC=0.426±0.181  G-Mean=0.701±0.092  AUC=0.787±0.073
#     Bagging                    Acc=0.532±0.144  F1=0.524±0.147  MCC=0.305±0.221  G-Mean=0.636±0.115  AUC=0.743±0.092
#     GradientBoosting           Acc=0.537±0.100  F1=0.526±0.099  MCC=0.315±0.155  G-Mean=0.642±0.080  AUC=0.745±0.074
#     LogisticRegression         Acc=0.518±0.067  F1=0.510±0.067  MCC=0.284±0.107  G-Mean=0.626±0.057  AUC=0.690±0.068
#     RidgeClassifier            Acc=0.500±0.079  F1=0.483±0.087  MCC=0.257±0.125  G-Mean=0.610±0.068  AUC=N/A
#     DecisionTree               Acc=0.523±0.147  F1=0.519±0.148  MCC=0.288±0.223  G-Mean=0.628±0.119  AUC=0.631±0.116
#     NaiveBayes                 Acc=0.574±0.100  F1=0.563±0.103  MCC=0.373±0.156  G-Mean=0.672±0.079  AUC=0.777±0.073
#     Perceptron                 Acc=0.444±0.107  F1=0.373±0.094  MCC=0.189±0.186  G-Mean=0.563±0.090  AUC=N/A
#     SGDClassifier              Acc=0.500±0.093  F1=0.490±0.091  MCC=0.259±0.144  G-Mean=0.611±0.075  AUC=N/A
#     PassiveAggressive          Acc=0.449±0.056  F1=0.410±0.081  MCC=0.181±0.093  G-Mean=0.565±0.049  AUC=N/A
#     LDA                        Acc=0.509±0.069  F1=0.499±0.075  MCC=0.269±0.107  G-Mean=0.618±0.059  AUC=0.695±0.062
#     QDA                        Acc=0.471±0.096  F1=0.469±0.106  MCC=0.214±0.149  G-Mean=0.588±0.081  AUC=0.655±0.051
#     LightGBM                   Acc=0.575±0.108  F1=0.567±0.110  MCC=0.368±0.164  G-Mean=0.671±0.086  AUC=0.751±0.079
#     XGBoost                    Acc=0.560±0.091  F1=0.550±0.093  MCC=0.347±0.139  G-Mean=0.660±0.072  AUC=0.748±0.082
#     VotingSoft                 Acc=0.569±0.101  F1=0.562±0.103  MCC=0.361±0.153  G-Mean=0.668±0.080  AUC=0.770±0.078
#     VotingHard                 Acc=0.611±0.115  F1=0.610±0.115  MCC=0.424±0.172  G-Mean=0.701±0.090  AUC=N/A
#     Stacking                   Acc=0.588±0.133  F1=0.586±0.133  MCC=0.389±0.205  G-Mean=0.681±0.105  AUC=0.768±0.086
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS4_MutualInfo  |  shape=(216, 32)
# ======================================================================
#     RandomForest               Acc=0.588±0.109  F1=0.588±0.109  MCC=0.393±0.171  G-Mean=0.684±0.086  AUC=0.779±0.088
#     ExtraTrees                 Acc=0.587±0.094  F1=0.589±0.094  MCC=0.386±0.141  G-Mean=0.682±0.075  AUC=0.766±0.083
#     Bagging                    Acc=0.514±0.077  F1=0.510±0.077  MCC=0.280±0.119  G-Mean=0.625±0.064  AUC=0.731±0.072
#     GradientBoosting           Acc=0.555±0.108  F1=0.548±0.102  MCC=0.338±0.171  G-Mean=0.655±0.088  AUC=0.754±0.071
#     LogisticRegression         Acc=0.485±0.100  F1=0.477±0.098  MCC=0.229±0.152  G-Mean=0.598±0.084  AUC=0.665±0.078
#     RidgeClassifier            Acc=0.485±0.086  F1=0.470±0.087  MCC=0.233±0.133  G-Mean=0.599±0.073  AUC=N/A
#     DecisionTree               Acc=0.459±0.075  F1=0.451±0.081  MCC=0.192±0.113  G-Mean=0.578±0.063  AUC=0.588±0.059
#     NaiveBayes                 Acc=0.582±0.114  F1=0.569±0.111  MCC=0.380±0.175  G-Mean=0.676±0.091  AUC=0.762±0.082
#     Perceptron                 Acc=0.472±0.085  F1=0.452±0.090  MCC=0.225±0.137  G-Mean=0.590±0.068  AUC=N/A
#     SGDClassifier              Acc=0.439±0.118  F1=0.421±0.122  MCC=0.165±0.189  G-Mean=0.561±0.102  AUC=N/A
#     PassiveAggressive          Acc=0.462±0.084  F1=0.432±0.096  MCC=0.203±0.133  G-Mean=0.576±0.071  AUC=N/A
#     LDA                        Acc=0.471±0.090  F1=0.458±0.091  MCC=0.210±0.138  G-Mean=0.587±0.077  AUC=0.677±0.077
#     QDA                        Acc=0.449±0.042  F1=0.445±0.049  MCC=0.179±0.061  G-Mean=0.570±0.034  AUC=0.618±0.055
#     LightGBM                   Acc=0.560±0.099  F1=0.550±0.097  MCC=0.346±0.152  G-Mean=0.660±0.079  AUC=0.753±0.081
#     XGBoost                    Acc=0.542±0.117  F1=0.535±0.120  MCC=0.319±0.183  G-Mean=0.645±0.095  AUC=0.742±0.079
#     VotingSoft                 Acc=0.564±0.131  F1=0.556±0.129  MCC=0.351±0.202  G-Mean=0.662±0.106  AUC=0.768±0.081
#     VotingHard                 Acc=0.597±0.119  F1=0.598±0.118  MCC=0.401±0.182  G-Mean=0.690±0.094  AUC=N/A
#     Stacking                   Acc=0.597±0.078  F1=0.595±0.078  MCC=0.407±0.123  G-Mean=0.691±0.063  AUC=0.771±0.079
#
# ======================================================================
#   Combo: B2_RandomUnderSampling + FS5_RFImportance  |  shape=(216, 46)
# ======================================================================
#     RandomForest               Acc=0.592±0.132  F1=0.587±0.134  MCC=0.396±0.202  G-Mean=0.686±0.106  AUC=0.779±0.077
#     ExtraTrees                 Acc=0.583±0.110  F1=0.578±0.111  MCC=0.382±0.169  G-Mean=0.679±0.089  AUC=0.774±0.068
#     Bagging                    Acc=0.491±0.097  F1=0.490±0.095  MCC=0.242±0.149  G-Mean=0.604±0.081  AUC=0.696±0.071
#     GradientBoosting           Acc=0.546±0.124  F1=0.539±0.120  MCC=0.325±0.191  G-Mean=0.648±0.099  AUC=0.743±0.074
#     LogisticRegression         Acc=0.499±0.100  F1=0.490±0.099  MCC=0.252±0.154  G-Mean=0.611±0.084  AUC=0.642±0.065
#     RidgeClassifier            Acc=0.485±0.097  F1=0.475±0.093  MCC=0.232±0.149  G-Mean=0.600±0.082  AUC=N/A
#     DecisionTree               Acc=0.510±0.124  F1=0.503±0.125  MCC=0.266±0.188  G-Mean=0.617±0.101  AUC=0.627±0.092
#     NaiveBayes                 Acc=0.597±0.064  F1=0.580±0.063  MCC=0.403±0.101  G-Mean=0.689±0.052  AUC=0.759±0.072
#     Perceptron                 Acc=0.449±0.084  F1=0.413±0.095  MCC=0.195±0.131  G-Mean=0.571±0.071  AUC=N/A
#     SGDClassifier              Acc=0.476±0.078  F1=0.460±0.087  MCC=0.227±0.116  G-Mean=0.595±0.064  AUC=N/A
#     PassiveAggressive          Acc=0.473±0.070  F1=0.444±0.088  MCC=0.220±0.107  G-Mean=0.590±0.058  AUC=N/A
#     LDA                        Acc=0.490±0.103  F1=0.483±0.101  MCC=0.238±0.158  G-Mean=0.603±0.088  AUC=0.644±0.075
#     QDA                        Acc=0.417±0.076  F1=0.385±0.090  MCC=0.140±0.123  G-Mean=0.545±0.065  AUC=0.590±0.053
#     LightGBM                   Acc=0.555±0.105  F1=0.544±0.103  MCC=0.343±0.167  G-Mean=0.656±0.085  AUC=0.735±0.080
#     XGBoost                    Acc=0.560±0.110  F1=0.553±0.108  MCC=0.347±0.168  G-Mean=0.659±0.089  AUC=0.745±0.063
#     VotingSoft                 Acc=0.564±0.128  F1=0.549±0.122  MCC=0.354±0.199  G-Mean=0.662±0.102  AUC=0.766±0.083
#     VotingHard                 Acc=0.569±0.117  F1=0.561±0.120  MCC=0.362±0.179  G-Mean=0.668±0.094  AUC=N/A
#     Stacking                   Acc=0.560±0.098  F1=0.555±0.096  MCC=0.348±0.152  G-Mean=0.661±0.079  AUC=0.768±0.073
#
# ======================================================================
#   Combo: B3_ADASYN + FS1_Correlation  |  shape=(655, 13)
# ======================================================================
#     RandomForest               Acc=0.708±0.070  F1=0.708±0.070  MCC=0.566±0.105  G-Mean=0.778±0.054  AUC=0.862±0.042
#     ExtraTrees                 Acc=0.719±0.067  F1=0.719±0.066  MCC=0.581±0.099  G-Mean=0.786±0.052  AUC=0.863±0.043
#     Bagging                    Acc=0.653±0.058  F1=0.653±0.058  MCC=0.484±0.086  G-Mean=0.736±0.045  AUC=0.830±0.034
#     GradientBoosting           Acc=0.686±0.071  F1=0.687±0.070  MCC=0.531±0.108  G-Mean=0.760±0.056  AUC=0.841±0.038
#     LogisticRegression         Acc=0.505±0.051  F1=0.492±0.056  MCC=0.265±0.077  G-Mean=0.618±0.042  AUC=0.722±0.033
#     RidgeClassifier            Acc=0.511±0.055  F1=0.493±0.061  MCC=0.278±0.084  G-Mean=0.623±0.044  AUC=N/A
#     DecisionTree               Acc=0.628±0.072  F1=0.627±0.074  MCC=0.446±0.106  G-Mean=0.715±0.056  AUC=0.736±0.053
#     NaiveBayes                 Acc=0.537±0.054  F1=0.523±0.064  MCC=0.319±0.078  G-Mean=0.644±0.043  AUC=0.703±0.046
#     Perceptron                 Acc=0.420±0.062  F1=0.372±0.080  MCC=0.147±0.102  G-Mean=0.545±0.052  AUC=N/A
#     SGDClassifier              Acc=0.444±0.064  F1=0.402±0.077  MCC=0.187±0.111  G-Mean=0.566±0.055  AUC=N/A
#     PassiveAggressive          Acc=0.459±0.083  F1=0.435±0.096  MCC=0.200±0.123  G-Mean=0.579±0.068  AUC=N/A
#     LDA                        Acc=0.510±0.046  F1=0.496±0.051  MCC=0.273±0.070  G-Mean=0.622±0.037  AUC=0.719±0.032
#     QDA                        Acc=0.586±0.036  F1=0.584±0.036  MCC=0.384±0.055  G-Mean=0.683±0.029  AUC=0.756±0.036
#     LightGBM                   Acc=0.690±0.059  F1=0.690±0.059  MCC=0.538±0.088  G-Mean=0.764±0.046  AUC=0.851±0.034
#     XGBoost                    Acc=0.714±0.071  F1=0.716±0.071  MCC=0.575±0.106  G-Mean=0.783±0.055  AUC=0.862±0.041
#     VotingSoft                 Acc=0.711±0.071  F1=0.711±0.071  MCC=0.570±0.105  G-Mean=0.781±0.054  AUC=0.869±0.039
#     VotingHard                 Acc=0.718±0.064  F1=0.718±0.064  MCC=0.579±0.095  G-Mean=0.785±0.050  AUC=N/A
#     Stacking                   Acc=0.708±0.071  F1=0.709±0.071  MCC=0.566±0.105  G-Mean=0.778±0.055  AUC=0.867±0.038
#
# ======================================================================
#   Combo: B3_ADASYN + FS2_KBest  |  shape=(655, 46)
# ======================================================================
#     RandomForest               Acc=0.751±0.055  F1=0.748±0.056  MCC=0.633±0.080  G-Mean=0.811±0.043  AUC=0.907±0.031
#     ExtraTrees                 Acc=0.783±0.046  F1=0.782±0.047  MCC=0.680±0.068  G-Mean=0.836±0.036  AUC=0.917±0.029
#     Bagging                    Acc=0.731±0.039  F1=0.731±0.038  MCC=0.601±0.057  G-Mean=0.796±0.030  AUC=0.875±0.023
#     GradientBoosting           Acc=0.739±0.059  F1=0.739±0.058  MCC=0.612±0.087  G-Mean=0.802±0.045  AUC=0.888±0.037
#     LogisticRegression         Acc=0.522±0.052  F1=0.517±0.054  MCC=0.286±0.078  G-Mean=0.631±0.042  AUC=0.729±0.028
#     RidgeClassifier            Acc=0.530±0.052  F1=0.523±0.054  MCC=0.300±0.079  G-Mean=0.637±0.043  AUC=N/A
#     DecisionTree               Acc=0.661±0.062  F1=0.659±0.064  MCC=0.494±0.093  G-Mean=0.741±0.049  AUC=0.757±0.043
#     NaiveBayes                 Acc=0.534±0.056  F1=0.519±0.062  MCC=0.314±0.083  G-Mean=0.642±0.045  AUC=0.689±0.050
#     Perceptron                 Acc=0.510±0.057  F1=0.497±0.052  MCC=0.278±0.094  G-Mean=0.621±0.047  AUC=N/A
#     SGDClassifier              Acc=0.461±0.036  F1=0.429±0.053  MCC=0.218±0.058  G-Mean=0.583±0.029  AUC=N/A
#     PassiveAggressive          Acc=0.440±0.069  F1=0.427±0.071  MCC=0.165±0.108  G-Mean=0.561±0.058  AUC=N/A
#     LDA                        Acc=0.528±0.046  F1=0.524±0.049  MCC=0.295±0.068  G-Mean=0.636±0.037  AUC=0.732±0.031
#     QDA                        Acc=0.673±0.045  F1=0.670±0.048  MCC=0.513±0.067  G-Mean=0.750±0.035  AUC=0.849±0.033
#     LightGBM                   Acc=0.757±0.055  F1=0.757±0.055  MCC=0.640±0.083  G-Mean=0.816±0.043  AUC=0.907±0.036
#     XGBoost                    Acc=0.760±0.048  F1=0.759±0.049  MCC=0.646±0.070  G-Mean=0.818±0.037  AUC=0.908±0.036
#     VotingSoft                 Acc=0.770±0.054  F1=0.769±0.053  MCC=0.659±0.079  G-Mean=0.825±0.042  AUC=0.918±0.028
#     VotingHard                 Acc=0.774±0.051  F1=0.772±0.052  MCC=0.667±0.074  G-Mean=0.828±0.040  AUC=N/A
#     Stacking                   Acc=0.780±0.045  F1=0.780±0.045  MCC=0.674±0.066  G-Mean=0.833±0.035  AUC=0.919±0.027
#
# ======================================================================
#   Combo: B3_ADASYN + FS3_RFE  |  shape=(655, 25)
# ======================================================================
#     RandomForest               Acc=0.741±0.050  F1=0.738±0.050  MCC=0.618±0.073  G-Mean=0.803±0.038  AUC=0.882±0.028
#     ExtraTrees                 Acc=0.742±0.040  F1=0.741±0.040  MCC=0.618±0.058  G-Mean=0.804±0.031  AUC=0.885±0.018
#     Bagging                    Acc=0.710±0.034  F1=0.708±0.033  MCC=0.570±0.050  G-Mean=0.779±0.027  AUC=0.862±0.022
#     GradientBoosting           Acc=0.721±0.051  F1=0.721±0.051  MCC=0.586±0.076  G-Mean=0.788±0.039  AUC=0.867±0.035
#     LogisticRegression         Acc=0.534±0.045  F1=0.528±0.050  MCC=0.307±0.066  G-Mean=0.641±0.036  AUC=0.711±0.035
#     RidgeClassifier            Acc=0.525±0.050  F1=0.514±0.060  MCC=0.295±0.072  G-Mean=0.634±0.040  AUC=N/A
#     DecisionTree               Acc=0.640±0.026  F1=0.639±0.025  MCC=0.464±0.040  G-Mean=0.725±0.021  AUC=0.739±0.015
#     NaiveBayes                 Acc=0.554±0.049  F1=0.539±0.058  MCC=0.345±0.069  G-Mean=0.658±0.038  AUC=0.712±0.043
#     Perceptron                 Acc=0.461±0.040  F1=0.422±0.068  MCC=0.227±0.046  G-Mean=0.583±0.033  AUC=N/A
#     SGDClassifier              Acc=0.466±0.058  F1=0.438±0.076  MCC=0.217±0.089  G-Mean=0.586±0.048  AUC=N/A
#     PassiveAggressive          Acc=0.467±0.067  F1=0.438±0.075  MCC=0.218±0.103  G-Mean=0.586±0.055  AUC=N/A
#     LDA                        Acc=0.525±0.048  F1=0.518±0.054  MCC=0.293±0.071  G-Mean=0.634±0.039  AUC=0.711±0.036
#     QDA                        Acc=0.606±0.052  F1=0.605±0.051  MCC=0.414±0.080  G-Mean=0.698±0.041  AUC=0.791±0.028
#     LightGBM                   Acc=0.731±0.054  F1=0.731±0.052  MCC=0.602±0.082  G-Mean=0.796±0.042  AUC=0.882±0.029
#     XGBoost                    Acc=0.748±0.036  F1=0.748±0.036  MCC=0.629±0.054  G-Mean=0.809±0.028  AUC=0.897±0.024
#     VotingSoft                 Acc=0.750±0.046  F1=0.749±0.047  MCC=0.631±0.068  G-Mean=0.810±0.036  AUC=0.893±0.026
#     VotingHard                 Acc=0.753±0.050  F1=0.752±0.049  MCC=0.635±0.073  G-Mean=0.812±0.038  AUC=N/A
#     Stacking                   Acc=0.751±0.035  F1=0.751±0.035  MCC=0.633±0.051  G-Mean=0.811±0.027  AUC=0.891±0.020
#
# ======================================================================
#   Combo: B3_ADASYN + FS4_MutualInfo  |  shape=(655, 32)
# ======================================================================
#     RandomForest               Acc=0.745±0.058  F1=0.743±0.059  MCC=0.622±0.084  G-Mean=0.806±0.045  AUC=0.890±0.038
#     ExtraTrees                 Acc=0.763±0.049  F1=0.762±0.050  MCC=0.648±0.073  G-Mean=0.820±0.038  AUC=0.902±0.031
#     Bagging                    Acc=0.710±0.048  F1=0.710±0.047  MCC=0.569±0.071  G-Mean=0.779±0.037  AUC=0.866±0.034
#     GradientBoosting           Acc=0.718±0.064  F1=0.717±0.065  MCC=0.580±0.096  G-Mean=0.785±0.050  AUC=0.876±0.039
#     LogisticRegression         Acc=0.513±0.053  F1=0.505±0.056  MCC=0.275±0.079  G-Mean=0.624±0.043  AUC=0.725±0.042
#     RidgeClassifier            Acc=0.518±0.052  F1=0.507±0.059  MCC=0.283±0.077  G-Mean=0.628±0.042  AUC=N/A
#     DecisionTree               Acc=0.650±0.060  F1=0.649±0.061  MCC=0.480±0.091  G-Mean=0.733±0.047  AUC=0.745±0.047
#     NaiveBayes                 Acc=0.545±0.054  F1=0.530±0.059  MCC=0.333±0.081  G-Mean=0.651±0.044  AUC=0.700±0.051
#     Perceptron                 Acc=0.507±0.063  F1=0.479±0.086  MCC=0.278±0.090  G-Mean=0.618±0.052  AUC=N/A
#     SGDClassifier              Acc=0.478±0.050  F1=0.446±0.068  MCC=0.237±0.072  G-Mean=0.595±0.042  AUC=N/A
#     PassiveAggressive          Acc=0.438±0.066  F1=0.389±0.093  MCC=0.174±0.108  G-Mean=0.558±0.057  AUC=N/A
#     LDA                        Acc=0.524±0.044  F1=0.516±0.049  MCC=0.291±0.064  G-Mean=0.632±0.035  AUC=0.726±0.040
#     QDA                        Acc=0.624±0.052  F1=0.620±0.053  MCC=0.442±0.078  G-Mean=0.712±0.042  AUC=0.806±0.041
#     LightGBM                   Acc=0.730±0.046  F1=0.729±0.047  MCC=0.599±0.068  G-Mean=0.795±0.036  AUC=0.889±0.032
#     XGBoost                    Acc=0.745±0.058  F1=0.744±0.058  MCC=0.621±0.086  G-Mean=0.806±0.045  AUC=0.894±0.035
#     VotingSoft                 Acc=0.744±0.062  F1=0.742±0.062  MCC=0.619±0.091  G-Mean=0.805±0.048  AUC=0.902±0.032
#     VotingHard                 Acc=0.754±0.050  F1=0.752±0.051  MCC=0.635±0.073  G-Mean=0.813±0.039  AUC=N/A
#     Stacking                   Acc=0.759±0.052  F1=0.758±0.053  MCC=0.642±0.076  G-Mean=0.817±0.040  AUC=0.902±0.032
#
# ======================================================================
#   Combo: B3_ADASYN + FS5_RFImportance  |  shape=(655, 46)
# ======================================================================
#     RandomForest               Acc=0.763±0.053  F1=0.762±0.054  MCC=0.650±0.078  G-Mean=0.820±0.041  AUC=0.906±0.030
#     ExtraTrees                 Acc=0.779±0.054  F1=0.777±0.054  MCC=0.673±0.079  G-Mean=0.832±0.042  AUC=0.917±0.029
#     Bagging                    Acc=0.721±0.062  F1=0.719±0.062  MCC=0.585±0.093  G-Mean=0.787±0.048  AUC=0.873±0.030
#     GradientBoosting           Acc=0.757±0.054  F1=0.758±0.054  MCC=0.641±0.079  G-Mean=0.816±0.041  AUC=0.890±0.038
#     LogisticRegression         Acc=0.548±0.038  F1=0.543±0.037  MCC=0.327±0.058  G-Mean=0.652±0.031  AUC=0.733±0.031
#     RidgeClassifier            Acc=0.540±0.039  F1=0.534±0.042  MCC=0.316±0.059  G-Mean=0.646±0.032  AUC=N/A
#     DecisionTree               Acc=0.667±0.072  F1=0.666±0.073  MCC=0.504±0.108  G-Mean=0.746±0.056  AUC=0.762±0.051
#     NaiveBayes                 Acc=0.536±0.060  F1=0.520±0.064  MCC=0.317±0.087  G-Mean=0.643±0.048  AUC=0.688±0.048
#     Perceptron                 Acc=0.461±0.078  F1=0.425±0.092  MCC=0.203±0.130  G-Mean=0.580±0.065  AUC=N/A
#     SGDClassifier              Acc=0.485±0.055  F1=0.465±0.068  MCC=0.243±0.079  G-Mean=0.602±0.045  AUC=N/A
#     PassiveAggressive          Acc=0.426±0.082  F1=0.406±0.092  MCC=0.142±0.127  G-Mean=0.549±0.070  AUC=N/A
#     LDA                        Acc=0.536±0.042  F1=0.530±0.045  MCC=0.309±0.065  G-Mean=0.642±0.035  AUC=0.736±0.033
#     QDA                        Acc=0.670±0.039  F1=0.668±0.041  MCC=0.508±0.058  G-Mean=0.748±0.031  AUC=0.856±0.029
#     LightGBM                   Acc=0.769±0.047  F1=0.768±0.046  MCC=0.659±0.069  G-Mean=0.825±0.036  AUC=0.906±0.027
#     XGBoost                    Acc=0.777±0.052  F1=0.776±0.052  MCC=0.670±0.076  G-Mean=0.831±0.040  AUC=0.916±0.035
#     VotingSoft                 Acc=0.774±0.054  F1=0.773±0.054  MCC=0.666±0.079  G-Mean=0.829±0.041  AUC=0.916±0.029
#     VotingHard                 Acc=0.776±0.052  F1=0.775±0.052  MCC=0.670±0.075  G-Mean=0.830±0.040  AUC=N/A
#     Stacking                   Acc=0.777±0.049  F1=0.776±0.050  MCC=0.671±0.072  G-Mean=0.831±0.038  AUC=0.918±0.026
#
# ======================================================================
#   Combo: B4_SMOTE + FS1_Correlation  |  shape=(654, 13)
# ======================================================================
#     RandomForest               Acc=0.762±0.052  F1=0.760±0.052  MCC=0.644±0.079  G-Mean=0.819±0.040  AUC=0.894±0.033
#     ExtraTrees                 Acc=0.756±0.048  F1=0.754±0.048  MCC=0.635±0.072  G-Mean=0.814±0.037  AUC=0.898±0.027
#     Bagging                    Acc=0.733±0.048  F1=0.731±0.048  MCC=0.601±0.071  G-Mean=0.796±0.037  AUC=0.865±0.041
#     GradientBoosting           Acc=0.720±0.063  F1=0.719±0.063  MCC=0.584±0.097  G-Mean=0.787±0.049  AUC=0.867±0.036
#     LogisticRegression         Acc=0.607±0.073  F1=0.603±0.074  MCC=0.413±0.111  G-Mean=0.698±0.059  AUC=0.764±0.066
#     RidgeClassifier            Acc=0.596±0.069  F1=0.583±0.071  MCC=0.404±0.107  G-Mean=0.689±0.056  AUC=N/A
#     DecisionTree               Acc=0.659±0.058  F1=0.656±0.060  MCC=0.491±0.088  G-Mean=0.739±0.046  AUC=0.751±0.046
#     NaiveBayes                 Acc=0.615±0.073  F1=0.610±0.075  MCC=0.428±0.111  G-Mean=0.704±0.059  AUC=0.767±0.051
#     Perceptron                 Acc=0.508±0.066  F1=0.467±0.072  MCC=0.297±0.112  G-Mean=0.619±0.053  AUC=N/A
#     SGDClassifier              Acc=0.500±0.085  F1=0.456±0.099  MCC=0.274±0.133  G-Mean=0.612±0.071  AUC=N/A
#     PassiveAggressive          Acc=0.476±0.049  F1=0.445±0.057  MCC=0.236±0.074  G-Mean=0.592±0.040  AUC=N/A
#     LDA                        Acc=0.607±0.075  F1=0.602±0.077  MCC=0.414±0.114  G-Mean=0.698±0.061  AUC=0.768±0.068
#     QDA                        Acc=0.644±0.062  F1=0.642±0.063  MCC=0.469±0.094  G-Mean=0.727±0.050  AUC=0.795±0.042
#     LightGBM                   Acc=0.759±0.041  F1=0.756±0.041  MCC=0.640±0.062  G-Mean=0.816±0.031  AUC=0.886±0.030
#     XGBoost                    Acc=0.754±0.046  F1=0.752±0.046  MCC=0.632±0.069  G-Mean=0.813±0.035  AUC=0.890±0.025
#     VotingSoft                 Acc=0.760±0.048  F1=0.758±0.048  MCC=0.642±0.072  G-Mean=0.818±0.037  AUC=0.898±0.029
#     VotingHard                 Acc=0.762±0.044  F1=0.760±0.043  MCC=0.644±0.066  G-Mean=0.819±0.034  AUC=N/A
#     Stacking                   Acc=0.763±0.040  F1=0.761±0.040  MCC=0.647±0.059  G-Mean=0.820±0.030  AUC=0.902±0.029
#
# ======================================================================
#   Combo: B4_SMOTE + FS2_KBest  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.783±0.066  F1=0.781±0.067  MCC=0.677±0.099  G-Mean=0.835±0.051  AUC=0.922±0.026
#     ExtraTrees                 Acc=0.809±0.044  F1=0.808±0.044  MCC=0.715±0.065  G-Mean=0.855±0.034  AUC=0.932±0.026
#     Bagging                    Acc=0.745±0.069  F1=0.743±0.069  MCC=0.619±0.103  G-Mean=0.806±0.053  AUC=0.894±0.035
#     GradientBoosting           Acc=0.777±0.042  F1=0.776±0.044  MCC=0.667±0.063  G-Mean=0.831±0.033  AUC=0.906±0.025
#     LogisticRegression         Acc=0.606±0.050  F1=0.603±0.049  MCC=0.412±0.075  G-Mean=0.697±0.040  AUC=0.777±0.047
#     RidgeClassifier            Acc=0.603±0.057  F1=0.595±0.058  MCC=0.410±0.087  G-Mean=0.695±0.046  AUC=N/A
#     DecisionTree               Acc=0.691±0.065  F1=0.691±0.064  MCC=0.540±0.095  G-Mean=0.764±0.050  AUC=0.772±0.048
#     NaiveBayes                 Acc=0.595±0.056  F1=0.588±0.058  MCC=0.398±0.086  G-Mean=0.689±0.045  AUC=0.762±0.042
#     Perceptron                 Acc=0.528±0.103  F1=0.515±0.116  MCC=0.303±0.149  G-Mean=0.634±0.084  AUC=N/A
#     SGDClassifier              Acc=0.554±0.070  F1=0.534±0.071  MCC=0.352±0.110  G-Mean=0.656±0.056  AUC=N/A
#     PassiveAggressive          Acc=0.512±0.078  F1=0.480±0.082  MCC=0.289±0.120  G-Mean=0.622±0.065  AUC=N/A
#     LDA                        Acc=0.616±0.068  F1=0.612±0.067  MCC=0.429±0.103  G-Mean=0.705±0.054  AUC=0.782±0.049
#     QDA                        Acc=0.707±0.043  F1=0.705±0.044  MCC=0.563±0.066  G-Mean=0.777±0.034  AUC=0.860±0.019
#     LightGBM                   Acc=0.772±0.054  F1=0.771±0.055  MCC=0.660±0.082  G-Mean=0.827±0.042  AUC=0.915±0.022
#     XGBoost                    Acc=0.788±0.045  F1=0.786±0.045  MCC=0.683±0.067  G-Mean=0.839±0.034  AUC=0.927±0.019
#     VotingSoft                 Acc=0.783±0.047  F1=0.781±0.048  MCC=0.676±0.071  G-Mean=0.835±0.036  AUC=0.928±0.023
#     VotingHard                 Acc=0.798±0.046  F1=0.797±0.046  MCC=0.699±0.068  G-Mean=0.847±0.035  AUC=N/A
#     Stacking                   Acc=0.809±0.036  F1=0.809±0.036  MCC=0.716±0.056  G-Mean=0.855±0.028  AUC=0.933±0.027
#
# ======================================================================
#   Combo: B4_SMOTE + FS3_RFE  |  shape=(654, 25)
# ======================================================================
#     RandomForest               Acc=0.760±0.033  F1=0.759±0.033  MCC=0.642±0.050  G-Mean=0.818±0.025  AUC=0.908±0.027
#     ExtraTrees                 Acc=0.789±0.045  F1=0.788±0.045  MCC=0.685±0.068  G-Mean=0.840±0.035  AUC=0.918±0.027
#     Bagging                    Acc=0.736±0.051  F1=0.734±0.052  MCC=0.605±0.077  G-Mean=0.799±0.040  AUC=0.880±0.038
#     GradientBoosting           Acc=0.726±0.059  F1=0.725±0.060  MCC=0.592±0.089  G-Mean=0.791±0.046  AUC=0.886±0.036
#     LogisticRegression         Acc=0.602±0.056  F1=0.600±0.056  MCC=0.407±0.083  G-Mean=0.694±0.044  AUC=0.752±0.053
#     RidgeClassifier            Acc=0.587±0.050  F1=0.577±0.051  MCC=0.388±0.076  G-Mean=0.682±0.040  AUC=N/A
#     DecisionTree               Acc=0.675±0.065  F1=0.674±0.066  MCC=0.514±0.098  G-Mean=0.751±0.051  AUC=0.756±0.047
#     NaiveBayes                 Acc=0.634±0.059  F1=0.630±0.059  MCC=0.457±0.090  G-Mean=0.720±0.047  AUC=0.781±0.047
#     Perceptron                 Acc=0.508±0.036  F1=0.476±0.045  MCC=0.280±0.053  G-Mean=0.618±0.029  AUC=N/A
#     SGDClassifier              Acc=0.502±0.055  F1=0.460±0.084  MCC=0.287±0.070  G-Mean=0.614±0.044  AUC=N/A
#     PassiveAggressive          Acc=0.470±0.056  F1=0.436±0.059  MCC=0.226±0.086  G-Mean=0.587±0.045  AUC=N/A
#     LDA                        Acc=0.590±0.062  F1=0.587±0.061  MCC=0.389±0.093  G-Mean=0.685±0.049  AUC=0.753±0.058
#     QDA                        Acc=0.655±0.053  F1=0.654±0.052  MCC=0.485±0.080  G-Mean=0.735±0.042  AUC=0.811±0.031
#     LightGBM                   Acc=0.758±0.044  F1=0.757±0.045  MCC=0.639±0.065  G-Mean=0.816±0.034  AUC=0.903±0.025
#     XGBoost                    Acc=0.758±0.040  F1=0.757±0.041  MCC=0.638±0.061  G-Mean=0.816±0.031  AUC=0.901±0.028
#     VotingSoft                 Acc=0.774±0.036  F1=0.773±0.037  MCC=0.662±0.054  G-Mean=0.828±0.028  AUC=0.915±0.027
#     VotingHard                 Acc=0.778±0.037  F1=0.778±0.037  MCC=0.669±0.056  G-Mean=0.832±0.028  AUC=N/A
#     Stacking                   Acc=0.791±0.032  F1=0.791±0.032  MCC=0.687±0.048  G-Mean=0.841±0.024  AUC=0.918±0.029
#
# ======================================================================
#   Combo: B4_SMOTE + FS4_MutualInfo  |  shape=(654, 32)
# ======================================================================
#     RandomForest               Acc=0.775±0.063  F1=0.775±0.062  MCC=0.664±0.094  G-Mean=0.829±0.048  AUC=0.900±0.037
#     ExtraTrees                 Acc=0.774±0.056  F1=0.773±0.057  MCC=0.662±0.083  G-Mean=0.828±0.043  AUC=0.905±0.032
#     Bagging                    Acc=0.728±0.062  F1=0.727±0.062  MCC=0.593±0.094  G-Mean=0.793±0.048  AUC=0.876±0.045
#     GradientBoosting           Acc=0.743±0.035  F1=0.741±0.038  MCC=0.617±0.051  G-Mean=0.805±0.027  AUC=0.885±0.028
#     LogisticRegression         Acc=0.598±0.063  F1=0.595±0.064  MCC=0.401±0.094  G-Mean=0.691±0.050  AUC=0.763±0.056
#     RidgeClassifier            Acc=0.590±0.060  F1=0.582±0.061  MCC=0.391±0.091  G-Mean=0.685±0.049  AUC=N/A
#     DecisionTree               Acc=0.670±0.067  F1=0.669±0.066  MCC=0.508±0.101  G-Mean=0.748±0.052  AUC=0.751±0.052
#     NaiveBayes                 Acc=0.612±0.051  F1=0.607±0.051  MCC=0.423±0.080  G-Mean=0.702±0.041  AUC=0.766±0.041
#     Perceptron                 Acc=0.499±0.071  F1=0.462±0.093  MCC=0.265±0.107  G-Mean=0.609±0.060  AUC=N/A
#     SGDClassifier              Acc=0.517±0.059  F1=0.477±0.074  MCC=0.301±0.088  G-Mean=0.625±0.048  AUC=N/A
#     PassiveAggressive          Acc=0.471±0.072  F1=0.451±0.075  MCC=0.220±0.112  G-Mean=0.587±0.059  AUC=N/A
#     LDA                        Acc=0.603±0.073  F1=0.600±0.073  MCC=0.407±0.109  G-Mean=0.694±0.058  AUC=0.764±0.061
#     QDA                        Acc=0.699±0.055  F1=0.696±0.059  MCC=0.553±0.080  G-Mean=0.770±0.043  AUC=0.833±0.031
#     LightGBM                   Acc=0.730±0.053  F1=0.727±0.056  MCC=0.596±0.078  G-Mean=0.794±0.041  AUC=0.896±0.028
#     XGBoost                    Acc=0.762±0.051  F1=0.760±0.054  MCC=0.645±0.077  G-Mean=0.819±0.040  AUC=0.896±0.028
#     VotingSoft                 Acc=0.763±0.053  F1=0.762±0.054  MCC=0.646±0.079  G-Mean=0.820±0.041  AUC=0.908±0.028
#     VotingHard                 Acc=0.769±0.062  F1=0.769±0.062  MCC=0.655±0.093  G-Mean=0.825±0.048  AUC=N/A
#     Stacking                   Acc=0.780±0.044  F1=0.780±0.044  MCC=0.672±0.065  G-Mean=0.833±0.034  AUC=0.907±0.030
#
# ======================================================================
#   Combo: B4_SMOTE + FS5_RFImportance  |  shape=(654, 46)
# ======================================================================
#     RandomForest               Acc=0.786±0.056  F1=0.785±0.056  MCC=0.680±0.084  G-Mean=0.838±0.043  AUC=0.920±0.028
#     ExtraTrees                 Acc=0.795±0.050  F1=0.795±0.051  MCC=0.695±0.075  G-Mean=0.845±0.039  AUC=0.932±0.025
#     Bagging                    Acc=0.739±0.056  F1=0.737±0.057  MCC=0.609±0.084  G-Mean=0.801±0.044  AUC=0.895±0.030
#     GradientBoosting           Acc=0.763±0.049  F1=0.762±0.050  MCC=0.646±0.073  G-Mean=0.820±0.038  AUC=0.905±0.023
#     LogisticRegression         Acc=0.615±0.051  F1=0.612±0.051  MCC=0.426±0.078  G-Mean=0.704±0.041  AUC=0.777±0.048
#     RidgeClassifier            Acc=0.601±0.056  F1=0.594±0.057  MCC=0.407±0.085  G-Mean=0.693±0.045  AUC=N/A
#     DecisionTree               Acc=0.693±0.064  F1=0.693±0.065  MCC=0.542±0.095  G-Mean=0.766±0.050  AUC=0.774±0.049
#     NaiveBayes                 Acc=0.595±0.059  F1=0.590±0.060  MCC=0.397±0.090  G-Mean=0.688±0.047  AUC=0.761±0.044
#     Perceptron                 Acc=0.531±0.042  F1=0.515±0.052  MCC=0.311±0.067  G-Mean=0.637±0.035  AUC=N/A
#     SGDClassifier              Acc=0.567±0.057  F1=0.561±0.062  MCC=0.361±0.088  G-Mean=0.666±0.046  AUC=N/A
#     PassiveAggressive          Acc=0.508±0.091  F1=0.463±0.110  MCC=0.280±0.147  G-Mean=0.618±0.077  AUC=N/A
#     LDA                        Acc=0.613±0.066  F1=0.609±0.065  MCC=0.424±0.100  G-Mean=0.703±0.053  AUC=0.781±0.049
#     QDA                        Acc=0.703±0.060  F1=0.703±0.061  MCC=0.558±0.090  G-Mean=0.774±0.047  AUC=0.861±0.025
#     LightGBM                   Acc=0.775±0.060  F1=0.773±0.061  MCC=0.665±0.088  G-Mean=0.829±0.046  AUC=0.912±0.024
#     XGBoost                    Acc=0.778±0.057  F1=0.777±0.057  MCC=0.670±0.085  G-Mean=0.832±0.044  AUC=0.926±0.020
#     VotingSoft                 Acc=0.783±0.047  F1=0.781±0.048  MCC=0.676±0.070  G-Mean=0.835±0.036  AUC=0.927±0.024
#     VotingHard                 Acc=0.784±0.053  F1=0.783±0.052  MCC=0.678±0.079  G-Mean=0.837±0.040  AUC=N/A
#     Stacking                   Acc=0.801±0.045  F1=0.801±0.044  MCC=0.705±0.069  G-Mean=0.850±0.035  AUC=0.931±0.028
#
# ======================================================================
#   Combo: B5_BorderlineSMOTE + FS1_Correlation  |  shape=(654, 13)
# ======================================================================
#     RandomForest               Acc=0.719±0.056  F1=0.715±0.058  MCC=0.582±0.085  G-Mean=0.786±0.043  AUC=0.876±0.035
#     ExtraTrees                 Acc=0.711±0.053  F1=0.707±0.054  MCC=0.570±0.080  G-Mean=0.780±0.041  AUC=0.867±0.036
#     Bagging                    Acc=0.705±0.057  F1=0.703±0.057  MCC=0.560±0.086  G-Mean=0.775±0.044  AUC=0.852±0.045
#     GradientBoosting           Acc=0.710±0.065  F1=0.711±0.064  MCC=0.567±0.098  G-Mean=0.779±0.050  AUC=0.855±0.040
#     LogisticRegression         Acc=0.593±0.072  F1=0.588±0.072  MCC=0.394±0.111  G-Mean=0.687±0.058  AUC=0.749±0.076
#     RidgeClassifier            Acc=0.583±0.077  F1=0.567±0.079  MCC=0.384±0.121  G-Mean=0.678±0.063  AUC=N/A
#     DecisionTree               Acc=0.658±0.065  F1=0.657±0.065  MCC=0.490±0.098  G-Mean=0.738±0.051  AUC=0.758±0.049
#     NaiveBayes                 Acc=0.554±0.051  F1=0.536±0.054  MCC=0.342±0.080  G-Mean=0.655±0.042  AUC=0.715±0.053
#     Perceptron                 Acc=0.474±0.066  F1=0.436±0.088  MCC=0.230±0.101  G-Mean=0.590±0.055  AUC=N/A
#     SGDClassifier              Acc=0.494±0.069  F1=0.463±0.084  MCC=0.267±0.105  G-Mean=0.607±0.056  AUC=N/A
#     PassiveAggressive          Acc=0.483±0.071  F1=0.454±0.094  MCC=0.245±0.101  G-Mean=0.598±0.059  AUC=N/A
#     LDA                        Acc=0.593±0.080  F1=0.586±0.082  MCC=0.395±0.124  G-Mean=0.687±0.066  AUC=0.752±0.077
#     QDA                        Acc=0.618±0.060  F1=0.615±0.060  MCC=0.430±0.091  G-Mean=0.707±0.048  AUC=0.789±0.042
#     LightGBM                   Acc=0.716±0.048  F1=0.713±0.048  MCC=0.576±0.074  G-Mean=0.783±0.038  AUC=0.863±0.040
#     XGBoost                    Acc=0.713±0.045  F1=0.711±0.045  MCC=0.570±0.067  G-Mean=0.781±0.035  AUC=0.864±0.037
#     VotingSoft                 Acc=0.723±0.050  F1=0.721±0.050  MCC=0.588±0.077  G-Mean=0.789±0.039  AUC=0.878±0.036
#     VotingHard                 Acc=0.726±0.046  F1=0.723±0.047  MCC=0.593±0.069  G-Mean=0.792±0.035  AUC=N/A
#     Stacking                   Acc=0.716±0.060  F1=0.713±0.062  MCC=0.577±0.090  G-Mean=0.783±0.047  AUC=0.877±0.037
#
# ======================================================================
# ...
#     VotingSoft                 Acc=0.771±0.059  F1=0.768±0.060  MCC=0.660±0.087  G-Mean=0.826±0.045  AUC=0.901±0.032
#     VotingHard                 Acc=0.780±0.042  F1=0.777±0.043  MCC=0.675±0.062  G-Mean=0.833±0.032  AUC=N/A
#     Stacking                   Acc=0.779±0.046  F1=0.777±0.047  MCC=0.672±0.069  G-Mean=0.832±0.035  AUC=0.909±0.035
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS2_KBest  |  shape=(642, 46)
# ======================================================================
#     RandomForest               Acc=0.782±0.038  F1=0.779±0.039  MCC=0.677±0.056  G-Mean=0.834±0.029  AUC=0.924±0.023
#     ExtraTrees                 Acc=0.807±0.033  F1=0.805±0.034  MCC=0.714±0.048  G-Mean=0.853±0.025  AUC=0.934±0.024
#     Bagging                    Acc=0.771±0.046  F1=0.768±0.048  MCC=0.660±0.069  G-Mean=0.826±0.036  AUC=0.900±0.024
#     GradientBoosting           Acc=0.776±0.040  F1=0.773±0.040  MCC=0.668±0.060  G-Mean=0.830±0.031  AUC=0.909±0.029
#     LogisticRegression         Acc=0.629±0.071  F1=0.625±0.073  MCC=0.446±0.106  G-Mean=0.715±0.056  AUC=0.777±0.047
#     RidgeClassifier            Acc=0.614±0.060  F1=0.604±0.061  MCC=0.426±0.093  G-Mean=0.703±0.048  AUC=N/A
#     DecisionTree               Acc=0.701±0.046  F1=0.699±0.045  MCC=0.555±0.071  G-Mean=0.772±0.035  AUC=0.779±0.038
#     NaiveBayes                 Acc=0.601±0.048  F1=0.594±0.050  MCC=0.407±0.071  G-Mean=0.693±0.038  AUC=0.767±0.044
#     Perceptron                 Acc=0.520±0.050  F1=0.482±0.067  MCC=0.306±0.066  G-Mean=0.628±0.041  AUC=N/A
#     SGDClassifier              Acc=0.544±0.059  F1=0.514±0.072  MCC=0.338±0.085  G-Mean=0.646±0.047  AUC=N/A
#     PassiveAggressive          Acc=0.478±0.060  F1=0.453±0.077  MCC=0.232±0.086  G-Mean=0.593±0.049  AUC=N/A
#     LDA                        Acc=0.623±0.057  F1=0.619±0.059  MCC=0.437±0.087  G-Mean=0.711±0.045  AUC=0.784±0.048
#     QDA                        Acc=0.709±0.032  F1=0.710±0.030  MCC=0.566±0.048  G-Mean=0.778±0.025  AUC=0.857±0.016
#     LightGBM                   Acc=0.793±0.042  F1=0.789±0.043  MCC=0.694±0.063  G-Mean=0.842±0.032  AUC=0.919±0.026
#     XGBoost                    Acc=0.794±0.038  F1=0.793±0.037  MCC=0.696±0.058  G-Mean=0.844±0.029  AUC=0.922±0.026
#     VotingSoft                 Acc=0.791±0.039  F1=0.788±0.039  MCC=0.691±0.059  G-Mean=0.841±0.030  AUC=0.932±0.024
#     VotingHard                 Acc=0.801±0.038  F1=0.798±0.039  MCC=0.705±0.056  G-Mean=0.849±0.029  AUC=N/A
#     Stacking                   Acc=0.813±0.048  F1=0.812±0.048  MCC=0.723±0.069  G-Mean=0.858±0.036  AUC=0.937±0.023
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS3_RFE  |  shape=(642, 25)
# ======================================================================
#     RandomForest               Acc=0.759±0.059  F1=0.757±0.060  MCC=0.641±0.088  G-Mean=0.816±0.045  AUC=0.907±0.029
#     ExtraTrees                 Acc=0.779±0.037  F1=0.777±0.037  MCC=0.671±0.055  G-Mean=0.832±0.028  AUC=0.917±0.024
#     Bagging                    Acc=0.737±0.056  F1=0.735±0.057  MCC=0.607±0.083  G-Mean=0.799±0.043  AUC=0.893±0.040
#     GradientBoosting           Acc=0.734±0.065  F1=0.732±0.066  MCC=0.604±0.096  G-Mean=0.797±0.051  AUC=0.885±0.029
#     LogisticRegression         Acc=0.597±0.061  F1=0.591±0.062  MCC=0.398±0.094  G-Mean=0.690±0.049  AUC=0.746±0.049
#     RidgeClassifier            Acc=0.583±0.061  F1=0.567±0.064  MCC=0.382±0.092  G-Mean=0.678±0.048  AUC=N/A
#     DecisionTree               Acc=0.685±0.058  F1=0.683±0.059  MCC=0.530±0.086  G-Mean=0.759±0.045  AUC=0.768±0.044
#     NaiveBayes                 Acc=0.634±0.052  F1=0.625±0.055  MCC=0.457±0.078  G-Mean=0.719±0.041  AUC=0.787±0.042
#     Perceptron                 Acc=0.494±0.070  F1=0.459±0.086  MCC=0.258±0.107  G-Mean=0.606±0.058  AUC=N/A
#     SGDClassifier              Acc=0.495±0.031  F1=0.471±0.025  MCC=0.260±0.050  G-Mean=0.609±0.025  AUC=N/A
#     PassiveAggressive          Acc=0.486±0.076  F1=0.448±0.104  MCC=0.249±0.109  G-Mean=0.600±0.062  AUC=N/A
#     LDA                        Acc=0.594±0.063  F1=0.586±0.064  MCC=0.393±0.094  G-Mean=0.687±0.049  AUC=0.747±0.050
#     QDA                        Acc=0.664±0.026  F1=0.663±0.026  MCC=0.500±0.040  G-Mean=0.743±0.020  AUC=0.802±0.023
#     LightGBM                   Acc=0.749±0.049  F1=0.747±0.050  MCC=0.626±0.074  G-Mean=0.809±0.038  AUC=0.898±0.028
#     XGBoost                    Acc=0.760±0.060  F1=0.758±0.062  MCC=0.643±0.089  G-Mean=0.817±0.047  AUC=0.904±0.033
#     VotingSoft                 Acc=0.774±0.049  F1=0.772±0.050  MCC=0.665±0.072  G-Mean=0.828±0.038  AUC=0.913±0.028
#     VotingHard                 Acc=0.773±0.047  F1=0.770±0.047  MCC=0.662±0.070  G-Mean=0.827±0.036  AUC=N/A
#     Stacking                   Acc=0.788±0.057  F1=0.788±0.058  MCC=0.686±0.084  G-Mean=0.839±0.044  AUC=0.919±0.026
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS4_MutualInfo  |  shape=(642, 32)
# ======================================================================
#     RandomForest               Acc=0.788±0.049  F1=0.785±0.051  MCC=0.686±0.072  G-Mean=0.839±0.038  AUC=0.913±0.030
#     ExtraTrees                 Acc=0.793±0.052  F1=0.790±0.054  MCC=0.693±0.076  G-Mean=0.843±0.040  AUC=0.923±0.025
#     Bagging                    Acc=0.754±0.042  F1=0.752±0.043  MCC=0.634±0.062  G-Mean=0.813±0.033  AUC=0.895±0.032
#     GradientBoosting           Acc=0.748±0.046  F1=0.744±0.047  MCC=0.627±0.065  G-Mean=0.808±0.035  AUC=0.896±0.030
#     LogisticRegression         Acc=0.578±0.069  F1=0.571±0.070  MCC=0.370±0.104  G-Mean=0.675±0.054  AUC=0.754±0.051
#     RidgeClassifier            Acc=0.581±0.077  F1=0.569±0.079  MCC=0.377±0.117  G-Mean=0.677±0.061  AUC=N/A
#     DecisionTree               Acc=0.684±0.057  F1=0.681±0.059  MCC=0.529±0.086  G-Mean=0.758±0.045  AUC=0.767±0.045
#     NaiveBayes                 Acc=0.623±0.066  F1=0.616±0.068  MCC=0.440±0.098  G-Mean=0.711±0.052  AUC=0.779±0.048
#     Perceptron                 Acc=0.528±0.071  F1=0.505±0.091  MCC=0.310±0.106  G-Mean=0.633±0.059  AUC=N/A
#     SGDClassifier              Acc=0.516±0.066  F1=0.498±0.065  MCC=0.289±0.103  G-Mean=0.625±0.053  AUC=N/A
#     PassiveAggressive          Acc=0.527±0.064  F1=0.507±0.083  MCC=0.304±0.093  G-Mean=0.633±0.053  AUC=N/A
#     LDA                        Acc=0.591±0.073  F1=0.583±0.073  MCC=0.389±0.109  G-Mean=0.685±0.057  AUC=0.758±0.050
#     QDA                        Acc=0.667±0.045  F1=0.663±0.045  MCC=0.507±0.067  G-Mean=0.745±0.035  AUC=0.812±0.036
#     LightGBM                   Acc=0.757±0.053  F1=0.754±0.055  MCC=0.639±0.080  G-Mean=0.815±0.041  AUC=0.901±0.024
#     XGBoost                    Acc=0.774±0.041  F1=0.771±0.043  MCC=0.665±0.060  G-Mean=0.828±0.032  AUC=0.906±0.024
#     VotingSoft                 Acc=0.780±0.041  F1=0.777±0.042  MCC=0.675±0.059  G-Mean=0.833±0.031  AUC=0.920±0.025
#     VotingHard                 Acc=0.799±0.054  F1=0.796±0.057  MCC=0.702±0.080  G-Mean=0.847±0.042  AUC=N/A
#     Stacking                   Acc=0.804±0.060  F1=0.802±0.063  MCC=0.709±0.088  G-Mean=0.851±0.047  AUC=0.923±0.026
#
# ======================================================================
#   Combo: B7_SMOTETomek + FS5_RFImportance  |  shape=(642, 46)
# ======================================================================
#     RandomForest               Acc=0.790±0.036  F1=0.787±0.036  MCC=0.688±0.055  G-Mean=0.840±0.028  AUC=0.926±0.026
#     ExtraTrees                 Acc=0.815±0.036  F1=0.812±0.037  MCC=0.725±0.053  G-Mean=0.859±0.028  AUC=0.933±0.028
#     Bagging                    Acc=0.755±0.044  F1=0.752±0.046  MCC=0.636±0.066  G-Mean=0.814±0.034  AUC=0.898±0.026
#     GradientBoosting           Acc=0.771±0.037  F1=0.768±0.037  MCC=0.661±0.055  G-Mean=0.826±0.028  AUC=0.905±0.026
#     LogisticRegression         Acc=0.608±0.066  F1=0.603±0.068  MCC=0.413±0.099  G-Mean=0.698±0.052  AUC=0.774±0.047
#     RidgeClassifier            Acc=0.600±0.066  F1=0.590±0.068  MCC=0.404±0.101  G-Mean=0.692±0.052  AUC=N/A
#     DecisionTree               Acc=0.681±0.027  F1=0.678±0.027  MCC=0.523±0.040  G-Mean=0.756±0.021  AUC=0.763±0.024
#     NaiveBayes                 Acc=0.612±0.049  F1=0.605±0.051  MCC=0.423±0.072  G-Mean=0.702±0.038  AUC=0.766±0.044
#     Perceptron                 Acc=0.542±0.039  F1=0.516±0.047  MCC=0.336±0.058  G-Mean=0.646±0.032  AUC=N/A
#     SGDClassifier              Acc=0.528±0.074  F1=0.487±0.091  MCC=0.318±0.110  G-Mean=0.635±0.061  AUC=N/A
#     PassiveAggressive          Acc=0.491±0.061  F1=0.471±0.088  MCC=0.247±0.092  G-Mean=0.603±0.051  AUC=N/A
#     LDA                        Acc=0.614±0.066  F1=0.608±0.068  MCC=0.424±0.100  G-Mean=0.703±0.052  AUC=0.780±0.047
#     QDA                        Acc=0.701±0.046  F1=0.700±0.045  MCC=0.554±0.069  G-Mean=0.771±0.036  AUC=0.859±0.019
#     LightGBM                   Acc=0.784±0.045  F1=0.780±0.044  MCC=0.679±0.068  G-Mean=0.835±0.034  AUC=0.917±0.031
#     XGBoost                    Acc=0.798±0.039  F1=0.796±0.039  MCC=0.700±0.059  G-Mean=0.846±0.030  AUC=0.928±0.026
#     VotingSoft                 Acc=0.793±0.037  F1=0.790±0.037  MCC=0.694±0.055  G-Mean=0.842±0.028  AUC=0.931±0.024
#     VotingHard                 Acc=0.802±0.035  F1=0.800±0.036  MCC=0.707±0.051  G-Mean=0.850±0.026  AUC=N/A
#     Stacking                   Acc=0.824±0.054  F1=0.823±0.055  MCC=0.739±0.079  G-Mean=0.867±0.042  AUC=0.935±0.026
#
#
# -- Phase 3 Summary (top 30 combos by Accuracy) --
#                              Balancer+FS       Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#        B1_RandomOverSampling + FS2_KBest         Stacking     0.905     0.906 0.861   0.929 0.973
#          B1_RandomOverSampling + FS3_RFE         Stacking     0.899     0.900 0.851   0.924 0.976
# B1_RandomOverSampling + FS5_RFImportance         Stacking     0.895     0.895 0.844   0.920 0.973
#   B1_RandomOverSampling + FS4_MutualInfo         Stacking     0.893     0.893 0.841   0.919 0.971
#        B1_RandomOverSampling + FS2_KBest       ExtraTrees     0.889     0.887 0.835   0.916 0.975
#          B1_RandomOverSampling + FS3_RFE         LightGBM     0.884     0.881 0.830   0.912 0.957
#        B1_RandomOverSampling + FS2_KBest       VotingSoft     0.884     0.882 0.829   0.912 0.972
#        B1_RandomOverSampling + FS2_KBest       VotingHard     0.884     0.882 0.829   0.912   NaN
#          B1_RandomOverSampling + FS3_RFE       ExtraTrees     0.884     0.883 0.828   0.912 0.975
# B1_RandomOverSampling + FS5_RFImportance     RandomForest     0.881     0.879 0.824   0.910 0.971
# B1_RandomOverSampling + FS5_RFImportance       VotingHard     0.881     0.880 0.824   0.910   NaN
#        B1_RandomOverSampling + FS2_KBest         LightGBM     0.881     0.878 0.825   0.910 0.967
#          B1_RandomOverSampling + FS3_RFE       VotingHard     0.879     0.878 0.821   0.909   NaN
#        B1_RandomOverSampling + FS2_KBest          XGBoost     0.879     0.877 0.822   0.909 0.967
#          B1_RandomOverSampling + FS3_RFE       VotingSoft     0.878     0.875 0.820   0.908 0.969
# B1_RandomOverSampling + FS5_RFImportance       ExtraTrees     0.878     0.877 0.818   0.908 0.973
#        B1_RandomOverSampling + FS2_KBest     RandomForest     0.876     0.875 0.818   0.907 0.969
# B1_RandomOverSampling + FS5_RFImportance          XGBoost     0.875     0.873 0.815   0.905 0.968
# B1_RandomOverSampling + FS5_RFImportance       VotingSoft     0.875     0.873 0.816   0.905 0.972
#   B1_RandomOverSampling + FS4_MutualInfo       VotingSoft     0.872     0.869 0.810   0.903 0.967
# B1_RandomOverSampling + FS5_RFImportance         LightGBM     0.872     0.869 0.811   0.903 0.968
#          B1_RandomOverSampling + FS3_RFE     RandomForest     0.870     0.868 0.809   0.902 0.969
#          B1_RandomOverSampling + FS3_RFE          XGBoost     0.869     0.866 0.806   0.901 0.959
#   B1_RandomOverSampling + FS4_MutualInfo       ExtraTrees     0.867     0.866 0.803   0.900 0.971
#  B1_RandomOverSampling + FS1_Correlation         Stacking     0.866     0.865 0.800   0.898 0.965
# B1_RandomOverSampling + FS5_RFImportance          Bagging     0.862     0.860 0.798   0.896 0.958
#   B1_RandomOverSampling + FS4_MutualInfo       VotingHard     0.861     0.859 0.795   0.895   NaN
#   B1_RandomOverSampling + FS4_MutualInfo     RandomForest     0.860     0.857 0.793   0.894 0.965
#   B1_RandomOverSampling + FS4_MutualInfo         LightGBM     0.860     0.855 0.794   0.894 0.954
# B1_RandomOverSampling + FS5_RFImportance GradientBoosting     0.859     0.857 0.791   0.894 0.952
#
# -- Phase 3: Best Classifier per Balancer+FS combo --
#                               Balancer+FS   Classifier  Accuracy  Macro_F1   MCC  G_Mean   AUC
#         B1_RandomOverSampling + FS2_KBest     Stacking     0.905     0.906 0.861   0.929 0.973
#           B1_RandomOverSampling + FS3_RFE     Stacking     0.899     0.900 0.851   0.924 0.976
#  B1_RandomOverSampling + FS5_RFImportance     Stacking     0.895     0.895 0.844   0.920 0.973
#    B1_RandomOverSampling + FS4_MutualInfo     Stacking     0.893     0.893 0.841   0.919 0.971
#   B1_RandomOverSampling + FS1_Correlation     Stacking     0.866     0.865 0.800   0.898 0.965
#          B7_SMOTETomek + FS5_RFImportance     Stacking     0.824     0.823 0.739   0.867 0.935
#     B5_BorderlineSMOTE + FS5_RFImportance     Stacking     0.820     0.819 0.731   0.864 0.933
#       B5_BorderlineSMOTE + FS4_MutualInfo     Stacking     0.818     0.818 0.728   0.862 0.926
#            B5_BorderlineSMOTE + FS2_KBest   ExtraTrees     0.815     0.814 0.725   0.860 0.932
#                 B7_SMOTETomek + FS2_KBest     Stacking     0.813     0.812 0.723   0.858 0.937
#                      B4_SMOTE + FS2_KBest     Stacking     0.809     0.809 0.716   0.855 0.933
#            B7_SMOTETomek + FS4_MutualInfo     Stacking     0.804     0.802 0.709   0.851 0.923
#               B4_SMOTE + FS5_RFImportance     Stacking     0.801     0.801 0.705   0.850 0.931
#              B5_BorderlineSMOTE + FS3_RFE   ExtraTrees     0.794     0.792 0.693   0.844 0.919
#                        B4_SMOTE + FS3_RFE     Stacking     0.791     0.791 0.687   0.841 0.918
#                   B7_SMOTETomek + FS3_RFE     Stacking     0.788     0.788 0.686   0.839 0.919
#                     B3_ADASYN + FS2_KBest   ExtraTrees     0.783     0.782 0.680   0.836 0.917
#           B7_SMOTETomek + FS1_Correlation   VotingHard     0.780     0.777 0.675   0.833   NaN
#                 B4_SMOTE + FS4_MutualInfo     Stacking     0.780     0.780 0.672   0.833 0.907
#              B3_ADASYN + FS5_RFImportance   ExtraTrees     0.779     0.777 0.673   0.832 0.917
#                B3_ADASYN + FS4_MutualInfo   ExtraTrees     0.763     0.762 0.648   0.820 0.902
#                B4_SMOTE + FS1_Correlation     Stacking     0.763     0.761 0.647   0.820 0.902
#                       B3_ADASYN + FS3_RFE   VotingHard     0.753     0.752 0.635   0.812   NaN
#      B5_BorderlineSMOTE + FS1_Correlation   VotingHard     0.726     0.723 0.593   0.792   NaN
#               B3_ADASYN + FS1_Correlation   ExtraTrees     0.719     0.719 0.581   0.786 0.863
#          B6_TomekLinks + FS5_RFImportance   ExtraTrees     0.707     0.647 0.496   0.724 0.822
#            B6_TomekLinks + FS4_MutualInfo     LightGBM     0.705     0.653 0.498   0.733 0.805
#           B6_TomekLinks + FS1_Correlation     LightGBM     0.705     0.660 0.499   0.741 0.814
#                 B6_TomekLinks + FS2_KBest   VotingSoft     0.702     0.647 0.490   0.727 0.826
#                   B6_TomekLinks + FS3_RFE   NaiveBayes     0.696     0.645 0.509   0.746 0.820
#          B2_RandomUnderSampling + FS3_RFE   ExtraTrees     0.611     0.611 0.426   0.701 0.787
#  B2_RandomUnderSampling + FS1_Correlation RandomForest     0.606     0.604 0.413   0.695 0.766
#   B2_RandomUnderSampling + FS4_MutualInfo     Stacking     0.597     0.595 0.407   0.691 0.771
# B2_RandomUnderSampling + FS5_RFImportance   NaiveBayes     0.597     0.580 0.403   0.689 0.759
#        B2_RandomUnderSampling + FS2_KBest   NaiveBayes     0.587     0.571 0.390   0.682 0.763

# %%
phase3_only = phase3_df[phase3_df['Phase'] == 'Phase3_Balancing+FS'].copy()

output = io.StringIO()
writer = csv.writer(output)

for combo in phase3_only['Variant'].unique():
    group = phase3_only[phase3_only['Variant'] == combo]

    # combo = "B1_RandomOverSampling + FS1_XXX" — split to get shape
    try:
        bal_name, fs_name = combo.split(" + ", 1)
        fs_df = FEATURE_SELECTORS[fs_name](balanced_datasets[bal_name])
        shape_info = fs_df.shape
    except:
        shape_info = "N/A"

    writer.writerow([f"Combo: {combo}  |  shape={shape_info}"] + [""] * (len(COLUMNS) - 1))
    writer.writerow(COLUMNS)

    for _, row in group.iterrows():
        writer.writerow([
            row["Classifier"],
            fmt_metric(row["Accuracy"],  row["Accuracy_SD"]),
            fmt_metric(row["MCC"],       row["MCC_SD"]),
            fmt_metric(row["G_Mean"],    row["G_Mean_SD"]),
            fmt_metric(row["Macro_F1"],  row["Macro_F1_SD"]),
            fmt_metric(row["AUC"],       row["AUC_SD"]),
        ])

    writer.writerow([""] * len(COLUMNS))

with open("Phase3_Balancing_x_FS_Results.csv", "w", encoding="utf-8-sig", newline="") as f:
    f.write(output.getvalue())

files.download("Phase3_Balancing_x_FS_Results.csv")
print(" Downloaded: Phase3_Balancing_x_FS_Results.csv")
# Out:
#  Downloaded: Phase3_Balancing_x_FS_Results.csv
